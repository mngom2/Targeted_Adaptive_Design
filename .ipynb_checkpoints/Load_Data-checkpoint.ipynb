# %%
import numpy as np
import torch

# %%
output_data = np.load("/Users/tianyuyang/Downloads/droughtSVDI_data_ouput.npy")
output_data.shape
# Out:
# (365, 18, 39, 16, 16)

# %%
output_data
# Out:
# array([[[[[-3.35508685e-01, -3.50428795e-01, -3.62086659e-01, ...,
#            -4.66516051e-01, -4.61064647e-01, -4.27985462e-01],
#           [-3.82294515e-01, -3.84746353e-01, -3.99426872e-01, ...,
#            -4.66865287e-01, -4.51955115e-01, -4.20936908e-01],
#           [-4.02687531e-01, -3.87153504e-01, -3.67094782e-01, ...,
#            -5.12237778e-01, -4.79291479e-01, -4.45707472e-01],
#           ...,
#           [-6.30022228e-01, -6.21538410e-01, -6.30013658e-01, ...,
#            -6.38926644e-01, -6.10013933e-01, -4.60031014e-01],
#           [-6.52665892e-01, -6.61529027e-01, -6.68931761e-01, ...,
#            -6.85548898e-01, -6.66313283e-01, -5.13375808e-01],
#           [-6.44233596e-01, -6.72910520e-01, -6.79495369e-01, ...,
#            -6.27480643e-01, -6.06849666e-01, -5.06031729e-01]],
#
#          [[-3.88183110e-01, -4.66516051e-01, -4.61064647e-01, ...,
#             3.44762777e-03, -9.43784506e-02, -2.04993368e-01],
# ...

# %%
input_data = np.load("/Users/tianyuyang/Downloads/droughtSVDI_data_input.npy")
input_data.shape
# Out:
# (365, 18, 39, 16, 16, 2)

# %%
input_data
# Out:
# array([[[[[[  52.93799973, -124.93800354],
#            [  52.93799973, -124.81300354],
#            [  52.93799973, -124.68800354],
#            ...,
#            [  52.93799973, -123.31300354],
#            [  52.93799973, -123.18800354],
#            [  52.93799973, -123.06300354]],
#
#           [[  52.81299973, -124.93800354],
#            [  52.81299973, -124.81300354],
#            [  52.81299973, -124.68800354],
#            ...,
#            [  52.81299973, -123.31300354],
#            [  52.81299973, -123.18800354],
#            [  52.81299973, -123.06300354]],
#
#           [[  52.68799973, -124.93800354],
#            [  52.68799973, -124.81300354],
#            [  52.68799973, -124.68800354],
#            ...,
#            [  52.68799973, -123.31300354],
#            [  52.68799973, -123.18800354],
#            [  52.68799973, -123.06300354]],
#
#           ...,
#
#           [[  51.31299973, -124.93800354],
#            [  51.31299973, -124.81300354],
# ...

# %%
train_x = torch.from_numpy(input_data)
train_x.shape
# Out:
# torch.Size([365, 18, 39, 16, 16, 2])

# %%
train_y = torch.from_numpy(output_data)
train_y.shape
# Out:
# torch.Size([365, 18, 39, 16, 16])
