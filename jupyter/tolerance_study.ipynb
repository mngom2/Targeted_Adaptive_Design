# %%
import math
import torch
from torch import nn
from torch import Tensor
from torch.nn  import functional as F
import gpytorch
import os
from matplotlib import pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
import matplotlib.cm as cm
import matplotlib.patches as patches
from mpl_toolkits.mplot3d import Axes3D 
import sys
from decimal import Decimal
from IPython.display import clear_output
sys.path.append("..")
from LBFGS import FullBatchLBFGS
from kernels import vvkernels as vvk, sep_vvkernels as svvk, vvk_rbfkernel as vvk_rbf
from means import vvmeans as vvm
from likelihood import vvlikelihood as vvll
from mlikelihoods import MarginalLogLikelihood as exmll
from predstrategies import GPprediction
from utils import ObjFun, get_vertices, stopping_criteria
from scipy import stats
import numpy as np
import seaborn as sns
import scipy
torch.manual_seed(0)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# for tol 0.1, 5 base kernels, v2 shape = 81, gtheta1 shape = 101, 25 iteration. current sol istensor([[0.8239, 0.5316]], device='cuda:0'), tgt =
# tensor([[0.3483, 0.3768]])
# for tol 0.08, 4 base kernels, v2 shape = 66, gtheta1 shape = 82, 20 iteration. current sol istensor([[0.8043, 0.5513]], device='cuda:0'), tgt = tensor([[0.2902, 0.3726]])
#
# for tol = 0.05, 5 base kernels. v2 shape = 495, gtheta1_shape = 653, current sol istensor([[0.7873, 0.4634]], device='cuda:0')
# Success is False and failure is True after 163 iterations,tgt = [0.3322, 0.3349]
# # Plots settings

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=40)     # fontsize of the axes title
plt.rc('axes', labelsize=32)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=32)    # fontsize of the tick labels
plt.rc('ytick', labelsize=32)    # fontsize of the tick labels
plt.rc('legend', fontsize=32)    # legend fontsize
plt.rc('font', size=32)          # controls default text sizes

# %% [markdown]
# # Objective function
#
# We sample from $$V_1(x_1, x_2) = 3(1 - x_1)^2 e^{-x_1^2 - (x_2 +1)^2} - 10 (x_1/5 - x_1 ^3 - x_2^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- (x_1 + 2) ^2 - x_2^2} + 0.5(2x_1 + x_2)$$
# $$V_2(x_1, x_2) = 3(1 +x_2)^2 e^{-x_2^2 - (x_1 +1)^2} - 10 (-x_2/5 + x_2 ^3 + x_1^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- ( 2- x_2) ^2 - x_1^2} + 0.5(2x_1 + x_2)$$
#
# where $(x_1, x_2) \in [-3, 3]^2$

# %%
torch.set_default_dtype(torch.float64)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')

vf = ObjFun()
f_target = vf.tgt_vec
f_target = torch.tensor([0.3380, 0.4502])
print(f_target)
sample_size = 4
D = vf.D
N = vf.N

vf.low = -1.5
vf.high = 1.5

high_minus_low = vf.high- vf.low
#high_minus_low = -
def g_theta(sample_size, D):
#     loc_x = (2. - 1.0 )  * np.random.random_sample((sample_size,1)) + 1.0
    
#     loc_y = (2.  -1.0)  * np.random.random_sample((sample_size,1)) - 2.
#     loc = np.concatenate((loc_x, loc_y), 1)
    loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
if use_cuda:
    train_x = train_x.cuda()
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    x = x.to(x.device)
    out = torch.zeros(x.shape[0], N)
    randn = torch.randn(N)
    randn = randn.to(x.device)
    out = vf(x[:,0], x[:,1]) + randn * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([0.3380, 0.4502])
# tensor([[ 0.3420, -1.4575],
#         [-1.3258,  0.1531],
#         [-1.3981, -1.2517],
#         [ 0.7261,  1.1842]], device='cuda:0')

# %%
import matplotlib.ticker
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
             self.format = r'$\mathdefault{%s}$' % self.format

# %%
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)
v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)
print(tgt_plot[tgt_plot == f_target])
print(tgt_plot.shape)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18, 8), tight_layout=True)
#ax.set_xlim(-3.5, 3.5)
cs11 = ax1.contourf(xv_plot, yv_plot, v_1, np.linspace(torch.min(v_1),torch.max(v_1), 100), cmap = 'jet')
cs12 =ax2.contourf(xv_plot, yv_plot, v_2, np.linspace(torch.min(v_2),torch.max(v_2), 100), cmap = 'jet')
cbar11 = fig.colorbar(cs11, ax = ax1,format=OOMFormatter(0, mathText=False))
cbar12 = fig.colorbar(cs12, ax = ax2,format=OOMFormatter(0, mathText=False))
#ax.set_ylim(-3.5, 3.5)
# Out:
# tensor([])
# torch.Size([10000, 2])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18, 8), tight_layout=True)
#ax.set_xlim(-3.5, 3.5)
cs11 = ax1.contourf(xv_plot, yv_plot, v_1+ v_2, np.linspace(torch.min(v_1+v_2),torch.max(v_1+v_2), 100), cmap = 'jet')
cs12 =ax2.contourf(xv_plot, yv_plot, v_2+ v_1, np.linspace(torch.min(v_2+v_1),torch.max(v_2+v_1), 100), cmap = 'jet')
cbar11 = fig.colorbar(cs11, ax = ax1,format=OOMFormatter(0, mathText=False))
cbar12 = fig.colorbar(cs12, ax = ax2,format=OOMFormatter(0, mathText=False))

# %%
f_target_ood = torch.tensor([0.3502, 0.3502])
print(tgt_plot[tgt_plot == f_target_ood])
# Out:
# tensor([])

# %% [markdown]
# ## GP model initialization
# We inialize the GP model following https://docs.gpytorch.ai/en/stable/examples/03_Multitask_Exact_GPs/Multitask_GP_Regression.html

# %%
x_train = train_x #loc #torch.linspace(0, 1, 10)
y_train = train_y #v  #torch.stack([torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,torch.cos(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,], -1)

class MultitaskGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood,num_base_kernels):
        super(MultitaskGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)  #vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)#vvm.TensorProductSubMean(gpytorch.means.ConstantMean(), num_tasks = 2)  # 
        base_kernels = [] #contain all the base kernels
        for i in range(num_base_kernels):
            base_kernels.append(gpytorch.kernels.ScaleKernel(( gpytorch.kernels.RBFKernel() ))) #gpytorch.kernels.PolynomialKernel(4)  ##gpytorch.kernels.MaternKernel()# (vvk_rbf.vvkRBFKernel())
 
            
        self.covar_module = svvk.SepTensorProductKernel(base_kernels,num_tasks = 2)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal(mean_x, covar_x)

# %% [markdown]
# # Hyperparamaters oprimization

# %%
# # ###hyperparameters optimization###
def hyper_opti(g_theta1, agg_data, training_iter,num_base_kernels,noise_value, current_model = None, current_likelihood = None):
    noises = torch.ones(agg_data.shape[0]) * (noise_value) #  torch.zeros(agg_data.shape[0]) # 
    noises = noises.reshape(g_theta1.shape[0], 2)
    
#     if (current_model is not None):
#         likelihood = current_likelihood #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises)  #

#         model = current_model#.get_fantasy_model(g_theta1, agg_data) #MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
#         model.set_train_data(g_theta1, agg_data,  strict=False)
#     else:
#         likelihood = vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2)#vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #
#         model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
        
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    likelihood =  vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2) #
    model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
    model.double()
    likelihood.double()

    """Put related things on GPU"""
    if use_cuda:
        print("Using CUDA")
        model = model.cuda()
        likelihood = likelihood.cuda()
        g_theta1 = g_theta1.cuda()
        agg_data = agg_data.cuda()
        cov_noise1 = cov_noise1.cuda()
        
    else:
        print("Using CPU")
    
    
    """end for GPU"""

    model.train()
    
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(),  lr=0.1) #, weight_decay=0.001)  # Includes GaussianLikelihood parameters
    mll = exmll(likelihood, model)
    # Is this a likelihood?

    for i in range(training_iter):
        optimizer.zero_grad()

        loss, chi_square = mll(agg_data,g_theta1, model, likelihood, cov_noise1)
        loss = -1. * loss
#         print('df is %.3f' %agg_data.shape[0] +'and chi_square %.3f' %chi_square) 
        #print('loss is %.3f' %loss)
#         df = agg_data.shape[0]
#         chi_square = chi_square.clone().detach()
        
#         p_val = 1. - stats.chi2.cdf(chi_square, df)
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
       # print(p_val)
#         if (p_val > 0.99999):
#             return model, likelihood


    
        
    print('loss is %.3f' %loss)
#     for params in model.named_parameters():
#         print(params)
    return model, likelihood

# %% [markdown]
# # Design parameters and sampling point optimization (where to explore?)

# %%
def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    g_theta2 = nn.Parameter(loc_sample)
    
    x_d= nn.Parameter(x0)
    
    optimizer = torch.optim.Adam([{'params': g_theta2, 'lr': 0.01},{'params': x_d, 'lr': 0.01}])

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    #scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    cov_noise2 =  noise_value * torch.eye(2 * g_theta2.shape[0])
    
    """Put related things on GPU for conduct_design_opti"""
    if use_cuda:
        print("Using CUDA for conduct_design_opti()")
        
        model = model.cuda()
        likelihood = likelihood.cuda()
        agg_data = agg_data.cuda()
        
        cov_noise1 = cov_noise1.cuda()
        cov_noise2 = cov_noise2.cuda()
        g_theta1 = g_theta1.cuda()
        g_theta2 = g_theta2.cuda()
        agg_data = agg_data.cuda()
        x_d = x_d.cuda()
        f_target = f_target.cuda()
        
    else:
        print("Using CPU for conduct_design_opti()")
    
    """end for GPU"""
    
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, g_theta2, cov_noise1, cov_noise2)

        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        scheduler.step(loss2)
        #scheduler.step()

    print('Loss design: %.3f' % ( loss2))
    #print(x_d)
    return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %% [markdown]
# # Conducting the TAD experiment

# %% [markdown]
# Initialization

# %%
loc_size = 2
#loc_sample0 = Tensor((2. - 1.5)  * np.random.random_sample((loc_size,2)) + 1.5)
x0 = Tensor(np.array([-2. , 2.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
x0 = x0.reshape(1,2)

dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(loc_size) )
                    #loc_size = 4
loc_sample = dis_2sample.sample((loc_size + 1,))


loc_sample0 = loc_sample.reshape(loc_size + 1, 2)

#loc_sample0[-1] = train_x[-1] + 0.01

# %%
path = ".//checkpoints/model_update_ootol_005"
isExist = os.path.exists(path)
if not isExist:

   # Create a new directory because it does not exist
   os.makedirs(path)
path = ".//checkpoints/model_goodmodel_ootol_005"
isExist = os.path.exists(path)
if not isExist:

   # Create a new directory because it does not exist
   os.makedirs(path)

# %% [markdown]
# TAD algorithm

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 100
iter_param = 100
num_base_kernels = 2
max_iter = 50

f_target = f_target.reshape(2,1) 
tol_vector = 0.05 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten().to(device)

data_fit_vec = torch.empty((1,1)).to(device)
entropy_vec = torch.empty((1,1)).to(device)
loss_vec = torch.empty((1,1)).to(device)




#
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])
p21_vec = torch.empty((1,1))

lr_new = .01

thresh_EI = 0.001
    
count_EI = 0
max_count_EI = 50  
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False



while(SUCCESS == False and FAILURE == False):
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None


        loc_sample_old = loc_sample.clone()
        x0_old = x0.clone()
        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)

        
# Before this is hyper_opti

        print('END HYPERPARAMETERS optimization')
    
   

 #     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
        
#     """end for CPU"""
    
    model.eval()
    likelihood.eval()
   
    
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
  
    cur_model = model
    cur_likelihood = likelihood
    
  
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])

    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
    
    
#     """Put everything back to CPU here"""
#     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
    
# #     cov_noise1 = cov_noise1.cpu()
# #     cov_noise2 = cov_noise2.cpu()
# #     g_theta1 = g_theta1.cuda()
#     g_theta2 = g_theta2.cpu()
# #     agg_data = agg_data.cuda()
# #     x_d = x_d.cpu()
#     f_target = f_target.cpu()
    
    
#     x0_new, loss, pf1, Qf1, Qf12, data_fit, Q21 = x0_new.cpu(), loss.cpu(), pf1.cpu(), Qf1.cpu(),Qf12.cpu(),data_fit.cpu(),Q21.cpu()
#     """End of putting everything back to CPU"""
    
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    
    print('expected info is '+str(entropy))
    print('log floor is' + str(math.floor(torch.log(entropy))))
    
    if not SUCCESS:
    


        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape)).cpu()
                
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value, N)
               
                eye = torch.eye(Qf12.shape[0]).to(device)
                chi_f12 = (Qf12 + noise_value*eye).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape)).cpu()
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                p21_vec = torch.cat([p21_vec, Tensor([p_val]).reshape(1,1)], 0)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    sum = torch.zeros(2, 2).to(device) #replace with num_tasks
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    x0_old = x0_old.to(device)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_old).t(), (g_theta2.detach()[i] - x0_old) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_old, covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    loc_sample = torch.cat([loc_sample, x0_old],0)
                    
                    x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
                        PATH = ".//checkpoints/model_update_ootol_005/model_base_"+str(iter)+".pt"
                        torch.save(model, PATH)
                        
                        entropy_vec = torch.cat([entropy_vec, entropy], 0)
                        data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is ' + str(num_base_kernels))
#     #                         
                        loc_sample = loc_sample_old
                        #x0 = x0_old
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                        g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                        print('acquiring 2, new size is ' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    PATH = ".//checkpoints/model_goodmodel_ootol_005/model_base_"+str(iter)+".pt"
                    torch.save(model, PATH)
                    vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                    loss_vec = torch.cat([loss_vec, -loss])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy <= thresh_EI): # math.floor(torch.log10(entropy)) <= -2.1):
                        count_EI = count_EI + 1
                    else:
                        count_EI = 0
                    if (count_EI >= max_count_EI):
                        FAILURE = True
#                     if (entropy < 1e-4 * tol_vector[0,0]):
#                         FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2).to(device)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum# + torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -3. or loc_sample[i,0] > 3. or loc_sample[i,1] < -3. or loc_sample[i,1] > 3.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target.to(device) - pf1).cpu()
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        

                        x0 = (x0_new.detach()) + torch.randn(D).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(D).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(D).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(D).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -3. or x0_new.detach()[0,0] > 3. or x0_new.detach()[0,1] < -3. or x0_new.detach()[0,1] > 3.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = torch.tensor([[0. , 0.]])
                        x0 = x0.to(device)
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                        x0 = x0.reshape(1,2)
                        #x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
           
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
PATH = ".//checkpoints/model_goodmodel_ootol_005/model_base_"+str(iter)+".pt"
torch.save(model, PATH)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[-2.1085,  1.8601],
#         [-1.9597,  2.0838],
#         [-2.0719,  1.9597]])
# 0
# START HYPERPARAMETERS optimization
# Using CUDA
# /home/mngom/BayesTAD/TadBayesOpt/code/jupyter/env_gpytorch_polaris/lib/python3.8/site-packages/gpytorch/lazy/triangular_lazy_tensor.py:130: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /soft/datascience/conda/2022-09-08/pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   res = torch.triangular_solve(right_tensor, self.evaluate(), upper=self.upper).solution
# loss is -1.777
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 82.295
# expected info is tensor([[2.6839]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is0
# current sol istensor([[-2.,  2.]], device='cuda:0')
# new data istensor([[-0.0935,  0.0069]], device='cuda:0')
# g_theta2 istensor([[-2.1085,  1.8601],
#         [-1.9597,  2.0838],
#         [-2.0719,  1.9597]], device='cuda:0')
# p21val is 0.000000000000000
# pf12val is 0.000012834862885
# chi_f12 is 22.526690853137534
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 0
# Using CUDA for conduct_design_opti()
# Loss design: 19.018
# expected info is tensor([[0.2085]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[-2.1761,  2.0705]], device='cuda:0')
# new data istensor([[-0.1443,  0.0021]], device='cuda:0')
# g_theta2 istensor([[-1.8326,  1.8134],
#         [-1.8504,  1.8729],
#         [-1.8567,  1.9179]], device='cuda:0')
# p21val is 0.000000000000000
# pf12val is 0.000000000000000
# chi_f12 is 222.130176651796432
# patience is 2.000
# adding complexity to model
# num base is 3
# acquiring 2, new size is 7
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.573
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 11.529
# expected info is tensor([[0.5966]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-1
# current sol istensor([[-2.4891,  2.3981]], device='cuda:0')
# new data istensor([[-0.1411, -0.0044]], device='cuda:0')
# g_theta2 istensor([[-2.1085,  1.8601],
#         [-1.9597,  2.0838],
#         [-2.0719,  1.9597]], device='cuda:0')
# p21val is 0.992057677658993
# pf12val is 0.732926952748529
# chi_f12 is 0.621418474495150
# p_val_ftarget is 1.4532129751776424e-06
# new 2 points
# tensor([[-1.7990,  1.6779],
#         [-2.6185,  2.6894],
#         [-2.4890,  2.3973]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.896
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 52.092
# expected info is tensor([[0.2377]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[-2.8394,  2.1224]], device='cuda:0')
# new data istensor([[-0.1775,  0.0093]], device='cuda:0')
# g_theta2 istensor([[-1.8435,  1.8476],
#         [-2.5943,  2.7753],
#         [-2.4096,  2.4895]], device='cuda:0')
# p21val is 0.228861987782103
# pf12val is 0.940706129005919
# chi_f12 is 0.122248969316524
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.4124,  2.5345],
#         [ 0.7308,  1.0271],
#         [-2.8385,  2.1232]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.147
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 68.284
# expected info is tensor([[0.1022]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-3.0008,  1.6070]], device='cuda:0')
# new data istensor([[-2.5069e-01, -1.6741e-04]], device='cuda:0')
# g_theta2 istensor([[-2.5564,  2.2333],
#         [ 0.6407,  1.2723],
#         [-2.6356,  2.3216]], device='cuda:0')
# p21val is 0.171961852608450
# pf12val is 0.765845014803593
# chi_f12 is 0.533550920513487
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4177,  0.3552],
#         [ 0.5564, -1.0098],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.228
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 31.865
# expected info is tensor([[0.7697]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-1
# current sol istensor([[ 0.3349, -0.2011]], device='cuda:0')
# new data istensor([[0.0614, 0.0733]], device='cuda:0')
# g_theta2 istensor([[-0.6754,  0.2137],
#         [ 0.8845, -1.4992],
#         [-0.3504,  0.3614]], device='cuda:0')
# p21val is 0.000000388825024
# pf12val is 0.225755482952524
# chi_f12 is 2.976605598522323
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# Using CUDA for conduct_design_opti()
# Loss design: 21.153
# expected info is tensor([[0.7289]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-1
# current sol istensor([[0.2752, 0.0648]], device='cuda:0')
# new data istensor([[0.0335, 0.2149]], device='cuda:0')
# g_theta2 istensor([[ 1.9162, -1.6265],
#         [-1.6399,  2.2381],
#         [-0.2587,  0.6674]], device='cuda:0')
# p21val is 0.039143610469386
# pf12val is 0.051478637582643
# chi_f12 is 5.933176723176086
# p_val_ftarget is 6.455402878913219e-11
# new 2 points
# tensor([[ 0.5263, -0.3754],
#         [-0.8024,  1.0941],
#         [ 0.2760,  0.0668]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.123
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 11.169
# expected info is tensor([[0.2479]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[0.6818, 0.3396]], device='cuda:0')
# new data istensor([[0.1977, 0.3740]], device='cuda:0')
# g_theta2 istensor([[ 0.3984, -0.5734],
#         [-0.9949,  1.2604],
#         [ 0.2116, -0.0757]], device='cuda:0')
# p21val is 0.060640687915249
# pf12val is 0.079102566091480
# chi_f12 is 5.074019927257570
# p_val_ftarget is 2.509280138118797e-07
# new 2 points
# tensor([[ 1.5684, -0.9636],
#         [-0.2986,  2.7042],
#         [ 0.6818,  0.3401]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.033
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: -2.580
# expected info is tensor([[0.0274]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-4
# current sol istensor([[0.9969, 0.4986]], device='cuda:0')
# new data istensor([[0.3830, 0.2639]], device='cuda:0')
# g_theta2 istensor([[ 1.2812, -1.2672],
#         [-0.6675,  2.9293],
#         [ 0.4818,  0.0692]], device='cuda:0')
# p21val is 0.628540969415513
# pf12val is 0.530633954132580
# chi_f12 is 1.267365694737056
# p_val_ftarget is 0.11768055943141498
# new 2 points
# tensor([[ 0.0379,  1.8923],
#         [ 1.8317, -0.4917],
#         [ 0.9970,  0.4993]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.829
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 3.027
# expected info is tensor([[0.1768]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[1.1154, 0.1198]], device='cuda:0')
# new data istensor([[ 0.4927, -0.0966]], device='cuda:0')
# g_theta2 istensor([[-0.4246,  1.3689],
#         [ 2.5230, -1.0874],
#         [ 0.8688,  0.4773]], device='cuda:0')
# p21val is 0.032039366743553
# pf12val is 0.000010420110177
# chi_f12 is 22.943545896119179
# p_val_ftarget is 0.0006074463058075574
# new 2 points
# tensor([[ 2.8322, -1.3171],
#         [ 0.5513,  0.6395],
#         [ 1.1153,  0.1202]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.965
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 45.114
# expected info is tensor([[0.0393]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-4
# current sol istensor([[ 0.8390, -0.1277]], device='cuda:0')
# new data istensor([[0.3323, 0.0202]], device='cuda:0')
# g_theta2 istensor([[ 2.9446, -1.2606],
#         [ 0.7066,  0.9240],
#         [ 1.0918,  0.2385]], device='cuda:0')
# p21val is 0.485826999779143
# pf12val is 0.735031666819408
# chi_f12 is 0.615683393178711
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0901, -1.0441],
#         [ 1.7532,  0.0859],
#         [ 0.8395, -0.1284]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.998
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 41.960
# expected info is tensor([[0.0548]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 1.0335, -0.5398]], device='cuda:0')
# new data istensor([[ 0.3575, -0.2920]], device='cuda:0')
# g_theta2 istensor([[-0.4420, -1.4557],
#         [ 2.3628,  0.0385],
#         [ 0.5963,  0.0985]], device='cuda:0')
# p21val is 0.482651514377614
# pf12val is 0.353230276734596
# chi_f12 is 2.081270185414114
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.1975, -2.4033],
#         [ 2.5744,  0.2916],
#         [ 1.0321, -0.5406]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.025
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 64.705
# expected info is tensor([[0.0542]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 1.4392, -0.7344]], device='cuda:0')
# new data istensor([[ 0.3302, -0.4595]], device='cuda:0')
# g_theta2 istensor([[-2.5841, -2.1261],
#         [ 2.9332,  0.9212],
#         [ 0.8994, -0.3427]], device='cuda:0')
# p21val is 0.006317574960665
# pf12val is 0.224599365970385
# chi_f12 is 2.986874119219433
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# Using CUDA for conduct_design_opti()
# Loss design: 115.873
# expected info is tensor([[0.1106]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 0.7433, -0.8506]], device='cuda:0')
# new data istensor([[0.0106, 0.0537]], device='cuda:0')
# g_theta2 istensor([[-0.5162, -1.3161],
#         [ 1.9917,  0.0682],
#         [ 1.0665, -0.3960]], device='cuda:0')
# p21val is 0.021457246023996
# pf12val is 0.334969231696662
# chi_f12 is 2.187433194113499
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5134, -1.6604],
#         [ 0.5164, -1.0319],
#         [ 0.7431, -0.8480]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.046
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 73.542
# expected info is tensor([[0.0820]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 0.9631, -1.5731]], device='cuda:0')
# new data istensor([[-0.3000,  0.1267]], device='cuda:0')
# g_theta2 istensor([[-0.4417, -1.8087],
#         [ 0.4017, -1.0313],
#         [ 0.5060, -0.6025]], device='cuda:0')
# p21val is 0.256780438684820
# pf12val is 0.676829165811647
# chi_f12 is 0.780672755850597
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 2.1022, -1.5495],
#         [ 2.4157, -1.2898],
#         [ 0.9624, -1.5743]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.079
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 43.392
# expected info is tensor([[0.1718]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[ 1.3127, -1.8942]], device='cuda:0')
# new data istensor([[-0.0622,  0.0409]], device='cuda:0')
# g_theta2 istensor([[ 2.0507, -1.7511],
#         [ 2.6467, -1.1344],
#         [ 0.8704, -1.4312]], device='cuda:0')
# p21val is 0.979587187121033
# pf12val is 0.856239324404756
# chi_f12 is 0.310410714663773
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.3527, -1.6283],
#         [ 2.7521, -1.0977],
#         [ 1.3147, -1.8934]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.145
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 29.470
# expected info is tensor([[0.0747]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 1.7191, -2.2052]], device='cuda:0')
# new data istensor([[ 0.0974, -0.0007]], device='cuda:0')
# g_theta2 istensor([[ 1.5486, -1.6132],
#         [ 2.7046, -1.1493],
#         [ 1.1759, -1.7135]], device='cuda:0')
# p21val is 0.890945718826660
# pf12val is 0.930670577809858
# chi_f12 is 0.143699802518117
# p_val_ftarget is 3.1086244689504383e-15
# new 2 points
# tensor([[ 0.8425, -2.3615],
#         [ 2.3720, -2.4793],
#         [ 1.7191, -2.2058]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.195
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 15.531
# expected info is tensor([[0.2533]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[ 2.1928, -2.5406]], device='cuda:0')
# new data istensor([[0.1077, 0.0193]], device='cuda:0')
# g_theta2 istensor([[ 0.6940, -2.1818],
#         [ 2.7667, -1.8556],
#         [ 1.5244, -2.0085]], device='cuda:0')
# p21val is 0.853909491264396
# pf12val is 0.900038089091497
# chi_f12 is 0.210636390681137
# samples escaped box
# p_val_ftarget is 7.786852718183468e-09
# new 2 points
# tensor([[ 1.4043, -0.6130],
#         [ 2.0225, -2.4592],
#         [ 2.1926, -2.5401]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.222
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 23.492
# expected info is tensor([[0.1531]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[ 2.4833, -2.8759]], device='cuda:0')
# new data istensor([[0.1363, 0.0012]], device='cuda:0')
# g_theta2 istensor([[ 1.0804, -0.3332],
#         [ 1.9358, -2.4929],
#         [ 2.0452, -2.3939]], device='cuda:0')
# p21val is 0.060106522838417
# pf12val is 0.993985651993068
# chi_f12 is 0.012065014088726
# samples escaped box
# samples escaped box
# p_val_ftarget is 1.5296652833285407e-12
# new 2 points
# tensor([[-0.0533, -0.8983],
#         [ 0.4311, -0.4521],
#         [ 2.4825, -2.8765]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.232
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 19.272
# expected info is tensor([[0.0129]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-5
# current sol istensor([[ 2.8980, -2.9739]], device='cuda:0')
# new data istensor([[0.1649, 0.0024]], device='cuda:0')
# g_theta2 istensor([[-0.1151, -0.8738],
#         [ 0.4393, -0.3995],
#         [ 2.3343, -2.6804]], device='cuda:0')
# p21val is 0.001967108309546
# pf12val is 0.791094448871574
# chi_f12 is 0.468675827907555
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# Using CUDA for conduct_design_opti()
# Loss design: 19.015
# expected info is tensor([[0.0126]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-5
# current sol istensor([[ 2.9007, -2.9732]], device='cuda:0')
# new data istensor([[ 0.1623, -0.0024]], device='cuda:0')
# g_theta2 istensor([[ 0.2748,  0.0435],
#         [ 0.7993, -0.6667],
#         [ 2.3349, -2.6808]], device='cuda:0')
# p21val is 0.004154467830838
# pf12val is 0.678629224710848
# chi_f12 is 0.775360722755417
# patience is 2.000
# adding complexity to model
# num base is 4
# acquiring 2, new size is 70
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.226
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 8.456
# expected info is tensor([[0.0065]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-6
# current sol istensor([[ 2.9997, -2.6260]], device='cuda:0')
# new data istensor([[0.1766, 0.0305]], device='cuda:0')
# g_theta2 istensor([[-0.3684, -0.6568],
#         [ 0.2361, -0.3809],
#         [ 2.4514, -2.8690]], device='cuda:0')
# p21val is 0.185040738340174
# pf12val is 0.718989295063326
# chi_f12 is 0.659817620036411
# p_val_ftarget is 7.427374938417941e-06
# new 2 points
# tensor([[-0.4492, -0.0724],
#         [ 2.5950, -2.4242],
#         [ 2.9981, -2.6251]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.235
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 37.914
# expected info is tensor([[0.0984]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[ 3.0004, -3.0018]], device='cuda:0')
# new data istensor([[ 0.1286, -0.0057]], device='cuda:0')
# g_theta2 istensor([[-0.9110,  0.3791],
#         [ 2.5212, -2.6793],
#         [ 2.8197, -2.5139]], device='cuda:0')
# p21val is 0.539887671274143
# pf12val is 0.843995754688758
# chi_f12 is 0.339215628776908
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.9609, -2.0730],
#         [ 1.1324,  0.7859],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.265
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 35.295
# expected info is tensor([[0.0011]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[-0.4607, -0.1833]], device='cuda:0')
# new data istensor([[0.2183, 0.0370]], device='cuda:0')
# g_theta2 istensor([[ 1.6847, -1.7270],
#         [ 1.0695,  1.1853],
#         [ 0.2607, -0.3175]], device='cuda:0')
# p21val is 0.098233845910471
# pf12val is 0.852732883142988
# chi_f12 is 0.318617860846222
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.3119, -1.2960],
#         [-0.3308, -0.6520],
#         [-0.4601, -0.1838]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.282
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 4.829
# expected info is tensor([[0.1076]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-0.8039, -0.5362]], device='cuda:0')
# new data istensor([[0.1099, 0.1408]], device='cuda:0')
# g_theta2 istensor([[-1.3353, -1.3002],
#         [-0.2963, -0.7232],
#         [-0.2537, -0.4026]], device='cuda:0')
# p21val is 0.260493430967353
# pf12val is 0.010114348161677
# chi_f12 is 9.187600506359507
# p_val_ftarget is 0.00010712075989305347
# new 2 points
# tensor([[-1.0787, -0.0816],
#         [-0.8417, -0.5052],
#         [-0.8024, -0.5365]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.277
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 47.865
# expected info is tensor([[0.0797]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-1.2103, -0.7814]], device='cuda:0')
# new data istensor([[-0.2178,  0.3892]], device='cuda:0')
# g_theta2 istensor([[-1.0285,  0.0552],
#         [-0.6841, -0.3390],
#         [-0.6475, -0.3728]], device='cuda:0')
# p21val is 0.709040201500678
# pf12val is 0.043505228846941
# chi_f12 is 6.269748289466772
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.4612, -1.3184],
#         [-0.9227, -0.4989],
#         [-1.2099, -0.7807]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.302
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 41.400
# expected info is tensor([[0.0055]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-6
# current sol istensor([[-1.6085, -0.5777]], device='cuda:0')
# new data istensor([[-0.4967,  0.6573]], device='cuda:0')
# g_theta2 istensor([[-1.3690, -1.3516],
#         [-0.7835, -0.4108],
#         [-1.1364, -0.7494]], device='cuda:0')
# p21val is 0.447739653680343
# pf12val is 0.929295519862338
# chi_f12 is 0.146656970822968
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.2525, -1.6684],
#         [-0.7635,  0.2622],
#         [-1.6097, -0.5777]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.311
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 43.923
# expected info is tensor([[0.0765]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-1.8697, -0.8574]], device='cuda:0')
# new data istensor([[-0.4368,  0.3824]], device='cuda:0')
# g_theta2 istensor([[-1.6426, -2.0357],
#         [-0.8909,  0.0737],
#         [-1.4909, -0.5342]], device='cuda:0')
# p21val is 0.467931571306865
# pf12val is 0.449889149974100
# chi_f12 is 1.597508119907427
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.2563, -0.4282],
#         [-2.3687, -0.8416],
#         [-1.8705, -0.8572]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.339
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 48.854
# expected info is tensor([[0.1402]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-2
# current sol istensor([[-2.2604, -1.1595]], device='cuda:0')
# new data istensor([[-0.3865,  0.0503]], device='cuda:0')
# g_theta2 istensor([[-2.0153, -0.6451],
#         [-2.5837, -0.4645],
#         [-1.6849, -0.6954]], device='cuda:0')
# p21val is 0.936454219623223
# pf12val is 0.918565290329235
# chi_f12 is 0.169884586413723
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.9568, -2.2933],
#         [-1.7115, -1.5931],
#         [-2.2610, -1.1600]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.367
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 58.725
# expected info is tensor([[0.0912]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-2.5637, -1.5007]], device='cuda:0')
# new data istensor([[-0.3629,  0.0312]], device='cuda:0')
# g_theta2 istensor([[-1.7246, -2.5069],
#         [-1.6309, -1.5568],
#         [-2.1161, -1.0242]], device='cuda:0')
# p21val is 0.744018777807484
# pf12val is 0.430975474350254
# chi_f12 is 1.683408189114444
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3746, -0.4910],
#         [-0.6131,  0.5710],
#         [-2.5637, -1.5010]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.352
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 52.768
# expected info is tensor([[0.0874]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-2.8927, -1.8036]], device='cuda:0')
# new data istensor([[-0.4371, -0.0128]], device='cuda:0')
# g_theta2 istensor([[-0.2781, -0.6299],
#         [-0.9893,  0.7059],
#         [-2.4281, -1.3532]], device='cuda:0')
# p21val is 0.623553899138826
# pf12val is 0.649775114476704
# chi_f12 is 0.862257907369408
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.1916,  1.3413],
#         [-0.1640,  0.3687],
#         [-2.8931, -1.8037]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.361
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 73.976
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[-2.9429, -2.2097]], device='cuda:0')
# new data istensor([[-0.4566,  0.0121]], device='cuda:0')
# g_theta2 istensor([[-0.9760,  1.4186],
#         [-0.1403,  0.4721],
#         [-2.7041, -1.6660]], device='cuda:0')
# p21val is 0.309900165301963
# pf12val is 0.896395845575027
# chi_f12 is 0.218746343264232
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4618, -1.4321],
#         [-1.0502,  1.0017],
#         [-2.9435, -2.2089]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.372
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 78.170
# expected info is tensor([[0.0136]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-5
# current sol istensor([[-2.6498, -2.4906]], device='cuda:0')
# new data istensor([[-0.4179,  0.0436]], device='cuda:0')
# g_theta2 istensor([[ 0.5796, -1.4800],
#         [-1.0403,  1.0730],
#         [-2.9382, -2.0810]], device='cuda:0')
# p21val is 0.876706790007615
# pf12val is 0.896600116043985
# chi_f12 is 0.218290635668199
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1340, -0.2242],
#         [-1.0578,  0.4751],
#         [-2.6502, -2.4892]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.414
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 78.186
# expected info is tensor([[0.0289]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-4
# current sol istensor([[-2.3729, -2.8760]], device='cuda:0')
# new data istensor([[-0.4239,  0.0194]], device='cuda:0')
# g_theta2 istensor([[-0.2213, -0.1032],
#         [-0.8939,  0.6698],
#         [-2.8439, -2.3401]], device='cuda:0')
# p21val is 0.899573190897015
# pf12val is 0.976996934956327
# chi_f12 is 0.046543528287063
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.2345, -2.2923],
#         [ 1.1932, -0.6516],
#         [-2.3728, -2.8738]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.444
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 107.236
# expected info is tensor([[0.0522]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-3
# current sol istensor([[-1.9429, -3.0016]], device='cuda:0')
# new data istensor([[-0.3961, -0.0211]], device='cuda:0')
# g_theta2 istensor([[-2.2683, -2.3201],
#         [ 1.0661, -0.5495],
#         [-2.4625, -2.7180]], device='cuda:0')
# p21val is 0.763426681523096
# pf12val is 0.937292501807287
# chi_f12 is 0.129519754081084
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.1311, -2.5746],
#         [-1.4103, -2.3666],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.457
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 203.907
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[-0.4321,  0.2535]], device='cuda:0')
# new data istensor([[0.0553, 0.0891]], device='cuda:0')
# g_theta2 istensor([[-1.6849, -2.9245],
#         [-1.7312, -2.4700],
#         [ 0.2349, -0.2234]], device='cuda:0')
# p21val is 0.598414618645025
# pf12val is 0.887094173028591
# chi_f12 is 0.239608264078470
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2967,  1.8834],
#         [-1.4948,  1.2719],
#         [-0.4310,  0.2553]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.490
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 205.393
# expected info is tensor([[0.0037]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-6
# current sol istensor([[-0.6336,  0.9057]], device='cuda:0')
# new data istensor([[ 0.1324, -0.1877]], device='cuda:0')
# g_theta2 istensor([[ 0.9486,  2.3544],
#         [-1.9901,  1.8721],
#         [-0.1862, -0.0065]], device='cuda:0')
# p21val is 0.019424803005310
# pf12val is 0.322023108224944
# chi_f12 is 2.266263942677904
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.7974,  1.3399],
#         [ 1.0632,  1.0204],
#         [-0.6350,  0.9055]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.485
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 65.648
# expected info is tensor([[0.0036]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-6
# current sol istensor([[0.1203, 0.8243]], device='cuda:0')
# new data istensor([[ 0.2579, -0.0324]], device='cuda:0')
# g_theta2 istensor([[-1.9732,  1.5103],
#         [ 1.0999,  1.3953],
#         [-0.8941,  0.6648]], device='cuda:0')
# p21val is 0.745416873677567
# pf12val is 0.385788853534513
# chi_f12 is 1.904930141502669
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.3910,  0.5345],
#         [ 1.4411, -0.6277],
#         [ 0.1203,  0.8256]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.469
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 39.914
# expected info is tensor([[0.0070]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-5
# current sol istensor([[0.5521, 0.6575]], device='cuda:0')
# new data istensor([[0.2182, 0.3398]], device='cuda:0')
# g_theta2 istensor([[ 1.4118,  0.1694],
#         [ 1.5043, -0.6601],
#         [-0.1309,  0.7916]], device='cuda:0')
# p21val is 0.156501091247969
# pf12val is 0.774183298226072
# chi_f12 is 0.511893228032341
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1326,  1.1591],
#         [ 0.2138,  1.5327],
#         [ 0.5510,  0.6578]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.472
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 20.664
# expected info is tensor([[0.0019]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[0.8024, 0.5919]], device='cuda:0')
# new data istensor([[0.3252, 0.3832]], device='cuda:0')
# g_theta2 istensor([[-0.2436,  1.5678],
#         [-0.0060,  1.7291],
#         [ 0.6905,  0.1258]], device='cuda:0')
# p21val is 0.667376958319005
# pf12val is 0.516221551949240
# chi_f12 is 1.322438482816623
# p_val_ftarget is 4.0900616227190767e-13
# new 2 points
# tensor([[ 1.3326, -0.0311],
#         [ 1.2273,  0.3477],
#         [ 0.8019,  0.5919]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.511
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 25.030
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7900, 0.5811]], device='cuda:0')
# new data istensor([[0.3178, 0.3549]], device='cuda:0')
# g_theta2 istensor([[ 1.4038, -0.1212],
#         [ 1.2494,  0.3020],
#         [ 0.3590,  0.1414]], device='cuda:0')
# p21val is 0.236735730168369
# pf12val is 0.425350354950467
# chi_f12 is 1.709684170140502
# p_val_ftarget is 3.6637359812630166e-15
# new 2 points
# tensor([[ 0.4345,  0.8009],
#         [-0.3265,  1.3572],
#         [ 0.7900,  0.5798]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.512
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 36.827
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7812, 0.5820]], device='cuda:0')
# new data istensor([[0.2735, 0.4122]], device='cuda:0')
# g_theta2 istensor([[ 0.2957,  0.9219],
#         [-0.3990,  1.3791],
#         [ 0.3451,  0.1231]], device='cuda:0')
# p21val is 0.961994073128306
# pf12val is 0.129102671217495
# chi_f12 is 4.094294580541654
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1811,  1.2243],
#         [ 0.8187,  0.5592],
#         [ 0.7821,  0.5813]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 38
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.504
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 38.301
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7940, 0.5835]], device='cuda:0')
# new data istensor([[0.3014, 0.3870]], device='cuda:0')
# g_theta2 istensor([[-0.3858,  1.4522],
#         [ 0.4675,  0.1366],
#         [ 0.3604,  0.1882]], device='cuda:0')
# p21val is 0.998488379246821
# pf12val is 0.934309927673608
# chi_f12 is 0.135894134903620
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.2612,  0.2791],
#         [-0.0263,  1.6028],
#         [ 0.7932,  0.5833]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 39
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.551
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 47.408
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7928, 0.5975]], device='cuda:0')
# new data istensor([[0.3315, 0.3771]], device='cuda:0')
# g_theta2 istensor([[ 1.2409,  0.2567],
#         [-0.1071,  1.6757],
#         [ 0.3795,  0.1642]], device='cuda:0')
# p21val is 0.397854524974481
# pf12val is 0.421281900865523
# chi_f12 is 1.728906142250489
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 2.6621, -1.5283],
#         [ 0.6327,  1.0073],
#         [ 0.7937,  0.5970]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 40
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.567
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 52.792
# expected info is tensor([[9.4711e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-10
# current sol istensor([[0.7874, 0.5948]], device='cuda:0')
# new data istensor([[0.2865, 0.3362]], device='cuda:0')
# g_theta2 istensor([[ 2.8422, -1.7190],
#         [ 0.5278,  1.1099],
#         [ 0.3680,  0.1503]], device='cuda:0')
# p21val is 0.162295466078478
# pf12val is 0.086047552392647
# chi_f12 is 4.905710401485059
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3197,  0.7997],
#         [ 0.0178,  1.8215],
#         [ 0.7875,  0.5946]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 41
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.594
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 66.478
# expected info is tensor([[5.8387e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-10
# current sol istensor([[0.7860, 0.4816]], device='cuda:0')
# new data istensor([[0.2868, 0.3948]], device='cuda:0')
# g_theta2 istensor([[-1.6662e-01,  7.7082e-01],
#         [-1.2801e-03,  1.7775e+00],
#         [ 3.4281e-01,  8.3683e-01]], device='cuda:0')
# p21val is 0.852110742589025
# pf12val is 0.839265956958881
# chi_f12 is 0.350455259893828
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2930,  1.9064],
#         [ 1.4705,  0.0763],
#         [ 0.7853,  0.4810]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 42
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.626
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 73.371
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7875, 0.5006]], device='cuda:0')
# new data istensor([[0.2948, 0.3846]], device='cuda:0')
# g_theta2 istensor([[-0.6835,  2.2856],
#         [ 1.2321, -0.0810],
#         [ 1.0527,  0.7444]], device='cuda:0')
# p21val is 0.976211481860593
# pf12val is 0.974859915438982
# chi_f12 is 0.050922989559163
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.6322, -0.5237],
#         [ 1.6652, -0.6158],
#         [ 0.7875,  0.5013]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 43
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.618
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 81.850
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7826, 0.5806]], device='cuda:0')
# new data istensor([[0.2968, 0.4036]], device='cuda:0')
# g_theta2 istensor([[ 1.7188, -0.5933],
#         [ 1.6610, -0.6234],
#         [ 1.1894,  0.3066]], device='cuda:0')
# p21val is 0.548406658123080
# pf12val is 0.523299694009533
# chi_f12 is 1.295201900673099
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0680,  1.7145],
#         [ 0.6192,  0.8990],
#         [ 0.7836,  0.5818]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 44
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.658
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 68.747
# expected info is tensor([[0.0024]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[0.7777, 0.3992]], device='cuda:0')
# new data istensor([[0.2793, 0.3751]], device='cuda:0')
# g_theta2 istensor([[-0.0618,  1.7207],
#         [ 0.4295,  1.0464],
#         [ 0.9702,  0.6677]], device='cuda:0')
# p21val is 0.889940589125219
# pf12val is 0.998894441902985
# chi_f12 is 0.002212339354336
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8386,  0.2732],
#         [-0.7214,  2.9000],
#         [ 0.7775,  0.4000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 45
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.680
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 90.361
# expected info is tensor([[0.0013]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[0.7681, 0.6292]], device='cuda:0')
# new data istensor([[0.2902, 0.3978]], device='cuda:0')
# g_theta2 istensor([[ 1.0998,  0.0197],
#         [-0.6538,  2.9436],
#         [ 1.1558,  0.6799]], device='cuda:0')
# p21val is 0.865811836881782
# pf12val is 0.452706248331692
# chi_f12 is 1.585023644536284
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.9239, -1.2769],
#         [-0.8484, -1.0648],
#         [ 0.7678,  0.6285]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 46
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.694
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 95.085
# expected info is tensor([[7.9545e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-10
# current sol istensor([[0.7701, 0.6373]], device='cuda:0')
# new data istensor([[0.2830, 0.3718]], device='cuda:0')
# g_theta2 istensor([[ 2.2316, -1.5736],
#         [-0.8848, -1.0971],
#         [ 1.0401,  0.3736]], device='cuda:0')
# p21val is 0.561393643094832
# pf12val is 0.676781008443216
# chi_f12 is 0.780815063789374
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.0259, -1.4424],
#         [-0.4316, -1.0553],
#         [ 0.7694,  0.6371]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 47
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.689
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 107.817
# expected info is tensor([[0.0011]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[0.7941, 0.5106]], device='cuda:0')
# new data istensor([[0.2865, 0.4164]], device='cuda:0')
# g_theta2 istensor([[ 1.0357, -1.5255],
#         [-0.6920, -1.3112],
#         [ 1.1582,  0.6564]], device='cuda:0')
# p21val is 0.954252906471808
# pf12val is 0.307412552208222
# chi_f12 is 2.359129230485576
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2244, -2.2380],
#         [-0.1167, -0.7546],
#         [ 0.7927,  0.5098]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 48
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.700
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 105.788
# expected info is tensor([[0.0015]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-7
# current sol istensor([[0.7992, 0.4716]], device='cuda:0')
# new data istensor([[0.2638, 0.4072]], device='cuda:0')
# g_theta2 istensor([[ 0.1691, -2.3105],
#         [-0.1873, -0.8417],
#         [ 1.0481,  0.7556]], device='cuda:0')
# p21val is 0.322428314552862
# pf12val is 0.176576188279579
# chi_f12 is 3.468005668214392
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0506,  0.8498],
#         [-0.9561,  0.0521],
#         [ 0.7989,  0.4737]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 49
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.723
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 110.327
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7970, 0.4583]], device='cuda:0')
# new data istensor([[0.2992, 0.3837]], device='cuda:0')
# g_theta2 istensor([[ 0.0561,  0.8404],
#         [-0.9960,  0.1789],
#         [ 1.0642,  0.7254]], device='cuda:0')
# p21val is 0.218891954716813
# pf12val is 0.919303326134919
# chi_f12 is 0.168278300004032
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.4337, 0.5862],
#         [1.7364, 0.7011],
#         [0.7966, 0.4559]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 50
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.740
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 118.126
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7981, 0.4601]], device='cuda:0')
# new data istensor([[0.2863, 0.3769]], device='cuda:0')
# g_theta2 istensor([[0.3297, 0.6872],
#         [1.8769, 0.8326],
#         [1.0814, 0.7232]], device='cuda:0')
# p21val is 0.463782741374438
# pf12val is 0.904021001100034
# chi_f12 is 0.201805375108913
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1257, -0.1538],
#         [ 0.2579,  0.1231],
#         [ 0.7981,  0.4607]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 51
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.713
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 124.804
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7716, 0.6382]], device='cuda:0')
# new data istensor([[0.2502, 0.3762]], device='cuda:0')
# g_theta2 istensor([[-0.0421,  0.0834],
#         [ 0.2796,  0.2152],
#         [ 1.1102,  0.4987]], device='cuda:0')
# p21val is 0.820088508826721
# pf12val is 0.043211183198652
# chi_f12 is 6.283311893788094
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.9960, 0.7227],
#         [0.1039, 0.1827],
#         [0.7702, 0.6390]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 52
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.746
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 127.961
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7642, 0.6660]], device='cuda:0')
# new data istensor([[0.3375, 0.3570]], device='cuda:0')
# g_theta2 istensor([[1.0967, 0.6096],
#         [0.1076, 0.1641],
#         [0.9952, 0.4166]], device='cuda:0')
# p21val is 0.352444737926727
# pf12val is 0.212067965353727
# chi_f12 is 3.101696928794731
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6333, 0.3070],
#         [1.1343, 0.6537],
#         [0.7628, 0.6658]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 53
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.761
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 141.900
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7606, 0.6597]], device='cuda:0')
# new data istensor([[0.3128, 0.4010]], device='cuda:0')
# g_theta2 istensor([[0.6255, 0.2912],
#         [1.1211, 0.6633],
#         [1.0156, 0.4262]], device='cuda:0')
# p21val is 0.998668505717516
# pf12val is 0.213462919641916
# chi_f12 is 3.088584279779025
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6755, 0.5038],
#         [0.5626, 0.3781],
#         [0.7612, 0.6611]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 54
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.779
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 139.070
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7571, 0.6660]], device='cuda:0')
# new data istensor([[0.2740, 0.4056]], device='cuda:0')
# g_theta2 istensor([[0.8147, 0.3525],
#         [0.5317, 0.2932],
#         [1.0086, 0.4349]], device='cuda:0')
# p21val is 0.981749788496161
# pf12val is 0.070026597433597
# chi_f12 is 5.317760291526927
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6194, 0.6197],
#         [0.6516, 0.2932],
#         [0.7562, 0.6660]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 55
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.794
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 151.015
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7601, 0.6569]], device='cuda:0')
# new data istensor([[0.2724, 0.3358]], device='cuda:0')
# g_theta2 istensor([[0.2928, 0.2862],
#         [0.5228, 0.2622],
#         [0.9860, 0.4369]], device='cuda:0')
# p21val is 0.996526622360293
# pf12val is 0.089746444154088
# chi_f12 is 4.821533743703363
# ...
# p21val is 0.140707789802678
# pf12val is 0.122322058000225
# chi_f12 is 4.202195785557965
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.2967, 0.0748],
#         [0.7036, 0.4457],
#         [0.7883, 0.4776]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 144
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.164
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 739.576
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7845, 0.4775]], device='cuda:0')
# new data istensor([[0.2666, 0.3587]], device='cuda:0')
# g_theta2 istensor([[0.3542, 0.2049],
#         [0.4400, 0.7104],
#         [1.0297, 0.7282]], device='cuda:0')
# p21val is 0.835945619632505
# pf12val is 0.196057588676772
# chi_f12 is 3.258693686257495
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.8503, 0.1404],
#         [1.7546, 0.8381],
#         [0.7852, 0.4761]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 145
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.159
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 821.482
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-8
# current sol istensor([[0.7879, 0.4590]], device='cuda:0')
# new data istensor([[0.2741, 0.4141]], device='cuda:0')
# g_theta2 istensor([[9.9830e-01, 6.4825e-04],
#         [1.7814e+00, 8.3334e-01],
#         [1.0298e+00, 7.1966e-01]], device='cuda:0')
# p21val is 0.042061874663966
# pf12val is 0.340529882783023
# chi_f12 is 2.154504791532155
# p_val_ftarget is 0.0
# new 2 points
# tensor([[1.3227, 0.5453],
#         [0.6334, 0.7398],
#         [0.7876, 0.4576]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 146
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.135
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 843.240
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7911, 0.4697]], device='cuda:0')
# new data istensor([[0.3041, 0.3992]], device='cuda:0')
# g_theta2 istensor([[1.0727, 0.5405],
#         [0.6250, 0.7535],
#         [1.0473, 0.7189]], device='cuda:0')
# p21val is 0.788337055238904
# pf12val is 0.597283231220371
# chi_f12 is 1.030727707876735
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6455, 0.6310],
#         [0.8864, 0.8061],
#         [0.7914, 0.4702]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 147
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.168
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 780.028
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7874, 0.4710]], device='cuda:0')
# new data istensor([[0.2930, 0.3519]], device='cuda:0')
# g_theta2 istensor([[0.5658, 0.7134],
#         [0.8235, 0.7561],
#         [1.0409, 0.7220]], device='cuda:0')
# p21val is 0.342521528216524
# pf12val is 0.171576557481151
# chi_f12 is 3.525451425351337
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.8981, 0.9880],
#         [0.7771, 0.3200],
#         [0.7885, 0.4698]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 148
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.168
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 758.159
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7881, 0.4905]], device='cuda:0')
# new data istensor([[0.2882, 0.3894]], device='cuda:0')
# g_theta2 istensor([[1.0073, 0.6869],
#         [0.9341, 0.1626],
#         [1.0392, 0.7280]], device='cuda:0')
# p21val is 0.491817751009496
# pf12val is 0.997446824095223
# chi_f12 is 0.005112881633649
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.7210, 0.0853],
#         [0.8029, 0.0977],
#         [0.7878, 0.4900]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 149
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.126
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 866.656
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7897, 0.4719]], device='cuda:0')
# new data istensor([[0.2883, 0.3907]], device='cuda:0')
# g_theta2 istensor([[0.7086, 0.0308],
#         [0.8863, 0.0519],
#         [1.0323, 0.7325]], device='cuda:0')
# p21val is 0.844678376473516
# pf12val is 0.986050319906820
# chi_f12 is 0.028095782586911
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8564,  0.5541],
#         [ 0.6108, -0.1886],
#         [ 0.7921,  0.4720]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 150
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.174
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 817.417
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7857, 0.4640]], device='cuda:0')
# new data istensor([[0.2625, 0.3527]], device='cuda:0')
# g_theta2 istensor([[1.0097, 0.7119],
#         [0.5275, 0.0887],
#         [1.0392, 0.7149]], device='cuda:0')
# p21val is 0.140859442990823
# pf12val is 0.111461335151395
# chi_f12 is 4.388155036326412
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.4732, 0.0822],
#         [0.6834, 0.3404],
#         [0.7847, 0.4634]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 151
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.174
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 840.187
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7883, 0.4679]], device='cuda:0')
# new data istensor([[0.2852, 0.3831]], device='cuda:0')
# g_theta2 istensor([[0.4704, 0.0909],
#         [0.4143, 0.0806],
#         [1.0419, 0.7257]], device='cuda:0')
# p21val is 0.787259643530823
# pf12val is 0.974074649795090
# chi_f12 is 0.052534671552791
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.7585, 0.4713],
#         [0.4037, 0.0320],
#         [0.7896, 0.4694]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 152
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.161
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 880.643
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7861, 0.4648]], device='cuda:0')
# new data istensor([[0.2924, 0.3862]], device='cuda:0')
# g_theta2 istensor([[1.0280, 0.7328],
#         [0.4365, 0.0946],
#         [1.0400, 0.7199]], device='cuda:0')
# p21val is 0.221942449522600
# pf12val is 0.925280992379500
# chi_f12 is 0.155315624109511
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3471, -0.0107],
#         [ 0.8152,  0.4836],
#         [ 0.7862,  0.4647]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 153
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.175
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 825.224
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7866, 0.4715]], device='cuda:0')
# new data istensor([[0.3125, 0.3845]], device='cuda:0')
# g_theta2 istensor([[0.3408, 0.1929],
#         [1.0413, 0.7141],
#         [1.0373, 0.7191]], device='cuda:0')
# p21val is 0.721084658370115
# pf12val is 0.389240422596841
# chi_f12 is 1.887116146663153
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0659, -0.1263],
#         [ 1.0588,  0.6927],
#         [ 0.7869,  0.4720]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 154
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.181
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 842.090
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7866, 0.4669]], device='cuda:0')
# new data istensor([[0.2970, 0.4131]], device='cuda:0')
# g_theta2 istensor([[ 0.0200, -0.0219],
#         [ 1.0311,  0.6661],
#         [ 1.0345,  0.7245]], device='cuda:0')
# p21val is 0.317829852659702
# pf12val is 0.395163982627142
# chi_f12 is 1.856908908677460
# p_val_ftarget is 0.0
# new 2 points
# tensor([[1.8739, 1.1297],
#         [0.1149, 0.0317],
#         [0.7859, 0.4679]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 155
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.174
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 903.104
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7874, 0.4625]], device='cuda:0')
# new data istensor([[0.2931, 0.4013]], device='cuda:0')
# g_theta2 istensor([[ 1.9178,  1.1651],
#         [ 0.0102, -0.0596],
#         [ 1.0414,  0.7203]], device='cuda:0')
# p21val is 0.795207225445638
# pf12val is 0.738321575397375
# chi_f12 is 0.606751620535019
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.5059, 0.2709],
#         [1.7191, 1.0727],
#         [0.7871, 0.4631]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 156
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.183
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 876.597
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7875, 0.4630]], device='cuda:0')
# new data istensor([[0.2866, 0.3891]], device='cuda:0')
# g_theta2 istensor([[0.3540, 0.1232],
#         [1.9648, 0.7852],
#         [1.0413, 0.7175]], device='cuda:0')
# p21val is 0.000252056884004
# pf12val is 0.997001560221360
# chi_f12 is 0.006005888210829
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 156
# Using CUDA for conduct_design_opti()
# Loss design: 876.549
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7875, 0.4626]], device='cuda:0')
# new data istensor([[0.2703, 0.3721]], device='cuda:0')
# g_theta2 istensor([[ 0.8832,  0.7532],
#         [-1.0702,  0.1900],
#         [ 1.0428,  0.7166]], device='cuda:0')
# p21val is 0.998625690199672
# pf12val is 0.544348396388862
# chi_f12 is 1.216331605157053
# p_val_ftarget is 0.0
# new 2 points
# tensor([[1.0173, 0.6415],
#         [0.9512, 0.2906],
#         [0.7888, 0.4637]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 157
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.182
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 906.834
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7870, 0.4622]], device='cuda:0')
# new data istensor([[0.2541, 0.3533]], device='cuda:0')
# g_theta2 istensor([[1.0352, 0.6625],
#         [1.0898, 0.1426],
#         [1.0422, 0.7189]], device='cuda:0')
# p21val is 0.947273103367346
# pf12val is 0.067930874680865
# chi_f12 is 5.378529279306019
# p_val_ftarget is 0.0
# new 2 points
# tensor([[1.1365, 0.7392],
#         [0.6899, 0.3989],
#         [0.7882, 0.4623]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 158
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.113
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1026.323
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7892, 0.4796]], device='cuda:0')
# new data istensor([[0.2794, 0.3571]], device='cuda:0')
# g_theta2 istensor([[1.0447, 0.6627],
#         [0.3535, 0.6821],
#         [1.0479, 0.7266]], device='cuda:0')
# p21val is 0.029441460625273
# pf12val is 0.295329738613703
# chi_f12 is 2.439325577712275
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.9316, 0.2860],
#         [1.4303, 0.7255],
#         [0.7884, 0.4796]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 159
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.189
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 901.297
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7833, 0.4449]], device='cuda:0')
# new data istensor([[0.2578, 0.3812]], device='cuda:0')
# g_theta2 istensor([[1.1196, 0.1046],
#         [1.5845, 0.8784],
#         [1.0198, 0.7145]], device='cuda:0')
# p21val is 0.875434445843751
# pf12val is 0.443841590262055
# chi_f12 is 1.624575117799274
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.7012, 0.5438],
#         [0.5236, 0.5117],
#         [0.7849, 0.4460]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 160
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.192
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 904.113
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7689, 0.3515]], device='cuda:0')
# new data istensor([[0.2775, 0.3844]], device='cuda:0')
# g_theta2 istensor([[0.5584, 0.6841],
#         [0.4227, 0.6032],
#         [0.9878, 0.6492]], device='cuda:0')
# p21val is 0.837073063983832
# pf12val is 0.715652505816155
# chi_f12 is 0.669121113806406
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.2584, 0.9140],
#         [0.9893, 0.1748],
#         [0.7690, 0.3494]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 161
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.189
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 953.287
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7865, 0.4580]], device='cuda:0')
# new data istensor([[0.2712, 0.3580]], device='cuda:0')
# g_theta2 istensor([[0.1958, 0.9699],
#         [1.1085, 0.1520],
#         [1.1136, 0.5847]], device='cuda:0')
# p21val is 0.928008080001080
# pf12val is 0.281672035415909
# chi_f12 is 2.534023759653055
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3581,  0.8242],
#         [ 1.3725, -0.0806],
#         [ 0.7855,  0.4581]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 162
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.184
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 984.210
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# log floor is-9
# current sol istensor([[0.7873, 0.4634]], device='cuda:0')
# new data istensor([[0.2849, 0.3953]], device='cuda:0')
# g_theta2 istensor([[ 0.4586,  0.6764],
#         [ 1.3195, -0.0648],
#         [ 1.0457,  0.7158]], device='cuda:0')
# p21val is 0.981286089091675
# pf12val is 0.916325182469538
# chi_f12 is 0.174767949221105
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8818,  0.2756],
#         [ 1.4729, -0.0753],
#         [ 0.7870,  0.4625]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# current sol istensor([[0.7873, 0.4634]], device='cuda:0')
# Success is False and failure is True after 163 iterations

# %%
print(lower_bound)
print(upper_bound)
print(f_target - 0.001)
print(f_target + 0.001)
print(pf1)
print(num_base_kernels)
print(vfield_(torch.tensor([0.8239, 0.5316]).reshape(1,2)))
# Out:
# tensor([[0.2834],
#         [0.3851]], grad_fn=<CopySlices>)
# tensor([[0.2871],
#         [0.3888]], grad_fn=<CopySlices>)
# tensor([[0.3370],
#         [0.4492]])
# tensor([[0.3390],
#         [0.4512]])
# tensor([[0.2852],
#         [0.3869]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# 5
# tensor([[0.3322, 0.3349]])

# %% [markdown]
# # Plotting model validation strategy

# %%
sns.set_style('ticks')
#plt.rcParams["pdf.use14corefonts"] = True
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
p21_vec_plot = p21_vec.detach()[1:]
f, ax = plt.subplots(1, 1, figsize=(14, 14))
#ax.plot(np.array(range(2,iter+2)), torch.log(entropy_vec_plot), '+-')
#print(p21_vec_plot)
ax.plot(p21_vec_plot,'s',color = 'blue', markersize=6)
ax.axhline(.01,linestyle = '--',color = 'red', markersize=12, alpha = 1.0)
ax.set_xlim(-0.3, p21_vec_plot.shape[0])
ax.set_ylim(-0.3, 1.)
#ax.set_yscale('log')
plt.xticks(np.arange(0, iter+7, step=5.))
ax.tick_params(labelsize='small', width=3)
ax.set_xlabel('# of Model Checks')
ax.set_ylabel('p-value')
ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.05, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(1.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.02, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(0.1,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.26, 0.34), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(6.2,        #x start point
             0.14,                      #y start point
             0,       #change in x 
             -0.07,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 



ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.29, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(7.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.57, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(14.15,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.69, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(17.18,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################



# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.32, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(10.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color

# ############################

# ############################
# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.33, 0.34), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(11.25,        #x start point
#              0.14,                      #y start point
#              0,       #change in x 
#              -0.07,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# #################################################

# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.38, 0.1), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(12.25,        #x start point
#              -0.15,                      #y start point
#              0,       #change in x 
#              0.1,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color





################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.38, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(13.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.55, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(18.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')  
# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.49, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(17.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.55, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(19.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.94, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(33.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ################################

ax.annotate('Threshold Line ($y = 0.01$)', xy=(1.0,0.01), xytext=(6,0), color='red', 
                xycoords = ax.get_yaxis_transform(), textcoords="offset points",
                size=14, va="center")


#ax.legend(['p-value'], loc = 'upper left', fontsize = 30)
plt.savefig('figures/qvalue_base_ootol_005.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plotting expected value and data fit term

# %%
sns.set_style('ticks')
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 8), tight_layout=True)

ax1.plot(np.array(range(1,iter+2)), (entropy_vec_plot.cpu()), '--o', color = 'blue', markersize=12)
#ax1.set_yscale('log')
# ax.plot(np.array(data_fit_vec_plot), (entropy_vec_plot), 'o')
#ax1.set_yscale('log')

ax2.plot(np.array(range(1,iter+2)), data_fit_vec_plot.cpu(), '--o', color = 'red', markersize=12)
#ax2.set_ylim(-10, 600)
ax1.set_xlabel('Iteration #', size=32)
ax2.set_xlabel('Iteration #', size=32)
ax1.set_ylabel('Expected Information (logscale)', size = 32)
ax2.set_ylabel('Log-Gaussian Term', size = 32)
ax1.set_xticks(np.arange(0, iter+3, step=15.))
ax2.set_xticks(np.arange(0, iter+3, step=15.))
plt.savefig('figures/exp_info/expectedinfo_log_vs_datafit_2_base_ootol_005.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Saving all data needed for plots

# %%
np.savetxt('data_plots/vec_x_success_base_ootol_005.txt',vec_x.cpu().detach().numpy())
np.savetxt('data_plots/g_theta2_success_base_ootol_005.txt', g_theta2.cpu().detach().numpy())
np.savetxt('data_plots/g_theta1_success_base_ootol_005.txt', g_theta1.cpu().detach().numpy())
np.savetxt('data_plots/x_train_ini_success_base_ootol_005.txt', x_train.cpu().detach().numpy())
np.savetxt('data_plots/y_train_ini_success_base_ootol_005.txt', y_train.cpu().detach().numpy())
np.savetxt('data_plots/entropy_vec_success_base_ootol_005.txt', entropy_vec_plot.cpu().detach().numpy())
np.savetxt('data_plots/datafit_success_base_ootol_005.txt', data_fit_vec_plot.cpu().detach().numpy())
np.savetxt('data_plots/p21_vec_success_base_ootol_005.txt',p21_vec_plot.cpu().detach().numpy())
np.savetxt('data_plots/loss_success_base_ootol_005.txt',loss.cpu().detach().numpy())
np.savetxt('data_plots/pf1_success_base_ootol_005.txt',pf1.cpu().detach().numpy())
np.savetxt('data_plots/Qf1_success_base_ootol_005.txt',Qf1.cpu().evaluate().detach().numpy())
np.savetxt('data_plots/Qf12_success_base_ootol_005.txt', Qf12.cpu().evaluate().detach().numpy())
np.savetxt( 'data_plots/Q21_success_base_ootol_005.txt', Q21.cpu().evaluate().detach().numpy())
#np.savetxt('data_plots/iter_success.txt', iter+1)

# %%
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2),2)
torch.save(v2, 'data_plots/v2_success_base_ootol_005.txt')

# %%
print(v2.shape)
# Out:
# torch.Size([495, 2])

# %% [markdown]
# # Plots for vizualization

# %%
fig, ax = plt.subplots(figsize = (14,14))
ax.set_xlim(-3.1, 3.2)
ax.set_ylim(-3.1, 3.2)
#ax.scatter(g_theta1[:, 0].detach(),g_theta1[:, 1].detach(), c="b", alpha=0.8)
ax.plot(g_theta1[:, 0].cpu().detach(),g_theta1[:, 1].cpu().detach() , 'o', color = 'blue',markersize=15, alpha = 0.2)
ax.plot((vec_x[-1,0]).cpu(), (vec_x[-1,1]).cpu(),'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)
ax.set_title('Final TAD configuration', fontsize = 40)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.legend(['1-points', 'TAD Candidate', 'Target'])
plt.savefig('figures/strategies/tad_sol_all_2_base_ootol_005.pdf')
plt.show()
# Out:
# /var/tmp/pbs.1778776.polaris-pbs-01.hsn.cm.polaris.alcf.anl.gov/ipykernel_53319/2470320733.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "gd" (-> color='g'). The keyword argument will take precedence.
#   ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)

# %%
print(g_theta1.shape[0])
# Out:
# 653

# %% [markdown]
# ##

# %%
vec_x = vec_x.detach()
#v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)
ii = 0
low = -3.2
high = 3.2
########################
f, ax = plt.subplots(1, 1, figsize=(14, 14))
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)
ax.plot((vec_x[ii,0]).cpu(), (vec_x[ii,1]).cpu(),'v', color = 'red',markersize=15)
ax.plot(x_train.cpu().detach()[:,0], x_train.cpu().detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.cpu().detach()[ii:ii+loc_size+1,0], v2.cpu().detach()[ii:ii+loc_size+1,1], 'o', color = 'blue', markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Initial Configuration', fontsize = 40)
ax.legend(['Target', 'Initial Target Candidate', 'Initial 1-sample','Initial 2-sample'])

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures/evol_solTAD/evol_sol_ini_2_base_ootol_005.pdf')

# %%
vec_x = vec_x.detach().cpu()
v2 = g_theta2_vec.cpu().reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)

low = -3.2
high = 3.2
#for iter_plt n range(1,iter):
iter_plt = 74
ii = 3 + (iter_plt - 1) * (loc_size + 1)
#######################

 
###########

f, ax = plt.subplots(1, 1, figsize=(14,14))

#ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 'bv', markersize=8)
for i in range(1, iter_plt):
    ax.plot(vec_x[i-1:i,0], vec_x[i-1:i,1],'v', color = 'red', markersize=15, alpha=0.2, label = '_nolegend_')
    
ax.plot(vec_x[0:iter_plt,0], vec_x[0:iter_plt,1],'v', color = 'red', markersize=15, linewidth=15, alpha= 0.2)
#ax.plot(g_theta1.detach()[:,0], g_theta.detach()[:,1], 'bv', markersize=8)
ax.plot(v2.detach()[0:ii,0], v2.detach()[0:ii,1], 's', color = 'blue', markersize=15,alpha=0.2)
ax.plot(x_train.cpu().detach()[:,0], x_train.cpu().detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'o',color = 'blue' , markersize=15)
ax.plot(0.8731, 0.5664,'gd',markersize=15)
ax.plot(vec_x[iter_plt,0], vec_x[iter_plt,1],'v', color = 'red',markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Iteration '+str(iter_plt), fontsize = 40)
#ax.set_title('Final Configuration')
ax.legend([ 'Previous Target Candidates', 'Previous 2-samples', 'Initial 1-sample','Current 2-sample', 'Target', 'Current Target Candidate'], fontsize = 30)

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures/evol_solTAD/evol_sol_base'+str(iter_plt)+'_final_ootol_005.pdf')

# %%
print(g_theta2_vec.shape)
# Out:
# torch.Size([990])

# %%
sleep
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 sleep
#
# NameError: name 'sleep' is not defined

# %% [markdown]
# # Grid Sampling

# %%
def conduct_design_pll(x0,f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    #g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        #print(g_theta)
        loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood, noise_value)
        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood ,noise_value)
    #loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
   # print(optimizer.state_dict())
    print(x_d)
    return x_d, lower_bound, upper_bound

# %%
x_plot = np.linspace(vf.low, vf.high, 15)
y_plot = np.linspace(vf.low, vf.high, 15)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n

g_theta_grid = x_concat
agg_data1_grid = vfield_(g_theta_grid)
agg_data1_grid = agg_data1_grid.flatten()


x0 = Tensor(np.array([-2.,2.])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_grid = Tensor(np.array([0.0,0.0])) 
vec_x_grid = vec_x_grid.reshape(1,2)

lr_new = 1.

SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')
model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)

print('END HYPERPARAMETERS optimization')
model_grid.eval()
likelihood_grid.eval()
x0_new_grid,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_grid, agg_data1_grid, model_grid, likelihood_grid, iter_design, iter_param, lr_new,noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
#loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_grid)
print(SUCCESS)

# %%
x0_grid = x0_new.detach()
fig, ax = plt.subplots(figsize = (14,14))
ax.plot(x_concat[:,0],x_concat[:,1], 's', color = 'blue', markersize=15, alpha = 0.2)
ax.plot(x0_new_grid.detach()[0,0], x0_new_grid.detach()[0,1],'v',color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Grid Solution', fontsize = 40)

plt.savefig('figures/strategies/grid_sol_2_base.pdf')

# %% [markdown]
# # Random sampling

# %%
# iter_hp = 30
# iter_design = 40 
# iter_param = 50
# num_base_kernels = 3

# f_target = Tensor(vf.tgt_vec) 
# f_target = f_target.reshape(f_target.shape[0],1) 
# tol_vector = 0.005 * torch.ones(f_target.shape)


loc_size_rdn = math.ceil(g_theta1.shape[0]) #(iter)*(loc_size+1) + sample_size

loc_sample = high_minus_low  * np.random.random_sample((loc_size_rdn,2)) + vf.low #np.random.random_sample((loc_size_rdn,2))
g_theta_ = (Tensor(loc_sample).clone())
agg_data1 = vfield_(g_theta_)
agg_data1 = agg_data1.flatten()


x0 = Tensor(np.array([-2.0,2.0])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_rdn = Tensor(np.array([0.,0.])) 
vec_x_rdn = vec_x_rdn.reshape(1,2)

lr_new = 1.


SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')

model_rdn, likelihood_rdn = hyper_opti(g_theta_,agg_data1,iter_hp,num_base_kernels,noise_value)




print('END HYPERPARAMETERS optimization')
model_rdn.eval()
likelihood_rdn.eval()
x0_new_rdn,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_, agg_data1, model_rdn, likelihood_rdn, iter_design, iter_param, lr_new, noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_rdn)
print(SUCCESS)
sol_rdn = x0_new_rdn

# %%
np.savetxt('data_plots/sol_rdn_success_base.txt', sol_rdn.detach().numpy())
np.savetxt('data_plots/sol_grid_success_base.txt', x0_new_grid.detach().numpy())
np.savetxt('data_plots/g_theta_rdn_success_base.txt', g_theta_.detach().numpy())
#np.savetxt('data_plots/g_theta_grid_success.txt', x_concat.detach().numpy)

# %%
print(g_theta1.shape)

# %%
fig, ax = plt.subplots(figsize = (14,14))

ax.plot(g_theta_[:,0].detach(),g_theta_[:,1].detach(), 's', color = 'blue',markersize=15, alpha = 0.2)
ax.plot(sol_rdn.detach()[0,0], sol_rdn.detach()[0,1],'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$', fontsize = 32)
ax.set_ylabel('$d_2$', fontsize = 32)
ax.set_title('Uniformly Random Solution', fontsize = 40)

plt.savefig('figures/strategies/rdn_sol_2_base.pdf')

# %% [markdown]
# # Vizualizing Means and Variances

# %%
import matplotlib.ticker
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
             self.format = r'$\mathdefault{%s}$' % self.format

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)

model.eval()

likelihood.eval()

#noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
#print(x_concat_)
with torch.no_grad(), gpytorch.settings.fast_pred_var(True):
    pred = GPprediction(model)
    pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
    #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
    pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
    mean_v_1 = pr_mean[:,0].reshape(n,n)
    mean_v_2 = pr_mean[:,1].reshape(n,n)
    pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T
    
    var_v_1 = pred_var[:,0].reshape(n,n)
    var_v_2 = pred_var[:,1].reshape(n,n)
#     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

# #     print(pr.covariance_matrix.mean(axis=0))
# #     print(AA)
# #     print(pr.variance)
# #     print((pr.covariance_matrix))
# #     K = model.covar_module
#     print((cov.diag()))
#     print(pr_mean)


fig, (ax1, ax2) = plt.subplots(2, 2, figsize = (28, 24), tight_layout=True)
diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
cs10 = ax1[0].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(0, 1.1, 100), cmap = 'jet')
ax1[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[0].set_title('$|v_1 - \mu(v_1)|$', fontsize = 40)
cbar10 = fig.colorbar(cs10, ax = ax1[0],format=OOMFormatter(0, mathText=False));

ax1[0].set_xlabel('$d_1$')
ax1[0].set_ylabel('$d_2$')
diff_mean_v1 = torch.abs(v_1 - mean_v_1.detach())/torch.sqrt(var_v_1)
#print(var_v_1)
cs11 = ax1[1].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(diff_mean_v1.min(), diff_mean_v1.max(), 100), cmap = 'jet')
ax1[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[1].set_title('$|v_1 - \mu(v_1)|/\sigma(v_1)$', fontsize = 40)
# ax1[0].set_aspect('equal')
# ax1[1].set_aspect('equal')
cbar11 = fig.colorbar(cs11, ax = ax1[1],format=OOMFormatter(0, mathText=False));
ax1[1].set_xlabel('$d_1$')
ax1[1].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())
cs20 = ax2[0].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(0, 1.1, 100), cmap = 'jet')
ax2[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[0].set_title('$|v_2 - \mu(v_2)|$', fontsize = 40)
cbar20 = fig.colorbar(cs20, ax = ax2[0],format=OOMFormatter(0, mathText=False));
ax2[0].set_xlabel('$d_1$')
ax2[0].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())/torch.sqrt(var_v_2)
cs21 = ax2[1].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(diff_mean_v2.min(), diff_mean_v2.max(), 100), cmap = 'jet')
ax2[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[1].set_title('$|v_2 - \mu(v_2)|/\sigma(v_2)$', fontsize = 40)
cbar21 = fig.colorbar(cs21, ax = ax2[1],format=OOMFormatter(0, mathText=False));
ax2[1].set_xlabel('$d_1$')
ax2[1].set_ylabel('$d_2$')


# ax2[0].set_aspect('equal')
# ax2[1].set_aspect('equal')

plt.savefig('figures/mean_var/mean_final_2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)
plot = [1, 6, 10, iter+1]

for ii in plot:
    try:
        
        PATH = ".//checkpoints/model_goodmodel/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
    except:
        PATH = ".//checkpoints/model_update/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
        
    #model_16 = torch.load(PATH)
    model_16.eval()

    likelihood.eval()

    #noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
    #print(x_concat_)
    with torch.no_grad(), gpytorch.settings.fast_pred_var(False):
        pred = GPprediction(model_16)
        pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
        #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
        pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
        mean_v_1 = pr_mean[:,0].reshape(n,n)
        mean_v_2 = pr_mean[:,1].reshape(n,n)
        pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T

        var_v_1 = pred_var[:,0].reshape(n,n)
        var_v_2 = pred_var[:,1].reshape(n,n)
    #     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

    # #     print(pr.covariance_matrix.mean(axis=0))
    # #     print(AA)
    # #     print(pr.variance)
    # #     print((pr.covariance_matrix))
    # #     K = model.covar_module
    #     print((cov.diag()))
    #     print(pr_mean)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (28, 12), tight_layout=True)
    diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
    minn = torch.min(var_v_1.detach().min(), var_v_2.detach().min())
    maxx = torch.min(var_v_1.detach().max(), var_v_2.detach().max())

    cs11 = ax1.contourf(xv_plot, yv_plot, var_v_1.detach(), np.linspace(0.0,1.1, 100), cmap = 'jet')
    ax1.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    
    ax1.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
  
    ax1.set_title('$\sigma^2(v_1)$ (Iteration '+str(ii)+')', fontsize = 40)
    # ax1[0].set_aspect('equal')
    # ax1[1].set_aspect('equal')
    cbar11 = fig.colorbar(cs11, ax = ax1,format=OOMFormatter(-0, mathText=False));
    ax1.set_xlabel('$d_1$')
    ax1.set_ylabel('$d_2$')


  


    cs21 = ax2.contourf(xv_plot, yv_plot, var_v_2.detach(), np.linspace(0.0, 1.1, 100), cmap = 'jet')
    ax2.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
    ax2.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    ax2.set_title('$\sigma^2(v_2)$ (Iteration '+str(ii)+')', fontsize = 40)
    cbar21 = fig.colorbar(cs21, ax = ax2,format=OOMFormatter(-0, mathText=False));
    ax2.set_xlabel('$d_1$')
    ax2.set_ylabel('$d_2$')


    # ax2[0].set_aspect('equal')
    # ax2[1].set_aspect('equal')

    plt.savefig('figures/mean_var/var_iter_base'+str(ii)+'.pdf', dpi=300, bbox_inches='tight')
    plt.show()

# %%
print(g_theta1.shape[0])

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# # #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
# #                     #loc_size = 4
# # loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# # loc_sample0 = loc_sample.reshape(2 + 1, 2)
# # g2 = loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# z = torch.zeros(n*n, 1)
# for ii in range(n*n):
#     print(ii)
#     x0 = x_concat_[ii,:].reshape(1,2)
#     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#                     #loc_size = 4
#     loc_sample = dis_2sample.sample((2 + 1,))
#     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#     g2 = loc_sample0 #Tensor(loc_sample) #.detach()
    
    
    
#     x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21 = conduct_2opt(agg_data,f_target,x0, g_theta1, model, likelihood, noise_value, g2, training_param_iter)
#     z[ii] = loss2
# z = z.reshape(n,n)

# %%
print(g_theta1.shape)

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
#                     #loc_size = 4
# loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# loc_sample0 = loc_sample.reshape(2 + 1, 2)
# g2 = g_theta2.detach() #loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# plot = [1, 7, 17, 26]
# zz = torch.zeros(n*n, 4)
# kk = 0
# for jj in plot:
#     try:
        
#         PATH = ".//checkpoints/model_goodmodel/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#     except:
#         PATH = ".//checkpoints/model_update/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#    # model_16 = torch.load(PATH)
#     model_16.eval()

#     likelihood.eval()
#     g2 = v2.detach()[jj - 1 +loc_size+1 : jj - 1 +loc_size+1 +loc_size+1]
#     g_theta1_cur = g_theta1[0:(4 + (jj - 1)* 3)]
#     agg_data_cur = agg_data[0:2 * (4 + (jj - 1)* 3)]
#     print(agg_data_cur.shape)
#     for ii in range(n*n):
#         print(ii)
#         x0 = x_concat_[ii,:].reshape(1,2)
#     #     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#     #                     #loc_size = 4
#     #     loc_sample = dis_2sample.sample((2 + 1,))
#     #     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#         #g2 = loc_sample0 #Tensor(loc_sample) #.detach()


        
#         loss2_, pf1_, Qf1_, Qf12_, data_fit_, Q21_ = likelihood.get_ell(agg_data_cur,f_target,x0, g_theta1_cur, model_16, likelihood, noise_value, g2)
#         zz[ii, kk] = loss2_
#     kk = kk+1
# zz = zz.reshape(n,n, 4)
# torch.save(zz.detach(), 'data_plots/zz_success.txt')

# %%
# #plot = [1, 5, 10, 20]

# for jj in range(4):
#     fig, ax = plt.subplots(figsize = (16,14))
#     #
#     cs = ax.contour(xv_plot, yv_plot,  zz[:,:,jj].detach(), np.linspace( zz[:,:,jj].detach().numpy().min(), zz[:,:,jj].detach().numpy().max(), 1000), cmap = 'jet')
#     cbar = fig.colorbar(cs, ax = ax,format=OOMFormatter(0, mathText=False));
#     ax.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
#     kk = plot[jj]
#     if kk < plot[3]:
#         ax.plot(vec_x[kk,0], vec_x[kk,1],'o', color = 'black',markersize=12)
#     if kk == plot[3]:
#         ax.plot(vec_x[- 1,0], vec_x[- 1,1],'o', color = 'black',markersize=12)
#     ax.set_title('TAD Acquisition Function (Iteration '+str(kk)+')', fontsize = 40)
#     ax.set_xlabel('$d_1$')
#     ax.set_ylabel('$d_2$')
    
#     plt.savefig('figures/tad_obj'+str(kk)+'.pdf', dpi=300, bbox_inches='tight')

# %%
p21_vec_plot

# %%
math.floor(torch.log(entropy))

# %%
torch.log10(Tensor([0.009]))
