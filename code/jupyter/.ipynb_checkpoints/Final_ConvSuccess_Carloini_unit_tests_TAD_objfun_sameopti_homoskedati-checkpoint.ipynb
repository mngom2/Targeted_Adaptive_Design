# %%
import math
import torch
from torch import nn
from torch import Tensor
from torch.nn  import functional as F
import gpytorch
from matplotlib import pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
import matplotlib.cm as cm
import matplotlib.patches as patches
from mpl_toolkits.mplot3d import Axes3D 
import sys
from decimal import Decimal
from IPython.display import clear_output
sys.path.append("..")
from LBFGS import FullBatchLBFGS
from kernels import vvkernels as vvk, sep_vvkernels as svvk, vvk_rbfkernel as vvk_rbf
from means import vvmeans as vvm
from likelihood import vvlikelihood as vvll
from mlikelihoods import MarginalLogLikelihood as exmll
from predstrategies import GPprediction
from utils import ObjFun, get_vertices, stopping_criteria
from scipy import stats
import numpy as np
import seaborn as sns
import scipy
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # If model is bad, initialize at previous 2 sample!!!

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=40)     # fontsize of the axes title
plt.rc('axes', labelsize=32)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=32)    # fontsize of the tick labels
plt.rc('ytick', labelsize=32)    # fontsize of the tick labels
plt.rc('legend', fontsize=32)    # legend fontsize
plt.rc('font', size=32)          # controls default text sizes

# %% [markdown]
# # Objective function
#
# We sample from $$V_1(x_1, x_2) = 3(1 - x_1)^2 e^{-x_1^2 - (x_2 +1)^2} - 10 (x_1/5 - x_1 ^3 - x_2^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- (x_1 + 2) ^2 - x_2^2} + 0.5(2x_1 + x_2)$$
# $$V_2(x_1, x_2) = 3(1 +x_2)^2 e^{-x_2^2 - (x_1 +1)^2} - 10 (-x_2/5 + x_2 ^3 + x_1^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- ( 2- x_2) ^2 - x_1^2} + 0.5(2x_1 + x_2)$$
#
# where $(x_1, x_2) \in [-3, 3]^2$

# %%
torch.set_default_dtype(torch.float64)

# %%
vf = ObjFun()
f_target = vf.tgt_vec
print(f_target)
sample_size = 15
D = vf.D
N = vf.N

vf.low = -3.
vf.high = 3.

high_minus_low = vf.high- vf.low
#high_minus_low = -
def g_theta(sample_size, D):
    loc_x = (2. - 1.0)  * np.random.random_sample((sample_size,1)) +1.0
    
    loc_y = (2. - 1.5)  * np.random.random_sample((sample_size,1)) -1.5
    loc = np.concatenate((loc_x, loc_y), 1)
    #loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0 #0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    out = torch.zeros(x.shape[0], N)
    
    out = vf(x[:,0], x[:,1]) + torch.randn(Tensor(vf(x[:,0], x[:,1])).size()) * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([0.3380, 0.3502], dtype=torch.float32)
# tensor([[ 1.6296, -1.3337],
#         [ 1.0085, -1.3141],
#         [ 1.6907, -1.2356],
#         [ 1.5435, -1.0891],
#         [ 1.5832, -1.3350],
#         [ 1.0341, -1.2968],
#         [ 1.9586, -1.1007],
#         [ 1.7169, -1.1242],
#         [ 1.8846, -1.2273],
#         [ 1.4385, -1.3768],
#         [ 1.1399, -1.3115],
#         [ 1.8467, -1.3847],
#         [ 1.6397, -1.0228],
#         [ 1.9800, -1.0364],
#         [ 1.6476, -1.2977]])

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
x_plot = np.linspace(vf.low, vf.high, 30)
y_plot = np.linspace(vf.low, vf.high, 30)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
out_plot = vfield_(x_concat)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(26, 10), tight_layout=True)
v_1 = out_plot[:,0].reshape(n,n)
v_2 = out_plot[:,1].reshape(n,n)


#pos = ax1.imshow(v_1, cmap='RdGy', interpolation='none')

cs1 = ax1.contourf(xv_plot, yv_plot,v_1, np.linspace(v_1.min(), v_1.max(), 100),cmap='jet')
ax1.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'ks', markersize=15)
#cs11 = ax1.contour(xv_plot, yv_plot, v_1,np.linspace(v_1.min(), v_1.max(), 30),colors='w')
ax1.set_title('$v_1$')
ax1.set_xlabel('$d_1$')
ax1.set_ylabel('$d_2$')


cbar1 = fig.colorbar(cs1, ax = ax1);

cs2 = ax2.contourf(xv_plot, yv_plot,v_2, np.linspace(v_2.min(), v_2.max(), 100),cmap='jet')
ax2.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'ks', markersize=15)
#cs11 = ax1.contour(xv_plot, yv_plot, v_1,np.linspace(v_1.min(), v_1.max(), 30),colors='w')
ax2.set_title('$v_2$')
ax2.set_xlabel('$d_1$')
ax2.set_ylabel('$d_2$')

cbar2 = fig.colorbar(cs2, ax = ax2);

plt.savefig('figures/target_fun.pdf')
plt.show()

# %% [markdown]
# ## GP model initialization
# We inialize the GP model following https://docs.gpytorch.ai/en/stable/examples/03_Multitask_Exact_GPs/Multitask_GP_Regression.html

# %%
x_train = train_x #loc #torch.linspace(0, 1, 10)
y_train = train_y #v  #torch.stack([torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,torch.cos(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,], -1)

class MultitaskGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood,num_base_kernels):
        super(MultitaskGPModel, self).__init__(train_x, train_y, likelihood)
        a = torch.ones(2,2)
        chol_q = torch.tril(a)
        self.mean_module = vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)  #vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)#vvm.TensorProductSubMean(gpytorch.means.ConstantMean(), num_tasks = 2)  # 
        base_kernels = []
        for i in range(num_base_kernels):
            base_kernels.append(gpytorch.kernels.ScaleKernel(( gpytorch.kernels.RBFKernel() ))) #gpytorch.kernels.PolynomialKernel(4)  ##gpytorch.kernels.MaternKernel()# (vvk_rbf.vvkRBFKernel())
 
            
        self.covar_module = svvk.SepTensorProductKernel(base_kernels,num_tasks = 2)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal(mean_x, covar_x)

# %% [markdown]
# # Hyperparamaters oprimization

# %%
# # ###hyperparameters optimization###
def hyper_opti(g_theta1, agg_data, training_iter,num_base_kernels,noise_value, current_model = None, current_likelihood = None):
    noises = torch.ones(agg_data.shape[0]) * (noise_value) #  torch.zeros(agg_data.shape[0]) # 
    noises = noises.reshape(g_theta1.shape[0], 2)
    
#     if (current_model is not None):
#         likelihood = current_likelihood #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises)  #

#         model = current_model#.get_fantasy_model(g_theta1, agg_data) #MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
#         model.set_train_data(g_theta1, agg_data,  strict=False)
#     else:
#         likelihood = vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2)#vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #
#         model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
        
    likelihood =  vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2) #
    model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
    model.double()
    likelihood.double()


    model.train()
    
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(),  lr=0.1) #, weight_decay=0.001)  # Includes GaussianLikelihood parameters
    mll = exmll(likelihood, model)

    for i in range(training_iter):
        optimizer.zero_grad()

        loss, chi_square = mll(agg_data,g_theta1, model, likelihood, noise_value)
        loss = -1. * loss
#         print('df is %.3f' %agg_data.shape[0] +'and chi_square %.3f' %chi_square) 
        #print('loss is %.3f' %loss)
        df = agg_data.shape[0]
        chi_square = chi_square.clone().detach()
        
        p_val = 1. - stats.chi2.cdf(chi_square, df)
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
       # print(p_val)
#         if (p_val > 0.99999):
#             return model, likelihood


    
        
    print('loss is %.3f' %loss)
#     for params in model.named_parameters():
#         print(params)
    return model, likelihood

# %% [markdown]
# # Design parameters and sampling point optimization

# %%
# def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):
#     g_theta2 = nn.Parameter(Tensor(loc_sample))

#     x_d= nn.Parameter(Tensor(x0))
#     #optimizer = torch.optim.LBFGS(list([g_theta2,x_d]), lr= .000001, max_iter = 100,line_search_fn="strong_wolfe")  #
    
#     optimizer = FullBatchLBFGS(list([g_theta2,x_d]), lr=.001)
#     def closure():
#         optimizer.zero_grad()
        
#         loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, noise_value, g_theta2)
        
#         loss2 = -1. * loss2

       

       
#         return loss2
        
#     loss2 = closure()
#     loss2.backward()
#     #fail = False
#     for i in range(training_design_iter):
#         options = {'closure': closure, 'current_loss': loss2, 'max_ls': 10}
#         loss2, _, _, _, _, _, _, fail = optimizer.step(options)
#         #print('design Iter %d/%d - Loss: %.3f' %(i + 1, training_design_iter, loss2.item()))
  
#         if fail:
#             print('Convergence reached!')

#             break
            
    
    

  
#     loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, noise_value, g_theta2)
#     loss2 = -1. * loss2
#     print('Loss design: %.3f' % ( loss2))
#     #print(x_d)
#     return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %%
def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': g_theta2, 'lr': 0.001},{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, noise_value, g_theta2)

        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, noise_value, g_theta2)
    loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
    #print(x_d)
    return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %%
# from functools import partial
# def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):
    
#     fun = partial(likelihood.get_ell, agg_data,f_target, g_theta1, model, likelihood, noise_value)
#     def tad_obj(samples):
#         loss2, pf1, Qf1, Qf12, data_fit, Q21 = fun(samples)
#         return -loss2.detach().numpy()
    
    
#     sample0 = torch.cat([x0, loc_sample], 0)
#     print(sample0)
#     #print(sample0.shape)
#     res = scipy.optimize.minimize(tad_obj, sample0)#, method='nelder-mead')
#     sample_opt = res.x
#     loss2, pf1, Qf1, Qf12, data_fit, Q21 = fun(sample_opt)
#     loss2 = -1. * loss2
#     print('Loss design: %.3f' % ( loss2))

#     x_d = sample_opt[0:g_theta1.shape[1]]
#     x_d = Tensor(x_d.reshape(math.ceil(x_d.shape[0]/g_theta1.shape[1]), g_theta1.shape[1]))
#     g_theta2 = sample_opt[g_theta1.shape[1]:]
#     g_theta2 = Tensor(g_theta2.reshape(math.ceil(g_theta2.shape[0]/g_theta1.shape[1]), g_theta1.shape[1]))
#     return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %% [markdown]
# # Conducting the TAD experiment

# %%
loc_size = 2
#loc_sample0 = Tensor((2. - 1.5)  * np.random.random_sample((loc_size,2)) + 1.5)

x0 = Tensor(np.array([-1.,-1.])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
x0 = x0.reshape(1,2)
print(x0)

dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= 0.1 * torch.eye(loc_size) )
                    #loc_size = 4
loc_sample = dis_2sample.sample((loc_size,))

loc_sample0 = loc_sample.reshape(loc_size, 2)
# Out:
# tensor([[-1., -1.]])

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 200
iter_param = 200
num_base_kernels = 1
max_iter = 50


f_target = f_target.reshape(2,1) 
tol_vector = 0.01 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten()

data_fit_vec = torch.empty((1,1))
entropy_vec = torch.empty((1,1))




 #
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])

lr_new = .01

    
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False
while(SUCCESS == False and FAILURE == False):
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None



        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)


        print('END HYPERPARAMETERS optimization')
    
    model.eval()
    likelihood.eval()
   
    loc_sample_old = loc_sample.clone()
    x0_old = x0.clone()
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
  
    cur_model = model
    cur_likelihood = likelihood
    
  
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])
#     d = torch.sqrt(gpytorch.inv_quad(Qf1, f_target - pf1))
#     print(d)
    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
    
    
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    
    print('expected info is '+str(entropy))
    print('mohabb disatance is' + str(Qf12.inv_quad(f_target - pf1)))
    if not SUCCESS:
    
    #var_vec[iter] = var
        
        

         #np.random.random_sample((loc_size,2))

        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape))
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value)
               
                #Qf12 = Qf12 + 
                chi_f12 = (Qf12 + noise_value*torch.eye(Qf12.shape[0])).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape))
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    x0 = x0_old #x0_new.detach() #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    sum = torch.zeros(2, 2)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0.detach()).t(), (g_theta2.detach()[i] - x0.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
#                         entropy_vec = torch.cat([entropy_vec, entropy], 0)
#                         data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        #iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is' + str(num_base_kernels))
    #                         x0 = x0_old.detach()
                       # loc_sample = loc_sample_old
# #                         loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#                         agg_data = agg_data12.clone()
#                         g_theta1 = g_theta12.clone()
#                         g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
#         #g_theta2_vec = torch.cat([g_theta2_vec, x0_new.flatten()], 0)
# #                         agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
# #                         g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
#                         print('acquiring, new size is' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    vec_x = torch.cat([vec_x, x0_new.detach()])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy < 1e-4 * tol_vector[0,0]):
                        FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -3. or loc_sample[i,0] > 3. or loc_sample[i,1] < -3. or loc_sample[i,1] > 3.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target - pf1)
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        

                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -3. or x0_new.detach()[0,0] > 3. or x0_new.detach()[0,1] < -3. or x0_new.detach()[0,1] > 3.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #x0_old #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
           
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[-1.1347, -0.8805],
#         [-0.9680, -0.9204]])
# 0
# START HYPERPARAMETERS optimization
# loss is -2.786
# END HYPERPARAMETERS optimization
# Loss design: 56.731
# expected info is tensor([[0.2730]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(121.0826, grad_fn=<SumBackward1>)
# current sol istensor([[-1.1553, -1.0715]])
# new data istensor([[-0.0741,  0.2625]])
# g_theta2 istensor([[-0.9478, -0.7677],
#         [-0.8585, -0.8603]])
# p21val is 0.000005201145328
# pf12val is 0.080293599200201
# chi_f12 is 5.044130744574902
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 0
# Loss design: 82.759
# expected info is tensor([[0.7864]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(172.4012, grad_fn=<SumBackward1>)
# current sol istensor([[-0.9049, -0.9258]])
# new data istensor([[0.0635, 0.2328]])
# g_theta2 istensor([[-0.7421, -0.5421],
#         [-1.1029, -1.1047]])
# p21val is 0.000001381946170
# pf12val is 0.278384558107524
# chi_f12 is 2.557503637256002
# patience is 2.000
# adding complexity to model
# num base is2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 0
# START HYPERPARAMETERS optimization
# loss is -2.599
# END HYPERPARAMETERS optimization
# Loss design: 14.734
# expected info is tensor([[1.7850]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(23.7481, grad_fn=<SumBackward1>)
# current sol istensor([[-0.9073, -1.0865]])
# new data istensor([[0.0050, 0.2299]])
# g_theta2 istensor([[-1.0393, -0.7555],
#         [-0.7301, -0.6848]])
# p21val is 0.380806218171516
# pf12val is 0.948546468038335
# chi_f12 is 0.105648999456388
# p_val_ftarget is 6.969020996727693e-06
# new 2 points
# tensor([[-1.2487, -1.1968],
#         [-0.9376, -1.2979],
#         [-0.9076, -1.0854]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# loss is -2.628
# END HYPERPARAMETERS optimization
# Loss design: 58.104
# expected info is tensor([[0.1481]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(127.2299, grad_fn=<SumBackward1>)
# current sol istensor([[-0.7936, -0.9871]])
# new data istensor([[0.1495, 0.1976]])
# g_theta2 istensor([[-1.3722, -1.3407],
#         [-0.9076, -1.3257],
#         [-0.9734, -1.1533]])
# p21val is 0.040037880756988
# pf12val is 0.244010587587738
# chi_f12 is 2.821087325754612
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7494, -0.9913],
#         [-0.6513, -0.8753],
#         [-0.7932, -0.9886]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# loss is -2.630
# END HYPERPARAMETERS optimization
# Loss design: 82.173
# expected info is tensor([[0.0364]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(177.7672, grad_fn=<SumBackward1>)
# current sol istensor([[-0.8359, -0.8688]])
# new data istensor([[0.1282, 0.2234]])
# g_theta2 istensor([[-0.6960, -1.0476],
#         [-0.5746, -0.8596],
#         [-0.7183, -1.0629]])
# p21val is 0.057790345803030
# pf12val is 0.715536906174413
# chi_f12 is 0.669444200718661
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9309, -0.7358],
#         [-0.8216, -0.9361],
#         [-0.8354, -0.8698]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# loss is -2.608
# END HYPERPARAMETERS optimization
# Loss design: 67.189
# expected info is tensor([[0.0030]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(148.6935, grad_fn=<SumBackward1>)
# current sol istensor([[-0.7014, -0.7020]])
# new data istensor([[0.2350, 0.2012]])
# g_theta2 istensor([[-1.0446, -0.6811],
#         [-0.7421, -1.0216],
#         [-0.6778, -0.9931]])
# p21val is 0.148540264834650
# pf12val is 0.531304829765089
# chi_f12 is 1.264838710199219
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5502, -0.3930],
#         [-0.7479, -0.7842],
#         [-0.7015, -0.7013]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# loss is -2.616
# END HYPERPARAMETERS optimization
# Loss design: 22.436
# expected info is tensor([[0.4047]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(55.9345, grad_fn=<SumBackward1>)
# current sol istensor([[-0.5252, -0.6129]])
# new data istensor([[0.3581, 0.1148]])
# g_theta2 istensor([[-0.6250, -0.2363],
#         [-0.8264, -0.8469],
#         [-0.8137, -0.7867]])
# p21val is 0.019808188377962
# pf12val is 0.365068039396429
# chi_f12 is 2.015343066932833
# p_val_ftarget is 7.144285163462882e-13
# new 2 points
# tensor([[-0.8448, -1.1227],
#         [-0.5983, -0.5008],
#         [-0.5273, -0.6127]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# loss is -2.611
# END HYPERPARAMETERS optimization
# Loss design: 20.743
# expected info is tensor([[0.0115]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(53.5633, grad_fn=<SumBackward1>)
# current sol istensor([[-0.4109, -0.7768]])
# new data istensor([[0.2816, 0.1537]])
# g_theta2 istensor([[-0.9484, -1.0722],
#         [-0.6335, -0.4649],
#         [-0.6102, -0.5296]])
# p21val is 0.028263000858638
# pf12val is 0.455850380994817
# chi_f12 is 1.571181270323389
# p_val_ftarget is 2.338240712163042e-12
# new 2 points
# tensor([[ 0.4651, -0.7830],
#         [-0.4013, -0.7733],
#         [-0.4103, -0.7790]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# loss is -2.618
# END HYPERPARAMETERS optimization
# Loss design: 23.001
# expected info is tensor([[0.0951]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(57.9788, grad_fn=<SumBackward1>)
# current sol istensor([[-0.3052, -0.8822]])
# new data istensor([[0.2002, 0.2803]])
# g_theta2 istensor([[ 0.5948, -0.6308],
#         [-0.4859, -0.6617],
#         [-0.4941, -0.6677]])
# p21val is 0.948128562410499
# pf12val is 0.176754898715550
# chi_f12 is 3.465982518168577
# p_val_ftarget is 2.5712765250318625e-13
# new 2 points
# tensor([[-0.5444, -1.1670],
#         [-0.3389, -0.7052],
#         [-0.3046, -0.8819]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# loss is -2.651
# END HYPERPARAMETERS optimization
# Loss design: 24.711
# expected info is tensor([[0.0205]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(60.2542, grad_fn=<SumBackward1>)
# current sol istensor([[-0.1877, -1.0340]])
# new data istensor([[-0.0711,  0.3224]])
# g_theta2 istensor([[-0.6640, -1.0122],
#         [-0.3662, -0.6807],
#         [-0.3963, -0.7770]])
# p21val is 0.330033811559259
# pf12val is 0.056265661878505
# chi_f12 is 5.755341686514686
# p_val_ftarget is 8.237854842718662e-14
# new 2 points
# tensor([[ 0.3732, -1.5323],
#         [-0.7942, -0.9293],
#         [-0.1876, -1.0343]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# loss is -2.652
# END HYPERPARAMETERS optimization
# Loss design: 77.684
# expected info is tensor([[0.0300]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(167.9489, grad_fn=<SumBackward1>)
# current sol istensor([[-0.0527, -0.8868]])
# new data istensor([[0.0264, 0.2499]])
# g_theta2 istensor([[ 0.4107, -1.6031],
#         [-0.8227, -1.0578],
#         [-0.2768, -1.0635]])
# p21val is 0.754922258497562
# pf12val is 0.317324235652248
# chi_f12 is 2.295662404865869
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0262, -1.4189],
#         [ 0.1926, -0.7465],
#         [-0.0519, -0.8867]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# loss is -2.686
# END HYPERPARAMETERS optimization
# Loss design: 119.738
# expected info is tensor([[0.1508]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(251.5383, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.1511, -0.8688]])
# new data istensor([[-0.1139,  0.2299]])
# g_theta2 istensor([[ 0.0300, -1.4281],
#         [ 0.3116, -0.5821],
#         [-0.1801, -0.7680]])
# p21val is 0.842827744641574
# pf12val is 0.468834077367530
# chi_f12 is 1.515012705461546
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1323, -1.1387],
#         [-0.0488, -1.6744],
#         [ 0.1512, -0.8687]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# loss is -2.705
# END HYPERPARAMETERS optimization
# Loss design: 295.679
# expected info is tensor([[0.0323]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(604.6646, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.3176, -0.8599]])
# new data istensor([[-0.1292,  0.2356]])
# g_theta2 istensor([[-0.0084, -1.2549],
#         [-0.0648, -1.8739],
#         [ 0.0346, -0.6667]])
# p21val is 0.742702206770366
# pf12val is 0.436814557347887
# chi_f12 is 1.656493055690271
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5276, -0.0481],
#         [ 0.1688, -1.2365],
#         [ 0.3178, -0.8607]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# loss is -2.716
# END HYPERPARAMETERS optimization
# Loss design: 535.226
# expected info is tensor([[0.0467]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(1084.4164, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.4797, -0.9636]])
# new data istensor([[-0.2565,  0.2327]])
# g_theta2 istensor([[ 0.3517,  0.1074],
#         [ 0.0242, -1.3661],
#         [ 0.1857, -0.7040]])
# p21val is 0.065518202408306
# pf12val is 0.833089466612443
# chi_f12 is 0.365228479372965
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3095, -1.5262],
#         [ 0.3326, -1.6808],
#         [ 0.4792, -0.9625]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# loss is -2.731
# END HYPERPARAMETERS optimization
# Loss design: 561.313
# expected info is tensor([[0.0217]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(1135.8350, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.5970, -1.1428]])
# new data istensor([[-0.3777,  0.2473]])
# g_theta2 istensor([[ 0.2450, -1.5931],
#         [ 0.3772, -1.6282],
#         [ 0.3582, -0.8309]])
# p21val is 0.520133948839092
# pf12val is 0.911573067175552
# chi_f12 is 0.185167053221907
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8341, -0.8347],
#         [ 0.1985, -1.7023],
#         [ 0.5972, -1.1430]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# loss is -2.761
# END HYPERPARAMETERS optimization
# Loss design: 1174.378
# expected info is tensor([[0.0214]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(2363.2428, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.6874, -1.3046]])
# new data istensor([[-0.4110,  0.2529]])
# g_theta2 istensor([[ 0.7623, -0.9310],
#         [ 0.2759, -1.6126],
#         [ 0.7871, -0.9896]])
# p21val is 0.020203272127681
# pf12val is 0.138022127010522
# chi_f12 is 3.960682532044325
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6040, -1.3797],
#         [ 0.5133, -0.9530],
#         [ 0.6879, -1.3058]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# loss is -2.765
# END HYPERPARAMETERS optimization
# Loss design: 1564.758
# expected info is tensor([[0.0102]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(3146.1092, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.8172, -1.0555]])
# new data istensor([[-0.1633,  0.1255]])
# g_theta2 istensor([[ 0.5123, -1.4962],
#         [ 0.3285, -0.8584],
#         [ 0.9003, -1.3962]])
# p21val is 0.272922562095304
# pf12val is 0.568569037136300
# chi_f12 is 1.129265071618993
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6703, -1.4357],
#         [ 0.7770, -1.3332],
#         [ 0.8171, -1.0563]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# loss is -2.790
# END HYPERPARAMETERS optimization
# Loss design: 478.333
# expected info is tensor([[0.0067]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(971.1048, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.9804, -0.8884]])
# new data istensor([[ 0.1155, -0.0797]])
# g_theta2 istensor([[ 0.8041, -1.4624],
#         [ 0.8024, -1.3745],
#         [ 0.7317, -1.1540]])
# p21val is 0.534767779230664
# pf12val is 0.664007453252456
# chi_f12 is 0.818923809581811
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8104, -1.5192],
#         [ 1.1125, -0.5802],
#         [ 0.9803, -0.8886]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# loss is -2.775
# END HYPERPARAMETERS optimization
# Loss design: 396.156
# expected info is tensor([[0.5361]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(805.3286, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.8904, -0.7249]])
# new data istensor([[ 0.1288, -0.0975]])
# g_theta2 istensor([[ 0.7601, -1.4634],
#         [ 1.3105, -0.4497],
#         [ 0.8384, -1.0252]])
# p21val is 0.533786105119147
# pf12val is 0.285138533311895
# chi_f12 is 2.509560270033704
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8633, -0.8008],
#         [ 0.8495, -0.5822],
#         [ 0.8889, -0.7251]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# loss is -2.823
# END HYPERPARAMETERS optimization
# Loss design: 291.403
# expected info is tensor([[0.0799]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(595.7468, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.8771, -0.5453]])
# new data istensor([[ 0.2489, -0.1462]])
# g_theta2 istensor([[ 0.7774, -0.8842],
#         [ 0.7123, -0.7545],
#         [ 0.7816, -0.8450]])
# p21val is 0.022059127822396
# pf12val is 0.621150291039760
# chi_f12 is 0.952364423545356
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.0646, -0.2391],
#         [ 1.1024, -0.1142],
#         [ 0.8771, -0.5459]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# loss is -2.800
# END HYPERPARAMETERS optimization
# Loss design: 207.163
# expected info is tensor([[0.2629]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(426.8981, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.7400, -0.3979]])
# new data istensor([[ 0.2495, -0.0463]])
# g_theta2 istensor([[ 1.1952, -0.1489],
#         [ 1.1925, -0.0564],
#         [ 1.0177, -0.6540]])
# p21val is 0.226047320769918
# pf12val is 0.507196302013491
# chi_f12 is 1.357714333737131
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4517, -0.6249],
#         [ 0.1420, -0.7791],
#         [ 0.7410, -0.3966]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# loss is -2.785
# END HYPERPARAMETERS optimization
# Loss design: 153.667
# expected info is tensor([[0.0404]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(320.8443, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.6143, -0.2624]])
# new data istensor([[0.1537, 0.1105]])
# g_theta2 istensor([[ 0.3750, -0.7351],
#         [ 0.1755, -0.7497],
#         [ 0.9089, -0.5051]])
# p21val is 0.111214621062904
# pf12val is 0.010035040768829
# chi_f12 is 9.203344468157113
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.1339,  0.4135],
#         [ 0.7608,  0.0421],
#         [ 0.6154, -0.2645]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# loss is -2.808
# END HYPERPARAMETERS optimization
# Loss design: 124.157
# expected info is tensor([[0.0593]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(262.2297, grad_fn=<SumBackward1>)
# current sol istensor([[ 0.4990, -0.1285]])
# new data istensor([[0.0897, 0.1419]])
# g_theta2 istensor([[ 1.2496,  0.2481],
#         [ 0.8789,  0.1523],
#         [ 0.7427, -0.4089]])
# p21val is 0.481231065181588
# pf12val is 0.245124972457361
# chi_f12 is 2.811974213654481
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7403,  0.0290],
#         [ 0.5614, -0.1844],
#         [ 0.4975, -0.1285]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# loss is -2.797
# END HYPERPARAMETERS optimization
# Loss design: 153.854
# expected info is tensor([[0.0105]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(321.7530, grad_fn=<SumBackward1>)
# current sol istensor([[0.3240, 0.0221]])
# new data istensor([[0.0343, 0.2448]])
# g_theta2 istensor([[ 0.8014,  0.0801],
#         [ 0.6566, -0.2916],
#         [ 0.6172, -0.2757]])
# p21val is 0.763674541726895
# pf12val is 0.494193805620550
# chi_f12 is 1.409655039322561
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4957, -0.0456],
#         [ 0.5618,  0.0436],
#         [ 0.3233,  0.0219]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# loss is -2.822
# END HYPERPARAMETERS optimization
# Loss design: 53.136
# expected info is tensor([[0.0075]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(118.3099, grad_fn=<SumBackward1>)
# current sol istensor([[0.2207, 0.1846]])
# new data istensor([[0.0177, 0.2773]])
# g_theta2 istensor([[ 0.5171, -0.0231],
#         [ 0.5905,  0.0540],
#         [ 0.3920, -0.0816]])
# p21val is 0.481423602406373
# pf12val is 0.909739506423969
# chi_f12 is 0.189193954254923
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2477,  0.1735],
#         [-0.0996,  0.4250],
#         [ 0.2197,  0.1847]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# loss is -2.842
# END HYPERPARAMETERS optimization
# Loss design: 31.249
# expected info is tensor([[0.0560]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(74.5070, grad_fn=<SumBackward1>)
# current sol istensor([[0.3321, 0.3078]])
# new data istensor([[0.0675, 0.3475]])
# g_theta2 istensor([[ 0.2552,  0.0848],
#         [-0.1889,  0.3971],
#         [ 0.2234,  0.0994]])
# p21val is 0.040329591216877
# pf12val is 0.755618173493283
# chi_f12 is 0.560438183811910
# p_val_ftarget is 1.1102230246251565e-16
# new 2 points
# tensor([[ 0.0637,  0.3994],
#         [-0.0275,  0.6436],
#         [ 0.3332,  0.3084]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# loss is -2.829
# END HYPERPARAMETERS optimization
# Loss design: 17.530
# expected info is tensor([[0.0773]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(46.9372, grad_fn=<SumBackward1>)
# current sol istensor([[0.4347, 0.4163]])
# new data istensor([[0.1018, 0.3974]])
# g_theta2 istensor([[ 0.0166,  0.3443],
#         [-0.1460,  0.4781],
#         [ 0.2474,  0.2259]])
# p21val is 0.612745742313781
# pf12val is 0.921185397757328
# chi_f12 is 0.164187924977000
# p_val_ftarget is 6.422795628679978e-11
# new 2 points
# tensor([[0.7985, 0.5176],
#         [0.7069, 0.3560],
#         [0.4338, 0.4166]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# loss is -2.840
# END HYPERPARAMETERS optimization
# Loss design: 6.817
# expected info is tensor([[0.4422]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(24.8357, grad_fn=<SumBackward1>)
# current sol istensor([[0.6020, 0.5257]])
# new data istensor([[0.1656, 0.4228]])
# g_theta2 istensor([[0.9035, 0.3247],
#         [0.7635, 0.2422],
#         [0.4630, 0.3250]])
# p21val is 0.523890666992056
# pf12val is 0.629139383680735
# chi_f12 is 0.926804902307095
# p_val_ftarget is 4.045649975803478e-06
# new 2 points
# tensor([[0.0871, 0.9612],
#         [0.9227, 0.2478],
#         [0.6038, 0.5276]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# loss is -2.853
# END HYPERPARAMETERS optimization
# Loss design: 3.529
# expected info is tensor([[0.0551]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(18.9260, grad_fn=<SumBackward1>)
# current sol istensor([[0.7141, 0.6240]])
# new data istensor([[0.2645, 0.4149]])
# g_theta2 istensor([[0.0039, 0.8229],
#         [0.9315, 0.2038],
#         [0.5165, 0.4522]])
# p21val is 0.093389154276144
# pf12val is 0.448947621844937
# chi_f12 is 1.601698106356784
# p_val_ftarget is 7.767466086860964e-05
# new 2 points
# tensor([[0.5016, 1.0354],
#         [0.2066, 0.6217],
#         [0.7144, 0.6235]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# loss is -2.835
# END HYPERPARAMETERS optimization
# Loss design: -3.704
# expected info is tensor([[0.2547]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(4.3500, grad_fn=<SumBackward1>)
# current sol istensor([[0.8101, 0.7177]])
# new data istensor([[0.3121, 0.3293]])
# g_theta2 istensor([[0.3976, 1.0941],
#         [0.1336, 0.4374],
#         [0.6377, 0.5483]])
# p21val is 0.131766881780013
# pf12val is 0.251140170812158
# chi_f12 is 2.763488092548780
# p_val_ftarget is 0.11360643475479226
# new 2 points
# tensor([[0.1007, 0.1194],
#         [1.7106, 1.3577],
#         [0.8121, 0.7178]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# loss is -2.847
# END HYPERPARAMETERS optimization
# Loss design: -6.843
# expected info is tensor([[0.0783]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(0.6819, grad_fn=<SumBackward1>)
# current sol istensor([[0.8860, 0.6231]])
# new data istensor([[0.3216, 0.3213]])
# g_theta2 istensor([[-0.1061,  0.1625],
#         [ 1.8266,  1.4973],
#         [ 0.7032,  0.6392]])
# p21val is 0.038191985131497
# pf12val is 0.773158162110199
# chi_f12 is 0.514543286321703
# p_val_ftarget is 0.7110959030908086
# new 2 points
# tensor([[-0.8894, -0.7603],
#         [ 1.8974,  1.2335],
#         [ 0.8846,  0.6220]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# loss is -2.835
# END HYPERPARAMETERS optimization
# Loss design: -6.212
# expected info is tensor([[0.0520]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(3.4781, grad_fn=<SumBackward1>)
# current sol istensor([[0.8838, 0.5729]])
# new data istensor([[0.3322, 0.3325]])
# g_theta2 istensor([[-0.9320, -0.8006],
#         [ 1.9711,  1.3328],
#         [ 0.7397,  0.5106]])
# p21val is 0.885577115694586
# pf12val is 0.932527526056893
# chi_f12 is 0.139713218680319
# p_val_ftarget is 0.1756855795955622
# new 2 points
# tensor([[0.6571, 0.3780],
#         [0.5279, 0.3133],
#         [0.8829, 0.5734]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# loss is -2.852
# END HYPERPARAMETERS optimization
# Loss design: -6.345
# expected info is tensor([[0.0243]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(3.9232, grad_fn=<SumBackward1>)
# current sol istensor([[0.8784, 0.5778]])
# new data istensor([[0.3688, 0.3587]])
# g_theta2 istensor([[0.6239, 0.3447],
#         [0.6226, 0.3450],
#         [0.7465, 0.4333]])
# p21val is 0.463846332757285
# pf12val is 0.103533709546256
# chi_f12 is 4.535716046410162
# p_val_ftarget is 0.14063277786598394
# new 2 points
# tensor([[0.8413, 0.5439],
#         [0.4593, 0.1941],
#         [0.8781, 0.5778]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# loss is -2.862
# END HYPERPARAMETERS optimization
# Loss design: -8.106
# expected info is tensor([[0.0380]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(0.9815, grad_fn=<SumBackward1>)
# current sol istensor([[0.8740, 0.5584]])
# new data istensor([[0.3528, 0.3448]])
# g_theta2 istensor([[0.7167, 0.4238],
#         [0.3458, 0.0984],
#         [0.7461, 0.4489]])
# p21val is 0.627249234669651
# pf12val is 0.626551561718349
# chi_f12 is 0.935048413612318
# p_val_ftarget is 0.612161078679845
# new 2 points
# tensor([[1.1355, 0.7880],
#         [0.4985, 0.2319],
#         [0.8740, 0.5595]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# loss is -2.885
# END HYPERPARAMETERS optimization
# Loss design: -8.556
# expected info is tensor([[0.0441]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(0.6197, grad_fn=<SumBackward1>)
# current sol istensor([[0.8711, 0.5482]])
# new data istensor([[0.2791, 0.3495]])
# g_theta2 istensor([[1.2598, 0.9311],
#         [0.5957, 0.3348],
#         [0.7336, 0.7498]])
# p21val is 0.876079576587413
# pf12val is 0.034085666780311
# chi_f12 is 6.757756624157614
# p_val_ftarget is 0.7335453288398937
# new 2 points
# tensor([[ 0.5942,  0.2656],
#         [-0.0430, -0.3388],
#         [ 0.8715,  0.5483]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# loss is -2.892
# END HYPERPARAMETERS optimization
# Loss design: -8.311
# expected info is tensor([[0.0081]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(1.2234, grad_fn=<SumBackward1>)
# current sol istensor([[0.8797, 0.5886]])
# new data istensor([[0.3434, 0.3359]])
# g_theta2 istensor([[ 0.6668,  0.3388],
#         [ 0.0612, -0.4895],
#         [ 0.7577,  0.3659]])
# p21val is 0.882300251395888
# pf12val is 0.797062667961508
# chi_f12 is 0.453643946938795
# p_val_ftarget is 0.5424402868683043
# new 2 points
# tensor([[ 0.1316, -0.3520],
#         [ 1.2588,  1.0737],
#         [ 0.8806,  0.5887]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# loss is -2.909
# END HYPERPARAMETERS optimization
# Loss design: -8.479
# expected info is tensor([[0.0095]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(1.1853, grad_fn=<SumBackward1>)
# current sol istensor([[0.8774, 0.5834]])
# new data istensor([[0.3482, 0.3524]])
# g_theta2 istensor([[ 0.0053, -0.4686],
#         [ 1.2048,  1.0145],
#         [ 0.7374,  0.4188]])
# p21val is 0.829835416701390
# pf12val is 0.738347653966112
# chi_f12 is 0.606680978936423
# p_val_ftarget is 0.5528670299892924
# new 2 points
# tensor([[0.7281, 0.3932],
#         [0.8470, 0.5529],
#         [0.8776, 0.5852]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# loss is -2.913
# END HYPERPARAMETERS optimization
# Loss design: -8.829
# expected info is tensor([[0.0127]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(0.7120, grad_fn=<SumBackward1>)
# current sol istensor([[0.8762, 0.5750]])
# new data istensor([[0.3197, 0.3396]])
# g_theta2 istensor([[0.6689, 0.3337],
#         [0.7201, 0.4049],
#         [0.7419, 0.4131]])
# p21val is 0.267578927856072
# pf12val is 0.744994563744598
# chi_f12 is 0.588756715232634
# p_val_ftarget is 0.7004733811773076
# new 2 points
# tensor([[1.0106, 0.7320],
#         [0.4514, 0.0922],
#         [0.8763, 0.5753]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# loss is -2.924
# END HYPERPARAMETERS optimization
# Loss design: -8.732
# expected info is tensor([[0.0158]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(1.0870, grad_fn=<SumBackward1>)
# current sol istensor([[0.8786, 0.5841]])
# new data istensor([[0.3770, 0.3437]])
# g_theta2 istensor([[0.8466, 0.8976],
#         [0.3730, 0.0150],
#         [0.7382, 0.4037]])
# p21val is 0.975018065586045
# pf12val is 0.118193079536270
# chi_f12 is 4.270871448973420
# p_val_ftarget is 0.5807000726758571
# new 2 points
# tensor([[0.5343, 0.0433],
#         [0.7240, 0.6852],
#         [0.8799, 0.5852]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# loss is -2.943
# END HYPERPARAMETERS optimization
# Loss design: -9.176
# expected info is tensor([[0.0063]], grad_fn=<ReshapeAliasBackward0>)
# mohabb disatance istensor(0.4317, grad_fn=<SumBackward1>)
# current sol istensor([[0.8741, 0.5870]])
# Success is True and failure is False after 37 iterations

# %%
print(lower_bound)
print(upper_bound)
print(f_target - 0.001)
print(f_target + 0.001)
print(pf1)
print(num_base_kernels)
# Out:
# tensor([[0.3297],
#         [0.3424]], grad_fn=<CopySlices>)
# tensor([[0.3408],
#         [0.3534]], grad_fn=<CopySlices>)
# tensor([[0.3370],
#         [0.3492]], dtype=torch.float32)
# tensor([[0.3390],
#         [0.3512]], dtype=torch.float32)
# tensor([[0.3353],
#         [0.3479]], grad_fn=<ReshapeAliasBackward0>)
# 2

# %%
sns.set_style('ticks')
plt.rcParams["pdf.use14corefonts"] = True
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
f, ax = plt.subplots(1, 1, figsize=(12, 12))
#ax.plot(np.array(range(2,iter+2)), torch.log(entropy_vec_plot), '+-')

ax.plot(np.array(data_fit_vec_plot), (entropy_vec_plot),'o',color = 'blue', markersize=12)
#ax.set_xlim(-15.1, torch.max(data_fit_vec_plot)+0.1)
#ax.set_yscale('log')
ax.set_xlabel('data fit')
ax.set_ylabel('expected information')
#ax.plot(np.array(range(2,iter+2)), data_fit_vec_plot, 'rx-')
plt.savefig('figures/entropyvsdatafit_draft.eps',dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.set_style('ticks')
plt.rcParams["pdf.use14corefonts"] = True
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 8), tight_layout=True)

ax1.plot(np.array(range(1,iter+2)), (entropy_vec_plot), '--o', color = 'blue', markersize=12)
#ax1.set_yscale('log')
# ax.plot(np.array(data_fit_vec_plot), (entropy_vec_plot), 'o')
#ax1.set_yscale('log')

ax2.plot(np.array(range(1,iter+2)), data_fit_vec_plot, '--o', color = 'red', markersize=12)

ax1.set_xlabel('iteration #', size=24)
ax2.set_xlabel('iteration #', size=24)
ax1.set_ylabel('Expected information', size = 24)
ax2.set_ylabel('Data fit', size = 24)

plt.savefig('figures/expectedinfo_vs_datafit_acquiring.pdf',dpi=300, bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.

# %%
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2),2)

# %%
fig, ax = plt.subplots(figsize = (12,12))
ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'v', color = 'black',markersize=15, alpha = 0.3)
ax.plot(vec_x[-1,0], vec_x[-1,1],'s', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'gD', color = 'green',markersize=15)
ax.set_title('TAD solution')
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
plt.savefig('figures/tad_sol_allpoints.pdf')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.

# %%
print(g_theta1.shape[0])
# Out:
# 162

# %% [markdown]
# ##

# %%
vec_x = vec_x.detach()
#v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)
ii = 0
low = -3.1
high = 3.1
########################
f, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.plot(0.8731, 0.5664,'gs',markersize=15)
ax.plot(vec_x[ii,0], vec_x[ii,1],'ro',markersize=15)
ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 'bv', markersize=15)
ax.plot(v2.detach()[ii:ii+loc_size,0], v2.detach()[ii:ii+loc_size,1], 'kv', markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Initial Configuration')
ax.legend(['Target', 'Initial Target Candidate', 'Initial 1-sample','Initial 2-sample'])

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures/evol_solTAD/evol_sol_ini.pdf')

# %%
vec_x = vec_x.detach()
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)

low = -3.1
high = 3.1
#for iter_plt in range(1,iter):
iter_plt = 30
ii = 2  + (iter_plt - 1) * (loc_size + 1)
########################



###########
#print(alphas_x.shape)
f, ax = plt.subplots(1, 1, figsize=(12, 12))
ax.plot(0.8731, 0.5664,'gs',markersize=15)
#ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 'bv', markersize=8)
for i in range(1, iter_plt):
    ax.plot(vec_x[i-1:i,0], vec_x[i-1:i,1],'ro', markersize=15, alpha=1./(iter_plt+2) * i, label = '_nolegend_')
    
ax.plot(vec_x[0:iter_plt,0], vec_x[0:iter_plt,1],'ro-', linewidth=15, alpha= 0.3)
ax.plot(vec_x[iter_plt-1,0], vec_x[iter_plt-1,1],'ro',markersize=15)
#ax.plot(g_theta1.detach()[:,0], g_theta.detach()[:,1], 'bv', markersize=8)
ax.plot(v2.detach()[0:ii,0], v2.detach()[0:ii,1], 'v', color = 'black', markersize=15,alpha=0.3)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'bv', markersize=15)

ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Iteration '+str(iter_plt))
#ax.set_title('Final Configuration')
ax.legend(['Target',  'Previous Target Candidates', 'Current Target Candidate', 'Previous 2-samples','Current 2-sample'], fontsize = 'small')

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures/evol_solTAD/evol_sol_'+str(iter_plt)+'.pdf')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.
# findfont: Font family ['sans-serif'] not found. Falling back to Helvetica.

# %%
print(g_theta2_vec.shape)
# Out:
# torch.Size([230])

# %% [markdown]
# # Grid

# %%
def conduct_design_pll(x0,f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    #g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        #print(g_theta)
        loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood, noise_value)
        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood ,noise_value)
    #loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
   # print(optimizer.state_dict())
    print(x_d)
    return x_d, lower_bound, upper_bound

# %%
x_plot = np.linspace(vf.low, vf.high, 12)
y_plot = np.linspace(vf.low, vf.high, 12)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n

g_theta_grid = x_concat
agg_data1_grid = vfield_(g_theta_grid)
agg_data1_grid = agg_data1_grid.flatten()


x0 = Tensor(np.array([0.1,0.1])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_grid = Tensor(np.array([0.0,0.0])) 
vec_x_grid = vec_x_grid.reshape(1,2)

lr_new = 1.

SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')
model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)

print('END HYPERPARAMETERS optimization')
model_grid.eval()
likelihood_grid.eval()
x0_new,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_grid, agg_data1_grid, model_grid, likelihood_grid, iter_design, iter_param, lr_new,noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
#loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new)
print(SUCCESS)
# Out:
# START HYPERPARAMETERS optimization
# loss is -2.079
# END HYPERPARAMETERS optimization
# Loss design: 197.123
# Parameter containing:
# tensor([[ 0.0579, -0.1327]], requires_grad=True)
# tensor([[0.1090],
#         [0.0720]], grad_fn=<CopySlices>)
# tensor([[0.1438],
#         [0.1075]], grad_fn=<CopySlices>)
# tensor([[0.3280],
#         [0.3402]])
# tensor([[0.3480],
#         [0.3602]])
# Parameter containing:
# tensor([[ 0.0579, -0.1327]], requires_grad=True)
# False

# %%
x0_grid = x0_new.detach()
fig, ax = plt.subplots(figsize = (12,12))
ax.plot(x_concat[:,0],x_concat[:,1], 'v', color = 'black', markersize=15, alpha = 0.3)
ax.plot(x0_new.detach()[0,0], x0_new.detach()[0,1],'ro',markersize=15)
ax.plot(0.8731, 0.5664,'gs',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Grid Solution')

plt.savefig('figures/grid_sol.pdf')

# %% [markdown]
# # Random sol

# %%
# iter_hp = 30
# iter_design = 40 
# iter_param = 50
# num_base_kernels = 3

# f_target = Tensor(vf.tgt_vec) 
# f_target = f_target.reshape(f_target.shape[0],1) 
# tol_vector = 0.005 * torch.ones(f_target.shape)


loc_size_rdn = math.ceil(g_theta1.shape[0]) #(iter)*(loc_size+1) + sample_size

loc_sample = high_minus_low  * np.random.random_sample((loc_size_rdn,2)) + vf.low #np.random.random_sample((loc_size_rdn,2))
g_theta_ = (Tensor(loc_sample).clone())
agg_data1 = vfield_(g_theta_)
agg_data1 = agg_data1.flatten()


x0 = Tensor(np.array([0.1,0.1])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_rdn = Tensor(np.array([0.,0.])) 
vec_x_rdn = vec_x_rdn.reshape(1,2)

lr_new = 1.


SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')

model_rdn, likelihood_rdn = hyper_opti(g_theta_,agg_data1,iter_hp,num_base_kernels,noise_value)




print('END HYPERPARAMETERS optimization')
model_rdn.eval()
likelihood_rdn.eval()
x0_new_rdn,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_, agg_data1, model_rdn, likelihood_rdn, iter_design, iter_param, lr_new, noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_rdn)
print(SUCCESS)
sol_rdn = x0_new_rdn
# Out:
# START HYPERPARAMETERS optimization
# loss is -2.437
# END HYPERPARAMETERS optimization
# Loss design: 53.153
# Parameter containing:
# tensor([[0.3618, 0.2885]], requires_grad=True)
# tensor([[0.0664],
#         [0.3332]], grad_fn=<CopySlices>)
# tensor([[0.1118],
#         [0.3793]], grad_fn=<CopySlices>)
# tensor([[0.3280],
#         [0.3402]])
# tensor([[0.3480],
#         [0.3602]])
# Parameter containing:
# tensor([[0.3618, 0.2885]], requires_grad=True)
# False

# %%
print(g_theta1.shape)
# Out:
# torch.Size([162, 2])

# %%
fig, ax = plt.subplots(figsize = (12,12))

ax.plot(g_theta_[:,0].detach(),g_theta_[:,1].detach(), 'v', color = 'black',markersize=15, alpha = 0.3)
ax.plot(sol_rdn.detach()[0,0], sol_rdn.detach()[0,1],'ro',markersize=15)
ax.plot(0.8731, 0.5664,'gs',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Uniformly Random Solution')

plt.savefig('figures/rdn_sol.pdf')

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(vf.low, vf.high, 30)
y_plot = np.linspace(vf.low, vf.high, 30)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)

model.eval()

likelihood.eval()

#noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
#print(x_concat_)
with torch.no_grad(), gpytorch.settings.fast_pred_var(False):
    pred = GPprediction(model)
    pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
    #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
    pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
    mean_v_1 = pr_mean[:,0].reshape(n,n)
    mean_v_2 = pr_mean[:,1].reshape(n,n)
    pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T
    
    var_v_1 = pred_var[:,0].reshape(n,n)
    var_v_2 = pred_var[:,1].reshape(n,n)
#     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

# #     print(pr.covariance_matrix.mean(axis=0))
# #     print(AA)
# #     print(pr.variance)
# #     print((pr.covariance_matrix))
# #     K = model.covar_module
#     print((cov.diag()))
#     print(pr_mean)


fig, (ax1, ax2) = plt.subplots(2, 2, figsize = (20, 16), tight_layout=True)
diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
cs10 = ax1[0].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(diff_mean_v1.min(), diff_mean_v1.max(), 100), cmap = 'jet')
ax1[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 's', color = 'black', markersize=12)
ax1[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'v', color = 'black',markersize=12, alpha = 1.0)
ax1[0].set_title('$|v_1 - \mu(v_1)|$')
cbar10 = fig.colorbar(cs10, ax = ax1[0]);

ax1[0].set_xlabel('$d_1$')
ax1[0].set_ylabel('$d_2$')

cs11 = ax1[1].contourf(xv_plot, yv_plot, var_v_1.detach(), np.linspace(var_v_1.detach().min(), var_v_1.detach().max(), 100), cmap = 'jet')
ax1[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 's', color = 'black', markersize=12)
ax1[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'v', color = 'black',markersize=12, alpha = 1.0)
ax1[1].set_title('$\sigma^2(v_1)$')
# ax1[0].set_aspect('equal')
# ax1[1].set_aspect('equal')
cbar11 = fig.colorbar(cs11, ax = ax1[1]);
ax1[1].set_xlabel('$d_1$')
ax1[1].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())#/torch.abs(v_2)
cs20 = ax2[0].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(diff_mean_v2.min(), diff_mean_v2.max(), 100), cmap = 'jet')
ax2[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 's', color = 'black', markersize=12)
ax2[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'v', color = 'black',markersize=12, alpha = 1.0)
ax2[0].set_title('$|v_2 - \mu(v_2)|$')
cbar20 = fig.colorbar(cs20, ax = ax2[0]);
ax2[0].set_xlabel('$d_1$')
ax2[0].set_ylabel('$d_2$')



cs21 = ax2[1].contourf(xv_plot, yv_plot, var_v_2.detach(), np.linspace(var_v_2.detach().min(), var_v_2.detach().max(), 100), cmap = 'jet')
ax2[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'v', color = 'black',markersize=12, alpha = 1.0)
ax2[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 's', color = 'black', markersize=12)
ax2[1].set_title('$\sigma^2(v_2)$')
cbar21 = fig.colorbar(cs21, ax = ax2[1]);
ax2[1].set_xlabel('$d_1$')
ax2[1].set_ylabel('$d_2$')


# ax2[0].set_aspect('equal')
# ax2[1].set_aspect('equal')

plt.savefig('figures/mean_var.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # L2 norm

# %%
def conduct_design_L2(x0,f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    #g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        #print(g_theta)
        loss2,lower_bound, upper_bound = likelihood.get_l2(f_target,x_d, g_theta1, agg_data, model, likelihood, noise_value)
        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2,lower_bound, upper_bound = likelihood.get_l2(f_target,x_d, g_theta1, agg_data, model, likelihood ,noise_value)
    #loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
   # print(optimizer.state_dict())
    print(x_d)
    return x_d, lower_bound, upper_bound

# %%
x_plot = np.linspace(vf.low, vf.high, 12)
y_plot = np.linspace(vf.low, vf.high, 12)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n

g_theta_grid = x_concat
agg_data1_grid = vfield_(g_theta_grid)
agg_data1_grid = agg_data1_grid.flatten()


x0 = Tensor(np.array([0.1,0.1])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_grid = Tensor(np.array([0.0,0.0])) 
vec_x_grid = vec_x_grid.reshape(1,2)

lr_new = 1.

SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')
model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)

print('END HYPERPARAMETERS optimization')
model_grid.eval()
likelihood_grid.eval()
x0_new_l2,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_grid, agg_data1_grid, model_grid, likelihood_grid, iter_design, iter_param, lr_new,noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
#loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_l2)
print(SUCCESS)
# Out:
# START HYPERPARAMETERS optimization
# loss is -2.090
# END HYPERPARAMETERS optimization
# Loss design: 254.482
# Parameter containing:
# tensor([[-0.1645, -0.1385]], requires_grad=True)
# tensor([[ 0.1972],
#         [-0.0090]], grad_fn=<CopySlices>)
# tensor([[0.2302],
#         [0.0240]], grad_fn=<CopySlices>)
# tensor([[0.3280],
#         [0.3402]])
# tensor([[0.3480],
#         [0.3602]])
# Parameter containing:
# tensor([[-0.1645, -0.1385]], requires_grad=True)
# False

# %%
x0_grid = x0_new.detach()
fig, ax = plt.subplots(figsize = (12,12))
ax.plot(x_concat[:,0],x_concat[:,1], 'v', color = 'black', markersize=15, alpha = 0.3)
ax.plot(x0_new_l2.detach()[0,0], x0_new_l2.detach()[0,1],'ro',markersize=15)
ax.plot(0.8731, 0.5664,'gs',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Grid Solution (L2 norm)')

plt.savefig('figures/grid_sol_l2.pdf')

# %%
# iter_hp = 30
# iter_design = 40 
# iter_param = 50
# num_base_kernels = 3

# f_target = Tensor(vf.tgt_vec) 
# f_target = f_target.reshape(f_target.shape[0],1) 
# tol_vector = 0.005 * torch.ones(f_target.shape)


loc_size_rdn = math.ceil(g_theta1.shape[0]) #(iter)*(loc_size+1) + sample_size

loc_sample = high_minus_low  * np.random.random_sample((loc_size_rdn,2)) + vf.low #np.random.random_sample((loc_size_rdn,2))
g_theta_l2 = (Tensor(loc_sample).clone())
agg_data1_l2 = vfield_(g_theta_l2)
agg_data1_l2 = agg_data1.flatten()


x0 = Tensor(np.array([0.1,0.1])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_rdn = Tensor(np.array([0.,0.])) 
vec_x_rdn = vec_x_rdn.reshape(1,2)

lr_new = 1.


SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')

model_rdn_l2, likelihood_rdn_l2 = hyper_opti(g_theta_l2,agg_data1_l2,iter_hp,num_base_kernels,noise_value)




print('END HYPERPARAMETERS optimization')
model_rdn_l2.eval()
likelihood_rdn_l2.eval()
x0_new_rdn_l2,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_l2, agg_data1_l2, model_rdn_l2, likelihood_rdn_l2, iter_design, iter_param, lr_new, noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_rdn_l2)
print(SUCCESS)
sol_rdn_l2 = x0_new_rdn_l2
# Out:
# START HYPERPARAMETERS optimization
# loss is 0.443
# END HYPERPARAMETERS optimization
# Loss design: 1.102
# Parameter containing:
# tensor([[0.2285, 0.2782]], requires_grad=True)
# tensor([[-1.6873],
#         [-1.4966]], grad_fn=<CopySlices>)
# tensor([[2.3778],
#         [2.0534]], grad_fn=<CopySlices>)
# tensor([[0.3280],
#         [0.3402]])
# tensor([[0.3480],
#         [0.3602]])
# Parameter containing:
# tensor([[0.2285, 0.2782]], requires_grad=True)
# False

# %%
fig, ax = plt.subplots(figsize = (12,12))

ax.plot(g_theta_l2[:,0].detach(),g_theta_l2[:,1].detach(), 'v', color = 'black',markersize=15, alpha = 0.3)
ax.plot(sol_rdn_l2.detach()[0,0], sol_rdn_l2.detach()[0,1],'ro',markersize=15)
ax.plot(0.8731, 0.5664,'gs',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Uniformly Random Solution (L2 norm)')

plt.savefig('figures/rdn_sol_l2.pdf')
