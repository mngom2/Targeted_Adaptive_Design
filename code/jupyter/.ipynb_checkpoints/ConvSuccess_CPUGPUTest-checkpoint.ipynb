# %%
import math
import torch
from torch import nn
from torch import Tensor
from torch.nn  import functional as F
import gpytorch
from matplotlib import pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
import matplotlib.cm as cm
import matplotlib.patches as patches
from mpl_toolkits.mplot3d import Axes3D 
import sys
from decimal import Decimal
from IPython.display import clear_output
sys.path.append("..")
from LBFGS import FullBatchLBFGS
from kernels import vvkernels as vvk, sep_vvkernels as svvk, vvk_rbfkernel as vvk_rbf
from means import vvmeans as vvm
from likelihood import vvlikelihood as vvll
from mlikelihoods import MarginalLogLikelihood as exmll
from predstrategies import GPprediction
from utils import ObjFun, get_vertices, stopping_criteria
from scipy import stats
import numpy as np
import seaborn as sns
import scipy
import time
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Plots settings

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=40)     # fontsize of the axes title
plt.rc('axes', labelsize=32)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=32)    # fontsize of the tick labels
plt.rc('ytick', labelsize=32)    # fontsize of the tick labels
plt.rc('legend', fontsize=32)    # legend fontsize
plt.rc('font', size=32)          # controls default text sizes

# %% [markdown]
# # Objective function
#
# We sample from $$V_1(x_1, x_2) = 3(1 - x_1)^2 e^{-x_1^2 - (x_2 +1)^2} - 10 (x_1/5 - x_1 ^3 - x_2^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- (x_1 + 2) ^2 - x_2^2} + 0.5(2x_1 + x_2)$$
# $$V_2(x_1, x_2) = 3(1 +x_2)^2 e^{-x_2^2 - (x_1 +1)^2} - 10 (-x_2/5 + x_2 ^3 + x_1^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- ( 2- x_2) ^2 - x_1^2} + 0.5(2x_1 + x_2)$$
#
# where $(x_1, x_2) \in [-3, 3]^2$

# %%
torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Use CPU

# %%
# use_cuda = torch.cuda.is_available()
use_cuda = False
device = torch.device('cuda' if use_cuda else 'cpu')

vf = ObjFun() # need to write a function, input + output (training points), if switching to higher dimension. Google scalable Bayesian Optimization and use what they are using
# Need target point. 
f_target = vf.tgt_vec
print(f_target)
sample_size = 4
D = vf.D
N = vf.N

vf.low = -1.
vf.high = 1.

high_minus_low = vf.high - vf.low
#high_minus_low = -
def g_theta(sample_size, D):
#     loc_x = (2. - 1.0 )  * np.random.random_sample((sample_size,1)) + 1.0
    
#     loc_y = (2.  -1.0)  * np.random.random_sample((sample_size,1)) - 2.
#     loc = np.concatenate((loc_x, loc_y), 1)
    loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
if use_cuda:
    train_x = train_x.cuda()
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    out = torch.zeros(x.shape[0], N)
    randn = torch.randn(Tensor(vf(x[:,0], x[:,1])).size())
    randn = randn.to(x.device)
    out = vf(x[:,0], x[:,1]) + randn * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([0.3380, 0.3502], dtype=torch.float32)
# tensor([[-0.0021, -0.3493],
#         [-0.7796,  0.8589],
#         [ 0.6410, -0.8926],
#         [ 0.2043,  0.3390]])

# %% [markdown]
# ## GP model initialization
# We inialize the GP model following https://docs.gpytorch.ai/en/stable/examples/03_Multitask_Exact_GPs/Multitask_GP_Regression.html

# %%
x_train = train_x #loc #torch.linspace(0, 1, 10)
y_train = train_y #v  #torch.stack([torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,torch.cos(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,], -1)

class MultitaskGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood,num_base_kernels):
        super(MultitaskGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)  #vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)#vvm.TensorProductSubMean(gpytorch.means.ConstantMean(), num_tasks = 2)  # 
        base_kernels = [] #contain all the base kernels
        for i in range(num_base_kernels):
            base_kernels.append(gpytorch.kernels.ScaleKernel(( gpytorch.kernels.RBFKernel() ))) #gpytorch.kernels.PolynomialKernel(4)  ##gpytorch.kernels.MaternKernel()# (vvk_rbf.vvkRBFKernel())
 
            
        self.covar_module = svvk.SepTensorProductKernel(base_kernels,num_tasks = 2)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal(mean_x, covar_x)

# %% [markdown]
# # Hyperparamaters oprimization

# %%
# # ###hyperparameters optimization###
def hyper_opti(g_theta1, agg_data, training_iter,num_base_kernels,noise_value, current_model = None, current_likelihood = None):
    noises = torch.ones(agg_data.shape[0]) * (noise_value) #  torch.zeros(agg_data.shape[0]) # 
    noises = noises.reshape(g_theta1.shape[0], 2)
    
#     if (current_model is not None):
#         likelihood = current_likelihood #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises)  #

#         model = current_model#.get_fantasy_model(g_theta1, agg_data) #MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
#         model.set_train_data(g_theta1, agg_data,  strict=False)
#     else:
#         likelihood = vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2)#vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #
#         model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
        
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    likelihood =  vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2) #
    model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
    model.double()
    likelihood.double()

    """Put related things on GPU"""
    if use_cuda:
        print("Using CUDA")
        model = model.cuda()
        likelihood = likelihood.cuda()
#         g_theta1 = g_theta1.cuda()
#         agg_data = agg_data.cuda()
        cov_noise1 = cov_noise1.cuda()
        
    else:
        print("Using CPU")
    
    
    """end for GPU"""

    model.train()
    
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(),  lr=0.1) #, weight_decay=0.001)  # Includes GaussianLikelihood parameters
    mll = exmll(likelihood, model)
    # Is this a likelihood?

    for i in range(training_iter):
        optimizer.zero_grad()

        loss, chi_square = mll(agg_data,g_theta1, model, likelihood, cov_noise1)
        loss = -1. * loss
#         print('df is %.3f' %agg_data.shape[0] +'and chi_square %.3f' %chi_square) 
        #print('loss is %.3f' %loss)
#         df = agg_data.shape[0]
#         chi_square = chi_square.clone().detach()
        
#         p_val = 1. - stats.chi2.cdf(chi_square, df)
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
       # print(p_val)
#         if (p_val > 0.99999):
#             return model, likelihood


    
        
    print('loss is %.3f' %loss)
#     for params in model.named_parameters():
#         print(params)
    return model, likelihood

# %% [markdown]
# # Design parameters and sampling point optimization (where to explore?)

# %%
def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': g_theta2, 'lr': 0.01},{'params': x_d, 'lr': 0.01}])

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    #scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    cov_noise2 =  noise_value * torch.eye(2 * g_theta2.shape[0])
    
    """Put related things on GPU for conduct_design_opti"""
    if use_cuda:
        print("Using CUDA for conduct_design_opti()")
        
        model = model.cuda()
        likelihood = likelihood.cuda()
        agg_data = agg_data.cuda()
        
        cov_noise1 = cov_noise1.cuda()
        cov_noise2 = cov_noise2.cuda()
#         g_theta1 = g_theta1.cuda()
        g_theta2 = g_theta2.cuda()
#         agg_data = agg_data.cuda()
        x_d = x_d.cuda()
        f_target = f_target.cuda()
        
    else:
        print("Using CPU for conduct_design_opti()")
    
    """end for GPU"""
    
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, g_theta2, cov_noise1, cov_noise2)

        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        scheduler.step(loss2)
        #scheduler.step()

    print('Loss design: %.3f' % ( loss2))
    #print(x_d)
    return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %% [markdown]
# # Conducting the TAD experiment

# %% [markdown]
# Initialization

# %%
loc_size = 2
#loc_sample0 = Tensor((2. - 1.5)  * np.random.random_sample((loc_size,2)) + 1.5)
x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
x0 = x0.reshape(1,2)

dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(loc_size) )
                    #loc_size = 4
loc_sample = dis_2sample.sample((loc_size + 1,))

loc_sample0 = loc_sample.reshape(loc_size + 1, 2)
#loc_sample0[-1] = train_x[-1] + 0.01

# This will make TAD fail to find a solution
f_target = Tensor([[-1., -1.]]).reshape(2,1)
tol_vector = 0.01 * torch.ones(f_target.shape)
#####

# Failing criterion
thresh_EI = 0.0005 # This also
count_EI = 0
max_count_EI = 5 # This affects the number of iterations required to fail
#####

# %%
"""Saving x0, loc_sample0, x_train, and y_train for running (basically) the same thing on GPU again later"""
x0_copy = x0
loc_sample0_copy = loc_sample0
x_train_copy = x_train
y_train_copy = y_train

# %%
cpu_hyper_opti = []
cpu_conduct_design = []
cpu_total = []

# %% [markdown]
# TAD algorithm

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 100
iter_param = 100
num_base_kernels = 2
max_iter = 50

# f_target = f_target.reshape(2,1) 
# tol_vector = 0.01 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten().to(device)

data_fit_vec = torch.empty((1,1)).to(device)
entropy_vec = torch.empty((1,1)).to(device)
loss_vec = torch.empty((1,1)).to(device)




#
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])
p21_vec = torch.empty((1,1))

lr_new = .01

    
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False


g_theta1 = g_theta1.to(device)
agg_data = agg_data.to(device)


while(SUCCESS == False and FAILURE == False):
    total_time_start = time.time()
    
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None


        loc_sample_old = loc_sample.clone()
        x0_old = x0.clone()
        hyper_opti_start = time.time()
        
        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)
        
        hyper_opti_end = time.time()
        cpu_hyper_opti.append(hyper_opti_end - hyper_opti_start)
        
# Before this is hyper_opti

        print('END HYPERPARAMETERS optimization')

 #     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
        
#     """end for CPU"""
    
    model.eval()
    likelihood.eval()
   
    conduct_design_start = time.time()
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
    conduct_design_end = time.time()
    cpu_conduct_design.append(conduct_design_end - conduct_design_start)

    """Everything after here might be independent"""
    # torch.inv_quad, torch.det, everything with likelihood.something is expensive
    cur_model = model
    cur_likelihood = likelihood
    
# Check tolerance to see if we succeeded
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])

    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
# End of checking
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    # Computing entropy can be expensive to compute
    
    print('expected info is '+str(entropy))
    
    if not SUCCESS:
    


        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape)).cpu()
                
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value)
               
                eye = torch.eye(Qf12.shape[0]).to(device)
                chi_f12 = (Qf12 + noise_value*eye).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape)).cpu()
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                p21_vec = torch.cat([p21_vec, Tensor([p_val]).reshape(1,1)], 0)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    sum = torch.zeros(2, 2).to(device) #replace with num_tasks
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    x0_old = x0_old.to(device)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_old).t(), (g_theta2.detach()[i] - x0_old) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_old, covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    loc_sample = torch.cat([loc_sample, x0_old],0)
                    
                    x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
                        PATH = ".//model_Carlo/model_update/model_base_"+str(iter)+".pt"
                        torch.save(model, PATH)
                        
                        entropy_vec = torch.cat([entropy_vec, entropy], 0)
                        data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is ' + str(num_base_kernels))
#     #                         
                        loc_sample = loc_sample_old
                        #x0 = x0_old
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                        g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                        print('acquiring 2, new size is ' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
                    torch.save(model, PATH)
                    vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                    loss_vec = torch.cat([loss_vec, -loss])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy < thresh_EI):
                        count_EI = count_EI + 1
                    else:
                        count_EI = 0
                    if (count_EI >= max_count_EI):
                        FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2).to(device)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum# + torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -1. or loc_sample[i,0] > 1. or loc_sample[i,1] < -1. or loc_sample[i,1] > 1.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target.to(device) - pf1).cpu()
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        
                        rand = torch.randn(x0_new.detach().size()).to(device)
                        x0 = (x0_new.detach()) + rand * .001
                        loc_sample[-1] = (x0_new.detach()) + rand * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -1. or x0_new.detach()[0,0] > 1. or x0_new.detach()[0,1] < -1. or x0_new.detach()[0,1] > 1.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                        x0 = x0.reshape(1,2)
                        #x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
        total_time_end = time.time()
        cpu_total.append(total_time_end - total_time_start)
        
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
torch.save(model, PATH)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[-0.1492,  0.1147],
#         [-0.0187,  0.1390],
#         [ 0.0143, -0.1227]])
# 0
# START HYPERPARAMETERS optimization
# Using CPU
# /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/lazy/triangular_lazy_tensor.py:136: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /lus/theta-fs0/software/thetagpu/conda/2022-07-01/pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   res = torch.triangular_solve(right_tensor, self.evaluate(), upper=self.upper).solution
# loss is -2.491
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3012.757
# expected info is tensor([[0.1766]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4191, -0.4942]])
# new data istensor([[0.0385, 0.0760]])
# g_theta2 istensor([[-0.3804,  0.3521],
#         [-0.2958,  0.3531],
#         [-0.2894, -0.1590]])
# p21val is 0.000000103878469
# pf12val is 0.000183731470412
# chi_f12 is 17.204070532499141
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 0
# Using CPU for conduct_design_opti()
# Loss design: 920.370
# expected info is tensor([[0.1529]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4857, -0.0284]])
# new data istensor([[0.1264, 0.0189]])
# g_theta2 istensor([[-1.0312,  0.9707],
#         [ 0.2297, -0.2790],
#         [ 0.2466, -0.2563]])
# p21val is 0.000000000000000
# pf12val is 0.000000000004671
# chi_f12 is 52.179457646245098
# patience is 2.000
# adding complexity to model
# num base is 3
# acquiring 2, new size is 7
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.060
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 81.193
# expected info is tensor([[0.0014]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0118, -0.4975]])
# new data istensor([[-0.1194,  0.3573]])
# g_theta2 istensor([[0.0781, 0.3871],
#         [0.1793, 0.2664],
#         [0.2295, 0.0721]])
# p21val is 0.170617134554554
# pf12val is 0.000000002843877
# chi_f12 is 39.356195354712334
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0932,  0.3374],
#         [-0.6279, -0.2270],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.087
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 254.288
# expected info is tensor([[0.0022]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3207,  0.1311]])
# new data istensor([[0.1152, 0.0832]])
# g_theta2 istensor([[ 0.1300,  0.3849],
#         [-0.8984, -0.5707],
#         [ 0.2051, -0.2276]])
# p21val is 0.009572880790844
# pf12val is 0.904580191197755
# chi_f12 is 0.200568640072086
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# Using CPU for conduct_design_opti()
# Loss design: 251.929
# expected info is tensor([[0.0049]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3268,  0.1446]])
# new data istensor([[0.1377, 0.1026]])
# g_theta2 istensor([[-0.4308, -0.5507],
#         [ 0.9910,  0.5462],
#         [ 0.2088, -0.2214]])
# p21val is 0.000011565741205
# pf12val is 0.860159400434650
# chi_f12 is 0.301275115134070
# patience is 2.000
# adding complexity to model
# num base is 4
# acquiring 2, new size is 14
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.006
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 78.293
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.7398,  0.2145]])
# new data istensor([[-0.1552,  0.1764]])
# g_theta2 istensor([[ 0.1378,  0.3505],
#         [-0.8655, -0.5343],
#         [ 0.2014, -0.2035]])
# p21val is 0.210031956446012
# pf12val is 0.449355355396859
# chi_f12 is 1.599882533703675
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2936,  0.4469],
#         [-0.3055,  0.6719],
#         [-0.7403,  0.2156]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.119
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 240.390
# expected info is tensor([[0.0208]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1411,  0.0875]])
# new data istensor([[-0.5062,  0.5877]])
# g_theta2 istensor([[ 0.1984,  0.2342],
#         [-0.2076,  0.7892],
#         [-0.7002,  0.3416]])
# p21val is 0.632400960944873
# pf12val is 0.039240533805218
# chi_f12 is 6.476090081557363
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9273,  0.0948],
#         [-0.3674,  0.6687],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.193
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1129.467
# expected info is tensor([[0.0086]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3242, -0.0315]])
# new data istensor([[0.1900, 0.0346]])
# g_theta2 istensor([[-0.9798,  0.1073],
#         [-0.6003,  0.8539],
#         [ 0.2185, -0.2197]])
# p21val is 0.660934454688064
# pf12val is 0.321506607306403
# chi_f12 is 2.269474368036553
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5893, -0.6785],
#         [ 0.2123, -0.6848],
#         [-0.3223, -0.0317]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.340
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 2365.014
# expected info is tensor([[0.0029]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3810,  0.4739]])
# new data istensor([[0.1255, 0.0519]])
# g_theta2 istensor([[-0.6383, -0.5997],
#         [ 0.5521, -1.1196],
#         [-0.0376, -0.3393]])
# p21val is 0.247776213722047
# pf12val is 0.015947916552303
# chi_f12 is 8.276854163926732
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7190,  0.8192],
#         [-0.5708,  0.2249],
#         [-0.3798,  0.4750]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.357
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3579.983
# expected info is tensor([[0.0123]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1476,  0.1137]])
# new data istensor([[0.1442, 0.1184]])
# g_theta2 istensor([[-0.4300,  0.6987],
#         [-0.6925,  0.1017],
#         [-0.7043,  0.1371]])
# p21val is 0.083835140048809
# pf12val is 0.984207194010900
# chi_f12 is 0.031837682151916
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9621,  0.3100],
#         [-0.4939,  0.4497],
#         [-0.1470,  0.1142]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.427
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 2416.983
# expected info is tensor([[0.0028]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.7746, -0.2304]])
# new data istensor([[-0.0484,  0.1329]])
# g_theta2 istensor([[-1.4050,  1.1017],
#         [-0.3283,  0.6918],
#         [ 0.1123,  0.3680]])
# p21val is 0.517653561172380
# pf12val is 0.105269521289666
# chi_f12 is 4.502462696363662
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4551,  0.6090],
#         [-0.3624,  0.3278],
#         [-0.7746, -0.2293]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.488
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 189.864
# expected info is tensor([[0.0045]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4420, -0.7027]])
# new data istensor([[-0.3647,  0.5512]])
# g_theta2 istensor([[ 0.1755,  0.2804],
#         [-0.0945,  0.5046],
#         [-0.5040,  0.0226]])
# p21val is 0.400039665288481
# pf12val is 0.210621659888393
# chi_f12 is 3.115383672195802
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8361,  0.6743],
#         [-0.3510, -0.1308],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.501
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 5299.882
# expected info is tensor([[0.0018]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4425, -0.2826]])
# new data istensor([[ 0.2541, -0.0071]])
# g_theta2 istensor([[-0.9449,  0.9497],
#         [-0.6949, -0.6102],
#         [ 0.2155, -0.2175]])
# p21val is 0.349662972335881
# pf12val is 0.830592082529446
# chi_f12 is 0.371232960122592
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2702, -0.4744],
#         [-0.2737, -0.9952],
#         [-0.4421, -0.2806]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.576
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 970.744
# expected info is tensor([[0.0109]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3335, -0.2422]])
# new data istensor([[-0.5824,  0.7591]])
# g_theta2 istensor([[-0.1842, -0.5173],
#         [ 0.1279, -1.2900],
#         [-0.1716, -0.5462]])
# p21val is 0.018790074914735
# pf12val is 0.171410263992197
# chi_f12 is 3.527390782686054
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8384, -0.1271],
#         [ 0.1696,  0.2723],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.543
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 6709.968
# expected info is tensor([[0.0018]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0627, -0.0115]])
# new data istensor([[0.1579, 0.1015]])
# g_theta2 istensor([[-1.0256, -0.0252],
#         [ 0.1849,  0.2960],
#         [ 0.2347, -0.2221]])
# p21val is 0.024412395947943
# pf12val is 0.748226064531792
# chi_f12 is 0.580100242717295
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3647,  0.0378],
#         [ 0.2583, -0.1745],
#         [-0.0630, -0.0113]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.556
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1435.269
# expected info is tensor([[2.7034e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.8998,  0.6201]])
# new data istensor([[-0.2269,  0.1417]])
# g_theta2 istensor([[ 0.1963,  0.0760],
#         [ 0.2570, -0.1200],
#         [ 0.1942, -0.2640]])
# p21val is 0.963524804957564
# pf12val is 0.504622957624407
# chi_f12 is 1.367887494261515
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3618, -0.0869],
#         [-0.1231, -0.7503],
#         [-0.8991,  0.6209]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.638
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 348.776
# expected info is tensor([[0.0050]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3454,  0.6046]])
# new data istensor([[-0.5077,  0.5394]])
# g_theta2 istensor([[ 0.2497,  0.0067],
#         [-0.0347, -0.4415],
#         [-0.7053,  0.8207]])
# p21val is 0.085741766280284
# pf12val is 0.909705528857105
# chi_f12 is 0.189268653003628
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2308, -0.3515],
#         [-0.5271, -0.6926],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.643
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 7291.969
# expected info is tensor([[0.0001]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3943,  0.4076]])
# new data istensor([[0.0785, 0.0668]])
# g_theta2 istensor([[-0.2346, -0.5158],
#         [-0.4046, -0.5529],
#         [ 0.2307, -0.2327]])
# p21val is 0.965701746796477
# pf12val is 0.971438769604482
# chi_f12 is 0.057954077612192
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4512,  0.5134],
#         [-0.6733,  0.2353],
#         [-0.3963,  0.4079]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.713
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 9242.628
# expected info is tensor([[0.0071]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1875,  0.2437]])
# new data istensor([[0.1259, 0.1676]])
# g_theta2 istensor([[-0.6050,  0.6645],
#         [-0.7855,  0.1295],
#         [-0.6087,  0.6202]])
# p21val is 0.640037335204102
# pf12val is 0.378709844247783
# chi_f12 is 1.941969899134595
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0772,  0.2135],
#         [-0.1088, -0.3572],
#         [-0.1890,  0.2441]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.760
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 10385.996
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4352,  0.2631]])
# new data istensor([[0.0344, 0.0882]])
# g_theta2 istensor([[ 0.0611,  0.1221],
#         [-0.0249, -0.4363],
#         [-0.0082,  0.0585]])
# p21val is 0.702046101712646
# pf12val is 0.178563638747868
# chi_f12 is 3.445620443409107
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6941, -0.2328],
#         [-0.7923,  0.7942],
#         [-0.4349,  0.2623]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.789
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3066.098
# expected info is tensor([[0.0050]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0914,  0.5578]])
# new data istensor([[-0.3887,  0.3575]])
# g_theta2 istensor([[ 0.8874, -0.4198],
#         [-0.7212,  0.8107],
#         [-0.5993,  0.0476]])
# p21val is 0.275444071917292
# pf12val is 0.894832875006123
# chi_f12 is 0.222236619961151
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1690, -0.9736],
#         [ 0.5044,  0.9351],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.779
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 8441.990
# expected info is tensor([[0.0043]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6385, -0.2790]])
# new data istensor([[0.1169, 0.0529]])
# g_theta2 istensor([[-0.4254, -1.7228],
#         [ 0.9470,  1.0200],
#         [ 0.2269,  0.2316]])
# p21val is 0.910404121034512
# pf12val is 0.925896550105454
# chi_f12 is 0.153985535051030
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5236, -0.4774],
#         [ 0.5488,  0.2884],
#         [-0.6385, -0.2797]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.797
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 424.260
# expected info is tensor([[0.0018]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1846, -0.9287]])
# new data istensor([[-0.1257,  0.3348]])
# g_theta2 istensor([[ 0.6278, -0.5495],
#         [ 0.1939, -0.0139],
#         [-0.3898, -0.0415]])
# p21val is 0.191711198751554
# pf12val is 0.947242528670101
# chi_f12 is 0.108400233008477
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.7875, 0.1211],
#         [0.2477, 0.0890],
#         [0.0000, 0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.778
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 12630.794
# expected info is tensor([[9.2528e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3693, -0.2588]])
# new data istensor([[0.2474, 0.0228]])
# g_theta2 istensor([[0.9480, 0.1943],
#         [0.1908, 0.0268],
#         [0.2277, 0.2341]])
# p21val is 0.456927981124127
# pf12val is 0.212860511860238
# chi_f12 is 3.094236403383759
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1353,  0.7587],
#         [-0.0861, -0.0570],
#         [-0.3683, -0.2583]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.811
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 11807.069
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1499, -0.1903]])
# new data istensor([[0.2255, 0.0301]])
# g_theta2 istensor([[-0.1917,  1.0621],
#         [ 0.1330,  0.1860],
#         [-0.6144, -0.0272]])
# p21val is 0.096198116705170
# pf12val is 0.869233083345022
# chi_f12 is 0.280287938982901
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4846,  0.4606],
#         [ 0.3096,  0.7457],
#         [-0.1496, -0.1892]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.825
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 5328.161
# expected info is tensor([[0.0001]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1211, -0.4635]])
# new data istensor([[-0.2577,  0.4535]])
# g_theta2 istensor([[1.0005, 0.5801],
#         [0.5555, 1.0605],
#         [0.1068, 0.0582]])
# p21val is 0.075352776597646
# pf12val is 0.963791634921294
# chi_f12 is 0.073760308163570
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1785,  0.8282],
#         [ 0.5451, -0.3024],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.785
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 16066.511
# expected info is tensor([[0.0005]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4834, -0.3165]])
# new data istensor([[ 0.2397, -0.0078]])
# g_theta2 istensor([[-0.0539,  1.0474],
#         [ 0.6885, -0.5659],
#         [ 0.2191,  0.2304]])
# p21val is 0.426315725183947
# pf12val is 0.797738721694646
# chi_f12 is 0.451948303135074
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7755,  0.3836],
#         [-0.3406, -0.2649],
#         [-0.4835, -0.3168]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.840
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 7421.040
# expected info is tensor([[0.0028]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9747, -0.2234]])
# new data istensor([[-0.2720,  0.3493]])
# g_theta2 istensor([[-0.5912,  0.7425],
#         [-0.1775, -0.1122],
#         [-0.2487, -0.0885]])
# p21val is 0.974000582890078
# pf12val is 0.727868042218558
# chi_f12 is 0.635271015807898
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7836, -0.7209],
#         [-0.8456, -0.2436],
#         [-0.9753, -0.2229]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.868
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 295.216
# expected info is tensor([[0.0022]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.7684, -0.4141]])
# new data istensor([[-0.6318,  0.7196]])
# g_theta2 istensor([[-0.4196, -0.5184],
#         [-0.6517, -0.4507],
#         [-0.7271,  0.0503]])
# p21val is 0.077838369276184
# pf12val is 0.210870751472111
# chi_f12 is 3.113019770915473
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8551, -0.7844],
#         [ 0.5394, -0.5683],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.851
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3273.622
# expected info is tensor([[0.0011]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.0658, 0.7721]])
# new data istensor([[ 0.2730, -0.0464]])
# g_theta2 istensor([[-1.0461, -0.4278],
#         [ 0.6476, -0.6333],
#         [ 0.2236, -0.2237]])
# p21val is 0.903386919683462
# pf12val is 0.200574413098814
# chi_f12 is 3.213139926880221
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6729, -0.1543],
#         [ 0.3563, -0.0131],
#         [ 0.0658,  0.7727]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.859
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1358.445
# expected info is tensor([[0.0088]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.5719, 0.6689]])
# new data istensor([[0.1967, 0.3284]])
# g_theta2 istensor([[-0.6064, -0.0886],
#         [ 0.2779, -0.1015],
#         [-0.1389,  0.5684]])
# p21val is 0.127166495480462
# pf12val is 0.253048141206975
# chi_f12 is 2.748351053810680
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8776,  0.0591],
#         [ 0.9251,  0.4779],
#         [ 0.5720,  0.6705]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.876
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 4731.521
# expected info is tensor([[0.0042]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.7751, 0.8399]])
# new data istensor([[0.3506, 0.2444]])
# g_theta2 istensor([[-0.7733,  0.2279],
#         [ 0.9600,  0.4445],
#         [ 0.3542,  0.4500]])
# p21val is 0.364328818509941
# pf12val is 0.803305885116676
# chi_f12 is 0.438039419307669
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.8372, 0.3694],
#         [0.4126, 0.6979],
#         [0.7762, 0.8390]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.867
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 2790.671
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.6941, 0.0938]])
# new data istensor([[0.1708, 0.2582]])
# g_theta2 istensor([[1.0254, 0.1957],
#         [0.2165, 0.3805],
#         [0.5304, 1.1078]])
# p21val is 0.079028372199851
# pf12val is 0.312250575689538
# chi_f12 is 2.327898572593369
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5232,  0.1891],
#         [ 0.6890, -0.2020],
#         [ 0.6944,  0.0946]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.874
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 166.869
# expected info is tensor([[0.0056]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.3375, -0.3202]])
# new data istensor([[ 0.4835, -0.6084]])
# g_theta2 istensor([[ 0.3628,  0.3659],
#         [ 0.3956, -0.4556],
#         [ 0.4460,  0.2825]])
# p21val is 0.769548521899862
# pf12val is 0.094307940883688
# chi_f12 is 4.722379768306632
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2311, -0.6974],
#         [-0.5890,  0.0468],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.889
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 24912.063
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3016, -0.2804]])
# new data istensor([[ 0.2644, -0.0259]])
# g_theta2 istensor([[ 0.6149, -1.0089],
#         [-0.5305,  0.0969],
#         [ 0.2334,  0.2608]])
# p21val is 0.234043320931084
# pf12val is 0.429845750424009
# chi_f12 is 1.688657709188170
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2559, -0.6732],
#         [-0.4184,  0.0288],
#         [-0.3001, -0.2800]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.884
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 13600.746
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0215, -0.1611]])
# new data istensor([[-0.3794,  0.4203]])
# g_theta2 istensor([[ 0.5025, -0.4467],
#         [-0.6196,  0.1007],
#         [-0.0214, -0.0250]])
# p21val is 0.216472121390610
# pf12val is 0.100989616789937
# chi_f12 is 4.585475142971221
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6039, -0.1934],
#         [-0.4903, -0.1383],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.888
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 25813.166
# expected info is tensor([[8.5285e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5063, -0.3174]])
# new data istensor([[0.2590, 0.0248]])
# g_theta2 istensor([[-0.7601,  0.0859],
#         [-0.9988, -0.4808],
#         [ 0.2372,  0.2397]])
# p21val is 0.079116447842482
# pf12val is 0.515159205567418
# chi_f12 is 1.326558578134586
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2559,  0.1418],
#         [-0.2234, -0.8326],
#         [-0.5059, -0.3190]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.895
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 17864.382
# expected info is tensor([[0.0034]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9404, -0.1917]])
# new data istensor([[-0.2263,  0.3036]])
# g_theta2 istensor([[-0.4606, -0.0407],
#         [-0.0300, -0.5384],
#         [-0.2583, -0.1065]])
# p21val is 0.149186282570930
# pf12val is 0.670384695920973
# chi_f12 is 0.799807116710009
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6873, -0.3835],
#         [-0.3611, -0.2311],
#         [-0.9405, -0.1913]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.909
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 718.623
# expected info is tensor([[0.0006]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.5423,  0.2578]])
# new data istensor([[-0.6739,  0.8710]])
# g_theta2 istensor([[-0.5621, -0.5059],
#         [-0.4822, -0.3815],
#         [-0.6857, -0.0501]])
# p21val is 0.152768610771156
# pf12val is 0.822110201721054
# chi_f12 is 0.391761655115667
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4144, -0.7085],
#         [ 0.7387, -0.9315],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.905
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 35554.524
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1190, -0.2692]])
# new data istensor([[0.2291, 0.0216]])
# g_theta2 istensor([[-0.5977, -0.4285],
#         [ 1.1481, -1.2259],
#         [ 0.2115,  0.0132]])
# p21val is 0.496138757952449
# pf12val is 0.829967836477561
# chi_f12 is 0.372736660348392
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2307, -0.9548],
#         [ 0.4378, -0.1389],
#         [-0.1197, -0.2691]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 38
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.916
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1658.006
# expected info is tensor([[0.0026]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2390, -0.8035]])
# new data istensor([[-0.0380,  0.1960]])
# g_theta2 istensor([[ 0.4540, -1.1943],
#         [ 0.2516, -0.2098],
#         [ 0.1476,  0.0077]])
# p21val is 0.278614450095209
# pf12val is 0.777757663716010
# chi_f12 is 0.502680579103730
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3903, -0.8258],
#         [ 0.0768,  0.6847],
#         [ 0.2382, -0.8032]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 39
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.918
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 374.506
# expected info is tensor([[0.0010]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3735, -1.1945]])
# new data istensor([[-0.1315,  0.3448]])
# g_theta2 istensor([[-0.6742, -0.5103],
#         [-0.0861,  0.6039],
#         [ 0.4722, -0.5837]])
# p21val is 0.295867537032026
# pf12val is 0.887194802812992
# chi_f12 is 0.239381401857312
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7221,  0.1297],
#         [ 0.8021, -0.3741],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 40
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.926
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 18648.237
# expected info is tensor([[3.2801e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4519,  0.4538]])
# new data istensor([[0.0302, 0.0700]])
# g_theta2 istensor([[-0.8325,  0.1419],
#         [ 0.7772, -0.4981],
#         [ 0.2212, -0.2311]])
# p21val is 0.102807201821855
# pf12val is 0.751074045990831
# chi_f12 is 0.572502071105160
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1499,  0.0081],
#         [-0.2126,  0.1210],
#         [-0.4527,  0.4512]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 41
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.920
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 4066.938
# expected info is tensor([[0.0011]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.2218,  0.8482]])
# new data istensor([[-0.3191,  0.2697]])
# g_theta2 istensor([[-0.5717,  0.2953],
#         [-0.0761, -0.0049],
#         [-0.1719,  0.7187]])
# p21val is 0.369858538352097
# pf12val is 0.310504830600867
# chi_f12 is 2.339111640477811
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6116, -0.5350],
#         [ 0.9482, -0.8040],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 42
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.942
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 22165.599
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3251,  0.4018]])
# new data istensor([[0.0794, 0.1013]])
# g_theta2 istensor([[ 0.6605, -0.5804],
#         [ 1.1867, -0.8601],
#         [ 0.2251, -0.2374]])
# p21val is 0.763632064295636
# pf12val is 0.848863351872628
# chi_f12 is 0.327714114965695
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4737, -0.1577],
#         [-0.5356, -0.6999],
#         [-0.3274,  0.4015]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 43
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.944
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 7964.803
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0858,  0.5319]])
# new data istensor([[-0.3718,  0.3529]])
# g_theta2 istensor([[-0.6344,  0.1902],
#         [-0.7108, -0.4202],
#         [-0.2079,  0.3225]])
# p21val is 0.850624525682122
# pf12val is 0.457115500626954
# chi_f12 is 1.565638366837594
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7561,  0.2903],
#         [-0.6409,  0.1475],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 44
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.963
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 18509.316
# expected info is tensor([[0.0004]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4307,  0.7354]])
# new data istensor([[ 0.1452, -0.1205]])
# g_theta2 istensor([[-1.1193,  0.0740],
#         [-0.7501,  0.3428],
#         [ 0.2238, -0.2340]])
# p21val is 0.326482496165092
# pf12val is 0.110210511977958
# chi_f12 is 4.410725993626080
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1338,  0.2717],
#         [ 0.6939,  0.1439],
#         [-0.4309,  0.7358]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 45
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.972
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 559.367
# expected info is tensor([[0.0051]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6875,  1.2047]])
# new data istensor([[ 0.3432, -0.3544]])
# g_theta2 istensor([[ 0.2164,  0.1799],
#         [ 0.8470, -0.0022],
#         [-0.6068,  0.5386]])
# p21val is 0.240378779902262
# pf12val is 0.529691590106583
# chi_f12 is 1.270920694535875
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6503,  0.0574],
#         [ 0.6287, -0.8399],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 46
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.979
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 28422.554
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3073,  0.4299]])
# new data istensor([[0.0684, 0.0983]])
# g_theta2 istensor([[-0.6913,  0.1238],
#         [ 0.6111, -0.6154],
#         [ 0.2259, -0.2378]])
# p21val is 0.748378086678260
# pf12val is 0.618456544865589
# chi_f12 is 0.961056697051129
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7256,  0.3984],
#         [-0.7641, -0.3591],
#         [-0.3062,  0.4290]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 47
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.994
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 29764.487
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2697,  0.3195]])
# new data istensor([[0.0658, 0.1205]])
# g_theta2 istensor([[ 0.6330,  0.5705],
#         [-0.8189, -0.4018],
#         [-0.5676,  0.6989]])
# p21val is 0.121820991968430
# pf12val is 0.332100894168763
# chi_f12 is 2.204632916269279
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6264,  0.1255],
#         [-0.4951, -0.4263],
#         [-0.2684,  0.3198]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 48
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.990
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 11427.958
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0671,  0.5246]])
# new data istensor([[-0.4148,  0.3969]])
# g_theta2 istensor([[-0.7186,  0.1143],
#         [-0.5358, -0.5702],
#         [-0.1935,  0.7298]])
# p21val is 0.579120146705517
# pf12val is 0.022357545981458
# chi_f12 is 7.601182774200574
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7324, -0.2675],
#         [ 0.0063,  0.0924],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 49
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.991
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3357.432
# expected info is tensor([[0.0001]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1037, -0.9130]])
# new data istensor([[-0.0691,  0.2948]])
# g_theta2 istensor([[-0.9221, -0.5439],
#         [ 0.2068,  0.2973],
#         [ 0.2268,  0.2481]])
# p21val is 0.890452814835898
# pf12val is 0.463958503570019
# chi_f12 is 1.535920325432648
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1988, -0.0059],
#         [-0.5511, -0.1236],
#         [ 0.1033, -0.9142]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 50
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.998
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 233.883
# expected info is tensor([[0.0011]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.0637, -1.6414]])
# new data istensor([[-0.8112,  0.3014]])
# g_theta2 istensor([[ 0.0531, -0.1217],
#         [-0.2560, -0.0137],
#         [ 0.3512, -0.6726]])
# p21val is 0.325385473266741
# pf12val is 0.547235125224765
# chi_f12 is 1.205753447798416
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0423, -0.3463],
#         [ 0.0239, -0.5830],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 51
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.007
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 33419.465
# expected info is tensor([[7.6906e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3359,  0.5966]])
# new data istensor([[0.0554, 0.0193]])
# g_theta2 istensor([[-0.0667, -0.4244],
#         [-0.0336, -0.3789],
#         [ 0.2267, -0.2377]])
# p21val is 0.064443005398239
# pf12val is 0.129742167969754
# chi_f12 is 4.084412242452413
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3370,  0.5401],
#         [-0.3649,  0.7264],
#         [-0.3352,  0.5962]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 52
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.999
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 5728.143
# expected info is tensor([[0.0014]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.2470, 1.0012]])
# new data istensor([[ 0.4778, -0.1345]])
# g_theta2 istensor([[-0.5262,  0.3527],
#         [-0.6722,  0.8298],
#         [-0.5383,  0.3937]])
# p21val is 0.114969273866039
# pf12val is 0.460302555400051
# chi_f12 is 1.551742553154910
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2921,  0.7914],
#         [-0.5956, -0.4837],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 53
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.998
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 29784.747
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1045,  0.5934]])
# new data istensor([[0.0970, 0.0624]])
# g_theta2 istensor([[ 0.5882,  1.0405],
#         [-0.5640, -0.4370],
#         [ 0.2319, -0.2652]])
# p21val is 0.043283345799174
# pf12val is 0.377864394593212
# chi_f12 is 1.946439784378281
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3497,  0.1838],
#         [-0.0200,  0.5971],
#         [-0.1041,  0.5932]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 54
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.999
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 8856.540
# expected info is tensor([[0.0037]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.2884, 0.8379]])
# new data istensor([[0.2707, 0.0691]])
# g_theta2 istensor([[-0.0898,  0.4034],
#         [-0.2065,  0.3781],
#         [-0.2976,  0.3958]])
# p21val is 0.222413159216499
# pf12val is 0.162980531938249
# chi_f12 is 3.628249042540161
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3439,  0.8533],
#         [-0.3838,  0.2219],
#         [ 0.2887,  0.8372]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 55
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.998
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 413.636
# expected info is tensor([[0.0013]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.0786, 1.4504]])
# new data istensor([[ 0.9953, -0.5181]])
# g_theta2 istensor([[ 0.6862,  1.0913],
#         [-0.4092,  0.1385],
#         [-0.0507,  0.5230]])
# p21val is 0.185009566096674
# pf12val is 0.989618379243479
# chi_f12 is 0.020871771359844
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.3918, 0.9372],
#         [0.7619, 0.9375],
#         [0.0000, 0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 56
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.993
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 48324.591
# expected info is tensor([[0.0005]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2416,  0.1615]])
# new data istensor([[0.1218, 0.0762]])
# g_theta2 istensor([[ 0.3775,  0.9413],
#         [ 0.8269,  1.0110],
#         [ 0.2234, -0.2283]])
# p21val is 0.379265305698032
# pf12val is 0.199148934543510
# chi_f12 is 3.227404638777664
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8420, -0.4250],
#         [ 0.2577,  0.8856],
#         [-0.2420,  0.1615]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 57
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.996
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 17463.414
# expected info is tensor([[3.8901e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1526, -0.1416]])
# new data istensor([[-0.4839,  0.5717]])
# g_theta2 istensor([[ 1.2035, -0.9559],
#         [ 0.4153,  0.9977],
#         [-0.4756,  0.4782]])
# p21val is 0.147844768602862
# pf12val is 0.640992430644667
# chi_f12 is 0.889475261595711
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3402,  0.8308],
#         [-0.5996, -0.8532],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 58
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.011
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 47985.821
# expected info is tensor([[0.0007]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2276,  0.1685]])
# new data istensor([[0.1005, 0.1081]])
# g_theta2 istensor([[-0.4185,  0.9215],
#         [-0.3334, -0.5966],
#         [ 0.2468, -0.2709]])
# p21val is 0.679044229881953
# pf12val is 0.320315451659313
# chi_f12 is 2.276897964642748
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8948, -0.3157],
#         [-0.3342,  0.6146],
#         [-0.2270,  0.1688]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 59
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.010
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 26025.932
# expected info is tensor([[0.0007]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0882, -0.2076]])
# new data istensor([[-0.3688,  0.4916]])
# g_theta2 istensor([[-1.4942,  0.1799],
#         [-0.1374,  0.3247],
#         [-0.4478,  0.4801]])
# p21val is 0.316983039686641
# pf12val is 0.544997000367949
# chi_f12 is 1.213949976492121
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8033, -0.6995],
#         [-0.8221, -0.3927],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 60
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.012
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 50026.221
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4150, -0.2033]])
# new data istensor([[ 0.2417, -0.0286]])
# g_theta2 istensor([[-0.8909, -0.3955],
#         [-1.2283, -0.6387],
#         [ 0.2147, -0.0616]])
# p21val is 0.845929467863958
# pf12val is 0.199419908750519
# chi_f12 is 3.224685166311936
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1436, -0.0871],
#         [ 0.1278,  0.0949],
#         [-0.4156, -0.2042]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 61
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.032
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 31021.292
# expected info is tensor([[0.0005]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9025, -0.1996]])
# new data istensor([[-0.1565,  0.2526]])
# g_theta2 istensor([[-0.0038,  0.0420],
#         [ 0.2394, -0.0390],
#         [-0.1422,  0.0501]])
# p21val is 0.765860719881481
# pf12val is 0.090211524950385
# chi_f12 is 4.811196178014043
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1642, -0.0502],
#         [ 0.5387,  0.1178],
#         [-0.9018, -0.1999]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 62
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.034
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 33395.307
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.8693, -0.2073]])
# new data istensor([[-0.1514,  0.2474]])
# g_theta2 istensor([[ 0.0152,  0.0758],
#         [ 0.2312,  0.0288],
#         [-0.5191,  0.1502]])
# p21val is 0.701190083132869
# pf12val is 0.899215328786433
# chi_f12 is 0.212465505700149
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3443, -0.0283],
#         [ 0.4333, -0.9082],
#         [-0.8692, -0.2064]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 63
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.046
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 12835.161
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3748,  0.1893]])
# new data istensor([[-0.6528,  0.7766]])
# g_theta2 istensor([[ 0.1947, -0.0704],
#         [ 0.2446, -0.5978],
#         [-0.5779,  0.0643]])
# p21val is 0.611032459296944
# pf12val is 0.413669508810087
# chi_f12 is 1.765375823713247
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7052, -0.7307],
#         [-0.8505,  0.1230],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 64
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.053
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 8050.888
# expected info is tensor([[0.0010]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.0103, -0.8793]])
# new data istensor([[0.0021, 0.2610]])
# g_theta2 istensor([[ 0.8230, -0.7171],
#         [-0.6429, -0.1694],
#         [ 0.2225,  0.2627]])
# p21val is 0.402426822667558
# pf12val is 0.943287044066433
# chi_f12 is 0.116769296222342
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8767, -0.2265],
#         [-0.1140, -0.6285],
#         [ 0.0115, -0.8793]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 65
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.047
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 570.883
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6924, -1.4139]])
# new data istensor([[-0.2172,  0.2311]])
# g_theta2 istensor([[-0.8649, -0.2889],
#         [-0.1708, -0.4336],
#         [ 0.2462, -0.6604]])
# p21val is 0.518706143926738
# pf12val is 0.997959197554105
# chi_f12 is 0.004085775441559
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4417, -0.5424],
#         [-0.7908, -0.1556],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 66
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.060
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 55151.103
# expected info is tensor([[0.0008]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2044, -0.2936]])
# new data istensor([[ 0.2395, -0.0071]])
# g_theta2 istensor([[-0.7658, -0.4007],
#         [-1.0169,  0.0589],
#         [ 0.2157,  0.2223]])
# p21val is 0.119203244561968
# pf12val is 0.455841336783137
# chi_f12 is 1.571220951331799
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4751, -0.4865],
#         [ 0.9265, -0.4545],
#         [-0.2031, -0.2941]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 67
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.056
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 10926.804
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.3011, -0.9819]])
# new data istensor([[-0.2428,  0.2826]])
# g_theta2 istensor([[-0.4994, -0.4826],
#         [ 1.3545, -0.2220],
#         [ 0.1046,  0.0255]])
# p21val is 0.791600114681280
# pf12val is 0.752355339253385
# chi_f12 is 0.569093082068917
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8567,  0.3753],
#         [-0.8991, -0.9910],
#         [ 0.2996, -0.9817]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 68
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.071
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 2340.360
# expected info is tensor([[0.0006]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2363, -1.4942]])
# new data istensor([[-0.5792,  0.3276]])
# g_theta2 istensor([[ 0.3461,  0.0795],
#         [-1.1795, -0.5810],
#         [ 0.5265, -0.7621]])
# p21val is 0.806660455072542
# pf12val is 0.151456785857993
# chi_f12 is 3.774909873166687
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2857, -0.8189],
#         [ 0.1881, -0.0238],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 69
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.074
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 58674.365
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2401, -0.2218]])
# new data istensor([[0.2175, 0.0190]])
# g_theta2 istensor([[-0.7784, -1.3216],
#         [ 0.2311, -0.2821],
#         [ 0.2201,  0.2772]])
# p21val is 0.742170388079997
# pf12val is 0.203068938432400
# chi_f12 is 3.188419518803203
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4168,  0.3463],
#         [ 0.0518, -0.1824],
#         [-0.2391, -0.2224]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 70
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.071
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 15978.625
# expected info is tensor([[1.4431e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.2677,  0.3155]])
# new data istensor([[-0.5853,  0.6631]])
# g_theta2 istensor([[ 0.2002,  0.0841],
#         [ 0.2201, -0.0337],
#         [ 0.0522,  0.0761]])
# p21val is 0.156905532097829
# pf12val is 0.966566769676331
# chi_f12 is 0.068009797459889
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6263, -0.8161],
#         [ 0.9175,  0.5124],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 71
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.072
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 8257.892
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1603, -0.9907]])
# new data istensor([[-0.0134,  0.2862]])
# g_theta2 istensor([[ 0.7489, -0.8662],
#         [ 0.5862,  0.1960],
#         [ 0.2338,  0.2221]])
# p21val is 0.595501750517763
# pf12val is 0.421579198915661
# chi_f12 is 1.727495242815010
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9492, -0.0835],
#         [-0.1110, -0.4148],
#         [-0.1616, -0.9922]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.087
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3671.091
# expected info is tensor([[0.0006]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.7294, -1.0385]])
# new data istensor([[0.0686, 0.2397]])
# g_theta2 istensor([[ 0.5514, -0.5366],
#         [-0.2880, -0.5638],
#         [ 0.0780, -0.7483]])
# p21val is 0.665822772351517
# pf12val is 0.604382624736999
# chi_f12 is 1.007095593900254
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9049, -0.5557],
#         [-0.1228, -0.8181],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 73
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.091
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 63277.527
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2570, -0.1831]])
# new data istensor([[ 0.2442, -0.0034]])
# g_theta2 istensor([[-1.0475, -0.4772],
#         [-0.5306, -1.2274],
#         [ 0.2048,  0.2542]])
# p21val is 0.700334042545764
# pf12val is 0.814074717280589
# chi_f12 is 0.411406253842144
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6158, -0.7255],
#         [-0.3324, -0.1799],
#         [-0.2549, -0.1808]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 74
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.096
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 17103.786
# expected info is tensor([[7.7648e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.2131,  0.4438]])
# new data istensor([[-0.5804,  0.5620]])
# g_theta2 istensor([[ 0.0127, -0.2956],
#         [-0.6158,  0.2667],
#         [ 0.0248,  0.0768]])
# p21val is 0.554017879824414
# pf12val is 0.008949227977561
# chi_f12 is 9.432376019812672
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7143, -0.4072],
#         [-0.3467, -0.0348],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 75
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.095
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 11656.085
# expected info is tensor([[0.0005]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0970, -1.0247]])
# new data istensor([[-0.1282,  0.3595]])
# g_theta2 istensor([[ 0.7110, -0.5065],
#         [-0.7261, -0.2106],
#         [ 0.2375,  0.2167]])
# p21val is 0.529163138231249
# pf12val is 0.071885035383563
# chi_f12 is 5.265374333766275
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4334, -0.1504],
#         [-0.4252, -0.8012],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 76
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.095
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 61289.711
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3737, -0.1625]])
# new data istensor([[0.2306, 0.0105]])
# g_theta2 istensor([[ 0.1857, -0.0217],
#         [-0.7929, -1.1811],
#         [ 0.2342,  0.2678]])
# p21val is 0.151896778154038
# pf12val is 0.959812449886836
# chi_f12 is 0.082034756615274
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6754, -0.2901],
#         [-0.6914, -0.7035],
#         [-0.3739, -0.1627]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 77
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.098
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 19245.575
# expected info is tensor([[9.5642e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.2473,  0.4482]])
# new data istensor([[-0.5337,  0.5713]])
# g_theta2 istensor([[-0.9090, -0.4724],
#         [-0.8662, -0.4652],
#         [-0.1053,  0.1231]])
# p21val is 0.520144219891587
# pf12val is 0.786299217393794
# chi_f12 is 0.480835750574944
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8106, -0.6015],
#         [-0.7513, -0.3236],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# current sol istensor([[-1.2473,  0.4482]])
# Success is False and failure is True after 78 iterations

# %% [markdown]
# # Use GPU

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')

vf = ObjFun()
# f_target = vf.tgt_vec
# print(f_target)
sample_size = 4
D = vf.D
N = vf.N

vf.low = -1.
vf.high = 1.

high_minus_low = vf.high- vf.low
#high_minus_low = -
def g_theta(sample_size, D):
#     loc_x = (2. - 1.0 )  * np.random.random_sample((sample_size,1)) + 1.0
    
#     loc_y = (2.  -1.0)  * np.random.random_sample((sample_size,1)) - 2.
#     loc = np.concatenate((loc_x, loc_y), 1)
    loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
if use_cuda:
    train_x = train_x.cuda()
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    out = torch.zeros(x.shape[0], N)
    randn = torch.randn(Tensor(vf(x[:,0], x[:,1])).size())
    randn = randn.to(x.device)
    out = vf(x[:,0], x[:,1]) + randn * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([[ 0.4861, -0.9694],
#         [ 0.1601, -0.8918],
#         [ 0.5152, -0.9356],
#         [-0.0589, -0.9228]], device='cuda:0')

# %%
gpu_hyper_opti = []
gpu_conduct_design = []
gpu_total = []

# %%
x0 = x0_copy
loc_sample0 = loc_sample0_copy
x_train = x_train_copy
y_train = y_train_copy

# This will make TAD fail to find a solution
f_target = Tensor([[-1., -1.]]).reshape(2,1)
tol_vector = 0.01 * torch.ones(f_target.shape)
#####

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 100
iter_param = 100
num_base_kernels = 2
max_iter = 50

# f_target = f_target.reshape(2,1) 
# tol_vector = 0.01 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten().to(device)

data_fit_vec = torch.empty((1,1)).to(device)
entropy_vec = torch.empty((1,1)).to(device)
loss_vec = torch.empty((1,1)).to(device)




#
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])
p21_vec = torch.empty((1,1))

lr_new = .01

    
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False


g_theta1 = g_theta1.to(device)
agg_data = agg_data.to(device)


while(SUCCESS == False and FAILURE == False):
    total_time_start = time.time()
    
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None


        loc_sample_old = loc_sample.clone()
        x0_old = x0.clone()
        hyper_opti_start = time.time()
        
        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)
        
        hyper_opti_end = time.time()
        gpu_hyper_opti.append(hyper_opti_end - hyper_opti_start)
        
# Before this is hyper_opti

        print('END HYPERPARAMETERS optimization')

 #     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
        
#     """end for CPU"""
    
    model.eval()
    likelihood.eval()
   
    conduct_design_start = time.time()
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
    conduct_design_end = time.time()
    gpu_conduct_design.append(conduct_design_end - conduct_design_start)


    cur_model = model
    cur_likelihood = likelihood
    
  
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])

    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
    
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    
    print('expected info is '+str(entropy))
    
    if not SUCCESS:
    


        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape)).cpu()
                
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value)
               
                eye = torch.eye(Qf12.shape[0]).to(device)
                chi_f12 = (Qf12 + noise_value*eye).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape)).cpu()
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                p21_vec = torch.cat([p21_vec, Tensor([p_val]).reshape(1,1)], 0)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    sum = torch.zeros(2, 2).to(device) #replace with num_tasks
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    x0_old = x0_old.to(device)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_old).t(), (g_theta2.detach()[i] - x0_old) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_old, covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    loc_sample = torch.cat([loc_sample, x0_old],0)
                    
                    x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
                        PATH = ".//model_Carlo/model_update/model_base_"+str(iter)+".pt"
                        torch.save(model, PATH)
                        
                        entropy_vec = torch.cat([entropy_vec, entropy], 0)
                        data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is ' + str(num_base_kernels))
#     #                         
                        loc_sample = loc_sample_old
                        #x0 = x0_old
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                        g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                        print('acquiring 2, new size is ' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
                    torch.save(model, PATH)
                    vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                    loss_vec = torch.cat([loss_vec, -loss])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy < thresh_EI):
                        count_EI = count_EI + 1
                    else:
                        count_EI = 0
                    if (count_EI >= max_count_EI):
                        FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2).to(device)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum# + torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -1. or loc_sample[i,0] > 1. or loc_sample[i,1] < -1. or loc_sample[i,1] > 1.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target.to(device) - pf1).cpu()
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        
                        rand = torch.randn(x0_new.detach().size()).to(device)
                        x0 = (x0_new.detach()) + rand * .001
                        loc_sample[-1] = (x0_new.detach()) + rand * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -1. or x0_new.detach()[0,0] > 1. or x0_new.detach()[0,1] < -1. or x0_new.detach()[0,1] > 1.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                        x0 = x0.reshape(1,2)
                        #x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
        total_time_end = time.time()
        gpu_total.append(total_time_end - total_time_start)
        
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
torch.save(model, PATH)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[-0.1492,  0.1147],
#         [-0.0187,  0.1390],
#         [ 0.0143, -0.1227]])
# 0
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.510
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 3842.096
# expected info is tensor([[0.2179]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4191, -0.4942]], device='cuda:0')
# new data istensor([[0.0794, 0.0394]], device='cuda:0')
# g_theta2 istensor([[-0.1492,  0.1147],
#         [-0.0187,  0.1390],
#         [ 0.0143, -0.1227]], device='cuda:0')
# p21val is 0.193189312942105
# pf12val is 0.000000000392763
# chi_f12 is 43.315627778944190
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1105, -0.0463],
#         [ 0.4858,  0.8109],
#         [ 0.4207, -0.4938]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.195
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 320.951
# expected info is tensor([[0.0080]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.7822, -0.2026]], device='cuda:0')
# new data istensor([[0.2670, 0.0563]], device='cuda:0')
# g_theta2 istensor([[-0.0642,  0.0764],
#         [ 0.4941,  0.8423],
#         [ 0.3359, -0.5522]], device='cuda:0')
# p21val is 0.000045863599080
# pf12val is 0.000002545700116
# chi_f12 is 25.762209702263640
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# Using CUDA for conduct_design_opti()
# Loss design: 302.658
# expected info is tensor([[0.0111]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.7980, -0.2001]], device='cuda:0')
# new data istensor([[ 0.2846, -0.0284]], device='cuda:0')
# g_theta2 istensor([[ 0.4750,  0.8228],
#         [ 0.2381,  0.4741],
#         [ 0.3332, -0.5538]], device='cuda:0')
# p21val is 0.000000002548436
# pf12val is 0.000000047415137
# chi_f12 is 33.728648609663082
# patience is 2.000
# adding complexity to model
# num base is 3
# acquiring 2, new size is 11
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.223
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 137.343
# expected info is tensor([[0.0077]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.3454, 0.0152]], device='cuda:0')
# new data istensor([[ 0.5391, -0.5425]], device='cuda:0')
# g_theta2 istensor([[-0.0537, -0.1990],
#         [ 0.4600,  0.8369],
#         [ 0.3620, -0.5367]], device='cuda:0')
# p21val is 0.438163988751717
# pf12val is 0.035053229098214
# chi_f12 is 6.701775082816089
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1023,  0.0261],
#         [-0.7821,  0.5368],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.306
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 14632.612
# expected info is tensor([[0.0050]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0942, 0.1101]], device='cuda:0')
# g_theta2 istensor([[ 0.5335,  0.6497],
#         [-0.9946,  0.7606],
#         [ 0.4004, -0.5797]], device='cuda:0')
# p21val is 0.000114021572357
# pf12val is 0.200333151116213
# chi_f12 is 3.215547085370207
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# Using CUDA for conduct_design_opti()
# Loss design: 1095.902
# expected info is tensor([[0.0352]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5299,  0.2770]], device='cuda:0')
# new data istensor([[0.0349, 0.1191]], device='cuda:0')
# g_theta2 istensor([[ 0.8344, -0.4460],
#         [ 0.3125,  0.7119],
#         [ 0.0512, -0.2276]], device='cuda:0')
# p21val is 0.014638445890476
# pf12val is 0.053193964764813
# chi_f12 is 5.867620666680522
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4612,  0.0375],
#         [-0.7253, -0.3693],
#         [-0.5296,  0.2767]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.347
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 277.470
# expected info is tensor([[0.0115]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0069,  0.3359]], device='cuda:0')
# new data istensor([[-0.4144,  0.4121]], device='cuda:0')
# g_theta2 istensor([[ 0.8030, -0.3760],
#         [-0.0998, -0.6443],
#         [-0.3202,  0.0715]], device='cuda:0')
# p21val is 0.000349957902608
# pf12val is 0.013890422452340
# chi_f12 is 8.553111417086104
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# Using CUDA for conduct_design_opti()
# Loss design: 250.208
# expected info is tensor([[0.0965]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.8680, -0.0815]], device='cuda:0')
# new data istensor([[-0.2005,  0.2558]], device='cuda:0')
# g_theta2 istensor([[ 0.1170, -0.5790],
#         [-1.2800,  1.1513],
#         [-0.3727,  0.4204]], device='cuda:0')
# p21val is 0.069124708562472
# pf12val is 0.694579455897275
# chi_f12 is 0.728897431984540
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9408,  0.3875],
#         [-0.7020, -0.4553],
#         [-0.8678, -0.0837]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.177
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 103.359
# expected info is tensor([[0.1212]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1124, -0.4237]], device='cuda:0')
# new data istensor([[-0.2479,  0.4947]], device='cuda:0')
# g_theta2 istensor([[-0.7949,  0.5294],
#         [-0.4325, -0.2606],
#         [-0.7539,  0.0034]], device='cuda:0')
# p21val is 0.183442146424110
# pf12val is 0.718137471703223
# chi_f12 is 0.662188526986464
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6073,  0.5810],
#         [-0.0165, -0.4901],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.275
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 11954.137
# expected info is tensor([[0.0053]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1219, 0.1258]], device='cuda:0')
# g_theta2 istensor([[-0.8083,  0.3748],
#         [ 0.0449, -0.4285],
#         [-0.2857, -0.3175]], device='cuda:0')
# p21val is 0.181697357072532
# pf12val is 0.926699710172188
# chi_f12 is 0.152251406284233
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.0072e-01,  3.8686e-01],
#         [ 7.6945e-01, -6.4575e-01],
#         [-7.0200e-04, -3.6954e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.397
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 780.933
# expected info is tensor([[0.0128]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.4370, 0.0459]], device='cuda:0')
# new data istensor([[0.0569, 0.2655]], device='cuda:0')
# g_theta2 istensor([[ 0.0525,  0.2402],
#         [ 0.6255, -0.5401],
#         [-0.1545, -0.1823]], device='cuda:0')
# p21val is 0.209169862221723
# pf12val is 0.199909563229272
# chi_f12 is 3.219780397107383
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7593,  0.0546],
#         [ 0.8138, -0.7118],
#         [ 0.4373,  0.0468]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.450
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 930.367
# expected info is tensor([[0.1172]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.9561, 0.0265]], device='cuda:0')
# new data istensor([[0.4359, 0.0184]], device='cuda:0')
# g_theta2 istensor([[ 1.1357,  0.5948],
#         [ 0.8595, -1.2561],
#         [ 0.2085,  0.2828]], device='cuda:0')
# p21val is 0.003486986401538
# pf12val is 0.038653023471251
# chi_f12 is 6.506260560135495
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# Using CUDA for conduct_design_opti()
# Loss design: 457.046
# expected info is tensor([[0.0548]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.8168, 0.4454]], device='cuda:0')
# new data istensor([[0.3264, 0.4034]], device='cuda:0')
# g_theta2 istensor([[ 0.5955,  1.0170],
#         [-0.5115,  1.5100],
#         [ 0.2560, -0.1504]], device='cuda:0')
# p21val is 0.000469312840318
# pf12val is 0.000157973468348
# chi_f12 is 17.506166921765665
# patience is 2.000
# adding complexity to model
# num base is 4
# acquiring 2, new size is 38
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.349
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 86.487
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.3573, 0.7928]], device='cuda:0')
# new data istensor([[0.4151, 0.0294]], device='cuda:0')
# g_theta2 istensor([[ 0.5368, -0.1325],
#         [ 0.8874, -0.6281],
#         [ 0.3968,  0.0036]], device='cuda:0')
# p21val is 0.795347518385973
# pf12val is 0.040199590998612
# chi_f12 is 6.427796915145621
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.0294, 0.6566],
#         [0.6136, 0.8461],
#         [0.0000, 0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.379
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 17243.306
# expected info is tensor([[0.0015]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0855, 0.1194]], device='cuda:0')
# g_theta2 istensor([[ 0.2017,  0.8699],
#         [ 0.5997,  0.9045],
#         [ 0.3825, -0.3734]], device='cuda:0')
# p21val is 0.148363405927972
# pf12val is 0.337569291870528
# chi_f12 is 2.171968960993205
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 6.0760e-01, -9.5580e-01],
#         [ 4.7256e-01,  9.2454e-02],
#         [-7.1447e-04,  3.2374e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.429
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1022.808
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3345,  0.7534]], device='cuda:0')
# new data istensor([[ 0.1479, -0.1468]], device='cuda:0')
# g_theta2 istensor([[ 0.6138, -0.9597],
#         [ 0.1336,  0.2866],
#         [ 0.1853, -0.2036]], device='cuda:0')
# p21val is 0.990345204531632
# pf12val is 0.457934186669839
# chi_f12 is 1.562059604841630
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7883, -0.7899],
#         [-0.0721,  0.9560],
#         [-0.3355,  0.7538]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.510
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 978.087
# expected info is tensor([[0.0463]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4295,  1.1475]], device='cuda:0')
# new data istensor([[ 0.4819, -0.3713]], device='cuda:0')
# g_theta2 istensor([[ 0.7891, -0.7882],
#         [ 0.2706,  1.1672],
#         [-0.1426,  0.5829]], device='cuda:0')
# p21val is 0.433509515606386
# pf12val is 0.178787524719555
# chi_f12 is 3.443114381877835
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2986, -0.9455],
#         [-0.6630, -0.9943],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.488
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 23241.274
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1363, 0.0747]], device='cuda:0')
# g_theta2 istensor([[-0.2492, -0.9846],
#         [-0.7972, -1.0237],
#         [ 0.3701, -0.3919]], device='cuda:0')
# p21val is 0.374088116814384
# pf12val is 0.101293392595806
# chi_f12 is 4.579468191914846
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-4.8166e-01, -4.6124e-02],
#         [ 6.0640e-01,  2.9326e-01],
#         [-2.5860e-03,  5.4213e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.546
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 4906.786
# expected info is tensor([[0.0045]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4838,  0.0372]], device='cuda:0')
# new data istensor([[0.1267, 0.0291]], device='cuda:0')
# g_theta2 istensor([[-0.7122, -0.3218],
#         [ 0.2725,  0.4518],
#         [ 0.1584, -0.2066]], device='cuda:0')
# p21val is 0.661707754136652
# pf12val is 0.233901416632478
# chi_f12 is 2.905711097674231
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8594,  0.0980],
#         [-0.1094,  0.1657],
#         [-0.4841,  0.0369]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.608
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 7243.808
# expected info is tensor([[0.0037]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6170, -0.0450]], device='cuda:0')
# new data istensor([[0.0226, 0.0951]], device='cuda:0')
# g_theta2 istensor([[ 1.0759, -0.0958],
#         [-0.0051,  0.1173],
#         [-0.2641,  0.2582]], device='cuda:0')
# p21val is 0.810977705983454
# pf12val is 0.294865852546075
# chi_f12 is 2.442469526397104
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8202, -0.2044],
#         [-0.0957,  0.2430],
#         [-0.6167, -0.0443]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.628
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 292.096
# expected info is tensor([[0.0039]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1846,  0.4360]], device='cuda:0')
# new data istensor([[-0.5171,  0.5537]], device='cuda:0')
# g_theta2 istensor([[-0.7913, -0.1477],
#         [-0.2329,  0.2369],
#         [-0.8361, -0.2308]], device='cuda:0')
# p21val is 0.306284583033541
# pf12val is 0.448513279576145
# chi_f12 is 1.603633978112383
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6781, -0.4787],
#         [-0.9382,  0.6737],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.605
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 30727.487
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0900, 0.1416]], device='cuda:0')
# g_theta2 istensor([[-0.8755, -0.2509],
#         [-0.8202,  0.5508],
#         [ 0.3667, -0.3686]], device='cuda:0')
# p21val is 0.973400754433160
# pf12val is 0.124348114357969
# chi_f12 is 4.169340545673377
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 9.0637e-01, -4.4353e-01],
#         [ 4.0734e-01, -2.8389e-01],
#         [ 1.8525e-04, -1.1327e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.652
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 5222.898
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5043,  0.8071]], device='cuda:0')
# new data istensor([[ 0.1365, -0.1384]], device='cuda:0')
# g_theta2 istensor([[ 0.9777, -0.3605],
#         [ 0.4101, -0.4305],
#         [ 0.2121, -0.2242]], device='cuda:0')
# p21val is 0.253936670957291
# pf12val is 0.597171765204022
# chi_f12 is 1.031100986123320
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0365,  0.0500],
#         [ 0.0077,  0.3244],
#         [-0.5039,  0.8052]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.721
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 506.523
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9453,  1.3232]], device='cuda:0')
# new data istensor([[ 0.1852, -0.2145]], device='cuda:0')
# g_theta2 istensor([[-0.4564,  0.1397],
#         [ 0.1442,  0.1768],
#         [-0.2934,  0.5938]], device='cuda:0')
# p21val is 0.598139360779286
# pf12val is 0.426541946270744
# chi_f12 is 1.704089133792851
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3357,  0.2235],
#         [-0.6958,  0.6141],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.746
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 33624.988
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1126, 0.1187]], device='cuda:0')
# g_theta2 istensor([[-0.4015,  0.2674],
#         [-0.7504,  0.6176],
#         [ 0.3386, -0.3460]], device='cuda:0')
# p21val is 0.320759120422154
# pf12val is 0.924784842815855
# chi_f12 is 0.156388341774149
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 2.9584e-01, -2.2240e-01],
#         [ 4.5857e-01, -3.7645e-01],
#         [-4.1267e-04, -1.3795e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.769
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1751.008
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4340, -0.6828]], device='cuda:0')
# new data istensor([[0.3606, 0.1202]], device='cuda:0')
# g_theta2 istensor([[ 0.4100, -0.3688],
#         [ 0.5274, -0.5637],
#         [ 0.1937,  0.1516]], device='cuda:0')
# p21val is 0.546506909223502
# pf12val is 0.244684080782807
# chi_f12 is 2.815574733413866
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4485, -0.4229],
#         [-0.7475, -0.6958],
#         [-0.4339, -0.6839]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.806
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 239.879
# expected info is tensor([[0.0048]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1604, -1.2509]], device='cuda:0')
# new data istensor([[-0.5287,  0.3930]], device='cuda:0')
# g_theta2 istensor([[ 0.5338, -0.4318],
#         [-0.8390, -0.6320],
#         [-0.6767, -0.4458]], device='cuda:0')
# p21val is 0.157917257408150
# pf12val is 0.251869667577320
# chi_f12 is 2.757687034828398
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9789,  0.1994],
#         [-0.2179, -0.6889],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.796
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 38645.038
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0996, 0.1367]], device='cuda:0')
# g_theta2 istensor([[ 1.0797,  0.2960],
#         [-0.3931, -0.8739],
#         [ 0.3449, -0.3589]], device='cuda:0')
# p21val is 0.355563577261621
# pf12val is 0.360037059299660
# chi_f12 is 2.043096620662283
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-7.0819e-01,  4.6220e-01],
#         [-7.6052e-01,  1.5239e-01],
#         [-1.1137e-03,  7.5658e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.785
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 9276.864
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3194, -0.6267]], device='cuda:0')
# new data istensor([[0.3298, 0.0652]], device='cuda:0')
# g_theta2 istensor([[-0.8591,  0.5525],
#         [-1.0273, -0.2252],
#         [ 0.2035,  0.1842]], device='cuda:0')
# p21val is 0.749748086172983
# pf12val is 0.387391201611499
# chi_f12 is 1.896640479293722
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7891, -0.6470],
#         [-0.8789,  0.7422],
#         [-0.3198, -0.6271]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.826
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1968.906
# expected info is tensor([[0.0033]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1519, -0.9605]], device='cuda:0')
# new data istensor([[-0.1487,  0.3082]], device='cuda:0')
# g_theta2 istensor([[-0.7736, -0.6214],
#         [-0.8191,  0.5688],
#         [-0.5319, -0.3974]], device='cuda:0')
# p21val is 0.682558331421219
# pf12val is 0.425910902393527
# chi_f12 is 1.707050207797008
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4057, -0.5510],
#         [ 0.0116,  0.3874],
#         [ 0.1524, -0.9603]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.839
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 86.887
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5822, -1.4816]], device='cuda:0')
# new data istensor([[-0.5808,  0.2779]], device='cuda:0')
# g_theta2 istensor([[-0.2454, -0.8207],
#         [ 0.0320,  0.1927],
#         [-0.0773, -0.7347]], device='cuda:0')
# p21val is 0.766332439542318
# pf12val is 0.314191735343261
# chi_f12 is 2.315503714630826
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8209,  0.7468],
#         [-0.7536, -0.3151],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.855
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 46398.944
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1440, 0.1307]], device='cuda:0')
# g_theta2 istensor([[-0.7375,  0.6707],
#         [-0.8374, -0.3732],
#         [ 0.3014,  0.3037]], device='cuda:0')
# p21val is 0.211966689017471
# pf12val is 0.288836593224274
# chi_f12 is 2.483788344299886
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1719,  0.6216],
#         [-0.4749, -0.3266],
#         [ 0.0030, -0.0012]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.867
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 16178.649
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3753, -0.3548]], device='cuda:0')
# new data istensor([[ 0.3288, -0.0230]], device='cuda:0')
# g_theta2 istensor([[ 0.0583,  0.8517],
#         [-0.7563, -0.5976],
#         [ 0.2193,  0.2275]], device='cuda:0')
# p21val is 0.230474914098864
# pf12val is 0.319675761554300
# chi_f12 is 2.280896084022114
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8196, -0.7302],
#         [-0.2293, -0.5965],
#         [-0.3750, -0.3535]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.869
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 2501.823
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1724,  0.1948]], device='cuda:0')
# new data istensor([[-0.5592,  0.6325]], device='cuda:0')
# g_theta2 istensor([[-0.4897, -0.4634],
#         [-0.0752, -0.7496],
#         [-0.1277, -0.5914]], device='cuda:0')
# p21val is 0.854817237594551
# pf12val is 0.898507115740749
# chi_f12 is 0.214041306423954
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4197,  0.9149],
#         [-0.4480,  0.9721],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.894
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 49533.058
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0936, 0.1179]], device='cuda:0')
# g_theta2 istensor([[ 0.5898,  0.8017],
#         [-0.5966,  0.7805],
#         [ 0.2999,  0.3039]], device='cuda:0')
# p21val is 0.118030015220600
# pf12val is 0.482834066455195
# chi_f12 is 1.456164464134822
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 6.0340e-01, -3.6845e-02],
#         [ 3.1122e-01, -8.7148e-01],
#         [-2.9231e-04, -4.3540e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.892
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 19388.675
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4642, -0.0785]], device='cuda:0')
# new data istensor([[0.1592, 0.0210]], device='cuda:0')
# g_theta2 istensor([[ 0.4289, -0.2220],
#         [ 0.0670, -0.7904],
#         [ 0.2609,  0.2277]], device='cuda:0')
# p21val is 0.784138156536793
# pf12val is 0.801373006220806
# chi_f12 is 0.442857529251287
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3728,  0.3965],
#         [-0.7017,  0.4208],
#         [-0.4639, -0.0780]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.930
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 7577.327
# expected info is tensor([[0.0014]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9989,  0.1536]], device='cuda:0')
# new data istensor([[-0.4192,  0.4075]], device='cuda:0')
# g_theta2 istensor([[-0.5010,  0.4267],
#         [-0.8841,  0.6160],
#         [-0.8637, -0.3218]], device='cuda:0')
# p21val is 0.188894957045235
# pf12val is 0.815290723381895
# chi_f12 is 0.408421027086450
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0905,  0.7225],
#         [-0.4452,  0.1340],
#         [-0.9991,  0.1525]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.938
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 370.395
# expected info is tensor([[0.0030]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4925, -0.2082]], device='cuda:0')
# new data istensor([[-0.6710,  0.8565]], device='cuda:0')
# g_theta2 istensor([[-0.3057,  0.4960],
#         [-0.6833,  0.3153],
#         [-0.7855,  0.3613]], device='cuda:0')
# p21val is 0.594405195761091
# pf12val is 0.027922311307013
# chi_f12 is 7.156658442623644
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8056,  0.2175],
#         [-0.0961,  0.4261],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.941
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 51298.034
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0696, 0.1252]], device='cuda:0')
# g_theta2 istensor([[-0.8780,  0.2849],
#         [-0.0889,  0.4195],
#         [ 0.2991,  0.3027]], device='cuda:0')
# p21val is 0.688003622054950
# pf12val is 0.060672718238785
# chi_f12 is 5.604522268719007
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4550, -0.0175],
#         [-0.3943,  0.2247],
#         [ 0.0006, -0.0012]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.946
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 21765.940
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3444, -0.2186]], device='cuda:0')
# new data istensor([[ 0.2156, -0.0068]], device='cuda:0')
# g_theta2 istensor([[ 0.1319, -0.3679],
#         [-0.4514,  0.2925],
#         [ 0.2399,  0.2597]], device='cuda:0')
# p21val is 0.857102870248594
# pf12val is 0.079169523425475
# chi_f12 is 5.072327718904392
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4867,  0.1022],
#         [-0.6929, -0.2411],
#         [-0.3460, -0.2189]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.949
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 250.821
# expected info is tensor([[0.0015]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1789, -1.0286]], device='cuda:0')
# new data istensor([[-0.0822,  0.2931]], device='cuda:0')
# g_theta2 istensor([[-0.6165,  0.2658],
#         [-0.9989, -0.3110],
#         [-0.0933,  0.0376]], device='cuda:0')
# p21val is 0.161244829585400
# pf12val is 0.929043952889008
# chi_f12 is 0.147198458486672
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7288,  0.0319],
#         [ 0.7098, -0.4547],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.959
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 58299.219
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1134, 0.1109]], device='cuda:0')
# g_theta2 istensor([[-0.8722,  0.1747],
#         [ 0.7059, -0.4416],
#         [ 0.3059,  0.3059]], device='cuda:0')
# p21val is 0.711409893651948
# pf12val is 0.954010619641142
# chi_f12 is 0.094160951792994
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2790,  0.0699],
#         [ 0.2022, -0.0388],
#         [-0.0007, -0.0008]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 38
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.961
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 23996.050
# expected info is tensor([[6.3799e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2562, -0.4929]], device='cuda:0')
# new data istensor([[0.3229, 0.0556]], device='cuda:0')
# g_theta2 istensor([[-0.4765,  0.3344],
#         [ 0.3845,  0.1050],
#         [ 0.2319,  0.2386]], device='cuda:0')
# p21val is 0.791418057864675
# pf12val is 0.367852289535570
# chi_f12 is 2.000147617044374
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2610,  0.3713],
#         [ 0.2086, -0.7015],
#         [-0.2542, -0.4925]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 39
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.992
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 2783.571
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4553, -1.2276]], device='cuda:0')
# new data istensor([[-0.5276,  0.3166]], device='cuda:0')
# g_theta2 istensor([[-0.6608,  0.2051],
#         [ 0.8216, -1.2533],
#         [-0.4906, -0.2536]], device='cuda:0')
# p21val is 0.110682435086204
# pf12val is 0.344123811107696
# chi_f12 is 2.133507540704450
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9874, -0.3313],
#         [-0.7092,  0.5103],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 40
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.970
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 65497.544
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1254, 0.1294]], device='cuda:0')
# g_theta2 istensor([[ 0.9681, -0.2973],
#         [-0.7798,  0.5718],
#         [ 0.3098,  0.3100]], device='cuda:0')
# p21val is 0.318425667478436
# pf12val is 0.732717591596842
# chi_f12 is 0.621989857656009
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 4.9033e-01, -4.4797e-01],
#         [-9.2959e-01,  3.0914e-01],
#         [ 2.1110e-04,  6.4843e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 41
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.984
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 30189.194
# expected info is tensor([[2.4660e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2381, -0.4642]], device='cuda:0')
# new data istensor([[0.3292, 0.0051]], device='cuda:0')
# g_theta2 istensor([[ 0.6532, -0.5504],
#         [-0.8694,  0.1923],
#         [ 0.2545,  0.2581]], device='cuda:0')
# p21val is 0.312522864572226
# pf12val is 0.599199763269405
# chi_f12 is 1.024320483713936
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4427, -0.9221],
#         [ 0.5567, -0.9824],
#         [-0.2374, -0.4635]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 42
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.996
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 5918.860
# expected info is tensor([[0.0073]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4056, -1.1232]], device='cuda:0')
# new data istensor([[-0.4005,  0.3279]], device='cuda:0')
# g_theta2 istensor([[ 0.8166, -1.2196],
#         [ 1.5088, -1.8049],
#         [-0.4693, -0.2313]], device='cuda:0')
# p21val is 0.712991060136624
# pf12val is 0.669229095349944
# chi_f12 is 0.803257666010721
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9012,  0.9226],
#         [ 0.1692, -0.9123],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 43
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.997
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 65718.276
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1383, 0.0894]], device='cuda:0')
# g_theta2 istensor([[ 0.8821,  0.8864],
#         [ 0.0968, -0.8639],
#         [ 0.3074,  0.3080]], device='cuda:0')
# p21val is 0.994062172015585
# pf12val is 0.201631597436210
# chi_f12 is 3.202626043503543
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3446,  0.8663],
#         [ 0.9087,  0.0247],
#         [-0.0021,  0.0010]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 44
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.000
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 37634.111
# expected info is tensor([[0.0016]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3059, -0.2878]], device='cuda:0')
# new data istensor([[ 0.3005, -0.0895]], device='cuda:0')
# g_theta2 istensor([[-0.0074,  0.5797],
#         [ 1.0733, -0.1716],
#         [ 0.2013,  0.1991]], device='cuda:0')
# p21val is 0.075961429142754
# pf12val is 0.000219291382057
# chi_f12 is 16.850218401634798
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6760, -0.9189],
#         [-0.4869,  0.1039],
#         [-0.3049, -0.2862]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 45
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.985
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 18555.253
# expected info is tensor([[0.0017]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9336,  0.0302]], device='cuda:0')
# new data istensor([[-0.3336,  0.3514]], device='cuda:0')
# g_theta2 istensor([[-0.5726, -0.7907],
#         [-0.8704,  0.4978],
#         [-0.5900, -0.4618]], device='cuda:0')
# p21val is 0.346495801952218
# pf12val is 0.083610423954287
# chi_f12 is 4.963174156432069
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0840, -0.9801],
#         [-0.1378, -0.0061],
#         [-0.9341,  0.0304]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 46
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.984
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 544.418
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4638,  0.6748]], device='cuda:0')
# new data istensor([[-0.5121,  0.5196]], device='cuda:0')
# g_theta2 istensor([[-0.1532, -0.7440],
#         [ 0.0548,  0.0146],
#         [-0.7217,  0.2532]], device='cuda:0')
# p21val is 0.526398816152333
# pf12val is 0.102248998980524
# chi_f12 is 4.560688548057357
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9252, -0.8597],
#         [-0.8673,  0.3598],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 47
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.997
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 71220.496
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1258, 0.1145]], device='cuda:0')
# g_theta2 istensor([[ 0.8431, -0.7810],
#         [-0.8353,  0.3324],
#         [ 0.3036,  0.3052]], device='cuda:0')
# p21val is 0.198881909420031
# pf12val is 0.878717061616429
# chi_f12 is 0.258584639568648
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-3.8890e-01, -6.4875e-01],
#         [-9.9851e-01,  5.4864e-01],
#         [-4.1124e-04, -9.6507e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 48
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.003
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 36038.531
# expected info is tensor([[0.0027]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2756, -0.2455]], device='cuda:0')
# new data istensor([[ 0.2815, -0.0126]], device='cuda:0')
# g_theta2 istensor([[-0.7033, -0.9496],
#         [-1.1109,  0.6667],
#         [ 0.1748,  0.1740]], device='cuda:0')
# p21val is 0.409325073376047
# pf12val is 0.785571366447187
# chi_f12 is 0.482687941222467
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2711,  0.1452],
#         [-0.3784,  0.2900],
#         [-0.2757, -0.2458]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 49
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.011
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 24878.554
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.7007, -0.0409]], device='cuda:0')
# new data istensor([[-0.0397,  0.1239]], device='cuda:0')
# g_theta2 istensor([[-0.0347,  0.3121],
#         [-0.4352,  0.3298],
#         [-0.5330, -0.4702]], device='cuda:0')
# p21val is 0.854473376703030
# pf12val is 0.954884228590415
# chi_f12 is 0.092330344913681
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5600, -0.9262],
#         [-0.8803, -0.0672],
#         [-0.7016, -0.0401]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 50
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.026
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 26400.017
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6755, -0.0237]], device='cuda:0')
# new data istensor([[-0.0202,  0.1069]], device='cuda:0')
# g_theta2 istensor([[-0.5125, -0.8442],
#         [-1.0053, -0.2448],
#         [-0.9808,  0.2574]], device='cuda:0')
# p21val is 0.231116709893570
# pf12val is 0.991027892237237
# chi_f12 is 0.018025199002133
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1321,  0.3870],
#         [-0.6437,  0.8325],
#         [-0.6756, -0.0252]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 51
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.015
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1497.614
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4695,  0.2285]], device='cuda:0')
# new data istensor([[-0.6428,  0.8239]], device='cuda:0')
# g_theta2 istensor([[-0.0300,  0.0215],
#         [-0.7283,  0.4945],
#         [-0.4695,  0.2492]], device='cuda:0')
# p21val is 0.205766722787964
# pf12val is 0.178090369358225
# chi_f12 is 3.450928328997638
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8615,  0.3842],
#         [ 0.0228, -0.1049],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 52
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.024
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 79737.914
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1013, 0.1011]], device='cuda:0')
# g_theta2 istensor([[-0.8333,  0.3519],
#         [ 0.3229, -0.3922],
#         [ 0.3026,  0.3059]], device='cuda:0')
# p21val is 0.268816638314064
# pf12val is 0.614977681157119
# chi_f12 is 0.972338605271159
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-5.6752e-01,  1.0984e-01],
#         [-3.1063e-01,  1.6315e-01],
#         [ 8.5752e-04, -8.9999e-05]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 53
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.034
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 39436.950
# expected info is tensor([[0.0027]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2768, -0.2380]], device='cuda:0')
# new data istensor([[ 0.2888, -0.0117]], device='cuda:0')
# g_theta2 istensor([[-0.6368,  0.1693],
#         [-0.4747,  0.3493],
#         [ 0.1703,  0.1749]], device='cuda:0')
# p21val is 0.064428158216080
# pf12val is 0.529808415538065
# chi_f12 is 1.270479635805027
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4437,  0.0394],
#         [-0.2298, -0.4167],
#         [-0.2758, -0.2371]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 54
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.031
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 30435.700
# expected info is tensor([[0.0022]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4640,  0.0210]], device='cuda:0')
# new data istensor([[0.1013, 0.0606]], device='cuda:0')
# g_theta2 istensor([[-0.7452,  0.3453],
#         [ 0.0028, -0.5796],
#         [-0.4936, -0.4790]], device='cuda:0')
# p21val is 0.628714055505321
# pf12val is 0.489117513952836
# chi_f12 is 1.430305007092549
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5576,  0.1477],
#         [ 0.3638, -0.3083],
#         [-0.4642,  0.0210]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 55
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.041
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 33178.758
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4418, -0.0052]], device='cuda:0')
# new data istensor([[0.1435, 0.0578]], device='cuda:0')
# g_theta2 istensor([[-0.7394,  0.3208],
#         [ 0.4069, -0.2929],
#         [-0.7650,  0.3204]], device='cuda:0')
# p21val is 0.371337641342016
# pf12val is 0.834436491702150
# chi_f12 is 0.361997284377804
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1427,  0.6543],
#         [ 0.3228, -0.2025],
#         [-0.4412, -0.0052]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 56
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.054
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 7246.798
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3281, -0.0500]], device='cuda:0')
# new data istensor([[-0.6691,  0.7924]], device='cuda:0')
# g_theta2 istensor([[-0.4870,  0.0997],
#         [ 0.4470, -0.3098],
#         [-0.3846,  0.2875]], device='cuda:0')
# p21val is 0.519677331853901
# pf12val is 0.138694667107551
# chi_f12 is 3.950960803033940
# samples escaped box
# ...
# new data istensor([[0.1104, 0.1023]], device='cuda:0')
# g_theta2 istensor([[-0.8649,  0.8521],
#         [-0.3406,  0.4058],
#         [ 0.3083,  0.3084]], device='cuda:0')
# p21val is 0.381115228840880
# pf12val is 0.785957633890821
# chi_f12 is 0.481704777815801
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.9701e-01,  1.4873e-01],
#         [ 4.5910e-01, -4.5807e-01],
#         [-2.2879e-03,  3.0681e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 76
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.113
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 70611.584
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2722, -0.2797]], device='cuda:0')
# new data istensor([[ 0.2713, -0.0519]], device='cuda:0')
# g_theta2 istensor([[-0.3561,  0.3487],
#         [ 0.2049, -0.2574],
#         [ 0.1944,  0.1985]], device='cuda:0')
# p21val is 0.811477168721774
# pf12val is 0.102870806676195
# chi_f12 is 4.548562764329853
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4208, -0.7369],
#         [ 0.1687, -0.6124],
#         [-0.2728, -0.2791]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 77
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.126
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 2659.588
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1750, -1.2415]], device='cuda:0')
# new data istensor([[-0.3497,  0.3857]], device='cuda:0')
# g_theta2 istensor([[-0.4528, -0.7837],
#         [ 0.4528, -0.9689],
#         [-0.4749, -0.0649]], device='cuda:0')
# p21val is 0.355722984009327
# pf12val is 0.253098051224856
# chi_f12 is 2.747956622171847
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5710, -0.4932],
#         [-0.0046,  0.7583],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 78
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.127
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 111583.919
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1356, 0.1100]], device='cuda:0')
# g_theta2 istensor([[-0.6479, -0.5626],
#         [-0.0708,  0.8251],
#         [ 0.3033,  0.3043]], device='cuda:0')
# p21val is 0.534029130670080
# pf12val is 0.600764478046116
# chi_f12 is 1.019104609408075
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9065, -0.8936],
#         [-0.1471,  0.1028],
#         [ 0.0010, -0.0013]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 79
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.132
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 70816.762
# expected info is tensor([[0.0014]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2533, -0.2656]], device='cuda:0')
# new data istensor([[0.2552, 0.0341]], device='cuda:0')
# g_theta2 istensor([[-1.2213, -1.1829],
#         [-0.2955,  0.3248],
#         [ 0.1859,  0.1873]], device='cuda:0')
# p21val is 0.156488776870281
# pf12val is 0.088360978724291
# chi_f12 is 4.852649647875602
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3776, -0.5200],
#         [-0.5202, -0.2826],
#         [-0.2527, -0.2643]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 80
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.120
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 27789.570
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4395, -0.9699]], device='cuda:0')
# new data istensor([[-0.2548,  0.2588]], device='cuda:0')
# g_theta2 istensor([[ 0.4642, -0.3791],
#         [-0.6312, -0.5210],
#         [-0.4651, -0.0489]], device='cuda:0')
# p21val is 0.733725445001912
# pf12val is 0.385996531965062
# chi_f12 is 1.903853788208278
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6479, -0.8147],
#         [-0.5901, -0.7199],
#         [ 0.4402, -0.9698]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 81
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.129
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 931.698
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2904, -1.6552]], device='cuda:0')
# new data istensor([[-0.8181,  0.2883]], device='cuda:0')
# g_theta2 istensor([[ 0.7663, -0.6814],
#         [-0.7719, -0.5852],
#         [ 0.6474, -0.7650]], device='cuda:0')
# p21val is 0.821924082095382
# pf12val is 0.293135994778239
# chi_f12 is 2.454237263293376
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5676,  0.8328],
#         [-0.0792, -0.9302],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 82
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.129
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 121104.219
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1476, 0.1012]], device='cuda:0')
# g_theta2 istensor([[ 0.5245,  0.7923],
#         [-0.0173, -0.8848],
#         [ 0.3075,  0.3072]], device='cuda:0')
# p21val is 0.750069876604840
# pf12val is 0.232071300790973
# chi_f12 is 2.921421247073497
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4324, -0.7391],
#         [-0.7916,  0.0163],
#         [ 0.0019,  0.0018]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 83
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.140
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 45096.395
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0167, -0.6620]], device='cuda:0')
# new data istensor([[0.2000, 0.1062]], device='cuda:0')
# g_theta2 istensor([[-0.7827, -1.0427],
#         [-0.7608, -0.0835],
#         [ 0.2151,  0.2364]], device='cuda:0')
# p21val is 0.654618902198031
# pf12val is 0.273757018140270
# chi_f12 is 2.591028722275937
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0253, -0.5759],
#         [ 0.3820, -0.8664],
#         [-0.0189, -0.6637]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 84
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.145
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 991.023
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5861, -1.3129]], device='cuda:0')
# new data istensor([[-0.1587,  0.3247]], device='cuda:0')
# g_theta2 istensor([[ 0.2037, -0.4015],
#         [ 0.0605, -0.7779],
#         [ 0.1940, -0.4502]], device='cuda:0')
# p21val is 0.275795253546502
# pf12val is 0.720279701978964
# chi_f12 is 0.656231334876236
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9434, -0.0892],
#         [-0.8859, -0.4988],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 85
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.141
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 124679.568
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1391, 0.1275]], device='cuda:0')
# g_theta2 istensor([[ 1.0392, -0.1720],
#         [-0.8145, -0.4164],
#         [ 0.3074,  0.3073]], device='cuda:0')
# p21val is 0.868875909972321
# pf12val is 0.423966196580745
# chi_f12 is 1.716203103947604
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1812, -0.0958],
#         [-0.6149,  0.0192],
#         [ 0.0008, -0.0010]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 86
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.150
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 53418.119
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0825, -0.6226]], device='cuda:0')
# new data istensor([[0.2485, 0.1080]], device='cuda:0')
# g_theta2 istensor([[-0.6240, -0.5369],
#         [-0.3629, -0.2299],
#         [ 0.2220,  0.2353]], device='cuda:0')
# p21val is 0.944835424309362
# pf12val is 0.408900731500982
# chi_f12 is 1.788565725329574
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5068, -0.6231],
#         [-0.1922, -0.6431],
#         [-0.0828, -0.6209]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 87
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.158
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 3993.484
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3785, -1.3354]], device='cuda:0')
# new data istensor([[-0.3030,  0.3490]], device='cuda:0')
# g_theta2 istensor([[-0.5847, -0.7825],
#         [-0.4321, -0.3827],
#         [ 0.1326, -0.4045]], device='cuda:0')
# p21val is 0.471683470338713
# pf12val is 0.766419988927708
# chi_f12 is 0.532049942158693
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5177, -0.0983],
#         [ 0.9337, -0.4007],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 88
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.153
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 127476.103
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1370, 0.1189]], device='cuda:0')
# g_theta2 istensor([[-0.5182, -0.0903],
#         [ 0.8940, -0.3570],
#         [ 0.3068,  0.3069]], device='cuda:0')
# p21val is 0.986279947181499
# pf12val is 0.594179449407698
# chi_f12 is 1.041147803727132
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 7.3573e-01, -4.4871e-01],
#         [ 5.9348e-01,  2.3372e-01],
#         [ 9.9325e-04, -6.1902e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 89
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.162
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 47507.211
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1384, -0.7913]], device='cuda:0')
# new data istensor([[0.1532, 0.2326]], device='cuda:0')
# g_theta2 istensor([[ 0.9125, -0.6257],
#         [ 0.4623,  0.0477],
#         [ 0.2308,  0.2350]], device='cuda:0')
# p21val is 0.896230764162498
# pf12val is 0.050445781724301
# chi_f12 is 5.973712297350555
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2127, -0.1917],
#         [-0.2399, -0.2387],
#         [-0.1393, -0.7909]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 90
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.161
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 6534.454
# expected info is tensor([[7.1626e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3124, -1.3572]], device='cuda:0')
# new data istensor([[-0.3974,  0.3743]], device='cuda:0')
# g_theta2 istensor([[ 0.2390, -0.1461],
#         [-0.4340, -0.7379],
#         [ 0.0777, -0.5837]], device='cuda:0')
# p21val is 0.585221767186684
# pf12val is 0.335571521243063
# chi_f12 is 2.183840334435790
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1346, -0.9997],
#         [-0.4118, -0.4905],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 91
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.175
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 127265.558
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1601, 0.1267]], device='cuda:0')
# g_theta2 istensor([[ 0.3186, -0.8297],
#         [-0.5835, -0.6656],
#         [ 0.3025,  0.3047]], device='cuda:0')
# p21val is 0.679455622006889
# pf12val is 0.088801711014591
# chi_f12 is 4.842698721974618
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-7.6846e-01, -5.3511e-01],
#         [-7.7358e-01,  2.9847e-01],
#         [ 2.5170e-04, -8.9441e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 92
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.176
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 59347.382
# expected info is tensor([[4.6552e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0827, -0.5257]], device='cuda:0')
# new data istensor([[0.2377, 0.0715]], device='cuda:0')
# g_theta2 istensor([[-0.8518, -0.6122],
#         [-0.6883,  0.1189],
#         [ 0.2092,  0.2314]], device='cuda:0')
# p21val is 0.410065886560013
# pf12val is 0.475243343219755
# chi_f12 is 1.487856609227685
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1741, -0.9865],
#         [ 0.4287, -0.6657],
#         [-0.0839, -0.5248]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 93
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.172
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 12635.497
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2307, -1.2397]], device='cuda:0')
# new data istensor([[-0.2916,  0.3880]], device='cuda:0')
# g_theta2 istensor([[ 0.2071, -0.9450],
#         [ 0.0245, -0.7741],
#         [ 0.1470, -0.2940]], device='cuda:0')
# p21val is 0.698914368614018
# pf12val is 0.866983084365026
# chi_f12 is 0.285471625856461
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5631,  0.6037],
#         [-0.3096,  0.2106],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 94
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.182
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 128096.318
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0580, 0.1067]], device='cuda:0')
# g_theta2 istensor([[ 0.5901,  0.6684],
#         [-0.4444,  0.3403],
#         [ 0.2995,  0.3037]], device='cuda:0')
# p21val is 0.037751785434636
# pf12val is 0.011933439264749
# chi_f12 is 8.856821594697472
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-4.6596e-01,  2.7334e-01],
#         [ 3.4205e-01,  6.9042e-01],
#         [-1.7313e-04,  4.5020e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# current sol istensor([[0., 0.]], device='cuda:0')
# Success is False and failure is True after 95 iterations

# %%
f_target.shape
# Out:
# torch.Size([2, 1])

# %%
print(cpu_hyper_opti)
print(cpu_conduct_design)
print(cpu_total)
print()
print(gpu_hyper_opti)
print(gpu_conduct_design)
print(gpu_total)
# Out:
# [0.21732306480407715, 0.22070670127868652, 0.2441549301147461, 0.383929967880249, 0.3149693012237549, 0.38434433937072754, 0.4169178009033203, 0.37300729751586914, 0.36512184143066406, 0.3830552101135254, 0.4166600704193115, 0.44108080863952637, 0.48545122146606445, 0.47988224029541016, 0.5142683982849121, 0.5458691120147705, 0.7633843421936035, 0.7069578170776367, 0.748037576675415, 0.6763267517089844, 0.693514347076416, 0.7200469970703125, 0.7945418357849121, 1.2414722442626953, 0.8815150260925293, 1.0204036235809326, 1.2507703304290771, 1.1589972972869873, 1.0714068412780762, 1.1273038387298584, 1.2050766944885254, 1.4176051616668701, 1.1468594074249268, 1.2868750095367432, 1.4039535522460938, 1.2247004508972168, 1.2818071842193604, 1.3607008457183838, 1.2797253131866455, 1.3095958232879639, 1.3037774562835693, 1.336487054824829, 1.6426596641540527, 1.4641175270080566, 1.539729118347168, 1.534376859664917, 1.728926420211792, 1.7216284275054932, 1.704787254333496, 1.683544397354126, 1.796595573425293, 1.6731772422790527, 1.7458219528198242, 1.9556450843811035, 1.8276636600494385, 1.8620834350585938, 1.9552273750305176, 1.9542315006256104, 2.0354127883911133, 2.0972533226013184, 2.1644253730773926, 2.249645233154297, 2.3062894344329834, 2.2778613567352295, 2.0684940814971924, 2.433777332305908, 2.330860137939453, 2.346191883087158, 2.242189407348633, 2.3732852935791016, 2.406525135040283, 2.706475019454956, 2.608991861343384, 2.751377820968628, 2.733668327331543, 2.7937731742858887, 2.772885799407959, 2.8975155353546143]
# [2.9348578453063965, 3.2340593338012695, 3.6264524459838867, 3.8951334953308105, 4.543599605560303, 5.742552995681763, 5.565504550933838, 6.553743839263916, 6.199466943740845, 5.732544898986816, 5.654545068740845, 5.862478733062744, 5.949402332305908, 5.942615270614624, 5.889409303665161, 6.034811973571777, 6.395346403121948, 6.5432281494140625, 7.767508268356323, 7.380670070648193, 8.019791603088379, 6.78338098526001, 6.884797096252441, 6.835248231887817, 7.353891849517822, 8.433226346969604, 8.60804533958435, 9.463797807693481, 9.461571216583252, 8.030667543411255, 8.068283319473267, 8.40466046333313, 10.245159149169922, 10.018826246261597, 9.575431823730469, 11.14140272140503, 10.433894395828247, 8.930980920791626, 11.538722276687622, 12.300832509994507, 10.979668378829956, 11.717586040496826, 11.79652738571167, 12.797513008117676, 12.060878038406372, 12.28929352760315, 12.003416061401367, 12.725352764129639, 12.54235577583313, 11.370200634002686, 14.191390991210938, 13.711860418319702, 14.389610290527344, 14.485960960388184, 14.532386302947998, 15.490178346633911, 15.05082392692566, 13.47914719581604, 11.787480592727661, 12.34717583656311, 11.64374828338623, 15.863578081130981, 15.863929271697998, 16.471911191940308, 16.6451632976532, 13.445150375366211, 12.522538900375366, 13.677764654159546, 14.295480489730835, 13.795700311660767, 14.204315423965454, 13.546453714370728, 14.853464603424072, 15.088949203491211, 15.361513614654541, 15.878419637680054, 14.111649513244629, 15.078307151794434, 14.489377737045288, 16.078904390335083]
# [3.1862282752990723, 3.260122776031494, 3.875953435897827, 4.163877964019775, 4.578150510787964, 6.164666175842285, 5.954514980316162, 6.986875057220459, 6.654712915420532, 6.146990776062012, 6.064187049865723, 6.284148216247559, 6.406015634536743, 6.433915138244629, 6.415206670761108, 6.555269718170166, 6.951173782348633, 7.134072542190552, 8.57960295677185, 8.136251449584961, 8.816591501235962, 7.5044169425964355, 7.6225364208221436, 7.600579500198364, 8.195103168487549, 9.722423791885376, 9.547244548797607, 10.546294927597046, 10.777119636535645, 9.243609189987183, 9.19233250617981, 9.586083173751831, 11.536478757858276, 11.501265525817871, 10.796599388122559, 12.497676134109497, 11.90011715888977, 10.211753606796265, 12.893742799758911, 13.722562313079834, 12.327398538589478, 13.096717596054077, 13.176862716674805, 14.252164125442505, 13.774847507476807, 13.831850290298462, 13.617486715316772, 14.343813180923462, 14.346590757369995, 13.15333890914917, 15.992235898971558, 15.489729166030884, 16.26068115234375, 16.239288568496704, 16.38034749031067, 17.53693723678589, 16.97678542137146, 15.427595615386963, 13.81360936164856, 14.370003938674927, 13.75269365310669, 18.056432723999023, 18.12769603729248, 19.22221612930298, 19.027125358581543, 15.804804801940918, 14.674771547317505, 16.199523448944092, 16.710235595703125, 16.212722539901733, 16.535621166229248, 16.003345251083374, 17.345813035964966, 17.884348154067993, 18.06807279586792, 18.72620677947998, 16.930776596069336, 17.955577850341797, 17.34958267211914, 19.073044300079346]
#
# [1.8316528797149658, 0.2916536331176758, 0.3861851692199707, 0.39164209365844727, 0.39121103286743164, 0.3916041851043701, 0.38930201530456543, 0.3915257453918457, 0.3903820514678955, 0.48324108123779297, 0.48478126525878906, 0.4852631092071533, 0.48894596099853516, 0.4886617660522461, 0.4870290756225586, 0.49527454376220703, 0.49700021743774414, 0.49414610862731934, 0.49315357208251953, 0.49117374420166016, 0.49461936950683594, 0.4961235523223877, 0.4966592788696289, 0.5126087665557861, 0.5050334930419922, 0.5065610408782959, 0.5174479484558105, 0.5225365161895752, 0.5291519165039062, 0.5360383987426758, 0.5359885692596436, 0.5353169441223145, 0.5340597629547119, 0.5497415065765381, 0.7248039245605469, 0.49475693702697754, 0.49077343940734863, 0.5582845211029053, 0.48859071731567383, 0.4886319637298584, 0.49504756927490234, 0.4947166442871094, 0.4994046688079834, 0.5121171474456787, 0.5050415992736816, 0.5470826625823975, 0.5515437126159668, 0.5587024688720703, 0.5411796569824219, 0.5623414516448975, 0.5736713409423828, 0.584630012512207, 0.5892848968505859, 0.6060340404510498, 0.6250474452972412, 0.6187131404876709, 0.6354925632476807, 0.6186449527740479, 0.6212317943572998, 0.6638052463531494, 0.6934764385223389, 0.6812403202056885, 0.6910202503204346, 0.6958332061767578, 0.7574872970581055, 0.7441153526306152, 0.7775609493255615, 0.7983331680297852, 0.7893145084381104, 0.7880096435546875, 0.8608386516571045, 0.8594796657562256, 0.826399564743042, 0.8390321731567383, 0.850836992263794, 0.8662371635437012, 0.9184892177581787, 1.015134572982788, 0.8941771984100342, 0.9242498874664307, 0.9221436977386475, 0.9571502208709717, 0.9774453639984131, 0.9782850742340088, 0.996070146560669, 1.012521743774414, 1.0346999168395996, 1.0486586093902588, 1.0587735176086426, 1.0562152862548828, 1.0834407806396484, 1.1200547218322754, 1.1826667785644531, 1.191054105758667, 1.1623129844665527]
# [4.676206111907959, 4.65956711769104, 4.837801694869995, 6.640631437301636, 6.8234992027282715, 6.809319257736206, 6.638800144195557, 6.823680639266968, 6.645639657974243, 6.9509007930755615, 6.593203544616699, 6.619799852371216, 6.8042473793029785, 8.389748573303223, 8.920953750610352, 8.572941541671753, 8.784042835235596, 8.597753524780273, 8.973330736160278, 8.641923904418945, 8.846801996231079, 8.644253492355347, 9.00733232498169, 8.6277494430542, 8.824696779251099, 8.65547490119934, 9.028126239776611, 8.45025897026062, 8.670316219329834, 8.518340826034546, 8.84119176864624, 8.746796131134033, 8.948765754699707, 8.746363639831543, 9.106891393661499, 8.884591102600098, 9.041519403457642, 9.218839645385742, 9.34887981414795, 8.864287376403809, 9.024808406829834, 9.043458700180054, 8.884523153305054, 8.462367534637451, 8.627860069274902, 8.613219261169434, 8.896125555038452, 8.472252368927002, 8.690069913864136, 9.042840242385864, 9.125481605529785, 8.906171560287476, 9.119145631790161, 9.10925030708313, 9.14503526687622, 8.638282775878906, 9.32619571685791, 8.934072256088257, 9.160043478012085, 8.868492364883423, 9.738508462905884, 9.204093217849731, 8.918636560440063, 9.46111273765564, 9.510695457458496, 9.332961320877075, 9.549601793289185, 8.912909984588623, 9.436546087265015, 9.265316009521484, 9.599313497543335, 9.272054433822632, 9.480612993240356, 9.247878789901733, 9.159708976745605, 9.247414350509644, 8.926850080490112, 8.980056047439575, 8.934219121932983, 8.787941217422485, 9.282087802886963, 8.821712255477905, 8.964710712432861, 8.971280813217163, 9.455529928207397, 9.105674266815186, 9.195434808731079, 9.439476728439331, 9.513614416122437, 9.332849264144897, 9.53824520111084, 9.160112380981445, 9.253186464309692, 8.977754831314087, 9.687048196792603, 9.049479007720947, 9.467080116271973, 9.075243711471558, 9.423169136047363]
# [6.9896934032440186, 4.982651710510254, 4.8744797706604, 7.077178955078125, 7.269131183624268, 6.85952353477478, 7.0723185539245605, 6.874293088912964, 7.087656497955322, 7.390084981918335, 7.034891843795776, 7.0520477294921875, 6.852100133895874, 8.93407130241394, 9.466835498809814, 9.119556188583374, 9.334757089614868, 9.147686243057251, 9.521945714950562, 9.198663711547852, 9.405686855316162, 9.199496507644653, 9.562390327453613, 9.180694341659546, 9.381080627441406, 9.213374853134155, 9.586608171463013, 9.0378577709198, 9.240896701812744, 9.094050168991089, 9.429929494857788, 9.337931156158447, 9.552679300308228, 9.350931167602539, 9.712718725204468, 9.49478554725647, 9.648805141448975, 9.836015462875366, 10.138716220855713, 9.439129114151001, 9.594520330429077, 9.672460317611694, 9.43764877319336, 9.015470504760742, 9.187225341796875, 9.171143054962158, 9.460909366607666, 9.047163009643555, 9.260261058807373, 9.66053318977356, 9.748228549957275, 9.543113231658936, 9.731799602508545, 9.743542671203613, 9.797574043273926, 9.29311227798462, 9.986523628234863, 9.61921763420105, 9.85631799697876, 9.567649126052856, 10.439752101898193, 9.888448715209961, 9.609412670135498, 10.20334792137146, 10.285895347595215, 10.083028554916382, 10.30799674987793, 9.683555841445923, 10.27865219116211, 10.092553853988647, 10.464704275131226, 10.151063680648804, 10.343640565872192, 10.148003339767456, 10.11058783531189, 10.186986207962036, 9.82830023765564, 9.892328262329102, 9.857639074325562, 9.727059364318848, 10.274178266525269, 9.918379783630371, 9.93202829360962, 9.972090721130371, 10.452142715454102, 10.148999691009521, 10.250615358352661, 10.495201349258423, 10.581570386886597, 10.420525074005127, 10.657329559326172, 10.282949924468994, 10.389051675796509, 10.10816478729248, 10.845382690429688, 10.328702211380005, 10.734031677246094, 10.344842195510864, 10.670405864715576]

# %%
cpu_total_x = list(range(1, len(cpu_total)+1))
gpu_total_x = list(range(1, len(gpu_total)+1))

cpu_conduct_x = list(range(1, len(cpu_conduct_design)+1))
gpu_conduct_x = list(range(1, len(gpu_conduct_design)+1))

cpu_hyper_x = list(range(1, len(cpu_hyper_opti)+1))
gpu_hyper_x = list(range(1, len(gpu_hyper_opti)+1))

# %%
# Plotting CPU vs. GPU time

# # Initialize plots
plt.style.use('default')
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 6))

plt.suptitle('CPU vs. GPU TAD Running Time Per Iteration', fontweight='bold')

ax1.plot(cpu_hyper_x, cpu_hyper_opti, 'r-', label='CPU hyper_opti')
ax1.plot(gpu_hyper_x, gpu_hyper_opti, 'b-', label='GPU hyper_opti')
ax1.legend()


plt.subplot(132)
ax2.plot(cpu_conduct_x, cpu_conduct_design, 'g-', label='CPU conduct_design_opti')
ax2.plot(gpu_conduct_x, gpu_conduct_design, 'c-', label='GPU conduct_design_opti')
ax2.legend()
# plt.ylabel('Time')
# plt.xlabel('Input Size')

plt.subplot(133)
ax3.plot(cpu_total_x, cpu_total, 'y-', label='CPU whole iteration')
ax3.plot(gpu_total_x, gpu_total, 'm-', label='GPU whole iteration')
ax3.legend()

plt.setp([ax1,ax2,ax3], xlabel='Iteration')
plt.setp(ax1, ylabel='Time (Second)')

plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Ignore the part below

# %%
print(lower_bound)
print(upper_bound)
print(f_target - 0.001)
print(f_target + 0.001)
print(pf1)
print(num_base_kernels)
# Out:
# tensor([[0.1146],
#         [0.1118]], grad_fn=<CopySlices>)
# tensor([[0.1208],
#         [0.1180]], grad_fn=<CopySlices>)
# tensor([[-1.0010],
#         [-1.0010]])
# tensor([[-0.9990],
#         [-0.9990]])
# tensor([[0.1177],
#         [0.1149]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# 4

# %% [markdown]
# # Plotting model validation strategy

# %%
sns.set_style('ticks')
#plt.rcParams["pdf.use14corefonts"] = True
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
p21_vec_plot = p21_vec.detach()[1:]
f, ax = plt.subplots(1, 1, figsize=(14, 14))
#ax.plot(np.array(range(2,iter+2)), torch.log(entropy_vec_plot), '+-')
#print(p21_vec_plot)
ax.plot(p21_vec_plot,'s',color = 'blue', markersize=6)
ax.axhline(.01,linestyle = '--',color = 'red', markersize=12, alpha = 1.0)
ax.set_xlim(-0.3, p21_vec_plot.shape[0])
ax.set_ylim(-0.3, 1.)
#ax.set_yscale('log')
plt.xticks(np.arange(0, iter+7, step=5.))
ax.tick_params(labelsize='small', width=3)
ax.set_xlabel('# of Model Checks')
ax.set_ylabel('p-value')
ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.05, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(1.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.02, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(0.1,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.26, 0.34), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(6.2,        #x start point
             0.14,                      #y start point
             0,       #change in x 
             -0.07,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 



ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.29, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(7.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.57, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(14.15,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.69, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(17.18,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################



# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.32, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(10.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color

# ############################

# ############################
# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.33, 0.34), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(11.25,        #x start point
#              0.14,                      #y start point
#              0,       #change in x 
#              -0.07,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# #################################################

# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.38, 0.1), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(12.25,        #x start point
#              -0.15,                      #y start point
#              0,       #change in x 
#              0.1,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color





################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.38, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(13.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.55, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(18.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')  
# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.49, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(17.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.55, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(19.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.94, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(33.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ################################

ax.annotate('Threshold Line ($y = 0.01$)', xy=(1.0,0.01), xytext=(6,0), color='red', 
                xycoords = ax.get_yaxis_transform(), textcoords="offset points",
                size=14, va="center")


#ax.legend(['p-value'], loc = 'upper left', fontsize = 30)
plt.savefig('figures_Carlo/qvalue_base.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Putting the data back to CPU for plotting and analysis

# %%
if use_cuda:
    vec_x = vec_x.cpu()
    g_theta1 = g_theta1.cpu()
    g_theta2 = g_theta2.cpu()
    x_train, y_train = x_train.cpu(), y_train.cpu()
    loss = loss.cpu()
    pf1 = pf1.cpu()
    Qf1 = Qf1.cpu()
    Qf12 = Qf12.cpu()
    Q21 = Q21.cpu()
    data_fit_vec = data_fit_vec.cpu()
    entropy_vec = entropy_vec.cpu()

# %% [markdown]
# # Plotting expected value and data fit term

# %%
sns.set_style('ticks')
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 8), tight_layout=True)

ax1.plot(np.array(range(1,iter+2)), (entropy_vec_plot), '--o', color = 'blue', markersize=12)
#ax1.set_yscale('log')
# ax.plot(np.array(data_fit_vec_plot), (entropy_vec_plot), 'o')
#ax1.set_yscale('log')

ax2.plot(np.array(range(1,iter+2)), data_fit_vec_plot, '--o', color = 'red', markersize=12)
#ax2.set_ylim(-10, 600)
ax1.set_xlabel('Iteration #', size=32)
ax2.set_xlabel('Iteration #', size=32)
ax1.set_ylabel('Expected Information', size = 32)
ax2.set_ylabel('Log-Gaussian Term', size = 32)
ax1.set_xticks(np.arange(0, iter+3, step=3.))
ax2.set_xticks(np.arange(0, iter+3, step=3.))
plt.savefig('figures_Carlo/exp_info/expectedinfo_vs_datafit_2_base.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Saving all data needed for plots

# %%
np.savetxt('data_plots/vec_x_success_base.txt',vec_x.detach().numpy())
np.savetxt('data_plots/g_theta2_success_base.txt', g_theta2.detach().numpy())
np.savetxt('data_plots/g_theta1_success_base.txt', g_theta1.detach().numpy())
np.savetxt('data_plots/x_train_ini_success_base.txt', x_train.detach().numpy())
np.savetxt('data_plots/y_train_ini_success_base.txt', y_train.detach().numpy())
np.savetxt('data_plots/entropy_vec_success_base.txt', entropy_vec_plot.detach().numpy())
np.savetxt('data_plots/datafit_success_base.txt', data_fit_vec_plot.detach().numpy())
np.savetxt('data_plots/p21_vec_success_base.txt',p21_vec_plot.detach().numpy())
np.savetxt('data_plots/loss_success_base.txt',loss.detach().numpy())
np.savetxt('data_plots/pf1_success_base.txt',pf1.detach().numpy())
np.savetxt('data_plots/Qf1_success_base.txt',Qf1.evaluate().detach().numpy())
np.savetxt('data_plots/Qf12_success_base.txt', Qf12.evaluate().detach().numpy())
np.savetxt( 'data_plots/Q21_success_base.txt', Q21.evaluate().detach().numpy())
#np.savetxt('data_plots/iter_success.txt', iter+1)

# %%
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2),2)
torch.save(v2, 'data_plots/v2_success_base.txt')

# %%
print(v2.shape)
# Out:
# torch.Size([291, 2])

# %% [markdown]
# # Plots for vizualization

# %%
fig, ax = plt.subplots(figsize = (14,14))
ax.set_xlim(-3.1, 3.2)
ax.set_ylim(-3.1, 3.2)
#ax.scatter(g_theta1[:, 0].detach(),g_theta1[:, 1].detach(), c="b", alpha=0.8)
ax.plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'blue',markersize=15, alpha = 0.2)
ax.plot(vec_x[-1,0], vec_x[-1,1],'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)
ax.set_title('Final TAD configuration', fontsize = 40)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.legend(['1-points', 'TAD solution', 'Target'])
plt.savefig('figures_Carlo/strategies/tad_sol_all_2_base.pdf')
plt.show()
# Out:
# /tmp/ipykernel_1441820/2505842117.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "gd" (-> color='g'). The keyword argument will take precedence.
#   ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)

# %%
print(g_theta1.shape[0])
# Out:
# 382

# %% [markdown]
# ##

# %%
vec_x = vec_x.detach()
#v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)
ii = 0
low = -3.2
high = 3.2
v2 = v2.cpu()
########################
f, ax = plt.subplots(1, 1, figsize=(14, 14))
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)
ax.plot(vec_x[ii,0], vec_x[ii,1],'v', color = 'red',markersize=15)
ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'o', color = 'blue', markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Initial Configuration', fontsize = 40)
ax.legend(['Target', 'Initial Target Candidate', 'Initial 1-sample','Initial 2-sample'])

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures_Carlo/evol_solTAD/evol_sol_ini_2_base.pdf')

# %%
vec_x = vec_x.detach()
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2).cpu()

low = -3.2
high = 3.2
#for iter_plt in range(1,iter):
iter_plt = 13
ii = 3 + (iter_plt - 1) * (loc_size + 1)
#######################

 
###########

f, ax = plt.subplots(1, 1, figsize=(14,14))

#ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 'bv', markersize=8)
for i in range(1, iter_plt):
    ax.plot(vec_x[i-1:i,0], vec_x[i-1:i,1],'v', color = 'red', markersize=15, alpha=0.2, label = '_nolegend_')
    
ax.plot(vec_x[0:iter_plt,0], vec_x[0:iter_plt,1],'v', color = 'red', markersize=15, linewidth=15, alpha= 0.2)
#ax.plot(g_theta1.detach()[:,0], g_theta.detach()[:,1], 'bv', markersize=8)
ax.plot(v2.detach()[0:ii,0], v2.detach()[0:ii,1], 's', color = 'blue', markersize=15,alpha=0.2)
ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'o',color = 'blue' , markersize=15)
ax.plot(0.8731, 0.5664,'gd',markersize=15)
ax.plot(vec_x[iter_plt,0], vec_x[iter_plt,1],'v', color = 'red',markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
#ax.set_title('Iteration '+str(iter_plt), fontsize = 40)
ax.set_title('Final Configuration')
ax.legend([ 'Previous Target Candidates', 'Previous 2-samples', 'Initial 1-sample','Current 2-sample', 'Target', 'Current Target Candidate'], fontsize = 30)

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures_Carlo/evol_solTAD/evol_sol_base'+str(iter_plt)+'_final.pdf')

# %%
print(g_theta2_vec.shape)
# Out:
# torch.Size([582])

# %% [markdown]
# # Grid Sampling

# %%
def conduct_design_pll(x0,f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    #g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        #print(g_theta)
        loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood, noise_value)
        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood ,noise_value)
    #loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
   # print(optimizer.state_dict())
    print(x_d)
    return x_d, lower_bound, upper_bound

# %%
# Ensure everything is on CPU
use_cuda = False
#

x_plot = np.linspace(vf.low, vf.high, 15)
y_plot = np.linspace(vf.low, vf.high, 15)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n

g_theta_grid = x_concat
agg_data1_grid = vfield_(g_theta_grid)
agg_data1_grid = agg_data1_grid.flatten()


x0 = Tensor(np.array([-2.,2.])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_grid = Tensor(np.array([0.0,0.0])) 
vec_x_grid = vec_x_grid.reshape(1,2)

lr_new = 1.

SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')
model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)

print('END HYPERPARAMETERS optimization')
model_grid.eval()
likelihood_grid.eval()
x0_new_grid,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_grid, agg_data1_grid, model_grid, likelihood_grid, iter_design, iter_param, lr_new,noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
#loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_grid)
print(SUCCESS)
# Out:
# START HYPERPARAMETERS optimization
# Using CUDA
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [33], in <cell line: 32>()
#      30 tol = 0.009
#      31 print('START HYPERPARAMETERS optimization')
# ---> 32 model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)
#      34 print('END HYPERPARAMETERS optimization')
#      35 model_grid.eval()
#
# Input In [6], in hyper_opti(g_theta1, agg_data, training_iter, num_base_kernels, noise_value, current_model, current_likelihood)
#      44     for i in range(training_iter):
#      45         optimizer.zero_grad()
# ---> 47         loss, chi_square = mll(agg_data,g_theta1, model, likelihood, cov_noise1)
#      48         loss = -1. * loss
#      49 #         print('df is %.3f' %agg_data.shape[0] +'and chi_square %.3f' %chi_square)
#      50         #print('loss is %.3f' %loss)
#      51 #         df = agg_data.shape[0]
#      52 #         chi_square = chi_square.clone().detach()
#      53
#      54 #         p_val = 1. - stats.chi2.cdf(chi_square, df)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/module.py:30, in Module.__call__(self, *inputs, **kwargs)
#      29 def __call__(self, *inputs, **kwargs):
# ---> 30     outputs = self.forward(*inputs, **kwargs)
#      31     if isinstance(outputs, list):
#      32         return [_validate_module_outputs(output) for output in outputs]
#
# File /lus/grand/projects/datascience/tiany/Targeted_Adaptive_Design/code/jupyter/../mlikelihoods/tadmlls.py:58, in MarginalLogLikelihood.forward(self, agg_data, g_theta1, model, likelihood, cov_noise1)
#      44         r"""
#      45         Computes the MLL given :math:`p(\mathbf f)` and :math:`\mathbf y`.
#      46
#    (...)
#      51         :return: Exact MLL. Output shape corresponds to batch shape of the model/input data.
#      52         """
#      53         # move the cov_noise1 to jupyter notebook Conv_Success
#      54 #         cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])    #likelihood._shaped_noise_covar([ agg_data.shape[0],
#      55
#      56         #output = model(g_theta1)
#      57         #output_ll = likelihood(output)
# ---> 58         m0 = model.mean_module.forward(g_theta1) #output_ll.loc #
#      59         #print(m0)
#      60         #C11= output_ll.covariance_matrix #+ cov_noise1
#      61         K = model.covar_module
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/means/multitask_mean.py:43, in MultitaskMean.forward(self, input)
#      39 def forward(self, input):
#      40     """
#      41     Evaluate each mean in self.base_means on the input data, and return as an `n x t` matrix of means.
#      42     """
# ---> 43     return torch.cat([sub_mean(input).unsqueeze(-1) for sub_mean in self.base_means], dim=-1)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/means/multitask_mean.py:43, in <listcomp>(.0)
#      39 def forward(self, input):
#      40     """
#      41     Evaluate each mean in self.base_means on the input data, and return as an `n x t` matrix of means.
#      42     """
# ---> 43     return torch.cat([sub_mean(input).unsqueeze(-1) for sub_mean in self.base_means], dim=-1)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/means/mean.py:22, in Mean.__call__(self, x)
#      19 if x.ndimension() == 1:
#      20     x = x.unsqueeze(1)
# ---> 22 res = super(Mean, self).__call__(x)
#      24 return res
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/module.py:30, in Module.__call__(self, *inputs, **kwargs)
#      29 def __call__(self, *inputs, **kwargs):
# ---> 30     outputs = self.forward(*inputs, **kwargs)
#      31     if isinstance(outputs, list):
#      32         return [_validate_module_outputs(output) for output in outputs]
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/means/linear_mean.py:18, in LinearMean.forward(self, x)
#      17 def forward(self, x):
# ---> 18     res = x.matmul(self.weights).squeeze(-1)
#      19     if self.bias is not None:
#      20         res = res + self.bias
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument mat2 in method wrapper_mm)

# %%
x0_grid = x0_new.detach()
fig, ax = plt.subplots(figsize = (14,14))
ax.plot(x_concat[:,0],x_concat[:,1], 's', color = 'blue', markersize=15, alpha = 0.2)
ax.plot(x0_new_grid.detach()[0,0], x0_new_grid.detach()[0,1],'v',color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Grid Solution', fontsize = 40)

plt.savefig('figures_Carlo/strategies/grid_sol_2_base.pdf')

# %% [markdown]
# # Random sampling

# %%
# iter_hp = 30
# iter_design = 40 
# iter_param = 50
# num_base_kernels = 3

# f_target = Tensor(vf.tgt_vec) 
# f_target = f_target.reshape(f_target.shape[0],1) 
# tol_vector = 0.005 * torch.ones(f_target.shape)


loc_size_rdn = math.ceil(g_theta1.shape[0]) #(iter)*(loc_size+1) + sample_size

loc_sample = high_minus_low  * np.random.random_sample((loc_size_rdn,2)) + vf.low #np.random.random_sample((loc_size_rdn,2))
g_theta_ = (Tensor(loc_sample).clone())
agg_data1 = vfield_(g_theta_)
agg_data1 = agg_data1.flatten()


x0 = Tensor(np.array([-2.0,2.0])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_rdn = Tensor(np.array([0.,0.])) 
vec_x_rdn = vec_x_rdn.reshape(1,2)

lr_new = 1.


SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')

model_rdn, likelihood_rdn = hyper_opti(g_theta_,agg_data1,iter_hp,num_base_kernels,noise_value)




print('END HYPERPARAMETERS optimization')
model_rdn.eval()
likelihood_rdn.eval()
x0_new_rdn,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_, agg_data1, model_rdn, likelihood_rdn, iter_design, iter_param, lr_new, noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_rdn)
print(SUCCESS)
sol_rdn = x0_new_rdn

# %%
np.savetxt('data_plots/sol_rdn_success_base.txt', sol_rdn.detach().numpy())
np.savetxt('data_plots/sol_grid_success_base.txt', x0_new_grid.detach().numpy())
np.savetxt('data_plots/g_theta_rdn_success_base.txt', g_theta_.detach().numpy())
#np.savetxt('data_plots/g_theta_grid_success.txt', x_concat.detach().numpy)

# %%
print(g_theta1.shape)

# %%
fig, ax = plt.subplots(figsize = (14,14))

ax.plot(g_theta_[:,0].detach(),g_theta_[:,1].detach(), 's', color = 'blue',markersize=15, alpha = 0.2)
ax.plot(sol_rdn.detach()[0,0], sol_rdn.detach()[0,1],'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$', fontsize = 32)
ax.set_ylabel('$d_2$', fontsize = 32)
ax.set_title('Uniformly Random Solution', fontsize = 40)

plt.savefig('figures_Carlo/strategies/rdn_sol_2_base.pdf')

# %% [markdown]
# # Vizualizing Means and Variances

# %%
import matplotlib.ticker
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
             self.format = r'$\mathdefault{%s}$' % self.format

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)

model.eval()

likelihood.eval()

#noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
#print(x_concat_)
with torch.no_grad(), gpytorch.settings.fast_pred_var(True):
    pred = GPprediction(model)
    pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
    #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
    pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
    mean_v_1 = pr_mean[:,0].reshape(n,n)
    mean_v_2 = pr_mean[:,1].reshape(n,n)
    pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T
    
    var_v_1 = pred_var[:,0].reshape(n,n)
    var_v_2 = pred_var[:,1].reshape(n,n)
#     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

# #     print(pr.covariance_matrix.mean(axis=0))
# #     print(AA)
# #     print(pr.variance)
# #     print((pr.covariance_matrix))
# #     K = model.covar_module
#     print((cov.diag()))
#     print(pr_mean)


fig, (ax1, ax2) = plt.subplots(2, 2, figsize = (28, 24), tight_layout=True)
diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
cs10 = ax1[0].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(0, 1.1, 100), cmap = 'jet')
ax1[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[0].set_title('$|v_1 - \mu(v_1)|$', fontsize = 40)
cbar10 = fig.colorbar(cs10, ax = ax1[0],format=OOMFormatter(0, mathText=False));

ax1[0].set_xlabel('$d_1$')
ax1[0].set_ylabel('$d_2$')
diff_mean_v1 = torch.abs(v_1 - mean_v_1.detach())/torch.sqrt(var_v_1)
#print(var_v_1)
cs11 = ax1[1].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(diff_mean_v1.min(), diff_mean_v1.max(), 100), cmap = 'jet')
ax1[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[1].set_title('$|v_1 - \mu(v_1)|/\sigma(v_1)$', fontsize = 40)
# ax1[0].set_aspect('equal')
# ax1[1].set_aspect('equal')
cbar11 = fig.colorbar(cs11, ax = ax1[1],format=OOMFormatter(0, mathText=False));
ax1[1].set_xlabel('$d_1$')
ax1[1].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())
cs20 = ax2[0].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(0, 1.1, 100), cmap = 'jet')
ax2[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[0].set_title('$|v_2 - \mu(v_2)|$', fontsize = 40)
cbar20 = fig.colorbar(cs20, ax = ax2[0],format=OOMFormatter(0, mathText=False));
ax2[0].set_xlabel('$d_1$')
ax2[0].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())/torch.sqrt(var_v_2)
cs21 = ax2[1].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(diff_mean_v2.min(), diff_mean_v2.max(), 100), cmap = 'jet')
ax2[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[1].set_title('$|v_2 - \mu(v_2)|/\sigma(v_2)$', fontsize = 40)
cbar21 = fig.colorbar(cs21, ax = ax2[1],format=OOMFormatter(0, mathText=False));
ax2[1].set_xlabel('$d_1$')
ax2[1].set_ylabel('$d_2$')


# ax2[0].set_aspect('equal')
# ax2[1].set_aspect('equal')

plt.savefig('figures_Carlo/mean_var/mean_final_2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)
plot = [1, 6, 10, iter+1]

for ii in plot:
    try:
        
        PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
    except:
        PATH = ".//model_Carlo/model_update/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
        
    #model_16 = torch.load(PATH)
    model_16.eval()

    likelihood.eval()

    #noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
    #print(x_concat_)
    with torch.no_grad(), gpytorch.settings.fast_pred_var(False):
        pred = GPprediction(model_16)
        pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
        #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
        pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
        mean_v_1 = pr_mean[:,0].reshape(n,n)
        mean_v_2 = pr_mean[:,1].reshape(n,n)
        pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T

        var_v_1 = pred_var[:,0].reshape(n,n)
        var_v_2 = pred_var[:,1].reshape(n,n)
    #     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

    # #     print(pr.covariance_matrix.mean(axis=0))
    # #     print(AA)
    # #     print(pr.variance)
    # #     print((pr.covariance_matrix))
    # #     K = model.covar_module
    #     print((cov.diag()))
    #     print(pr_mean)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (28, 12), tight_layout=True)
    diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
    minn = torch.min(var_v_1.detach().min(), var_v_2.detach().min())
    maxx = torch.min(var_v_1.detach().max(), var_v_2.detach().max())

    cs11 = ax1.contourf(xv_plot, yv_plot, var_v_1.detach(), np.linspace(0.0,1.1, 100), cmap = 'jet')
    ax1.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    
    ax1.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
  
    ax1.set_title('$\sigma^2(v_1)$ (Iteration '+str(ii)+')', fontsize = 40)
    # ax1[0].set_aspect('equal')
    # ax1[1].set_aspect('equal')
    cbar11 = fig.colorbar(cs11, ax = ax1,format=OOMFormatter(-0, mathText=False));
    ax1.set_xlabel('$d_1$')
    ax1.set_ylabel('$d_2$')


  


    cs21 = ax2.contourf(xv_plot, yv_plot, var_v_2.detach(), np.linspace(0.0, 1.1, 100), cmap = 'jet')
    ax2.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
    ax2.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    ax2.set_title('$\sigma^2(v_2)$ (Iteration '+str(ii)+')', fontsize = 40)
    cbar21 = fig.colorbar(cs21, ax = ax2,format=OOMFormatter(-0, mathText=False));
    ax2.set_xlabel('$d_1$')
    ax2.set_ylabel('$d_2$')


    # ax2[0].set_aspect('equal')
    # ax2[1].set_aspect('equal')

    plt.savefig('figures_Carlo/mean_var/var_iter_base'+str(ii)+'.pdf', dpi=300, bbox_inches='tight')
    plt.show()

# %%
print(g_theta1.shape[0])

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# # #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
# #                     #loc_size = 4
# # loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# # loc_sample0 = loc_sample.reshape(2 + 1, 2)
# # g2 = loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# z = torch.zeros(n*n, 1)
# for ii in range(n*n):
#     print(ii)
#     x0 = x_concat_[ii,:].reshape(1,2)
#     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#                     #loc_size = 4
#     loc_sample = dis_2sample.sample((2 + 1,))
#     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#     g2 = loc_sample0 #Tensor(loc_sample) #.detach()
    
    
    
#     x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21 = conduct_2opt(agg_data,f_target,x0, g_theta1, model, likelihood, noise_value, g2, training_param_iter)
#     z[ii] = loss2
# z = z.reshape(n,n)

# %%
print(g_theta1.shape)

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
#                     #loc_size = 4
# loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# loc_sample0 = loc_sample.reshape(2 + 1, 2)
# g2 = g_theta2.detach() #loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# plot = [1, 7, 17, 26]
# zz = torch.zeros(n*n, 4)
# kk = 0
# for jj in plot:
#     try:
        
#         PATH = ".//model_Carlo/model_goodmodel/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#     except:
#         PATH = ".//model_Carlo/model_update/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#    # model_16 = torch.load(PATH)
#     model_16.eval()

#     likelihood.eval()
#     g2 = v2.detach()[jj - 1 +loc_size+1 : jj - 1 +loc_size+1 +loc_size+1]
#     g_theta1_cur = g_theta1[0:(4 + (jj - 1)* 3)]
#     agg_data_cur = agg_data[0:2 * (4 + (jj - 1)* 3)]
#     print(agg_data_cur.shape)
#     for ii in range(n*n):
#         print(ii)
#         x0 = x_concat_[ii,:].reshape(1,2)
#     #     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#     #                     #loc_size = 4
#     #     loc_sample = dis_2sample.sample((2 + 1,))
#     #     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#         #g2 = loc_sample0 #Tensor(loc_sample) #.detach()


        
#         loss2_, pf1_, Qf1_, Qf12_, data_fit_, Q21_ = likelihood.get_ell(agg_data_cur,f_target,x0, g_theta1_cur, model_16, likelihood, noise_value, g2)
#         zz[ii, kk] = loss2_
#     kk = kk+1
# zz = zz.reshape(n,n, 4)
# torch.save(zz.detach(), 'data_plots/zz_success.txt')

# %%
# #plot = [1, 5, 10, 20]

# for jj in range(4):
#     fig, ax = plt.subplots(figsize = (16,14))
#     #
#     cs = ax.contour(xv_plot, yv_plot,  zz[:,:,jj].detach(), np.linspace( zz[:,:,jj].detach().numpy().min(), zz[:,:,jj].detach().numpy().max(), 1000), cmap = 'jet')
#     cbar = fig.colorbar(cs, ax = ax,format=OOMFormatter(0, mathText=False));
#     ax.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
#     kk = plot[jj]
#     if kk < plot[3]:
#         ax.plot(vec_x[kk,0], vec_x[kk,1],'o', color = 'black',markersize=12)
#     if kk == plot[3]:
#         ax.plot(vec_x[- 1,0], vec_x[- 1,1],'o', color = 'black',markersize=12)
#     ax.set_title('TAD Acquisition Function (Iteration '+str(kk)+')', fontsize = 40)
#     ax.set_xlabel('$d_1$')
#     ax.set_ylabel('$d_2$')
    
#     plt.savefig('figures_Carlo/tad_obj'+str(kk)+'.pdf', dpi=300, bbox_inches='tight')

# %%
p21_vec_plot
