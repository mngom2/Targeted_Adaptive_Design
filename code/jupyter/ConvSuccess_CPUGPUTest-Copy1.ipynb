# %% [markdown]
# # TAD CPU vs. GPU Numerical Tests
# In this notebook, we test the running speed of various components of TAD on CPU vs. GPU. TAD is an example application of Gaussian Process (GP) and GPytorch.

# %%
import math
import torch
from torch import nn
from torch import Tensor
from torch.nn  import functional as F
import gpytorch
from matplotlib import pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
import matplotlib.cm as cm
import matplotlib.patches as patches
from mpl_toolkits.mplot3d import Axes3D 
import sys
from decimal import Decimal
from IPython.display import clear_output
sys.path.append("..")
from LBFGS import FullBatchLBFGS
from kernels import vvkernels as vvk, sep_vvkernels as svvk, vvk_rbfkernel as vvk_rbf
from means import vvmeans as vvm
from likelihood import vvlikelihood as vvll
from mlikelihoods import MarginalLogLikelihood as exmll
from predstrategies import GPprediction
from utils import ObjFun, get_vertices, stopping_criteria
from scipy import stats
import numpy as np
import seaborn as sns
import scipy
import time
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Plots settings

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
plt.rc('axes', titlesize=40)     # fontsize of the axes title
plt.rc('axes', labelsize=32)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=32)    # fontsize of the tick labels
plt.rc('ytick', labelsize=32)    # fontsize of the tick labels
plt.rc('legend', fontsize=32)    # legend fontsize
plt.rc('font', size=32)          # controls default text sizes

# %% [markdown]
# # Objective function
#
# We sample from $$V_1(x_1, x_2) = 3(1 - x_1)^2 e^{-x_1^2 - (x_2 +1)^2} - 10 (x_1/5 - x_1 ^3 - x_2^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- (x_1 + 2) ^2 - x_2^2} + 0.5(2x_1 + x_2)$$
# $$V_2(x_1, x_2) = 3(1 +x_2)^2 e^{-x_2^2 - (x_1 +1)^2} - 10 (-x_2/5 + x_2 ^3 + x_1^5) e^{-x_1^2 - x_2 ^2} - 3 e^{- ( 2- x_2) ^2 - x_1^2} + 0.5(2x_1 + x_2)$$
#
# where $(x_1, x_2) \in [-3, 3]^2$

# %%
torch.set_default_dtype(torch.float64)

# %% [markdown]
# # Use CPU

# %%
# use_cuda = torch.cuda.is_available()
use_cuda = False
device = torch.device('cuda' if use_cuda else 'cpu')

vf = ObjFun() # need to write a function, input + output (training points), if switching to higher dimension. Google scalable Bayesian Optimization and use what they are using
# Need target point. 
f_target = vf.tgt_vec
print(f_target)
sample_size = 4
D = vf.D
N = vf.N

vf.low = -1.
vf.high = 1.

high_minus_low = vf.high - vf.low
#high_minus_low = -
def g_theta(sample_size, D):
#     loc_x = (2. - 1.0 )  * np.random.random_sample((sample_size,1)) + 1.0
    
#     loc_y = (2.  -1.0)  * np.random.random_sample((sample_size,1)) - 2.
#     loc = np.concatenate((loc_x, loc_y), 1)
    loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
if use_cuda:
    train_x = train_x.cuda()
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    out = torch.zeros(x.shape[0], N)
    randn = torch.randn(Tensor(vf(x[:,0], x[:,1])).size())
    randn = randn.to(x.device)
    out = vf(x[:,0], x[:,1]) + randn * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([0.3380, 0.3502], dtype=torch.float32)
# tensor([[ 0.3339, -0.3930],
#         [ 0.5098,  0.5823],
#         [-0.7086, -0.1766],
#         [-0.9982,  0.9635]])

# %% [markdown]
# ## GP model initialization
# We inialize the GP model following https://docs.gpytorch.ai/en/stable/examples/03_Multitask_Exact_GPs/Multitask_GP_Regression.html

# %%
x_train = train_x #loc #torch.linspace(0, 1, 10)
y_train = train_y #v  #torch.stack([torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,torch.cos(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2,], -1)

class MultitaskGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood,num_base_kernels):
        super(MultitaskGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)  #vvm.TensorProductSubMean(gpytorch.means.LinearMean(2), num_tasks = 2)#vvm.TensorProductSubMean(gpytorch.means.ConstantMean(), num_tasks = 2)  # 
        base_kernels = [] #contain all the base kernels
        for i in range(num_base_kernels):
            base_kernels.append(gpytorch.kernels.ScaleKernel(( gpytorch.kernels.RBFKernel() ))) #gpytorch.kernels.PolynomialKernel(4)  ##gpytorch.kernels.MaternKernel()# (vvk_rbf.vvkRBFKernel())
 
            
        self.covar_module = svvk.SepTensorProductKernel(base_kernels,num_tasks = 2)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal(mean_x, covar_x)

# %% [markdown]
# # Hyperparamaters oprimization

# %%
# # ###hyperparameters optimization###
def hyper_opti(g_theta1, agg_data, training_iter,num_base_kernels,noise_value, current_model = None, current_likelihood = None):
    noises = torch.ones(agg_data.shape[0]) * (noise_value) #  torch.zeros(agg_data.shape[0]) # 
    noises = noises.reshape(g_theta1.shape[0], 2)
    
#     if (current_model is not None):
#         likelihood = current_likelihood #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises)  #

#         model = current_model#.get_fantasy_model(g_theta1, agg_data) #MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
#         model.set_train_data(g_theta1, agg_data,  strict=False)
#     else:
#         likelihood = vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2)#vvll.FixedNoiseMultitaskGaussianLikelihood(2, noises) #
#         model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
        
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    likelihood =  vvll.FixedNoiseMultitaskGaussianLikelihood(noises) #vvll.TensorProductLikelihood(num_tasks = 2) #
    model = MultitaskGPModel(g_theta1, agg_data, likelihood,num_base_kernels)
    model.double()
    likelihood.double()

    """Put related things on GPU"""
    if use_cuda:
        print("Using CUDA")
        model = model.cuda()
        likelihood = likelihood.cuda()
#         g_theta1 = g_theta1.cuda()
#         agg_data = agg_data.cuda()
        cov_noise1 = cov_noise1.cuda()
        
    else:
        print("Using CPU")
    
    
    """end for GPU"""

    model.train()
    
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(),  lr=0.1) #, weight_decay=0.001)  # Includes GaussianLikelihood parameters
    mll = exmll(likelihood, model)
    # Is this a likelihood?

    for i in range(training_iter):
        optimizer.zero_grad()

        loss, chi_square = mll(agg_data,g_theta1, model, likelihood, cov_noise1)
        loss = -1. * loss
#         print('df is %.3f' %agg_data.shape[0] +'and chi_square %.3f' %chi_square) 
        #print('loss is %.3f' %loss)
#         df = agg_data.shape[0]
#         chi_square = chi_square.clone().detach()
        
#         p_val = 1. - stats.chi2.cdf(chi_square, df)
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
       # print(p_val)
#         if (p_val > 0.99999):
#             return model, likelihood


    
        
    print('loss is %.3f' %loss)
#     for params in model.named_parameters():
#         print(params)
    return model, likelihood

# %% [markdown]
# # Design parameters and sampling point optimization (where to explore?)

# %%
def conduct_design_opti(x0,loc_sample, f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': g_theta2, 'lr': 0.01},{'params': x_d, 'lr': 0.01}])

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    #scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    
    cov_noise1 =  noise_value * torch.eye(agg_data.shape[0])
    cov_noise2 =  noise_value * torch.eye(2 * g_theta2.shape[0])
    
    """Put related things on GPU for conduct_design_opti"""
    if use_cuda:
        print("Using CUDA for conduct_design_opti()")
        
        model = model.cuda()
        likelihood = likelihood.cuda()
        agg_data = agg_data.cuda()
        
        cov_noise1 = cov_noise1.cuda()
        cov_noise2 = cov_noise2.cuda()
#         g_theta1 = g_theta1.cuda()
        g_theta2 = g_theta2.cuda()
#         agg_data = agg_data.cuda()
        x_d = x_d.cuda()
        f_target = f_target.cuda()
        
    else:
        print("Using CPU for conduct_design_opti()")
    
    """end for GPU"""
    
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        loss2, pf1, Qf1, Qf12, data_fit, Q21 = likelihood.get_ell(agg_data,f_target,x_d, g_theta1, model, likelihood, g_theta2, cov_noise1, cov_noise2)

        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        scheduler.step(loss2)
        #scheduler.step()

    print('Loss design: %.3f' % ( loss2))
    #print(x_d)
    return x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21

# %% [markdown]
# # Conducting the TAD experiment

# %% [markdown]
# Initialization

# %%
loc_size = 2
#loc_sample0 = Tensor((2. - 1.5)  * np.random.random_sample((loc_size,2)) + 1.5)
x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
x0 = x0.reshape(1,2)

dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(loc_size) )
                    #loc_size = 4
loc_sample = dis_2sample.sample((loc_size + 1,))

loc_sample0 = loc_sample.reshape(loc_size + 1, 2)
#loc_sample0[-1] = train_x[-1] + 0.01

# This will make TAD fail to find a solution
f_target = Tensor([[-1., -1.]]).reshape(2,1)
tol_vector = 0.01 * torch.ones(f_target.shape)
#####

# Failing criterion
thresh_EI = 0.0007 # This also
count_EI = 0
max_count_EI = 5 # This affects the number of iterations required to fail
#####

# %%
"""Saving x0, loc_sample0, x_train, and y_train for running (basically) the same thing on GPU again later"""
x0_copy = x0
loc_sample0_copy = loc_sample0
x_train_copy = x_train
y_train_copy = y_train

# %%
cpu_hyper_opti = []
cpu_conduct_design = []
cpu_total = []

# %% [markdown]
# TAD algorithm

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 100
iter_param = 100
num_base_kernels = 2
max_iter = 50

# f_target = f_target.reshape(2,1) 
# tol_vector = 0.01 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten().to(device)

data_fit_vec = torch.empty((1,1)).to(device)
entropy_vec = torch.empty((1,1)).to(device)
loss_vec = torch.empty((1,1)).to(device)




#
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])
p21_vec = torch.empty((1,1))

lr_new = .01

    
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False


g_theta1 = g_theta1.to(device)
agg_data = agg_data.to(device)


while(SUCCESS == False and FAILURE == False):
    total_time_start = time.time()
    
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None


        loc_sample_old = loc_sample.clone()
        x0_old = x0.clone()
        hyper_opti_start = time.time()
        
        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)
        
        hyper_opti_end = time.time()
        cpu_hyper_opti.append(hyper_opti_end - hyper_opti_start)
        
# Before this is hyper_opti

        print('END HYPERPARAMETERS optimization')

 #     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
        
#     """end for CPU"""
    
    model.eval()
    likelihood.eval()
   
    conduct_design_start = time.time()
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
    conduct_design_end = time.time()
    cpu_conduct_design.append(conduct_design_end - conduct_design_start)

    """Everything after here might be independent"""
    # torch.inv_quad, torch.det, everything with likelihood.something is expensive
    cur_model = model
    cur_likelihood = likelihood
    
# Check tolerance to see if we succeeded
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])

    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
# End of checking
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    # Computing entropy can be expensive to compute
    
    print('expected info is '+str(entropy))
    
    if not SUCCESS:
    


        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape)).cpu()
                
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value)
               
                eye = torch.eye(Qf12.shape[0]).to(device)
                chi_f12 = (Qf12 + noise_value*eye).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape)).cpu()
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                p21_vec = torch.cat([p21_vec, Tensor([p_val]).reshape(1,1)], 0)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    sum = torch.zeros(2, 2).to(device) #replace with num_tasks
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    x0_old = x0_old.to(device)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_old).t(), (g_theta2.detach()[i] - x0_old) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_old, covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    loc_sample = torch.cat([loc_sample, x0_old],0)
                    
                    x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
                        PATH = ".//model_Carlo/model_update/model_base_"+str(iter)+".pt"
                        torch.save(model, PATH)
                        
                        entropy_vec = torch.cat([entropy_vec, entropy], 0)
                        data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is ' + str(num_base_kernels))
#     #                         
                        loc_sample = loc_sample_old
                        #x0 = x0_old
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                        g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                        print('acquiring 2, new size is ' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
                    torch.save(model, PATH)
                    vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                    loss_vec = torch.cat([loss_vec, -loss])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy < thresh_EI):
                        count_EI = count_EI + 1
                    else:
                        count_EI = 0
                    if (count_EI >= max_count_EI):
                        FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2).to(device)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum# + torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -1. or loc_sample[i,0] > 1. or loc_sample[i,1] < -1. or loc_sample[i,1] > 1.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target.to(device) - pf1).cpu()
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        
                        rand = torch.randn(x0_new.detach().size()).to(device)
                        x0 = (x0_new.detach()) + rand * .001
                        loc_sample[-1] = (x0_new.detach()) + rand * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -1. or x0_new.detach()[0,0] > 1. or x0_new.detach()[0,1] < -1. or x0_new.detach()[0,1] > 1.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                        x0 = x0.reshape(1,2)
                        #x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
        total_time_end = time.time()
        cpu_total.append(total_time_end - total_time_start)
        
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
torch.save(model, PATH)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[ 0.0110,  0.1198],
#         [ 0.0006,  0.0524],
#         [-0.1489, -0.0370]])
# 0
# START HYPERPARAMETERS optimization
# Using CPU
# /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/lazy/triangular_lazy_tensor.py:136: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /lus/theta-fs0/software/thetagpu/conda/2022-07-01/pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   res = torch.triangular_solve(right_tensor, self.evaluate(), upper=self.upper).solution
# loss is -2.546
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1922.214
# expected info is tensor([[0.1166]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.0468, -0.0822]])
# new data istensor([[0.1408, 0.0913]])
# g_theta2 istensor([[-0.3998,  0.3880],
#         [-0.3300,  0.3261],
#         [-0.4364,  0.2867]])
# p21val is 0.016373151472259
# pf12val is 0.017584954489814
# chi_f12 is 8.081423202142499
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6525, -0.7243],
#         [ 0.3641, -0.4203],
#         [ 0.0476, -0.0807]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.135
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 656.668
# expected info is tensor([[0.0635]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3756, -0.6515]])
# new data istensor([[0.3227, 0.0951]])
# g_theta2 istensor([[ 0.6332, -0.6375],
#         [ 0.5228, -0.5066],
#         [ 0.1633,  0.1634]])
# p21val is 0.101317815406616
# pf12val is 0.000000000000000
# chi_f12 is 70.834223397656714
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4617, -0.6409],
#         [ 0.5807, -0.6778],
#         [-0.3770, -0.6508]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.323
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 223.433
# expected info is tensor([[0.0300]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1879, -0.9227]])
# new data istensor([[0.0913, 0.2934]])
# g_theta2 istensor([[-0.5156, -0.6632],
#         [ 0.6891, -0.6749],
#         [-0.4564, -0.6332]])
# p21val is 0.146057929468263
# pf12val is 0.000000005948765
# chi_f12 is 37.880164553655966
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4240, -0.7891],
#         [ 0.9044, -0.7683],
#         [-0.1885, -0.9235]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.078
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 255.708
# expected info is tensor([[0.0601]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2488, -1.2091]])
# new data istensor([[-0.4884,  0.3732]])
# g_theta2 istensor([[ 0.5876, -0.5816],
#         [ 1.0759, -0.9079],
#         [-0.3783, -0.7472]])
# p21val is 0.357919059086476
# pf12val is 0.016801915003108
# chi_f12 is 8.172524821577653
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6867, 0.9576],
#         [0.7892, 0.2638],
#         [0.0000, 0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.138
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1265.956
# expected info is tensor([[0.0034]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2895, -0.2186]])
# new data istensor([[0.2436, 0.0189]])
# g_theta2 istensor([[0.4394, 1.2457],
#         [0.8727, 0.3097],
#         [0.1067, 0.1338]])
# p21val is 0.001833039247993
# pf12val is 0.773468272851978
# chi_f12 is 0.513741254909529
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# Using CPU for conduct_design_opti()
# Loss design: 1262.507
# expected info is tensor([[0.0034]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2931, -0.2123]])
# new data istensor([[ 0.2771, -0.0146]])
# g_theta2 istensor([[ 0.1282, -1.4137],
#         [ 1.6454,  1.5097],
#         [ 0.1075,  0.1327]])
# p21val is 0.209602458826248
# pf12val is 0.224179320503333
# chi_f12 is 2.990618018850792
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0866,  0.6089],
#         [ 0.5705, -0.2794],
#         [-0.2917, -0.2132]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.132
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 230.938
# expected info is tensor([[0.0155]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9012,  0.2781]])
# new data istensor([[-0.2994,  0.2989]])
# g_theta2 istensor([[ 0.6119,  1.0781],
#         [ 0.4020, -0.4785],
#         [-0.0867, -0.3900]])
# p21val is 0.557847837286243
# pf12val is 0.173224788493257
# chi_f12 is 3.506330344927535
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5816,  0.7324],
#         [ 0.7309,  0.1971],
#         [-0.9017,  0.2789]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.177
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 199.722
# expected info is tensor([[0.0645]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.2812,  0.5517]])
# new data istensor([[-0.5250,  0.5516]])
# g_theta2 istensor([[-0.8198,  0.4891],
#         [ 1.0598, -0.2275],
#         [-0.7411,  0.1006]])
# p21val is 0.220686428459328
# pf12val is 0.055568013549254
# chi_f12 is 5.780295078296976
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2828,  0.2263],
#         [-0.6338,  0.5757],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.169
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 4612.086
# expected info is tensor([[0.0031]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4604,  0.0136]])
# new data istensor([[0.0992, 0.0552]])
# g_theta2 istensor([[-0.4192,  0.3880],
#         [-0.8790,  0.3378],
#         [ 0.2188,  0.1316]])
# p21val is 0.574864769353115
# pf12val is 0.712234566354463
# chi_f12 is 0.678695949397792
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7385,  0.0513],
#         [-0.0460,  0.1041],
#         [-0.4602,  0.0130]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.308
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 181.008
# expected info is tensor([[0.0071]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.0057, -0.6850]])
# new data istensor([[-0.0229,  0.2803]])
# g_theta2 istensor([[-0.9621,  0.3661],
#         [ 0.0496,  0.1105],
#         [-0.7778,  0.3338]])
# p21val is 0.832547551985436
# pf12val is 0.743316943170521
# chi_f12 is 0.593265505971122
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5004,  0.9216],
#         [-0.3877, -0.4604],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.390
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 9554.060
# expected info is tensor([[0.0060]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2123, -0.2322]])
# new data istensor([[ 0.2289, -0.0106]])
# g_theta2 istensor([[ 0.5494,  1.0414],
#         [-0.5536, -0.6257],
#         [ 0.1773,  0.1776]])
# p21val is 0.330044030236505
# pf12val is 0.417222982171609
# chi_f12 is 1.748268941343704
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1789, -0.3363],
#         [ 0.4964,  0.9632],
#         [-0.2129, -0.2319]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.457
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 9169.294
# expected info is tensor([[0.0030]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5028,  0.0418]])
# new data istensor([[0.0905, 0.0798]])
# g_theta2 istensor([[-0.1661, -0.3700],
#         [ 0.5674,  0.8651],
#         [-0.0891, -0.3247]])
# p21val is 0.224537014046374
# pf12val is 0.442798030579207
# chi_f12 is 1.629283051621294
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2660,  0.5070],
#         [-0.7246, -0.3068],
#         [-0.5009,  0.0414]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.521
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 371.571
# expected info is tensor([[0.0033]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.1432, -0.2573]])
# new data istensor([[-0.4127,  0.5457]])
# g_theta2 istensor([[ 0.4296,  0.3492],
#         [-1.0825, -0.7493],
#         [-0.3433,  0.3094]])
# p21val is 0.265424863327080
# pf12val is 0.063038055261701
# chi_f12 is 5.528033366366824
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9633, -0.6070],
#         [-0.9157,  0.7851],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.510
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 12730.381
# expected info is tensor([[0.0110]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2998,  0.0661]])
# new data istensor([[0.1687, 0.0548]])
# g_theta2 istensor([[-0.9149, -0.6905],
#         [-1.0646,  0.6795],
#         [ 0.2419,  0.2415]])
# p21val is 0.754616840968677
# pf12val is 0.485880806042414
# chi_f12 is 1.443583880436690
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1379, -0.2975],
#         [ 0.0532,  0.2188],
#         [-0.3013,  0.0667]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.570
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 4216.269
# expected info is tensor([[0.0023]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9151, -0.3517]])
# new data istensor([[-0.0969,  0.2856]])
# g_theta2 istensor([[-0.1331, -0.3802],
#         [ 0.0917,  0.1405],
#         [-0.1051,  0.2530]])
# p21val is 0.899312859346640
# pf12val is 0.302229312139031
# chi_f12 is 2.393138476039839
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0135, -0.3279],
#         [-0.8721, -0.2322],
#         [-0.9136, -0.3509]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.635
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 303.160
# expected info is tensor([[0.0019]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4679, -0.6722]])
# new data istensor([[-0.4053,  0.5673]])
# g_theta2 istensor([[-0.1315, -0.1936],
#         [-0.6627, -0.0499],
#         [-0.6730, -0.1175]])
# p21val is 0.432707683980347
# pf12val is 0.329238536052665
# chi_f12 is 2.221945514663840
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6858,  0.7267],
#         [ 0.2456,  0.0266],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.661
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 17255.017
# expected info is tensor([[0.0015]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5123,  0.1107]])
# new data istensor([[0.0594, 0.0943]])
# g_theta2 istensor([[-0.9649,  1.0855],
#         [ 0.3154,  0.1674],
#         [ 0.1954,  0.1341]])
# p21val is 0.926644327906886
# pf12val is 0.650995736679572
# chi_f12 is 0.858504371348636
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3216,  0.9949],
#         [-0.2500,  0.1330],
#         [-0.5113,  0.1120]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.712
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1978.130
# expected info is tensor([[0.0007]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3336, -0.3117]])
# new data istensor([[-0.5119,  0.7847]])
# g_theta2 istensor([[ 0.5618,  1.2050],
#         [-0.1248,  0.2366],
#         [-0.2838,  0.3395]])
# p21val is 0.790149742798354
# pf12val is 0.017538126343000
# chi_f12 is 8.086756239387634
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3293,  0.9528],
#         [-0.9001, -0.4194],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.720
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 2011.502
# expected info is tensor([[0.0052]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.6463, -0.0742]])
# new data istensor([[0.1714, 0.1600]])
# g_theta2 istensor([[-0.3363,  1.1741],
#         [-1.0416, -0.6356],
#         [-0.3091,  0.1826]])
# p21val is 0.654988703484618
# pf12val is 0.138712254063374
# chi_f12 is 3.950707212304872
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5737, -0.3718],
#         [ 0.4302, -0.6733],
#         [ 0.6475, -0.0754]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.730
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 233.465
# expected info is tensor([[0.0122]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.0567, 0.3027]])
# new data istensor([[0.4530, 0.1153]])
# g_theta2 istensor([[-0.4099, -0.7538],
#         [ 0.5426, -0.5798],
#         [ 0.4561, -0.2700]])
# p21val is 0.322842874996866
# pf12val is 0.681793486970201
# chi_f12 is 0.766056944044812
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0387,  0.0986],
#         [ 0.4377, -0.5809],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.740
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 4758.404
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.8005, -0.0726]])
# new data istensor([[0.2801, 0.0458]])
# g_theta2 istensor([[ 0.2467,  0.2500],
#         [ 0.6602, -0.6664],
#         [-0.2857,  0.2117]])
# p21val is 0.279743459588008
# pf12val is 0.422449227917857
# chi_f12 is 1.723372020029196
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8732, -0.2781],
#         [ 0.4712, -0.3024],
#         [ 0.7990, -0.0710]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.757
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 198.524
# expected info is tensor([[0.0082]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.4454, 0.0890]])
# new data istensor([[ 0.5704, -0.5349]])
# g_theta2 istensor([[ 1.0220, -0.3954],
#         [ 0.4143, -0.3876],
#         [ 0.5506, -0.2941]])
# p21val is 0.948859606796168
# pf12val is 0.666880429455572
# chi_f12 is 0.810289030640332
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9450,  0.3947],
#         [-0.4028,  0.4950],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.784
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 9737.994
# expected info is tensor([[0.0014]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.7409, 0.0020]])
# new data istensor([[0.2503, 0.1974]])
# g_theta2 istensor([[ 1.0663,  0.4007],
#         [-0.3788,  0.2486],
#         [-0.3366,  0.1862]])
# p21val is 0.842176386512764
# pf12val is 0.075277560403135
# chi_f12 is 5.173146382404606
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7171,  0.7960],
#         [ 0.3185, -0.0507],
#         [ 0.7422,  0.0045]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.810
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 417.371
# expected info is tensor([[0.0020]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.4786, -0.2581]])
# new data istensor([[ 0.5402, -0.6970]])
# g_theta2 istensor([[-1.0040,  0.9703],
#         [ 0.1408, -0.1074],
#         [ 0.5201, -0.2135]])
# p21val is 0.963639992311557
# pf12val is 0.886437387160232
# chi_f12 is 0.241089570446232
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6260, -0.8239],
#         [ 0.2203,  0.7123],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.832
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 8653.337
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9554, -0.4161]])
# new data istensor([[-0.1242,  0.3103]])
# g_theta2 istensor([[-0.3116, -0.7028],
#         [ 0.5473,  0.9657],
#         [ 0.2500,  0.2088]])
# p21val is 0.590974627246155
# pf12val is 0.631394910221331
# chi_f12 is 0.919647527981883
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5837, -0.9418],
#         [ 0.6327,  0.7778],
#         [-0.9559, -0.4161]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.861
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 356.807
# expected info is tensor([[0.0069]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.6220,  0.0992]])
# new data istensor([[-0.7534,  0.8754]])
# g_theta2 istensor([[-0.3594, -0.7535],
#         [ 0.5084,  0.6126],
#         [-0.7410, -0.6318]])
# p21val is 0.630743182072665
# pf12val is 0.020128328962350
# chi_f12 is 7.811254110157352
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3828, -0.0829],
#         [ 0.0581, -0.1537],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.862
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 11860.788
# expected info is tensor([[0.0004]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.7326, -0.3989]])
# new data istensor([[0.1082, 0.0931]])
# g_theta2 istensor([[ 0.4870, -0.0043],
#         [ 0.3931, -0.2992],
#         [ 0.2357,  0.1957]])
# p21val is 0.107128116191427
# pf12val is 0.778478419620934
# chi_f12 is 0.500828017107063
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1463, -0.2154],
#         [ 0.3912, -0.0560],
#         [-0.7327, -0.4003]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.894
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 12970.428
# expected info is tensor([[0.0012]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6093, -0.3544]])
# new data istensor([[0.1774, 0.0179]])
# g_theta2 istensor([[ 0.4322,  0.0730],
#         [ 0.3764,  0.0473],
#         [-0.9931, -0.1348]])
# p21val is 0.841210324577100
# pf12val is 0.639673978199436
# chi_f12 is 0.893593282969357
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9210,  0.2714],
#         [ 0.6192,  0.1372],
#         [-0.6095, -0.3543]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.913
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 15407.101
# expected info is tensor([[0.0004]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5587, -0.3429]])
# new data istensor([[0.2194, 0.0334]])
# g_theta2 istensor([[ 1.0581,  0.3992],
#         [ 0.5437,  0.1307],
#         [-0.9042, -0.0559]])
# p21val is 0.631875174220989
# pf12val is 0.682452562438307
# chi_f12 is 0.764124519847092
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0014,  0.7497],
#         [ 0.2333, -0.0186],
#         [-0.5586, -0.3421]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.908
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 1204.775
# expected info is tensor([[0.0028]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.6132, -0.3809]])
# new data istensor([[-0.5741,  0.7940]])
# g_theta2 istensor([[ 0.3741,  1.0996],
#         [ 0.3596,  0.1030],
#         [-0.5481, -0.0106]])
# p21val is 0.183734538865175
# pf12val is 0.556151937668545
# chi_f12 is 1.173427505749497
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9435, -0.2978],
#         [ 0.6640, -0.4942],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.904
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3882.239
# expected info is tensor([[0.0004]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1376, -0.6975]])
# new data istensor([[0.1118, 0.1452]])
# g_theta2 istensor([[-0.7548, -0.4994],
#         [ 1.1028, -0.9654],
#         [ 0.2254,  0.2012]])
# p21val is 0.860077405243981
# pf12val is 0.300196796479720
# chi_f12 is 2.406634062252910
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7352, -0.4561],
#         [ 0.7619, -0.2478],
#         [ 0.1374, -0.6970]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.920
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 245.318
# expected info is tensor([[0.0012]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.7612, -1.2205]])
# new data istensor([[-0.2856,  0.2057]])
# g_theta2 istensor([[-0.2927, -0.3509],
#         [ 0.8052, -0.1973],
#         [-0.1241, -0.4603]])
# p21val is 0.116570342698236
# pf12val is 0.795740818544083
# chi_f12 is 0.456963502005275
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3962,  0.1454],
#         [ 0.3331, -0.6752],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.941
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 5342.101
# expected info is tensor([[0.0018]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1965, -0.7548]])
# new data istensor([[0.0156, 0.1878]])
# g_theta2 istensor([[ 0.3141,  0.1448],
#         [ 0.7438, -1.2727],
#         [ 0.2378,  0.1830]])
# p21val is 0.528479143028871
# pf12val is 0.776477269260506
# chi_f12 is 0.505975820300513
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7986, -0.9931],
#         [ 0.4980, -0.3904],
#         [ 0.1960, -0.7560]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.935
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3063.751
# expected info is tensor([[0.0019]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4815, -1.1142]])
# new data istensor([[-0.3625,  0.2987]])
# g_theta2 istensor([[-0.9796, -0.6600],
#         [ 0.3925, -0.5223],
#         [-0.0382, -0.5348]])
# p21val is 0.290553918810504
# pf12val is 0.622657370928822
# chi_f12 is 0.947517755776130
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7258, -0.4826],
#         [-0.1913, -0.5545],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.960
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 17905.221
# expected info is tensor([[0.0004]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1799, -0.2967]])
# new data istensor([[0.0661, 0.0463]])
# g_theta2 istensor([[ 1.0444, -0.5201],
#         [-0.1957, -0.5803],
#         [ 0.2370,  0.1836]])
# p21val is 0.677464722420485
# pf12val is 0.090912189783157
# chi_f12 is 4.795722371529225
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0047, -0.3687],
#         [-0.7505, -0.8150],
#         [ 0.1786, -0.2975]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.952
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 22580.997
# expected info is tensor([[0.0007]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1840, -0.2675]])
# new data istensor([[0.1078, 0.0808]])
# g_theta2 istensor([[-0.1830, -0.5724],
#         [-1.0774, -0.5586],
#         [-0.1567, -0.6355]])
# p21val is 0.241190594662875
# pf12val is 0.495648494836455
# chi_f12 is 1.403776566509259
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2514, -0.3596],
#         [-0.6145, -0.3718],
#         [ 0.1834, -0.2657]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.972
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 24222.970
# expected info is tensor([[0.0012]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1831, -0.0410]])
# new data istensor([[0.1450, 0.0553]])
# g_theta2 istensor([[ 0.4497, -0.5510],
#         [-0.8336, -0.6218],
#         [ 0.4361, -0.5139]])
# p21val is 0.629025832386988
# pf12val is 0.175403907438841
# chi_f12 is 3.481327843979575
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4843,  0.7396],
#         [-0.3541,  0.4075],
#         [-0.1824, -0.0407]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.989
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 24383.281
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1993, -0.2335]])
# new data istensor([[0.0474, 0.0974]])
# g_theta2 istensor([[ 0.4781,  0.7521],
#         [-0.3016,  0.1938],
#         [-0.4475,  0.2273]])
# p21val is 0.736256996460600
# pf12val is 0.029582019414497
# chi_f12 is 7.041177108877808
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0432, -0.5998],
#         [ 0.1278,  0.1381],
#         [ 0.1987, -0.2331]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.989
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 27768.503
# expected info is tensor([[0.0001]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1673, -0.2335]])
# new data istensor([[0.0795, 0.0888]])
# g_theta2 istensor([[-0.0209, -0.6596],
#         [-0.0883,  0.1805],
#         [ 0.5137, -0.5490]])
# p21val is 0.601806067375414
# pf12val is 0.367308972547200
# chi_f12 is 2.003103796132204
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2024, -0.5142],
#         [ 0.2003,  0.6443],
#         [ 0.1656, -0.2335]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 38
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -2.996
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 13838.040
# expected info is tensor([[3.3231e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9867, -0.1176]])
# new data istensor([[-0.3249,  0.4049]])
# g_theta2 istensor([[ 0.4335, -0.6530],
#         [-0.4122,  1.1808],
#         [ 0.4754, -0.5229]])
# p21val is 0.491057577469396
# pf12val is 0.137129003136290
# chi_f12 is 3.973666334952400
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6055,  0.8004],
#         [-0.8388, -0.1516],
#         [-0.9866, -0.1166]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 39
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.013
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3263.465
# expected info is tensor([[0.0062]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3159,  0.1834]])
# new data istensor([[-0.6571,  0.7845]])
# g_theta2 istensor([[ 0.6684,  0.9436],
#         [-0.6822, -0.2906],
#         [-0.8069, -0.2864]])
# p21val is 0.841064464240540
# pf12val is 0.441491935489782
# chi_f12 is 1.635191050532519
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3577,  0.7162],
#         [-0.7105,  0.4012],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 40
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.021
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 28091.770
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.4579, -0.1998]])
# new data istensor([[0.2075, 0.0134]])
# g_theta2 istensor([[ 0.5225,  0.8948],
#         [-0.9716,  0.4806],
#         [ 0.2163,  0.1556]])
# p21val is 0.566483050806234
# pf12val is 0.955354056622812
# chi_f12 is 0.091346534578589
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4068, -0.3886],
#         [-0.1789, -0.0401],
#         [-0.4593, -0.2001]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 41
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.031
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 5861.837
# expected info is tensor([[0.0003]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.4364, -0.6705]])
# new data istensor([[-0.3416,  0.5623]])
# g_theta2 istensor([[-0.0936, -0.6352],
#         [-0.0522,  0.1373],
#         [-0.6665,  0.0433]])
# p21val is 0.626048971186872
# pf12val is 0.148351637785336
# chi_f12 is 3.816339784594484
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8709, -0.7966],
#         [-0.7788, -0.3713],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 42
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.032
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 32770.149
# expected info is tensor([[0.0009]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2073, -0.0643]])
# new data istensor([[0.2258, 0.0660]])
# g_theta2 istensor([[-1.1969, -1.1056],
#         [-1.0018, -0.5752],
#         [ 0.2216,  0.2042]])
# p21val is 0.669315057874283
# pf12val is 0.164307706649309
# chi_f12 is 3.612028698156948
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0997,  0.1801],
#         [-0.6875, -0.5874],
#         [-0.2082, -0.0655]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 43
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.034
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 29652.954
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6477, -0.3934]])
# new data istensor([[0.2003, 0.0638]])
# g_theta2 istensor([[-0.0361,  0.2303],
#         [-0.5886, -0.7528],
#         [ 0.0451,  0.1967]])
# p21val is 0.949856928975208
# pf12val is 0.405704659527395
# chi_f12 is 1.804259647361322
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6194, -0.4956],
#         [-0.6903,  0.0417],
#         [-0.6477, -0.3938]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 44
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.045
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 7940.322
# expected info is tensor([[7.7150e-05]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-1.3319,  0.2302]])
# new data istensor([[-0.6542,  0.7537]])
# g_theta2 istensor([[-0.3816, -0.7091],
#         [-0.8390,  0.3537],
#         [-0.4305, -0.0541]])
# p21val is 0.308816535522476
# pf12val is 0.889425496401398
# chi_f12 is 0.234359068696729
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7843, -0.2705],
#         [-0.3385, -0.5386],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 45
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.052
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 34033.170
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1810, -0.2841]])
# new data istensor([[0.0871, 0.0522]])
# g_theta2 istensor([[-1.0496, -0.5576],
#         [-0.2614, -0.5233],
#         [ 0.2253,  0.1933]])
# p21val is 0.196416678635454
# pf12val is 0.779414219897460
# chi_f12 is 0.498425283143656
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8366, -0.0760],
#         [ 0.4527, -0.3593],
#         [ 0.1802, -0.2835]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 46
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.059
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 36477.678
# expected info is tensor([[0.0007]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1918, -0.2575]])
# new data istensor([[0.0906, 0.0909]])
# g_theta2 istensor([[ 1.0394,  0.1139],
#         [ 0.5811, -0.4991],
#         [ 0.5080, -0.6162]])
# p21val is 0.841056680494931
# pf12val is 0.489456809887831
# chi_f12 is 1.428918108048394
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5855, -0.1687],
#         [-0.7934,  0.1464],
#         [ 0.1907, -0.2574]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 47
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.074
# END HYPERPARAMETERS optimization
# Using CPU for conduct_design_opti()
# Loss design: 3263.196
# expected info is tensor([[0.0002]], grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1376, -1.0820]])
# new data istensor([[-0.1652,  0.3548]])
# g_theta2 istensor([[ 0.4031, -0.5217],
#         [-0.4845, -0.2236],
#         [ 0.4683, -0.0288]])
# p21val is 0.041552150584094
# pf12val is 0.171054884007226
# chi_f12 is 3.531541629738499
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1160,  0.2213],
#         [-0.0043,  0.2290],
#         [ 0.0000,  0.0000]])
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# current sol istensor([[-0.1376, -1.0820]])
# Success is False and failure is True after 48 iterations

# %% [markdown]
# # Use GPU

# %%
use_cuda = torch.cuda.is_available()
device = torch.device('cuda' if use_cuda else 'cpu')

vf = ObjFun()
# f_target = vf.tgt_vec
# print(f_target)
sample_size = 4
D = vf.D
N = vf.N

vf.low = -1.
vf.high = 1.

high_minus_low = vf.high- vf.low
#high_minus_low = -
def g_theta(sample_size, D):
#     loc_x = (2. - 1.0 )  * np.random.random_sample((sample_size,1)) + 1.0
    
#     loc_y = (2.  -1.0)  * np.random.random_sample((sample_size,1)) - 2.
#     loc = np.concatenate((loc_x, loc_y), 1)
    loc = high_minus_low  * np.random.random_sample((sample_size,2)) + vf.low#(np.random.uniform(low=vf.low, high=vf.high, size=(sample_size, D)))
    return Tensor(loc)
train_x = g_theta(sample_size, D)
if use_cuda:
    train_x = train_x.cuda()
#train_x = Tensor([[-1.5, 1.5], [-1.5, 1.3]])
print(train_x)
noise_value = 0.0004 #noise_free = 0.
def vfield_(x):
    x = x.reshape(x.shape[0],D)
    out = torch.zeros(x.shape[0], N)
    randn = torch.randn(Tensor(vf(x[:,0], x[:,1])).size())
    randn = randn.to(x.device)
    out = vf(x[:,0], x[:,1]) + randn * math.sqrt(noise_value)
    return out #/torch.max(out)

train_y = vfield_(train_x)

# print(train_y)
# train_y = (train_y - train_y.mean())/train_y.std(dim=-2, keepdim=True)
# train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)
# print(train_y)
# print(train_y.std(dim=-2, keepdim=True))
# Out:
# tensor([[-0.9483, -0.6811],
#         [-0.0041, -0.0877],
#         [ 0.7434,  0.8437],
#         [ 0.1782,  0.2072]], device='cuda:0')

# %%
gpu_hyper_opti = []
gpu_conduct_design = []
gpu_total = []

# %%
x0 = x0_copy
loc_sample0 = loc_sample0_copy
x_train = x_train_copy
y_train = y_train_copy

# This will make TAD fail to find a solution
f_target = Tensor([[-1., -1.]]).reshape(2,1)
tol_vector = 0.01 * torch.ones(f_target.shape)
#####

# %%
loc_sample = loc_sample0.clone()
iter_hp = 50
iter_design = 100
iter_param = 100
num_base_kernels = 2
max_iter = 50

# f_target = f_target.reshape(2,1) 
# tol_vector = 0.01 * torch.ones(f_target.shape)

plot_freq = 1


 #np.random.random_sample((loc_size,2))
#loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
#train_x = (train_x - train_x.mean())/train_x.std(dim=-2, keepdim=True)

#loc_sample = Tensor([[0.0, 0.1], [0.0, -0.1]]) #T
# loc_x = (-1.5 + 2.)  * np.random.random_sample((loc_size,1)) +2.

# # loc_y = (2. - 1.5)  * np.random.random_sample((loc_size,1)) - 1.5
# # loc = np.concatenate((loc_x, loc_y), 1)
print(loc_sample)


g_theta2_vec = (Tensor(loc_sample).clone()).flatten().to(device)

data_fit_vec = torch.empty((1,1)).to(device)
entropy_vec = torch.empty((1,1)).to(device)
loss_vec = torch.empty((1,1)).to(device)




#
vec_x = x0.clone() #Tensor(np.array([0.0,0.0])) 
vec_x = vec_x.reshape(1,2)
var_vec = torch.zeros([max_iter, 1])
p21_vec = torch.empty((1,1))

lr_new = .01

    
    

SUCCESS = False 
FAILURE = False 
show_TTRBox = False
iter = 0    
g_theta1 = x_train
agg_data = y_train.flatten()
patience = 0.0
patience_f = 0.0
patience_2 = 0.0
checking_model = False
model_double_check = False


g_theta1 = g_theta1.to(device)
agg_data = agg_data.to(device)


while(SUCCESS == False and FAILURE == False):
    total_time_start = time.time()
    
    print(iter)
    model_double_check = False
    if (checking_model == False):
        print('START HYPERPARAMETERS optimization')
        if (iter == 0):
            cur_model = None
            cur_likelihood = None


        loc_sample_old = loc_sample.clone()
        x0_old = x0.clone()
        hyper_opti_start = time.time()
        
        model, likelihood = hyper_opti(g_theta1,agg_data,iter_hp,num_base_kernels,noise_value, current_model = cur_model, current_likelihood = cur_likelihood)
        
        hyper_opti_end = time.time()
        gpu_hyper_opti.append(hyper_opti_end - hyper_opti_start)
        
# Before this is hyper_opti

        print('END HYPERPARAMETERS optimization')

 #     model = model.cpu()
#     likelihood = likelihood.cpu()
#     g_theta1 = g_theta1.cpu()
#     agg_data = agg_data.cpu()
        
#     """end for CPU"""
    
    model.eval()
    likelihood.eval()
   
    conduct_design_start = time.time()
    x0_new,g_theta2, loss, pf1, Qf1, Qf12, data_fit, Q21 = conduct_design_opti(x0, loc_sample, f_target, g_theta1, agg_data, model, likelihood, iter_design,iter_param, lr_new,noise_value)
    conduct_design_end = time.time()
    gpu_conduct_design.append(conduct_design_end - conduct_design_start)


    cur_model = model
    cur_likelihood = likelihood
    
  
    lower_bound = torch.zeros(pf1.shape)
    upper_bound = torch.zeros(pf1.shape)
        
    for i in range(pf1.shape[0]):
        lower_bound[i] = pf1[i] -  torch.sqrt(Qf12[i,i])
        upper_bound[i] = pf1[i] +  torch.sqrt(Qf12[i,i])

    SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)
    
    entropy = ( 0.5 * torch.log( torch.det(Qf1.evaluate()) / torch.det(Qf12.evaluate()) ) ).reshape(1,1)
    
    print('expected info is '+str(entropy))
    
    if not SUCCESS:
    


        

        new_data = vfield_(g_theta2.detach())  
        agg_data12 = torch.cat([agg_data, new_data.flatten()], 0)
        g_theta12= torch.cat([g_theta1, g_theta2.detach()], 0)
        new_data_x = vfield_(x0_new.detach() )  
        print('current sol is'+str(x0_new.detach()))
        print('new data is' + str(new_data_x))
        print('g_theta2 is' + str(g_theta2.detach()))
        
        
        
        

        
        with torch.no_grad():

            
            if iter >= 0:
                
                
                p21 = likelihood.get_p21(g_theta1, g_theta2.detach(), agg_data, model, noise_value)
                
#                 Q21 = Q21 + noise_value*torch.eye(Q21.shape[0])
                chi_21 = (Q21).inv_quad(new_data.flatten() - p21.reshape(new_data.flatten().shape)).cpu()
                
                p_val = 1. - stats.chi2.cdf(chi_21, Q21.shape[0])
                pf12 = likelihood.get_pf12(Q21,g_theta1, g_theta2.detach(), x0_new.detach(), new_data.flatten(), pf1, p21, model, noise_value)
               
                eye = torch.eye(Qf12.shape[0]).to(device)
                chi_f12 = (Qf12 + noise_value*eye).inv_quad(new_data_x.flatten() - pf12.reshape(new_data_x.flatten().shape)).cpu()
                p_val_f12 = 1. - stats.chi2.cdf(chi_f12, Qf12.shape[0])
                print('p21val is %.15f' %p_val)
                p21_vec = torch.cat([p21_vec, Tensor([p_val]).reshape(1,1)], 0)
                print('pf12val is %.15f' %p_val_f12)
                print('chi_f12 is %.15f' %chi_f12 )
                
                if (p_val < 0.01):# or p_val_f12 < 0.001:
                    model_double_check = True
                    checking_model = True
                    patience = patience+1
                    print('patience is %.3f' %patience)

                if (model_double_check == True):
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_sample.shape[0],2)) + vf.low)
                    sum = torch.zeros(2, 2).to(device) #replace with num_tasks
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)
                    x0_old = x0_old.to(device)
                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_old).t(), (g_theta2.detach()[i] - x0_old) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum #+ torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_old, covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    loc_sample = torch.cat([loc_sample, x0_old],0)
                    
                    x0 = x0_old #Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    if (patience >= 2):# or patience_2 >= 2 or patience_f >= 2):
                        PATH = ".//model_Carlo/model_update/model_base_"+str(iter)+".pt"
                        torch.save(model, PATH)
                        
                        entropy_vec = torch.cat([entropy_vec, entropy], 0)
                        data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                        iter = iter + 1
                        patience = 0
#                         patience_2 = 0
#                         patience_f = 0
                        model_double_check = False
                        checking_model = False
                        num_base_kernels = num_base_kernels + 1
                        print('adding complexity to model')
                        print('num base is ' + str(num_base_kernels))
#     #                         
                        loc_sample = loc_sample_old
                        #x0 = x0_old
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                        g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                        print('acquiring 2, new size is ' + str(g_theta1.shape[0]))
                 
                    #iter_hp = iter_hp + 10
                    
                    
                
                
                else:
                    PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
                    torch.save(model, PATH)
                    vec_x = torch.cat([vec_x.to(device), x0_new.detach()])
                    loss_vec = torch.cat([loss_vec, -loss])
                    g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
                    entropy_vec = torch.cat([entropy_vec, entropy], 0)
                    data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
                    model_double_check = False
                    iter = iter + 1
                    patience = 0
                    patience_2 = 0
                    patience_f = 0
                    checking_model = False
                    if (entropy < thresh_EI):
                        count_EI = count_EI + 1
                    else:
                        count_EI = 0
                    if (count_EI >= max_count_EI):
                        FAILURE = True
                    
                    x0 = (x0_new.detach())# + torch.randn(x0_new.detach().size()) * .001)#/torch.norm(x0_new.detach())
                    sum = torch.zeros(2, 2).to(device)
                    mean_2 = torch.mean(g_theta2.detach(), 0, True)

                    for i in range(loc_size):
                        #sum =sum + torch.matmul((g_theta2.detach()[i] -mean_2).t(), ( g_theta2.detach()[i] - mean_2 ) )# sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) # 
                        sum =sum + torch.matmul((g_theta2.detach()[i] -x0_new.detach()).t(), (g_theta2.detach()[i] - x0_new.detach()) ) #sum + torch.matmul((g_theta2.detach()[i] -
                    emp_cov = 1./loc_size * sum# + torch.eye(sum.shape[0]) * 1e-8

                    dis_2sample = MultivariateNormal( loc = x0_new.detach(), covariance_matrix=emp_cov )
                    #loc_size = 4
                    loc_sample = dis_2sample.sample((loc_size,))

                    loc_sample = loc_sample.reshape(loc_size, 2)
                    #loc_sample = loc_sample#/torch.norm(loc_sample)
                    #loc_sample = 2. *  (loc_sample - torch.min(loc_sample)) / (torch.max(loc_sample) - torch.min(loc_sample)) - 1.
                    #loc_sample[0] = x0_new.detach() #+ torch.randn(x0_new.detach().size()) * .001 #g_theta2.detach() #loc_sample.reshape(loc_size, 2)
                    #loc_sample = Tensor(high_minus_low  * np.random.random_sample((loc_size,2)) + vf.low)
                    loc_sample = torch.cat([loc_sample, x0_new.detach()],0)
                    for i in range(loc_sample.shape[0]):
                        if loc_sample[i,0] < -1. or loc_sample[i,0] > 1. or loc_sample[i,1] < -1. or loc_sample[i,1] > 1.:
                            print('samples escaped box')
                            loc_sample[i] = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low)
                    
                    
#                     if p_val > 0.99 and p_val_f12 > 0.99:
#                         num_base_kernels = max(num_base_kernels - 1, 3)
                        #iter_hp = iter_hp - 10
                    chi_f_target = (Qf12 ).inv_quad(f_target.to(device) - pf1).cpu()
                    p_val_f_target = 1. - stats.chi2.cdf(chi_f_target, Qf12.shape[0])
                    print('p_val_ftarget is '+str(p_val_f_target))
                    if (p_val_f_target > .95):
                        print('acquiring target point becuse p_val_ftarget is '+str(p_val_f_target))
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
        
                        rand = torch.randn(x0_new.detach().size()).to(device)
                        x0 = (x0_new.detach()) + rand * .001
                        loc_sample[-1] = (x0_new.detach()) + rand * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                    else:
#                         x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()) * .001
#                         agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
#                         g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                       
                        agg_data = agg_data12.clone()
                        g_theta1 = g_theta12.clone()
                        x0 = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        loc_sample[-1] = (x0_new.detach()) + torch.randn(x0_new.detach().size()).to(device) * .001
                        agg_data = torch.cat([agg_data12, new_data_x.flatten()], 0)
                        g_theta1= torch.cat([g_theta12, x0_new.detach()], 0)
                        
                    if x0_new.detach()[0,0] < -1. or x0_new.detach()[0,0] > 1. or x0_new.detach()[0,1] < -1. or x0_new.detach()[0,1] > 1.:
#                         x0 = Tensor(np.array([0.0,-1.0])) # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = x0.reshape(1,2) 
                        x0 = Tensor(np.array([0. , 0.]))
 # 1./3. * Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
#                         x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                        x0 = x0.reshape(1,2)
                        #x0 = Tensor(high_minus_low  * np.random.random_sample((1,2)) + vf.low) #
                 
             #       loc_sample = (loc_sample - loc_sample.mean())/loc_sample.std(dim=-2, keepdim=True)
                        loc_sample[-1] = x0 #(x0_new.detach()) 
                    print('new 2 points')
                    print(loc_sample)
                  
 #                    agg_data  = (agg_data  - agg_data.mean())/agg_data .std(dim=-1, keepdim=True)
#                     g_theta1 = (g_theta1 - g_theta1.mean())/g_theta1.std(dim=-2, keepdim=True)
        
        
                    
                    
                    
                
            
            #clear_output(wait=False)
        total_time_end = time.time()
        gpu_total.append(total_time_end - total_time_start)
        
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
        

        
        

            
            
            
        
vec_x = torch.cat([vec_x, x0_new.detach()])
g_theta2_vec = torch.cat([g_theta2_vec, g_theta2.detach().flatten()], 0)
entropy_vec = torch.cat([entropy_vec, entropy], 0)
data_fit_vec = torch.cat([data_fit_vec, data_fit], 0)
PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(iter)+".pt"
torch.save(model, PATH)
print('current sol is'+str(x0_new.detach()))
    
print('Success is ' + str(SUCCESS) + ' and failure is ' + str(FAILURE)+' after '+ str(iter) + ' iterations')
# Out:
# tensor([[ 0.0110,  0.1198],
#         [ 0.0006,  0.0524],
#         [-0.1489, -0.0370]])
# 0
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.623
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 6448.644
# expected info is tensor([[1.5691]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.0468, -0.0822]], device='cuda:0')
# new data istensor([[0.1285, 0.0923]], device='cuda:0')
# g_theta2 istensor([[ 0.0110,  0.1198],
#         [ 0.0006,  0.0524],
#         [-0.1489, -0.0370]], device='cuda:0')
# p21val is 0.000016043580272
# pf12val is 0.307767808861448
# chi_f12 is 2.356819295284789
# patience is 1.000
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 0
# Using CUDA for conduct_design_opti()
# Loss design: 2763.353
# expected info is tensor([[0.0581]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.5192, 0.0734]], device='cuda:0')
# new data istensor([[0.0985, 0.2664]], device='cuda:0')
# g_theta2 istensor([[-0.2733, -0.5994],
#         [-0.4710,  0.3323],
#         [-0.3958,  0.1695]], device='cuda:0')
# p21val is 0.000000000000000
# pf12val is 0.044941253447469
# chi_f12 is 6.204798242073908
# patience is 2.000
# adding complexity to model
# num base is 3
# acquiring 2, new size is 7
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 1
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.070
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 124.583
# expected info is tensor([[0.0159]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.4572, -0.0027]], device='cuda:0')
# new data istensor([[0.0479, 0.2866]], device='cuda:0')
# g_theta2 istensor([[ 0.0110,  0.1198],
#         [ 0.0006,  0.0524],
#         [-0.1489, -0.0370]], device='cuda:0')
# p21val is 0.467585146378980
# pf12val is 0.115581260172956
# chi_f12 is 4.315562890230930
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3356,  0.0099],
#         [-0.1858,  0.1410],
#         [ 0.4594, -0.0024]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 2
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.163
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 297.429
# expected info is tensor([[0.0856]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.6854, -0.2532]], device='cuda:0')
# new data istensor([[0.2137, 0.0402]], device='cuda:0')
# g_theta2 istensor([[ 0.3551, -0.1473],
#         [-0.3629, -0.0260],
#         [ 0.3563,  0.1073]], device='cuda:0')
# p21val is 0.675773281996636
# pf12val is 0.006800176554523
# chi_f12 is 9.981613406473290
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5502, -0.2086],
#         [ 0.0096, -0.0933],
#         [ 0.6855, -0.2533]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -1.995
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 201.206
# expected info is tensor([[0.0667]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.9269, -0.6075]], device='cuda:0')
# new data istensor([[ 0.2495, -0.1656]], device='cuda:0')
# g_theta2 istensor([[ 0.4618, -0.1571],
#         [-0.1387,  0.0026],
#         [ 0.5351, -0.0849]], device='cuda:0')
# p21val is 0.733292645213155
# pf12val is 0.341725417124514
# chi_f12 is 2.147495476600665
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0836,  0.0223],
#         [-0.5263, -0.4374],
#         [ 0.9274, -0.6088]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 4
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.390
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 222.999
# expected info is tensor([[0.0677]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.2260, -0.9089]], device='cuda:0')
# new data istensor([[ 0.2113, -0.2273]], device='cuda:0')
# g_theta2 istensor([[-0.0738,  0.0480],
#         [-0.6457, -0.1969],
#         [ 0.7888, -0.4665]], device='cuda:0')
# p21val is 0.208010440431961
# pf12val is 0.308962658805289
# chi_f12 is 2.349069709354197
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5043,  0.3461],
#         [ 0.2477, -0.0061],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 5
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.408
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 13110.285
# expected info is tensor([[0.0160]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1587, 0.1190]], device='cuda:0')
# g_theta2 istensor([[-0.5192,  0.4300],
#         [ 0.4299,  0.1865],
#         [-0.2543,  0.2306]], device='cuda:0')
# p21val is 0.804384730189359
# pf12val is 0.398059466819167
# chi_f12 is 1.842307741480735
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2113, -0.2040],
#         [-0.7257,  0.3540],
#         [ 0.0009, -0.0012]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 6
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.540
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1978.463
# expected info is tensor([[0.0013]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.0180, -0.4489]], device='cuda:0')
# new data istensor([[0.1833, 0.0485]], device='cuda:0')
# g_theta2 istensor([[-0.4759,  0.0284],
#         [-0.4962,  0.0954],
#         [-0.1496,  0.0616]], device='cuda:0')
# p21val is 0.770350374791670
# pf12val is 0.268000129466705
# chi_f12 is 2.633535630773355
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.8965, -0.5010],
#         [-0.0904, -0.3650],
#         [ 0.0180, -0.4473]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 7
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.641
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 292.083
# expected info is tensor([[0.0947]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2972, -0.7965]], device='cuda:0')
# new data istensor([[-0.0659,  0.1785]], device='cuda:0')
# g_theta2 istensor([[ 0.8743, -0.5299],
#         [-0.1664, -0.2686],
#         [-0.1421, -0.2908]], device='cuda:0')
# p21val is 0.228869126807267
# pf12val is 0.002094690244335
# chi_f12 is 12.336699182544844
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.7813, -0.9799],
#         [-0.3452, -0.3588],
#         [ 0.2980, -0.7957]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 8
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.596
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 214.177
# expected info is tensor([[0.0625]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.6465, -1.1320]], device='cuda:0')
# new data istensor([[-0.3048,  0.2250]], device='cuda:0')
# g_theta2 istensor([[-1.1483, -0.6527],
#         [-0.2493, -0.4325],
#         [ 0.1200, -0.6298]], device='cuda:0')
# p21val is 0.457952758255033
# pf12val is 0.854210202150323
# chi_f12 is 0.315155954262632
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5005,  0.3669],
#         [ 0.7156,  0.7486],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 9
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.607
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 23336.963
# expected info is tensor([[0.0179]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1130, 0.1506]], device='cuda:0')
# g_theta2 istensor([[-0.6363,  0.2096],
#         [ 0.9511,  0.7218],
#         [-0.3261,  0.3583]], device='cuda:0')
# p21val is 0.906533309432614
# pf12val is 0.331754611594549
# chi_f12 is 2.206719410107855
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-9.2525e-01, -4.8065e-01],
#         [ 4.9851e-01,  4.8637e-01],
#         [-8.4971e-04, -1.6101e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 10
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.653
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1108.962
# expected info is tensor([[0.0128]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.0616, 0.6071]], device='cuda:0')
# new data istensor([[0.1282, 0.1229]], device='cuda:0')
# g_theta2 istensor([[-0.7492, -0.7908],
#         [ 0.7847,  0.7308],
#         [-0.1768, -0.1880]], device='cuda:0')
# p21val is 0.218537110400155
# pf12val is 0.061374148479925
# chi_f12 is 5.581533134035737
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1296, -0.6793],
#         [ 0.1138,  0.1716],
#         [ 0.0617,  0.6088]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 11
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.641
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 286.708
# expected info is tensor([[0.0425]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.2598,  0.9616]], device='cuda:0')
# new data istensor([[ 0.3953, -0.2975]], device='cuda:0')
# g_theta2 istensor([[ 0.0287, -0.4745],
#         [-0.0014, -0.0373],
#         [ 0.2462,  0.4399]], device='cuda:0')
# p21val is 0.366009685077564
# pf12val is 0.017051701298484
# chi_f12 is 8.143010594656579
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0041, -0.0255],
#         [-0.2318,  0.0978],
#         [-0.2574,  0.9611]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 12
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.643
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 247.536
# expected info is tensor([[0.0573]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5941,  1.3334]], device='cuda:0')
# new data istensor([[ 0.5357, -0.3966]], device='cuda:0')
# g_theta2 istensor([[ 0.1502, -0.0011],
#         [-0.1667,  0.3055],
#         [-0.0898,  0.7967]], device='cuda:0')
# p21val is 0.083927965003509
# pf12val is 0.792417579836900
# chi_f12 is 0.465333557689805
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.8029, -0.2717],
#         [ 0.1644, -0.9951],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 13
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.649
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 33497.519
# expected info is tensor([[0.0027]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1502, 0.1353]], device='cuda:0')
# g_theta2 istensor([[-0.7866, -0.2960],
#         [ 0.2673, -0.8808],
#         [-0.3241,  0.3537]], device='cuda:0')
# p21val is 0.660646295010203
# pf12val is 0.496731091622396
# chi_f12 is 1.399412924893995
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 5.4797e-01,  6.6110e-01],
#         [-1.5888e-01,  5.4914e-01],
#         [ 4.0823e-04, -8.1905e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 14
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.696
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 3663.977
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5118, -0.6265]], device='cuda:0')
# new data istensor([[0.0453, 0.0776]], device='cuda:0')
# g_theta2 istensor([[ 0.5956,  0.5906],
#         [ 0.1657,  0.0556],
#         [-0.2106,  0.1840]], device='cuda:0')
# p21val is 0.493769456895762
# pf12val is 0.089548353157365
# chi_f12 is 4.825953081694054
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5055,  0.5867],
#         [-0.5206, -1.0000],
#         [ 0.5141, -0.6255]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 15
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.726
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 507.667
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.0247, -1.2326]], device='cuda:0')
# new data istensor([[-0.1302,  0.0534]], device='cuda:0')
# g_theta2 istensor([[ 0.8152,  0.4719],
#         [-0.7108, -0.7713],
#         [ 0.2686, -0.3795]], device='cuda:0')
# p21val is 0.337081462946204
# pf12val is 0.776516835160001
# chi_f12 is 0.505873911608417
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0019, -0.5413],
#         [ 0.6051, -0.7347],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 16
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.729
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 41978.843
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1303, 0.1133]], device='cuda:0')
# g_theta2 istensor([[-0.0036, -0.5506],
#         [ 0.7021, -0.8448],
#         [-0.3343,  0.3516]], device='cuda:0')
# p21val is 0.796341365473214
# pf12val is 0.794342827457263
# chi_f12 is 0.460480276611548
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 1.3214e-01, -5.4318e-01],
#         [-8.4511e-02,  2.6583e-01],
#         [-8.0166e-04,  1.9127e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 17
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.776
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 9568.079
# expected info is tensor([[0.0017]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5241, -0.6080]], device='cuda:0')
# new data istensor([[0.0500, 0.0863]], device='cuda:0')
# g_theta2 istensor([[ 0.1402, -0.7619],
#         [-0.2236,  0.3675],
#         [-0.2141,  0.2038]], device='cuda:0')
# p21val is 0.500685602056207
# pf12val is 0.258851104534523
# chi_f12 is 2.703004537119975
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4581, -0.7316],
#         [ 0.9528, -0.7733],
#         [ 0.5259, -0.6066]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 18
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.808
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 4113.643
# expected info is tensor([[0.0126]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.9774, -0.9976]], device='cuda:0')
# new data istensor([[ 0.0033, -0.0374]], device='cuda:0')
# g_theta2 istensor([[ 0.2988, -0.8431],
#         [ 1.1095, -0.6302],
#         [ 0.2790, -0.3595]], device='cuda:0')
# p21val is 0.386932479000446
# pf12val is 0.980677620639541
# chi_f12 is 0.039022993252988
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.1926, -0.8912],
#         [ 0.8859,  0.5574],
#         [ 0.9774, -0.9985]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 19
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.836
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 6402.767
# expected info is tensor([[0.0052]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.8766, -1.0381]], device='cuda:0')
# new data istensor([[-0.0860,  0.0777]], device='cuda:0')
# g_theta2 istensor([[ 0.3011, -0.6841],
#         [ 0.9378,  0.5761],
#         [ 1.1844, -1.2126]], device='cuda:0')
# p21val is 0.892713286423896
# pf12val is 0.549044177428302
# chi_f12 is 1.199152743612088
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.2397, 0.2095],
#         [0.8208, 0.4844],
#         [0.0000, 0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 20
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.859
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 46019.849
# expected info is tensor([[0.0016]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0940, 0.1084]], device='cuda:0')
# g_theta2 istensor([[ 0.4172,  0.3931],
#         [ 0.9173,  0.5774],
#         [-0.3333,  0.3431]], device='cuda:0')
# p21val is 0.264014648407481
# pf12val is 0.147618522632713
# chi_f12 is 3.826247765195376
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-5.5511e-01, -3.5435e-01],
#         [-2.4769e-01, -1.5028e-01],
#         [-5.2923e-04, -1.5146e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 21
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.874
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 14736.621
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5179, -0.5409]], device='cuda:0')
# new data istensor([[0.0707, 0.0378]], device='cuda:0')
# g_theta2 istensor([[-0.7434, -0.1700],
#         [-0.1944, -0.2122],
#         [-0.2143,  0.1995]], device='cuda:0')
# p21val is 0.772285173986470
# pf12val is 0.959580521138907
# chi_f12 is 0.082518094321639
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1991,  0.5808],
#         [ 0.3392, -0.4595],
#         [ 0.5169, -0.5408]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 22
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.901
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 8499.948
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.0109, -0.9210]], device='cuda:0')
# new data istensor([[ 0.1009, -0.0634]], device='cuda:0')
# g_theta2 istensor([[-0.2089,  0.6530],
#         [ 0.1712, -0.2743],
#         [ 0.2674, -0.2901]], device='cuda:0')
# p21val is 0.026166089310132
# pf12val is 0.426830692092830
# chi_f12 is 1.702735700040116
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.9961, 0.7956],
#         [0.4233, 0.7370],
#         [0.0000, 0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 23
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.912
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 48496.230
# expected info is tensor([[0.0014]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1006, 0.1280]], device='cuda:0')
# g_theta2 istensor([[ 1.0414,  0.8612],
#         [ 0.2296,  0.6594],
#         [-0.3078, -0.3172]], device='cuda:0')
# p21val is 0.119203490566452
# pf12val is 0.379584995759754
# chi_f12 is 1.937353478954191
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-4.5838e-02, -5.5758e-01],
#         [-4.3400e-01, -7.6411e-02],
#         [ 3.0318e-04, -1.1399e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 24
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.903
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 14248.154
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5526, -0.6391]], device='cuda:0')
# new data istensor([[0.0671, 0.0959]], device='cuda:0')
# g_theta2 istensor([[ 0.0936, -0.5350],
#         [-0.1445, -0.2015],
#         [-0.2187,  0.1590]], device='cuda:0')
# p21val is 0.946617744998086
# pf12val is 0.112314602195150
# chi_f12 is 4.372902794477580
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7793, -0.7865],
#         [ 0.6003, -0.7014],
#         [ 0.5510, -0.6388]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 25
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.919
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 291.131
# expected info is tensor([[0.0023]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.3037, -1.3539]], device='cuda:0')
# new data istensor([[-0.6863,  0.4021]], device='cuda:0')
# g_theta2 istensor([[ 1.1366, -1.1605],
#         [ 1.1310, -0.8495],
#         [ 0.2970, -0.3802]], device='cuda:0')
# p21val is 0.327209895418512
# pf12val is 0.024474016064380
# chi_f12 is 7.420286586066642
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7149,  0.8819],
#         [-0.1882, -0.0244],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 26
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.914
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 53358.785
# expected info is tensor([[0.0012]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1348, 0.1083]], device='cuda:0')
# g_theta2 istensor([[ 0.8702,  0.6360],
#         [-0.3370, -0.1567],
#         [-0.3003, -0.3144]], device='cuda:0')
# p21val is 0.239923189909899
# pf12val is 0.738413423660116
# chi_f12 is 0.606502833141431
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-6.3989e-01, -4.9881e-01],
#         [-5.6819e-01, -4.9683e-01],
#         [-5.1351e-04,  4.5952e-05]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 27
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.926
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 14859.279
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.1734, 0.4826]], device='cuda:0')
# new data istensor([[0.0725, 0.2414]], device='cuda:0')
# g_theta2 istensor([[-0.8253, -0.7020],
#         [-0.8229, -0.6633],
#         [-0.1982, -0.2486]], device='cuda:0')
# p21val is 0.342456101175666
# pf12val is 0.883110435625003
# chi_f12 is 0.248610035081245
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.5666, 0.9395],
#         [0.3875, 0.7317],
#         [0.1741, 0.4825]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 28
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.946
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 416.603
# expected info is tensor([[0.0051]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.2567, 1.0830]], device='cuda:0')
# new data istensor([[ 0.5890, -0.2484]], device='cuda:0')
# g_theta2 istensor([[0.7793, 0.6180],
#         [0.8338, 0.6477],
#         [0.4051, 0.2437]], device='cuda:0')
# p21val is 0.209831963572797
# pf12val is 0.522081772876750
# chi_f12 is 1.299862100695418
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5231,  0.0677],
#         [-0.5676, -0.4461],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 29
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.945
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 57222.167
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1071, 0.1278]], device='cuda:0')
# g_theta2 istensor([[-0.6258,  0.2104],
#         [-0.8353, -0.7224],
#         [-0.3003, -0.3120]], device='cuda:0')
# p21val is 0.597218034295815
# pf12val is 0.600371592029841
# chi_f12 is 1.020412990831544
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.2126e-01,  6.0739e-01],
#         [ 7.3548e-01,  4.2101e-01],
#         [ 8.1743e-05,  5.2043e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 30
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.958
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 10336.512
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.1654, 0.7254]], device='cuda:0')
# new data istensor([[0.2019, 0.0664]], device='cuda:0')
# g_theta2 istensor([[-0.2949,  0.6498],
#         [ 0.9252,  0.6619],
#         [-0.1922, -0.2263]], device='cuda:0')
# p21val is 0.461002072567699
# pf12val is 0.952248036776096
# chi_f12 is 0.097859470588254
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1869,  0.6163],
#         [ 0.7355,  0.6270],
#         [ 0.1665,  0.7275]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 31
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.975
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 489.102
# expected info is tensor([[0.0038]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.7218, 1.2241]], device='cuda:0')
# new data istensor([[ 0.5515, -0.0164]], device='cuda:0')
# g_theta2 istensor([[-0.2493,  0.5476],
#         [ 0.7896,  0.5981],
#         [-0.0583,  0.5151]], device='cuda:0')
# p21val is 0.467447813626601
# pf12val is 0.475238054077104
# chi_f12 is 1.487878868022719
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.9794, -0.1262],
#         [-0.3003, -0.0032],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 32
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -2.986
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 61051.496
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1298, 0.1345]], device='cuda:0')
# g_theta2 istensor([[-0.7538, -0.3691],
#         [-0.3730,  0.0080],
#         [-0.2987, -0.3109]], device='cuda:0')
# p21val is 0.539839621265968
# pf12val is 0.816017310047303
# chi_f12 is 0.406639421899530
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2776, -0.1270],
#         [ 0.0640,  0.0926],
#         [-0.0011, -0.0016]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 33
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.004
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 18299.516
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5834, -0.3821]], device='cuda:0')
# new data istensor([[0.1365, 0.0448]], device='cuda:0')
# g_theta2 istensor([[-0.2031, -0.1590],
#         [-0.1284,  0.2841],
#         [-0.2121,  0.1481]], device='cuda:0')
# p21val is 0.393796096525256
# pf12val is 0.816659635005441
# chi_f12 is 0.405065748691923
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5229, -0.5703],
#         [ 0.9520, -0.4861],
#         [ 0.5822, -0.3825]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 34
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.007
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 771.581
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.0686, -0.0331]], device='cuda:0')
# new data istensor([[ 0.4639, -0.1894]], device='cuda:0')
# g_theta2 istensor([[ 0.3764, -0.7069],
#         [ 1.1320, -0.7783],
#         [ 0.3825, -0.5813]], device='cuda:0')
# p21val is 0.797767446266895
# pf12val is 0.015204569206713
# chi_f12 is 8.372318581195882
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.6042, 0.2936],
#         [0.8988, 0.6685],
#         [0.0000, 0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 35
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.012
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 66718.926
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1322, 0.1509]], device='cuda:0')
# g_theta2 istensor([[ 0.4242,  0.3670],
#         [ 0.8562,  0.6264],
#         [-0.2978, -0.3123]], device='cuda:0')
# p21val is 0.488397025132998
# pf12val is 0.350103315906499
# chi_f12 is 2.099053959507778
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 5.8872e-02,  8.0710e-02],
#         [ 7.1141e-01,  5.6624e-01],
#         [-6.3312e-04,  3.4431e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 36
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.015
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 31979.414
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.3666, -0.3704]], device='cuda:0')
# new data istensor([[0.0506, 0.0142]], device='cuda:0')
# g_theta2 istensor([[-0.1924,  0.2968],
#         [ 0.8778,  0.6103],
#         [-0.2320,  0.1734]], device='cuda:0')
# p21val is 0.485774202015644
# pf12val is 0.020519756086176
# chi_f12 is 7.772734290777642
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6411,  0.0599],
#         [ 0.8690, -0.4621],
#         [ 0.3678, -0.3696]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 37
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.016
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 5994.189
# expected info is tensor([[0.0027]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.9328, 0.0727]], device='cuda:0')
# new data istensor([[0.4031, 0.0643]], device='cuda:0')
# g_theta2 istensor([[ 1.2055,  0.5196],
#         [ 0.9966, -0.5604],
#         [ 0.1499, -0.5867]], device='cuda:0')
# p21val is 0.959023224978893
# pf12val is 0.341303533706770
# chi_f12 is 2.149966138910840
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.7628, -0.5110],
#         [ 0.9462,  0.0712],
#         [ 0.9347,  0.0742]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 38
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.029
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 326.402
# expected info is tensor([[0.0314]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.4167, -0.0608]], device='cuda:0')
# new data istensor([[ 0.5168, -0.6260]], device='cuda:0')
# g_theta2 istensor([[ 0.5969, -0.7046],
#         [ 0.7294, -0.1567],
#         [ 0.7194, -0.1514]], device='cuda:0')
# p21val is 0.161366090269050
# pf12val is 0.548589806494551
# chi_f12 is 1.200808563188958
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5566,  0.0298],
#         [ 0.4189,  0.5725],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 39
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.023
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 70882.803
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0897, 0.0954]], device='cuda:0')
# g_theta2 istensor([[-0.6489,  0.1414],
#         [ 0.2760,  0.8821],
#         [-0.3013, -0.3145]], device='cuda:0')
# p21val is 0.076831546668612
# pf12val is 0.085468304605202
# chi_f12 is 4.919219356279847
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 6.4481e-01,  7.1724e-01],
#         [ 4.2296e-01, -7.4741e-01],
#         [ 4.7062e-04, -2.6127e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 40
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.029
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 33037.665
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.3579, -0.2897]], device='cuda:0')
# new data istensor([[0.0637, 0.0803]], device='cuda:0')
# g_theta2 istensor([[ 0.5978,  0.6192],
#         [ 0.8229, -1.1148],
#         [-0.2309,  0.1847]], device='cuda:0')
# p21val is 0.968540278604896
# pf12val is 0.396968107257511
# chi_f12 is 1.847798671771754
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3669,  0.8931],
#         [ 0.7047,  0.3974],
#         [ 0.3589, -0.2889]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 41
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.038
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 6568.653
# expected info is tensor([[0.0036]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.1521, 0.1856]], device='cuda:0')
# new data istensor([[ 0.4923, -0.1782]], device='cuda:0')
# g_theta2 istensor([[ 0.1379,  1.5950],
#         [ 0.6257,  0.4838],
#         [ 0.1381, -0.5108]], device='cuda:0')
# p21val is 0.705561215624052
# pf12val is 0.053170090346742
# chi_f12 is 5.868518504524214
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5405,  0.6514],
#         [ 0.3458, -0.0020],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 42
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.040
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 72655.775
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1132, 0.1104]], device='cuda:0')
# g_theta2 istensor([[ 0.5909,  0.6948],
#         [ 0.5205, -0.1741],
#         [-0.3077,  0.3190]], device='cuda:0')
# p21val is 0.839201756670352
# pf12val is 0.730909750793402
# chi_f12 is 0.626930573562219
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.5902e-01, -6.5623e-01],
#         [ 3.9787e-01,  3.0787e-01],
#         [-5.3159e-04, -1.4298e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 43
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.045
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 39858.350
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2511, -0.4150]], device='cuda:0')
# new data istensor([[0.0894, 0.0192]], device='cuda:0')
# g_theta2 istensor([[-0.5211, -1.3596],
#         [ 0.3134,  0.0607],
#         [-0.2295,  0.1344]], device='cuda:0')
# p21val is 0.570445332203613
# pf12val is 0.529217781067921
# chi_f12 is 1.272710494808421
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0252, -0.6997],
#         [-0.5041, -0.7673],
#         [ 0.2535, -0.4136]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 44
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.050
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1680.144
# expected info is tensor([[0.0047]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3350, -0.9835]], device='cuda:0')
# new data istensor([[0.0966, 0.2833]], device='cuda:0')
# g_theta2 istensor([[ 0.3017, -1.3404],
#         [-0.7971, -0.6416],
#         [ 0.5358, -0.6573]], device='cuda:0')
# p21val is 0.759230074460596
# pf12val is 0.739764880977930
# chi_f12 is 0.602845743356978
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0097,  0.8777],
#         [-0.6099, -0.6898],
#         [-0.3364, -0.9823]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 45
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.055
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 396.103
# expected info is tensor([[0.0023]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1307, -1.5345]], device='cuda:0')
# new data istensor([[-0.7070,  0.3402]], device='cuda:0')
# g_theta2 istensor([[-0.3874,  0.6740],
#         [-0.6896, -0.6872],
#         [-0.5624, -0.7616]], device='cuda:0')
# p21val is 0.110541708848014
# pf12val is 0.226149411127552
# chi_f12 is 2.973118773927448
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2464, -0.3668],
#         [-0.4409,  0.5959],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 46
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.046
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 79091.647
# expected info is tensor([[0.0007]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1303, 0.1079]], device='cuda:0')
# g_theta2 istensor([[ 0.3149, -0.4489],
#         [-0.4468,  0.6168],
#         [-0.3082, -0.3203]], device='cuda:0')
# p21val is 0.053261982224874
# pf12val is 0.733509719014517
# chi_f12 is 0.619828862593353
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-3.1891e-01,  4.5159e-01],
#         [ 2.7343e-01, -3.9069e-01],
#         [ 8.2924e-04, -1.0184e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 47
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.056
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 38239.482
# expected info is tensor([[0.0006]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.3951, -0.1643]], device='cuda:0')
# new data istensor([[0.0606, 0.1347]], device='cuda:0')
# g_theta2 istensor([[-0.2230,  0.4848],
#         [ 0.5164, -0.6251],
#         [-0.2326,  0.1446]], device='cuda:0')
# p21val is 0.942151450820536
# pf12val is 0.501719466290903
# chi_f12 is 1.379428295170183
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.3360, -0.3016],
#         [-0.6718,  0.7198],
#         [ 0.3939, -0.1641]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 48
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.066
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 13384.326
# expected info is tensor([[3.5841e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.9249, 0.1716]], device='cuda:0')
# new data istensor([[0.4097, 0.1350]], device='cuda:0')
# g_theta2 istensor([[ 0.1721, -0.4594],
#         [-0.3749,  0.3791],
#         [ 0.1706, -0.3878]], device='cuda:0')
# p21val is 0.584195454121621
# pf12val is 0.322590719409414
# chi_f12 is 2.262741763619135
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4138,  0.3827],
#         [-0.9547,  0.4604],
#         [ 0.9255,  0.1700]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 49
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.074
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 267.576
# expected info is tensor([[0.0014]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.4922, 0.8454]], device='cuda:0')
# new data istensor([[ 0.4303, -0.0172]], device='cuda:0')
# g_theta2 istensor([[-0.2503,  0.2671],
#         [-0.7509,  0.6520],
#         [ 0.6922, -0.0665]], device='cuda:0')
# p21val is 0.245062143949417
# pf12val is 0.127857535583286
# chi_f12 is 4.113677276332387
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.0156, -0.5184],
#         [ 0.9505, -0.6812],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 50
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.066
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 82539.807
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1137, 0.1110]], device='cuda:0')
# g_theta2 istensor([[ 0.0131, -0.5077],
#         [ 1.0791, -0.8474],
#         [-0.3121,  0.3223]], device='cuda:0')
# p21val is 0.587352391527142
# pf12val is 0.791653546824252
# chi_f12 is 0.467262847502705
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1893,  0.1273],
#         [-0.4289,  0.4891],
#         [-0.0010,  0.0008]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 51
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.075
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 35305.470
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5038, -0.0499]], device='cuda:0')
# new data istensor([[0.1321, 0.2100]], device='cuda:0')
# g_theta2 istensor([[-0.3427,  0.2782],
#         [-0.2808,  0.3712],
#         [-0.2414,  0.1579]], device='cuda:0')
# p21val is 0.740571397579178
# pf12val is 0.245758012975027
# chi_f12 is 2.806815828561656
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6361, -0.1322],
#         [ 0.7216, -0.0770],
#         [ 0.5046, -0.0497]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 52
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.075
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 2958.970
# expected info is tensor([[0.0080]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[1.3622, 0.2469]], device='cuda:0')
# new data istensor([[ 0.5459, -0.3355]], device='cuda:0')
# g_theta2 istensor([[ 0.8335, -0.3257],
#         [ 0.9273, -0.3216],
#         [ 0.2699, -0.2701]], device='cuda:0')
# p21val is 0.437985317306343
# pf12val is 0.300758624322806
# chi_f12 is 2.402894496971889
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.6932, -0.6098],
#         [ 0.9747, -0.9779],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 53
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.079
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 87748.398
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1005, 0.1275]], device='cuda:0')
# g_theta2 istensor([[-0.8149, -0.7681],
#         [ 1.0141, -1.0093],
#         [-0.3082, -0.3200]], device='cuda:0')
# p21val is 0.598372336199837
# pf12val is 0.559648796667914
# chi_f12 is 1.160891681600627
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 3.9576e-01,  9.3750e-01],
#         [ 4.2517e-01, -8.7257e-01],
#         [-6.8552e-04, -1.3057e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 54
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.084
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 43148.035
# expected info is tensor([[9.0881e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.5090, -0.2702]], device='cuda:0')
# new data istensor([[0.0582, 0.0775]], device='cuda:0')
# g_theta2 istensor([[ 0.0925,  0.6353],
#         [ 0.7654, -1.1873],
#         [-0.2445,  0.1416]], device='cuda:0')
# p21val is 0.281356784600744
# pf12val is 0.089246071644324
# chi_f12 is 4.832715748961466
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0969,  0.6610],
#         [ 0.3354,  0.0321],
#         [ 0.5105, -0.2697]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 55
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.096
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 12558.979
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.7077, -1.0033]], device='cuda:0')
# new data istensor([[-0.1547,  0.1363]], device='cuda:0')
# g_theta2 istensor([[-0.0271,  0.5703],
#         [ 0.1769,  0.1369],
#         [ 0.2928, -0.0503]], device='cuda:0')
# p21val is 0.934770362766281
# pf12val is 0.799594010812819
# chi_f12 is 0.447302333226071
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.5985, -0.0300],
#         [ 0.9773, -0.6441],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 56
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.092
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 95374.046
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.0880, 0.1007]], device='cuda:0')
# g_theta2 istensor([[-0.6873,  0.0783],
#         [ 1.0981, -0.8035],
#         [-0.3194,  0.3266]], device='cuda:0')
# p21val is 0.836438888279312
# pf12val is 0.163677808435889
# chi_f12 is 3.619710732379524
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0694, -0.4504],
#         [-0.7223, -0.5046],
#         [-0.0008,  0.0011]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 57
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.108
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 55211.914
# expected info is tensor([[0.0009]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2319, -0.3356]], device='cuda:0')
# new data istensor([[0.1230, 0.0771]], device='cuda:0')
# g_theta2 istensor([[ 0.3990, -0.7257],
#         [-0.7440, -0.6670],
#         [-0.2145,  0.1815]], device='cuda:0')
# p21val is 0.048679810698762
# pf12val is 0.090484503247206
# chi_f12 is 4.805153355552230
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2804,  0.3381],
#         [-0.3954, -0.4810],
#         [ 0.2330, -0.3336]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 58
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.102
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 3937.825
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1853, -1.0544]], device='cuda:0')
# new data istensor([[-0.0576,  0.3476]], device='cuda:0')
# g_theta2 istensor([[-0.2772,  0.1554],
#         [-0.3940, -0.3313],
#         [ 0.4516, -0.1132]], device='cuda:0')
# p21val is 0.751731488384791
# pf12val is 0.892031349646660
# chi_f12 is 0.228508003351843
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4065, -0.7227],
#         [-0.2064, -0.7091],
# ...
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1143, 0.1210]], device='cuda:0')
# g_theta2 istensor([[-0.5856, -0.8817],
#         [-0.0145, -0.9413],
#         [-0.3111,  0.3183]], device='cuda:0')
# p21val is 0.937682530206059
# pf12val is 0.962150045549722
# chi_f12 is 0.077169735947938
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 5.9004e-01,  4.4219e-01],
#         [-9.3906e-01,  2.5248e-01],
#         [ 2.2796e-04,  1.3621e-03]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 60
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.116
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 25629.420
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0338, -0.7185]], device='cuda:0')
# new data istensor([[0.1571, 0.1218]], device='cuda:0')
# g_theta2 istensor([[ 0.4142,  0.5631],
#         [-0.8110,  0.6348],
#         [-0.2404,  0.2356]], device='cuda:0')
# p21val is 0.393694889997417
# pf12val is 0.567285487485602
# chi_f12 is 1.133785193410032
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5882,  0.5465],
#         [-0.0138,  0.2812],
#         [-0.0319, -0.7184]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 61
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.121
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 4258.165
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.1704, -1.3550]], device='cuda:0')
# new data istensor([[-0.4896,  0.3983]], device='cuda:0')
# g_theta2 istensor([[ 0.5012,  0.5033],
#         [-0.1996,  0.1289],
#         [ 0.1993, -0.4837]], device='cuda:0')
# p21val is 0.166151314597095
# pf12val is 0.870184587179424
# chi_f12 is 0.278099841332903
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.8393, 0.1110],
#         [0.2320, 0.4777],
#         [0.0000, 0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 62
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.127
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 101671.376
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1372, 0.0971]], device='cuda:0')
# g_theta2 istensor([[ 0.9494,  0.0325],
#         [ 0.2627,  0.5425],
#         [-0.3115,  0.3201]], device='cuda:0')
# p21val is 0.199614727456449
# pf12val is 0.325067477169900
# chi_f12 is 2.247444992283290
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.1136e-01,  3.8537e-01],
#         [-3.9077e-01,  4.2911e-01],
#         [-8.0957e-04,  2.3046e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 63
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.126
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 59946.095
# expected info is tensor([[0.0008]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.1139, -0.3747]], device='cuda:0')
# new data istensor([[0.1629, 0.0456]], device='cuda:0')
# g_theta2 istensor([[-0.1722,  0.4762],
#         [-0.2120,  0.4399],
#         [-0.2477,  0.1956]], device='cuda:0')
# p21val is 0.373885644430937
# pf12val is 0.322254583803250
# chi_f12 is 2.264826825787901
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1065,  0.2614],
#         [-0.5186,  0.2626],
#         [ 0.1148, -0.3742]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 64
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.127
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 12575.422
# expected info is tensor([[1.2319e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.3742, -0.9774]], device='cuda:0')
# new data istensor([[0.1111, 0.2809]], device='cuda:0')
# g_theta2 istensor([[-0.3795,  0.2631],
#         [-0.4885,  0.2641],
#         [ 0.3332, -0.1517]], device='cuda:0')
# p21val is 0.527555874751527
# pf12val is 0.566450472431044
# chi_f12 is 1.136731259284510
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3601, -0.6209],
#         [ 0.6051, -0.4636],
#         [-0.3737, -0.9782]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 65
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.129
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 275.761
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.9050, -1.3577]], device='cuda:0')
# new data istensor([[-0.1081,  0.2210]], device='cuda:0')
# g_theta2 istensor([[-0.1845, -0.5214],
#         [ 0.4265, -0.7518],
#         [-0.1571, -0.7702]], device='cuda:0')
# p21val is 0.470795397270535
# pf12val is 0.150807443435652
# chi_f12 is 3.783502929947130
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.9470,  0.6188],
#         [-0.3991,  0.0482],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 66
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.131
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 109531.975
# expected info is tensor([[0.0004]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1317, 0.1318]], device='cuda:0')
# g_theta2 istensor([[ 0.9110,  0.5654],
#         [-0.3721, -0.0128],
#         [-0.3220, -0.3310]], device='cuda:0')
# p21val is 0.545919041335795
# pf12val is 0.741684127520984
# chi_f12 is 0.597663661204219
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2810,  0.0154],
#         [-0.0978,  0.0469],
#         [ 0.0012, -0.0007]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 67
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.140
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 65504.414
# expected info is tensor([[5.6612e-05]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2951, -0.4140]], device='cuda:0')
# new data istensor([[0.1302, 0.0368]], device='cuda:0')
# g_theta2 istensor([[ 0.4257,  0.0103],
#         [-0.2984,  0.2410],
#         [-0.2505,  0.2050]], device='cuda:0')
# p21val is 0.440561091832037
# pf12val is 0.062859810009664
# chi_f12 is 5.533696540106846
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.6770, -0.9402],
#         [-0.2181, -0.0561],
#         [ 0.2948, -0.4176]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 68
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.136
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 1024.344
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.6767, -1.4297]], device='cuda:0')
# new data istensor([[-0.5260,  0.2631]], device='cuda:0')
# g_theta2 istensor([[ 1.2123, -1.2136],
#         [-0.2534, -0.0219],
#         [ 0.0453, -0.7861]], device='cuda:0')
# p21val is 0.925372826214421
# pf12val is 0.467470512770814
# chi_f12 is 1.520838013059382
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.4788, -0.2850],
#         [ 0.2076, -0.6313],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 69
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.143
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 114317.984
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1403, 0.0754]], device='cuda:0')
# g_theta2 istensor([[ 0.4377, -0.2461],
#         [ 0.0713, -0.5394],
#         [-0.3215, -0.3315]], device='cuda:0')
# p21val is 0.995266829050888
# pf12val is 0.046614109273799
# chi_f12 is 6.131704019123013
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-1.4258e-01, -3.3207e-01],
#         [-3.0007e-01,  6.2172e-03],
#         [ 2.1407e-03,  1.6436e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 70
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.144
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 41699.652
# expected info is tensor([[0.0001]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.0711, -0.6649]], device='cuda:0')
# new data istensor([[0.2158, 0.0949]], device='cuda:0')
# g_theta2 istensor([[-0.5389, -0.3924],
#         [-0.2561, -0.2229],
#         [-0.2360,  0.2107]], device='cuda:0')
# p21val is 0.634465648037473
# pf12val is 0.744091011724780
# chi_f12 is 0.591183848086769
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.2338, -0.7721],
#         [-0.1629, -0.3959],
#         [-0.0728, -0.6653]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 71
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.156
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 4343.439
# expected info is tensor([[0.0003]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.6228, -1.3406]], device='cuda:0')
# new data istensor([[-0.1846,  0.2844]], device='cuda:0')
# g_theta2 istensor([[ 0.3393, -0.7290],
#         [-0.3031, -0.2505],
#         [ 0.1452, -0.4468]], device='cuda:0')
# p21val is 0.321684206617363
# pf12val is 0.873376023202155
# chi_f12 is 0.270778181121165
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.1134, -0.4563],
#         [-0.3694,  0.7116],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 72
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.158
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 112596.800
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1382, 0.0927]], device='cuda:0')
# g_theta2 istensor([[-0.1273, -0.4845],
#         [-0.2955,  0.7638],
#         [-0.3090,  0.3166]], device='cuda:0')
# p21val is 0.900591969653690
# pf12val is 0.267494624425903
# chi_f12 is 2.637311616904193
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-2.4049e-01,  7.3877e-01],
#         [ 3.8369e-01, -9.4969e-01],
#         [-3.3538e-04, -1.4738e-04]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 73
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.164
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 70780.580
# expected info is tensor([[0.0010]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2194, -0.2976]], device='cuda:0')
# new data istensor([[0.0753, 0.0372]], device='cuda:0')
# g_theta2 istensor([[-0.0328,  0.5917],
#         [ 0.4797, -1.1046],
#         [-0.2023,  0.1791]], device='cuda:0')
# p21val is 0.016264932575876
# pf12val is 0.410468690773331
# chi_f12 is 1.780911247905117
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.3317,  0.9547],
#         [-0.8719,  0.9278],
#         [ 0.2203, -0.2993]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 74
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.155
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 10592.095
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[-0.5416, -1.0802]], device='cuda:0')
# new data istensor([[0.0554, 0.3144]], device='cuda:0')
# g_theta2 istensor([[-0.0113,  0.7420],
#         [-1.1009,  1.0948],
#         [ 0.4853, -0.5639]], device='cuda:0')
# p21val is 0.969669075192377
# pf12val is 0.283645459852796
# chi_f12 is 2.520060402994755
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.2363, -0.8264],
#         [ 0.2989,  0.4819],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 75
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.160
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 121317.716
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0., 0.]], device='cuda:0')
# new data istensor([[0.1287, 0.0887]], device='cuda:0')
# g_theta2 istensor([[-0.2156, -0.9213],
#         [ 0.3167,  0.5201],
#         [-0.3211, -0.3327]], device='cuda:0')
# p21val is 0.794077316875688
# pf12val is 0.299191862356238
# chi_f12 is 2.413340462517827
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.0155,  0.3606],
#         [-0.1106, -0.1390],
#         [ 0.0005, -0.0007]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 76
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.164
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 80899.710
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 0.2531, -0.3490]], device='cuda:0')
# new data istensor([[0.0938, 0.0659]], device='cuda:0')
# g_theta2 istensor([[-0.1826,  0.5179],
#         [-0.3010, -0.3012],
#         [-0.2299,  0.1693]], device='cuda:0')
# p21val is 0.664862470903043
# pf12val is 0.601045903179255
# chi_f12 is 1.018167938722985
# p_val_ftarget is 0.0
# new 2 points
# tensor([[-0.4659,  0.3700],
#         [ 0.6760, -0.6338],
#         [ 0.2536, -0.3488]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 77
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.173
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 21784.105
# expected info is tensor([[0.0002]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[0.8366, 0.2291]], device='cuda:0')
# new data istensor([[0.3216, 0.2847]], device='cuda:0')
# g_theta2 istensor([[-0.1776,  0.1807],
#         [ 0.5887, -0.6341],
#         [ 0.0408, -0.5662]], device='cuda:0')
# p21val is 0.993705836776024
# pf12val is 0.703560084040879
# chi_f12 is 0.703203997534230
# p_val_ftarget is 0.0
# new 2 points
# tensor([[0.9584, 0.7777],
#         [0.4573, 0.3833],
#         [0.8342, 0.2286]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 78
# START HYPERPARAMETERS optimization
# Using CUDA
# loss is -3.175
# END HYPERPARAMETERS optimization
# Using CUDA for conduct_design_opti()
# Loss design: 581.820
# expected info is tensor([[0.0005]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# current sol istensor([[ 1.5295, -0.4244]], device='cuda:0')
# new data istensor([[ 0.4323, -0.6790]], device='cuda:0')
# g_theta2 istensor([[ 0.9437,  0.7324],
#         [ 0.3349,  0.4933],
#         [ 0.5555, -0.0647]], device='cuda:0')
# p21val is 0.585844194656948
# pf12val is 0.991397134075996
# chi_f12 is 0.017280168369189
# samples escaped box
# samples escaped box
# samples escaped box
# p_val_ftarget is 0.0
# new 2 points
# tensor([[ 0.5575,  0.9991],
#         [-0.4076,  0.0339],
#         [ 0.0000,  0.0000]], device='cuda:0')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# current sol istensor([[ 1.5295, -0.4244]], device='cuda:0')
# Success is False and failure is True after 79 iterations

# %%
print(cpu_hyper_opti)
print(cpu_conduct_design)
print(cpu_total)
print()
print(gpu_hyper_opti)
print(gpu_conduct_design)
print(gpu_total)
# Out:
# [0.2671680450439453, 0.40056705474853516, 0.4047553539276123, 0.4071826934814453, 0.41199493408203125, 0.4635179042816162, 0.4668753147125244, 0.4772062301635742, 0.4803295135498047, 0.48765134811401367, 0.49892544746398926, 0.6307928562164307, 0.5656585693359375, 0.5804016590118408, 0.5857291221618652, 0.5947041511535645, 0.6791496276855469, 0.6323051452636719, 0.6188821792602539, 0.6808872222900391, 0.7011597156524658, 0.7111833095550537, 0.7042722702026367, 0.7140741348266602, 0.7280802726745605, 0.7953190803527832, 0.8159003257751465, 0.883476734161377, 0.8930447101593018, 0.9093523025512695, 0.9330959320068359, 1.0044877529144287, 0.9914031028747559, 1.0674841403961182, 1.1040048599243164, 1.1262433528900146, 1.2034940719604492, 1.2793781757354736, 1.2981626987457275, 1.2970890998840332, 1.369340419769287, 1.4053637981414795, 1.4343152046203613, 1.4865100383758545, 1.5614709854125977, 1.5961289405822754, 1.5945062637329102, 1.6033101081848145]
# [6.50650691986084, 6.771503686904907, 7.077473402023315, 6.91670298576355, 6.813601732254028, 7.094924688339233, 7.10463809967041, 7.098695278167725, 7.1960859298706055, 7.215653896331787, 7.040091276168823, 7.307213544845581, 7.371258497238159, 7.409306764602661, 7.584323883056641, 7.494027853012085, 7.959295749664307, 8.108656406402588, 7.999655485153198, 7.876188278198242, 8.118666410446167, 7.812617540359497, 8.108565330505371, 8.109371662139893, 8.189305067062378, 8.303436040878296, 8.599923372268677, 8.384991645812988, 8.87343692779541, 8.718537092208862, 8.687494993209839, 9.18942666053772, 9.184538125991821, 9.069686889648438, 9.31265664100647, 9.42027235031128, 9.591239929199219, 9.720212697982788, 9.916201829910278, 9.933531999588013, 10.022995948791504, 10.10520339012146, 10.314687967300415, 10.396457433700562, 10.390950918197632, 10.71268367767334, 11.0047767162323, 10.984593391418457, 11.310021162033081]
# [6.803887605667114, 7.201951026916504, 7.564042568206787, 7.40362548828125, 7.29959511756897, 7.125032186508179, 7.600905179977417, 7.594312429428101, 7.702993154525757, 7.777421951293945, 7.607547998428345, 7.887240409851074, 8.03158164024353, 8.005179643630981, 8.195381164550781, 8.11019253730774, 8.58540415763855, 8.869946241378784, 8.717736721038818, 8.526249170303345, 8.881683826446533, 8.596445083618164, 8.901887893676758, 8.895595788955688, 8.985186100006104, 9.122265577316284, 9.47967791557312, 9.233261346817017, 9.79224681854248, 9.695882081985474, 9.681427240371704, 10.207090854644775, 10.22370457649231, 10.095722436904907, 10.46593976020813, 10.609208345413208, 10.802563428878784, 11.009030818939209, 11.281450510025024, 11.318317413330078, 11.408416986465454, 11.564403533935547, 11.809223890304565, 11.918296575546265, 11.916553020477295, 12.362311124801636, 12.638920068740845, 12.668630599975586, 13.002012252807617]
#
# [2.9990460872650146, 0.3587665557861328, 0.3607177734375, 0.35985827445983887, 0.3614845275878906, 0.362041711807251, 0.3677496910095215, 0.36557555198669434, 0.36597752571105957, 0.3654005527496338, 0.36646127700805664, 0.3660597801208496, 0.36830925941467285, 0.36894774436950684, 0.37427520751953125, 0.3732326030731201, 0.37387537956237793, 0.37463855743408203, 0.37117767333984375, 0.3723788261413574, 0.37520766258239746, 0.38095903396606445, 0.4846522808074951, 0.4886927604675293, 0.49860477447509766, 0.49510645866394043, 0.49274754524230957, 0.5065624713897705, 0.49949169158935547, 0.49582743644714355, 0.5101571083068848, 0.4972856044769287, 0.4984118938446045, 0.5432281494140625, 0.535691499710083, 0.5297942161560059, 0.5007703304290771, 0.5416305065155029, 0.533933162689209, 0.5467135906219482, 0.5314412117004395, 0.5508909225463867, 0.5269639492034912, 0.5682411193847656, 0.535259485244751, 0.5249288082122803, 0.6930389404296875, 0.5292341709136963, 0.5501124858856201, 0.5724711418151855, 0.596135139465332, 0.5641059875488281, 0.5876853466033936, 0.5618860721588135, 0.5753557682037354, 0.5844848155975342, 0.604271650314331, 0.5997986793518066, 0.6435410976409912, 0.6320395469665527, 0.6430847644805908, 0.8172693252563477, 0.6571445465087891, 0.6893510818481445, 0.6963789463043213, 0.6888577938079834, 0.6901776790618896, 0.7121150493621826, 0.7716689109802246, 0.7322742938995361, 0.7864563465118408, 0.7439556121826172, 0.7917912006378174, 0.7770175933837891, 0.8024640083312988, 0.8020639419555664, 0.8412075042724609, 0.8137011528015137, 0.820382833480835]
# [4.290041923522949, 4.403371810913086, 6.451496839523315, 6.177838087081909, 6.183584690093994, 6.207112073898315, 6.338257074356079, 6.400139331817627, 6.298685550689697, 6.262163162231445, 6.269084930419922, 6.265984058380127, 6.4377381801605225, 6.357589960098267, 6.29056715965271, 6.368883848190308, 6.294225454330444, 6.604774236679077, 6.3081581592559814, 6.39201021194458, 6.299842119216919, 6.316275119781494, 6.502789258956909, 6.435200929641724, 6.544666767120361, 6.467143297195435, 6.5369038581848145, 6.631664752960205, 6.543776273727417, 6.456944465637207, 6.528338670730591, 6.456394672393799, 6.640753507614136, 6.489081382751465, 6.508635520935059, 6.604987382888794, 6.493739604949951, 6.7415080070495605, 6.506309747695923, 6.602023601531982, 6.51591944694519, 6.604447364807129, 6.701630592346191, 6.586725473403931, 6.6196370124816895, 6.534226179122925, 6.625261306762695, 6.519597291946411, 6.604358911514282, 6.566105127334595, 6.648367166519165, 6.588697195053101, 6.784446477890015, 6.788651943206787, 6.55912184715271, 6.5771825313568115, 6.735546588897705, 6.6380064487457275, 6.598509073257446, 6.648042917251587, 6.584923028945923, 6.663212299346924, 6.609949111938477, 6.7243170738220215, 6.809160947799683, 6.814640522003174, 6.962280511856079, 6.809705495834351, 6.892956733703613, 6.807777404785156, 6.870939493179321, 6.993030309677124, 6.853778839111328, 6.818428993225098, 6.906816005706787, 6.860018730163574, 7.004374742507935, 6.842387437820435, 6.837480068206787, 6.943566083908081]
# [7.536754846572876, 4.438288450241089, 6.858483791351318, 6.586990594863892, 6.591524362564087, 6.617033004760742, 6.748711109161377, 6.816220045089722, 6.712692737579346, 6.676899433135986, 6.683043956756592, 6.681863069534302, 6.852760076522827, 6.774632930755615, 6.708000183105469, 6.792182445526123, 6.716160774230957, 7.034684896469116, 6.731804370880127, 6.812432527542114, 6.7209672927856445, 6.7404844760894775, 6.932995557785034, 6.9839982986450195, 7.091130018234253, 7.023157835006714, 7.08955717086792, 7.181729316711426, 7.107715129852295, 7.014265537261963, 7.0819666385650635, 7.024403810501099, 7.196457386016846, 7.045175313949585, 7.110722541809082, 7.198626518249512, 7.081183671951294, 7.309026718139648, 7.105877637863159, 7.193753957748413, 7.1203932762146, 7.194340229034424, 7.3108229637146, 7.171661615371704, 7.246059894561768, 7.128782272338867, 7.208495616912842, 7.273387908935547, 7.192537069320679, 7.174289226531982, 7.27867317199707, 7.241541624069214, 7.406911849975586, 7.435307741165161, 7.179071664810181, 7.2115113735198975, 7.3782007694244385, 7.300498723983765, 7.2573113441467285, 7.349835395812988, 7.275934457778931, 7.365533113479614, 7.488746166229248, 7.446830987930298, 7.55859637260437, 7.571275472640991, 7.711418628692627, 7.560277462005615, 7.6649675369262695, 7.641354322433472, 7.66286563873291, 7.839951276779175, 7.6584312915802, 7.67246150970459, 7.744988203048706, 7.719030380249023, 7.866566896438599, 7.744282484054565, 7.721528053283691, 7.824680328369141]

# %%
cpu_total_x = list(range(1, len(cpu_total)+1))
gpu_total_x = list(range(1, len(gpu_total)+1))

cpu_conduct_x = list(range(1, len(cpu_conduct_design)+1))
gpu_conduct_x = list(range(1, len(gpu_conduct_design)+1))

cpu_hyper_x = list(range(1, len(cpu_hyper_opti)+1))
gpu_hyper_x = list(range(1, len(gpu_hyper_opti)+1))

# %%
# Plotting CPU vs. GPU time

# # Initialize plots
plt.style.use('default')
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 6))

plt.suptitle('CPU vs. GPU TAD Running Time Per Iteration', fontweight='bold')

ax1.plot(cpu_hyper_x[1:], cpu_hyper_opti[1:], 'r-', label='CPU hyper_opti')
ax1.plot(gpu_hyper_x[1:], gpu_hyper_opti[1:], 'b-', label='GPU hyper_opti')
ax1.legend()


plt.subplot(132)
ax2.plot(cpu_conduct_x[1:], cpu_conduct_design[1:], 'g-', label='CPU conduct_design_opti')
ax2.plot(gpu_conduct_x[1:], gpu_conduct_design[1:], 'c-', label='GPU conduct_design_opti')
ax2.legend()
# plt.ylabel('Time')
# plt.xlabel('Input Size')

plt.subplot(133)
ax3.plot(cpu_total_x[1:], cpu_total[1:], 'y-', label='CPU whole iteration')
ax3.plot(gpu_total_x[1:], gpu_total[1:], 'm-', label='GPU whole iteration')
ax3.legend()

plt.setp([ax1,ax2,ax3], xlabel='Iteration')
plt.setp(ax1, ylabel='Time (Second)')

plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Ignore the part below

# %%
print(lower_bound)
print(upper_bound)
print(f_target - 0.001)
print(f_target + 0.001)
print(pf1)
print(num_base_kernels)
# Out:
# tensor([[ 0.3823],
#         [-0.7340]], grad_fn=<CopySlices>)
# tensor([[ 0.4734],
#         [-0.6371]], grad_fn=<CopySlices>)
# tensor([[-1.0010],
#         [-1.0010]])
# tensor([[-0.9990],
#         [-0.9990]])
# tensor([[ 0.4278],
#         [-0.6855]], device='cuda:0', grad_fn=<ReshapeAliasBackward0>)
# 3

# %% [markdown]
# # Plotting model validation strategy

# %%
sns.set_style('ticks')
#plt.rcParams["pdf.use14corefonts"] = True
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
p21_vec_plot = p21_vec.detach()[1:]
f, ax = plt.subplots(1, 1, figsize=(14, 14))
#ax.plot(np.array(range(2,iter+2)), torch.log(entropy_vec_plot), '+-')
#print(p21_vec_plot)
ax.plot(p21_vec_plot,'s',color = 'blue', markersize=6)
ax.axhline(.01,linestyle = '--',color = 'red', markersize=12, alpha = 1.0)
ax.set_xlim(-0.3, p21_vec_plot.shape[0])
ax.set_ylim(-0.3, 1.)
#ax.set_yscale('log')
plt.xticks(np.arange(0, iter+7, step=5.))
ax.tick_params(labelsize='small', width=3)
ax.set_xlabel('# of Model Checks')
ax.set_ylabel('p-value')
ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.05, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(1.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.02, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(0.1,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.26, 0.34), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(6.2,        #x start point
             0.14,                      #y start point
             0,       #change in x 
             -0.07,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 



ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.29, 0.03), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(7.2,        #x start point
             -0.25,                      #y start point
             0,       #change in x 
             0.2,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black')             #arrow edge color

############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.57, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(14.15,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################


############################
ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.69, 0.4), xycoords='axes fraction', 
            fontsize=9*1.5, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white'))
ax.arrow(17.18,        #x start point
             0.23,                      #y start point
             0,       #change in x 
             -0.16,                      #change in y
             head_width=0.2,         #arrow head width
             head_length=0.06,        #arrow head length
             width=0.1,              #arrow stem width
             fc='black',             #arrow fill color
             ec='black') 
################################



# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.32, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(10.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color

# ############################

# ############################
# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.33, 0.34), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(11.25,        #x start point
#              0.14,                      #y start point
#              0,       #change in x 
#              -0.07,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# #################################################

# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.38, 0.1), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(12.25,        #x start point
#              -0.15,                      #y start point
#              0,       #change in x 
#              0.1,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')             #arrow edge color





################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.38, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(13.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ax.annotate('Update model', xy=(0.55, 0.2), xytext=(0.55, 0.03), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(18.25,        #x start point
#              -0.25,                      #y start point
#              0,       #change in x 
#              0.2,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black')  
# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.49, 0.4), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(17.25,        #x start point
#              0.23,                      #y start point
#              0,       #change in x 
#              -0.16,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ################################




# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.55, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(19.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################

# ax.annotate('Restart', xy=(0.55, 0.2), xytext=(0.94, 0.43), xycoords='axes fraction', 
#             fontsize=9*1.5, ha='center', va='bottom',
#             bbox=dict(boxstyle='square', fc='white'))
# ax.arrow(33.25,        #x start point
#              0.26,                      #y start point
#              0,       #change in x 
#              -0.19,                      #change in y
#              head_width=0.2,         #arrow head width
#              head_length=0.06,        #arrow head length
#              width=0.1,              #arrow stem width
#              fc='black',             #arrow fill color
#              ec='black') 
# ################################


# ################################

ax.annotate('Threshold Line ($y = 0.01$)', xy=(1.0,0.01), xytext=(6,0), color='red', 
                xycoords = ax.get_yaxis_transform(), textcoords="offset points",
                size=14, va="center")


#ax.legend(['p-value'], loc = 'upper left', fontsize = 30)
plt.savefig('figures_Carlo/qvalue_base.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Putting the data back to CPU for plotting and analysis

# %%
if use_cuda:
    vec_x = vec_x.cpu()
    g_theta1 = g_theta1.cpu()
    g_theta2 = g_theta2.cpu()
    x_train, y_train = x_train.cpu(), y_train.cpu()
    loss = loss.cpu()
    pf1 = pf1.cpu()
    Qf1 = Qf1.cpu()
    Qf12 = Qf12.cpu()
    Q21 = Q21.cpu()
    data_fit_vec = data_fit_vec.cpu()
    entropy_vec = entropy_vec.cpu()

# %% [markdown]
# # Plotting expected value and data fit term

# %%
sns.set_style('ticks')
data_fit_vec_plot = 0.5* data_fit_vec.detach()[1:]
entropy_vec_plot = entropy_vec.detach()[1:]
f, (ax1,ax2) = plt.subplots(1, 2, figsize=(18, 8), tight_layout=True)

ax1.plot(np.array(range(1,iter+2)), (entropy_vec_plot), '--o', color = 'blue', markersize=12)
#ax1.set_yscale('log')
# ax.plot(np.array(data_fit_vec_plot), (entropy_vec_plot), 'o')
#ax1.set_yscale('log')

ax2.plot(np.array(range(1,iter+2)), data_fit_vec_plot, '--o', color = 'red', markersize=12)
#ax2.set_ylim(-10, 600)
ax1.set_xlabel('Iteration #', size=32)
ax2.set_xlabel('Iteration #', size=32)
ax1.set_ylabel('Expected Information', size = 32)
ax2.set_ylabel('Log-Gaussian Term', size = 32)
ax1.set_xticks(np.arange(0, iter+3, step=3.))
ax2.set_xticks(np.arange(0, iter+3, step=3.))
plt.savefig('figures_Carlo/exp_info/expectedinfo_vs_datafit_2_base.pdf',dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Saving all data needed for plots

# %%
np.savetxt('data_plots/vec_x_success_base.txt',vec_x.detach().numpy())
np.savetxt('data_plots/g_theta2_success_base.txt', g_theta2.detach().numpy())
np.savetxt('data_plots/g_theta1_success_base.txt', g_theta1.detach().numpy())
np.savetxt('data_plots/x_train_ini_success_base.txt', x_train.detach().numpy())
np.savetxt('data_plots/y_train_ini_success_base.txt', y_train.detach().numpy())
np.savetxt('data_plots/entropy_vec_success_base.txt', entropy_vec_plot.detach().numpy())
np.savetxt('data_plots/datafit_success_base.txt', data_fit_vec_plot.detach().numpy())
np.savetxt('data_plots/p21_vec_success_base.txt',p21_vec_plot.detach().numpy())
np.savetxt('data_plots/loss_success_base.txt',loss.detach().numpy())
np.savetxt('data_plots/pf1_success_base.txt',pf1.detach().numpy())
np.savetxt('data_plots/Qf1_success_base.txt',Qf1.evaluate().detach().numpy())
np.savetxt('data_plots/Qf12_success_base.txt', Qf12.evaluate().detach().numpy())
np.savetxt( 'data_plots/Q21_success_base.txt', Q21.evaluate().detach().numpy())
#np.savetxt('data_plots/iter_success.txt', iter+1)

# %%
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2),2)
torch.save(v2, 'data_plots/v2_success_base.txt')

# %%
print(v2.shape)
# Out:
# torch.Size([243, 2])

# %% [markdown]
# # Plots for vizualization

# %%
fig, ax = plt.subplots(figsize = (14,14))
ax.set_xlim(-3.1, 3.2)
ax.set_ylim(-3.1, 3.2)
#ax.scatter(g_theta1[:, 0].detach(),g_theta1[:, 1].detach(), c="b", alpha=0.8)
ax.plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'blue',markersize=15, alpha = 0.2)
ax.plot(vec_x[-1,0], vec_x[-1,1],'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)
ax.set_title('Final TAD configuration', fontsize = 40)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.legend(['1-points', 'TAD solution', 'Target'])
plt.savefig('figures_Carlo/strategies/tad_sol_all_2_base.pdf')
plt.show()
# Out:
# /tmp/ipykernel_1341198/2505842117.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "gd" (-> color='g'). The keyword argument will take precedence.
#   ax.plot(0.8731, 0.5664,'gd', color = 'green',markersize=15)

# %%
vec_x = vec_x.detach()
#v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2)
ii = 0
low = -3.2
high = 3.2
v2 = v2.cpu()
########################
f, ax = plt.subplots(1, 1, figsize=(14, 14))
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)
ax.plot(vec_x[ii,0], vec_x[ii,1],'v', color = 'red',markersize=15)
ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'o', color = 'blue', markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Initial Configuration', fontsize = 40)
ax.legend(['Target', 'Initial Target Candidate', 'Initial 1-sample','Initial 2-sample'])

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures_Carlo/evol_solTAD/evol_sol_ini_2_base.pdf')

# %%
vec_x = vec_x.detach()
v2 = g_theta2_vec.reshape(math.ceil(g_theta2_vec.shape[0]/2), 2).cpu()

low = -3.2
high = 3.2
#for iter_plt in range(1,iter):
iter_plt = 13
ii = 3 + (iter_plt - 1) * (loc_size + 1)
#######################

 
###########

f, ax = plt.subplots(1, 1, figsize=(14,14))

#ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 'bv', markersize=8)
for i in range(1, iter_plt):
    ax.plot(vec_x[i-1:i,0], vec_x[i-1:i,1],'v', color = 'red', markersize=15, alpha=0.2, label = '_nolegend_')
    
ax.plot(vec_x[0:iter_plt,0], vec_x[0:iter_plt,1],'v', color = 'red', markersize=15, linewidth=15, alpha= 0.2)
#ax.plot(g_theta1.detach()[:,0], g_theta.detach()[:,1], 'bv', markersize=8)
ax.plot(v2.detach()[0:ii,0], v2.detach()[0:ii,1], 's', color = 'blue', markersize=15,alpha=0.2)
ax.plot(x_train.detach()[:,0], x_train.detach()[:,1], 's', color = 'black', markersize=15, alpha = 0.2)
ax.plot(v2.detach()[ii:ii+loc_size+1,0], v2.detach()[ii:ii+loc_size+1,1], 'o',color = 'blue' , markersize=15)
ax.plot(0.8731, 0.5664,'gd',markersize=15)
ax.plot(vec_x[iter_plt,0], vec_x[iter_plt,1],'v', color = 'red',markersize=15)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
#ax.set_title('Iteration '+str(iter_plt), fontsize = 40)
ax.set_title('Final Configuration')
ax.legend([ 'Previous Target Candidates', 'Previous 2-samples', 'Initial 1-sample','Current 2-sample', 'Target', 'Current Target Candidate'], fontsize = 30)

ax.set_xlim(low, high)
ax.set_ylim(low, high)
plt.savefig('figures_Carlo/evol_solTAD/evol_sol_base'+str(iter_plt)+'_final.pdf')

# %%
print(g_theta2_vec.shape)
# Out:
# torch.Size([486])

# %% [markdown]
# # Grid Sampling

# %%
def conduct_design_pll(x0,f_target, g_theta1, agg_data, model, likelihood, training_design_iter, training_param_iter, lr_new,noise_value):

    #g_theta2 = nn.Parameter(Tensor(loc_sample))

    x_d= nn.Parameter(Tensor(x0))
    
    optimizer = torch.optim.Adam([{'params': x_d, 'lr': 0.001}])

    #scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)
    
    for ii in range( training_param_iter ):
#         x_d = torch.cat([x_d_0, x_d_1]).reshape(1,2)
#         g_theta2 = torch.cat([g_theta20, g_theta21],1)
        optimizer.zero_grad()
        #print(g_theta)
        loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood, noise_value)
        loss2 = -1. * loss2
        
        loss2.backward()
        
        optimizer.step()
        
    loss2,lower_bound, upper_bound = likelihood.get_pll(f_target,x_d, g_theta1, agg_data, model, likelihood ,noise_value)
    #loss2 = -1. * loss2
    print('Loss design: %.3f' % ( loss2))
   # print(optimizer.state_dict())
    print(x_d)
    return x_d, lower_bound, upper_bound

# %%
# Ensure everything is on CPU
use_cuda = False
#

x_plot = np.linspace(vf.low, vf.high, 15)
y_plot = np.linspace(vf.low, vf.high, 15)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat = torch.zeros(n * n, 2)
i = 0
k = 0
while i < n*n:
    x_concat[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n

g_theta_grid = x_concat
agg_data1_grid = vfield_(g_theta_grid)
agg_data1_grid = agg_data1_grid.flatten()


x0 = Tensor(np.array([-2.,2.])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_grid = Tensor(np.array([0.0,0.0])) 
vec_x_grid = vec_x_grid.reshape(1,2)

lr_new = 1.

SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')
model_grid, likelihood_grid = hyper_opti(g_theta_grid,agg_data1_grid,iter_hp,num_base_kernels,noise_value)

print('END HYPERPARAMETERS optimization')
model_grid.eval()
likelihood_grid.eval()
x0_new_grid,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_grid, agg_data1_grid, model_grid, likelihood_grid, iter_design, iter_param, lr_new,noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
#loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_grid)
print(SUCCESS)
# Out:
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.133
# END HYPERPARAMETERS optimization
# Loss design: 19.514
# Parameter containing:
# tensor([[-1.8814,  1.8646]], requires_grad=True)
# tensor([[-0.2940],
#         [ 0.3429]], grad_fn=<CopySlices>)
# tensor([[0.3695],
#         [1.0166]], grad_fn=<CopySlices>)
# tensor([[-1.0100],
#         [-1.0100]])
# tensor([[-0.9900],
#         [-0.9900]])
# Parameter containing:
# tensor([[-1.8814,  1.8646]], requires_grad=True)
# False

# %%
x0_grid = x0_new.detach()
fig, ax = plt.subplots(figsize = (14,14))
ax.plot(x_concat[:,0],x_concat[:,1], 's', color = 'blue', markersize=15, alpha = 0.2)
ax.plot(x0_new_grid.detach()[0,0], x0_new_grid.detach()[0,1],'v',color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$')
ax.set_ylabel('$d_2$')
ax.set_title('Grid Solution', fontsize = 40)

plt.savefig('figures_Carlo/strategies/grid_sol_2_base.pdf')

# %% [markdown]
# # Random sampling

# %%
# iter_hp = 30
# iter_design = 40 
# iter_param = 50
# num_base_kernels = 3

# f_target = Tensor(vf.tgt_vec) 
# f_target = f_target.reshape(f_target.shape[0],1) 
# tol_vector = 0.005 * torch.ones(f_target.shape)


loc_size_rdn = math.ceil(g_theta1.shape[0]) #(iter)*(loc_size+1) + sample_size

loc_sample = high_minus_low  * np.random.random_sample((loc_size_rdn,2)) + vf.low #np.random.random_sample((loc_size_rdn,2))
g_theta_ = (Tensor(loc_sample).clone())
agg_data1 = vfield_(g_theta_)
agg_data1 = agg_data1.flatten()


x0 = Tensor(np.array([-2.0,2.0])) 
x0 = x0.reshape(1,2)
x00 = x0 
vec_x_rdn = Tensor(np.array([0.,0.])) 
vec_x_rdn = vec_x_rdn.reshape(1,2)

lr_new = 1.


SUCCESS = False 
FAILURE = False 
 
tol = 0.009 
print('START HYPERPARAMETERS optimization')

model_rdn, likelihood_rdn = hyper_opti(g_theta_,agg_data1,iter_hp,num_base_kernels,noise_value)




print('END HYPERPARAMETERS optimization')
model_rdn.eval()
likelihood_rdn.eval()
x0_new_rdn,lower_bound, upper_bound = conduct_design_pll(x0,f_target, g_theta_, agg_data1, model_rdn, likelihood_rdn, iter_design, iter_param, lr_new, noise_value)
print(lower_bound)
print(upper_bound)
print(f_target-tol_vector)
print(f_target+tol_vector)
loc_sample = np.random.random_sample((loc_size_rdn,2))


SUCCESS = stopping_criteria(tol_vector, f_target, lower_bound, upper_bound)


print(x0_new_rdn)
print(SUCCESS)
sol_rdn = x0_new_rdn
# Out:
# START HYPERPARAMETERS optimization
# Using CPU
# loss is -3.210
# END HYPERPARAMETERS optimization
# Loss design: 29.683
# Parameter containing:
# tensor([[-2.1107,  2.1045]], requires_grad=True)
# tensor([[ 0.1259],
#         [-0.0555]], grad_fn=<CopySlices>)
# tensor([[0.8427],
#         [0.5631]], grad_fn=<CopySlices>)
# tensor([[-1.0100],
#         [-1.0100]])
# tensor([[-0.9900],
#         [-0.9900]])
# Parameter containing:
# tensor([[-2.1107,  2.1045]], requires_grad=True)
# False

# %%
np.savetxt('data_plots/sol_rdn_success_base.txt', sol_rdn.detach().numpy())
np.savetxt('data_plots/sol_grid_success_base.txt', x0_new_grid.detach().numpy())
np.savetxt('data_plots/g_theta_rdn_success_base.txt', g_theta_.detach().numpy())
#np.savetxt('data_plots/g_theta_grid_success.txt', x_concat.detach().numpy)

# %%
print(g_theta1.shape)
# Out:
# torch.Size([319, 2])

# %%
fig, ax = plt.subplots(figsize = (14,14))

ax.plot(g_theta_[:,0].detach(),g_theta_[:,1].detach(), 's', color = 'blue',markersize=15, alpha = 0.2)
ax.plot(sol_rdn.detach()[0,0], sol_rdn.detach()[0,1],'v', color = 'red',markersize=15)
ax.plot(0.8731, 0.5664,'d', color = 'green',markersize=15)

ax.set_xlim(-3.1, 3.1)
ax.set_ylim(-3.1, 3.1)
ax.set_xlabel('$d_1$', fontsize = 32)
ax.set_ylabel('$d_2$', fontsize = 32)
ax.set_title('Uniformly Random Solution', fontsize = 40)

plt.savefig('figures_Carlo/strategies/rdn_sol_2_base.pdf')

# %% [markdown]
# # Vizualizing Means and Variances

# %%
import matplotlib.ticker
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
             self.format = r'$\mathdefault{%s}$' % self.format

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)

model.eval()

likelihood.eval()

#noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
#print(x_concat_)
with torch.no_grad(), gpytorch.settings.fast_pred_var(True):
    model = model.cpu()
    pred = GPprediction(model)
    agg_data = agg_data.cpu()
    pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
    #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
    pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
    mean_v_1 = pr_mean[:,0].reshape(n,n)
    mean_v_2 = pr_mean[:,1].reshape(n,n)
    pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T
    
    var_v_1 = pred_var[:,0].reshape(n,n)
    var_v_2 = pred_var[:,1].reshape(n,n)
#     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

# #     print(pr.covariance_matrix.mean(axis=0))
# #     print(AA)
# #     print(pr.variance)
# #     print((pr.covariance_matrix))
# #     K = model.covar_module
#     print((cov.diag()))
#     print(pr_mean)


fig, (ax1, ax2) = plt.subplots(2, 2, figsize = (28, 24), tight_layout=True)
diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
cs10 = ax1[0].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(0, 1.1, 100), cmap = 'jet')
ax1[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[0].set_title('$|v_1 - \mu(v_1)|$', fontsize = 40)
cbar10 = fig.colorbar(cs10, ax = ax1[0],format=OOMFormatter(0, mathText=False));

ax1[0].set_xlabel('$d_1$')
ax1[0].set_ylabel('$d_2$')
diff_mean_v1 = torch.abs(v_1 - mean_v_1.detach())/torch.sqrt(var_v_1)
#print(var_v_1)
cs11 = ax1[1].contourf(xv_plot, yv_plot,diff_mean_v1 ,np.linspace(diff_mean_v1.min(), diff_mean_v1.max(), 100), cmap = 'jet')
ax1[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax1[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax1[1].set_title('$|v_1 - \mu(v_1)|/\sigma(v_1)$', fontsize = 40)
# ax1[0].set_aspect('equal')
# ax1[1].set_aspect('equal')
cbar11 = fig.colorbar(cs11, ax = ax1[1],format=OOMFormatter(0, mathText=False));
ax1[1].set_xlabel('$d_1$')
ax1[1].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())
cs20 = ax2[0].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(0, 1.1, 100), cmap = 'jet')
ax2[0].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[0].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[0].set_title('$|v_2 - \mu(v_2)|$', fontsize = 40)
cbar20 = fig.colorbar(cs20, ax = ax2[0],format=OOMFormatter(0, mathText=False));
ax2[0].set_xlabel('$d_1$')
ax2[0].set_ylabel('$d_2$')


diff_mean_v2= torch.abs(v_2 - mean_v_2.detach())/torch.sqrt(var_v_2)
cs21 = ax2[1].contourf(xv_plot, yv_plot, diff_mean_v2,np.linspace(diff_mean_v2.min(), diff_mean_v2.max(), 100), cmap = 'jet')
ax2[1].plot(g_theta1[:, 0].detach(),g_theta1[:, 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
ax2[1].plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
ax2[1].set_title('$|v_2 - \mu(v_2)|/\sigma(v_2)$', fontsize = 40)
cbar21 = fig.colorbar(cs21, ax = ax2[1],format=OOMFormatter(0, mathText=False));
ax2[1].set_xlabel('$d_1$')
ax2[1].set_ylabel('$d_2$')


# ax2[0].set_aspect('equal')
# ax2[1].set_aspect('equal')

plt.savefig('figures_Edward/mean_var/mean_final_2.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
f_target = vf.tgt_vec
f_target = f_target.reshape(f_target.shape[0],1)
vf.tgt_loc = vf.tgt_loc.reshape(2,1)
#x0 = Tensor(np.array([0.1937, 0.1257]))
#x0 = Tensor(np.array([0.1885, 0.1038]))
x_plot = np.linspace(-3.5, 3.5, 100)
y_plot = np.linspace(-3.5, 3.5, 100)
xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
n = x_plot.shape[0]
x_concat_ = torch.zeros(n * n, 2)

# n_sample = x_concat_.shape[0]
num_tasks = 2
i = 0
k = 0
while i < n*n:
    x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
    x_concat_[i:i+n,1] = Tensor(y_plot)
    k = k+1
    i = i+n
    

tgt_plot = vfield_(x_concat_)



v_1 = tgt_plot[:,0].reshape(n,n)
v_2 = tgt_plot[:,1].reshape(n,n)
plot = [1, 6, 10, iter+1]

for ii in plot:
    try:
        
        PATH = ".//model_Carlo/model_goodmodel/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
    except:
        PATH = ".//model_Carlo/model_update/model_base_"+str(ii - 1)+".pt"
        model_16 = torch.load(PATH)
        
    #model_16 = torch.load(PATH)
    model_16.eval()

    likelihood.eval()

    #noise = torch.eye(2 * g_theta1.detach().shape[0]) * noise_value
    #print(x_concat_)
    with torch.no_grad(), gpytorch.settings.fast_pred_var(False):
        pred = GPprediction(model_16)
        pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
        #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
        pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
        mean_v_1 = pr_mean[:,0].reshape(n,n)
        mean_v_2 = pr_mean[:,1].reshape(n,n)
        pred_var = cov.diag().reshape(num_tasks, x_concat_.shape[0]).T

        var_v_1 = pred_var[:,0].reshape(n,n)
        var_v_2 = pred_var[:,1].reshape(n,n)
    #     AA = pr.covariance_matrix.mean(axis=0).reshape(num_tasks, x_concat_.shape[0]).T #.diag() #.reshape(num_tasks, num_tasks * g_theta1.shape[0]).T

    # #     print(pr.covariance_matrix.mean(axis=0))
    # #     print(AA)
    # #     print(pr.variance)
    # #     print((pr.covariance_matrix))
    # #     K = model.covar_module
    #     print((cov.diag()))
    #     print(pr_mean)


    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (28, 12), tight_layout=True)
    diff_mean_v1= torch.abs(v_1 - mean_v_1.detach())#/torch.abs(v_1)
    minn = torch.min(var_v_1.detach().min(), var_v_2.detach().min())
    maxx = torch.min(var_v_1.detach().max(), var_v_2.detach().max())

    cs11 = ax1.contourf(xv_plot, yv_plot, var_v_1.detach(), np.linspace(0.0,1.1, 100), cmap = 'jet')
    ax1.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    
    ax1.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
  
    ax1.set_title('$\sigma^2(v_1)$ (Iteration '+str(ii)+')', fontsize = 40)
    # ax1[0].set_aspect('equal')
    # ax1[1].set_aspect('equal')
    cbar11 = fig.colorbar(cs11, ax = ax1,format=OOMFormatter(-0, mathText=False));
    ax1.set_xlabel('$d_1$')
    ax1.set_ylabel('$d_2$')


  


    cs21 = ax2.contourf(xv_plot, yv_plot, var_v_2.detach(), np.linspace(0.0, 1.1, 100), cmap = 'jet')
    ax2.plot(g_theta1[0:(4 + (ii - 1)* 3), 0].detach(),g_theta1[0:(4 + (ii - 1)* 3), 1].detach() , 'o', color = 'black',markersize=12, alpha = 1.0)
    ax2.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
    ax2.set_title('$\sigma^2(v_2)$ (Iteration '+str(ii)+')', fontsize = 40)
    cbar21 = fig.colorbar(cs21, ax = ax2,format=OOMFormatter(-0, mathText=False));
    ax2.set_xlabel('$d_1$')
    ax2.set_ylabel('$d_2$')


    # ax2[0].set_aspect('equal')
    # ax2[1].set_aspect('equal')

    plt.savefig('figures_Carlo/mean_var/var_iter_base'+str(ii)+'.pdf', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [43], in <cell line: 31>()
#      47 with torch.no_grad(), gpytorch.settings.fast_pred_var(False):
#      48     pred = GPprediction(model_16)
# ---> 49     pr_mean, cov = pred.GPpred(g_theta1.detach(), agg_data, x_concat_, noise_value)
#      50     #pr = (model(g_theta1.detach())) # likelihood(model(x_concat_), noise = torch.ones(x_concat_.shape) * noise_value)#
#      51     pr_mean = pr_mean.reshape(x_concat_.shape[0], num_tasks)
#
# File /lus/grand/projects/datascience/tiany/Targeted_Adaptive_Design/code/jupyter/../predstrategies/predstrategies.py:30, in GPprediction.GPpred(self, train_inputs, agg_data, test_x, noise_value)
#      28 C11 = self.cov(train_inputs, train_inputs) + torch.eye(2*n) * noise_value
#      29 Cx1 = self.cov(test_x, train_inputs)
# ---> 30 f_ = C11.inv_matmul(agg_data, Cx1.evaluate())
#      31 C1x = Cx1.t()
#      32 Cxx = self.cov(test_x, test_x)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:357, in LazyEvaluatedKernelTensor.evaluate(self)
#     355 @cached
#     356 def evaluate(self):
# --> 357     return self.evaluate_kernel().evaluate()
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:336, in LazyEvaluatedKernelTensor.evaluate_kernel(self)
#     334     temp_active_dims = self.kernel.active_dims
#     335     self.kernel.active_dims = None
# --> 336     res = self.kernel(
#     337         x1,
#     338         x2,
#     339         diag=False,
#     340         last_dim_is_batch=self.last_dim_is_batch,
#     341         **self.params,
#     342     )
#     343     self.kernel.active_dims = temp_active_dims
#     345 # Check the size of the output
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/kernels/kernel.py:408, in Kernel.__call__(self, x1, x2, diag, last_dim_is_batch, **params)
#     406     res = LazyEvaluatedKernelTensor(x1_, x2_, kernel=self, last_dim_is_batch=last_dim_is_batch, **params)
#     407 else:
# --> 408     res = lazify(super(Kernel, self).__call__(x1_, x2_, last_dim_is_batch=last_dim_is_batch, **params))
#     409 return res
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/module.py:30, in Module.__call__(self, *inputs, **kwargs)
#      29 def __call__(self, *inputs, **kwargs):
# ---> 30     outputs = self.forward(*inputs, **kwargs)
#      31     if isinstance(outputs, list):
#      32         return [_validate_module_outputs(output) for output in outputs]
#
# File /lus/grand/projects/datascience/tiany/Targeted_Adaptive_Design/code/jupyter/../kernels/sep_vvkernels.py:53, in SepTensorProductKernel.forward(self, x1, x2, **params)
#      52 def forward(self, x1, x2, **params):
# ---> 53     res = self.covar_module_list[0].forward(x1, x2, **params)
#      54     for m in self.covar_module_list[1:]:
#      55         res += m.forward(x1, x2, **params)
#
# File /lus/grand/projects/datascience/tiany/Targeted_Adaptive_Design/code/jupyter/../kernels/vvkernels.py:30, in TensorProductKernel.forward(self, x1, x2, diag, last_dim_is_batch, add_jitter, **params)
#      28 if len(x1.shape[:-2]):
#      29     covar_i = covar_i.repeat(*x1.shape[:-2], 1, 1)
# ---> 30 covar_x = gpytorch.lazy.lazify(self.data_covar_module.forward(x1, x2, **params))#(self.data_covar_module.forward(x1, x2, **params))#
#      31 if (add_jitter == True):
#      32     covar_x = covar_x #+ (1e-6) * torch.eye(covar_x.shape[0])
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/kernels/scale_kernel.py:109, in ScaleKernel.forward(self, x1, x2, last_dim_is_batch, diag, **params)
#     108 def forward(self, x1, x2, last_dim_is_batch=False, diag=False, **params):
# --> 109     orig_output = self.base_kernel.forward(x1, x2, diag=diag, last_dim_is_batch=last_dim_is_batch, **params)
#     110     outputscales = self.outputscale
#     111     if last_dim_is_batch:
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/kernels/rbf_kernel.py:86, in RBFKernel.forward(self, x1, x2, diag, **params)
#      82     x2_ = x2.div(self.lengthscale)
#      83     return self.covar_dist(
#      84         x1_, x2_, square_dist=True, diag=diag, dist_postprocess_func=postprocess_rbf, postprocess=True, **params
#      85     )
# ---> 86 return RBFCovariance.apply(
#      87     x1,
#      88     x2,
#      89     self.lengthscale,
#      90     lambda x1, x2: self.covar_dist(
#      91         x1, x2, square_dist=True, diag=False, dist_postprocess_func=postprocess_rbf, postprocess=False, **params
#      92     ),
#      93 )
#
# File /grand/datascience/tiany/python_venv/lib/python3.8/site-packages/gpytorch/functions/rbf_covariance.py:12, in RBFCovariance.forward(ctx, x1, x2, lengthscale, sq_dist_func)
#      10     raise ValueError("RBFCovariance cannot handle multiple lengthscales")
#      11 needs_grad = any(ctx.needs_input_grad)
# ---> 12 x1_ = x1.div(lengthscale)
#      13 x2_ = x2.div(lengthscale)
#      14 unitless_sq_dist = sq_dist_func(x1_, x2_)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!

# %%
print(g_theta1.shape[0])

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# # #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
# #                     #loc_size = 4
# # loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# # loc_sample0 = loc_sample.reshape(2 + 1, 2)
# # g2 = loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# z = torch.zeros(n*n, 1)
# for ii in range(n*n):
#     print(ii)
#     x0 = x_concat_[ii,:].reshape(1,2)
#     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#                     #loc_size = 4
#     loc_sample = dis_2sample.sample((2 + 1,))
#     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#     g2 = loc_sample0 #Tensor(loc_sample) #.detach()
    
    
    
#     x_d, g_theta2, loss2, pf1, Qf1, Qf12, data_fit, Q21 = conduct_2opt(agg_data,f_target,x0, g_theta1, model, likelihood, noise_value, g2, training_param_iter)
#     z[ii] = loss2
# z = z.reshape(n,n)

# %%
print(g_theta1.shape)

# %%
# x_plot = np.linspace(-3., 3., 30)
# y_plot = np.linspace(-3., 3., 30)
# xv_plot, yv_plot = np.meshgrid(x_plot, y_plot)
# n = x_plot.shape[0]
# x_concat_ = torch.zeros(n * n, 2)
# training_param_iter = 200

# # n_sample = x_concat_.shape[0]
# num_tasks = 2
# i = 0
# k = 0
# while i < n*n:
#     x_concat_[i:i+n,0] = Tensor(xv_plot[:,k])
#     x_concat_[i:i+n,1] = Tensor(y_plot)
#     k = k+1
#     i = i+n

# #dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .01 * torch.eye(2) )
#                     #loc_size = 4
# loc_sample = 1./3. * Tensor(high_minus_low  * np.random.random_sample((3,2)) + vf.low) # #dis_2sample.sample((2 + 1,))
# loc_sample0 = loc_sample.reshape(2 + 1, 2)
# g2 = g_theta2.detach() #loc_sample0 #Tensor(loc_sample) #.detach()
# likelihood.eval()
# model.eval()
# plot = [1, 7, 17, 26]
# zz = torch.zeros(n*n, 4)
# kk = 0
# for jj in plot:
#     try:
        
#         PATH = ".//model_Carlo/model_goodmodel/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#     except:
#         PATH = ".//model_Carlo/model_update/model_"+str(jj - 1)+".pt"
#         model_16 = torch.load(PATH)
#    # model_16 = torch.load(PATH)
#     model_16.eval()

#     likelihood.eval()
#     g2 = v2.detach()[jj - 1 +loc_size+1 : jj - 1 +loc_size+1 +loc_size+1]
#     g_theta1_cur = g_theta1[0:(4 + (jj - 1)* 3)]
#     agg_data_cur = agg_data[0:2 * (4 + (jj - 1)* 3)]
#     print(agg_data_cur.shape)
#     for ii in range(n*n):
#         print(ii)
#         x0 = x_concat_[ii,:].reshape(1,2)
#     #     dis_2sample = MultivariateNormal( loc = x0, covariance_matrix= .001 * torch.eye(2) )
#     #                     #loc_size = 4
#     #     loc_sample = dis_2sample.sample((2 + 1,))
#     #     loc_sample0 = loc_sample.reshape(2 + 1, 2)
#         #g2 = loc_sample0 #Tensor(loc_sample) #.detach()


        
#         loss2_, pf1_, Qf1_, Qf12_, data_fit_, Q21_ = likelihood.get_ell(agg_data_cur,f_target,x0, g_theta1_cur, model_16, likelihood, noise_value, g2)
#         zz[ii, kk] = loss2_
#     kk = kk+1
# zz = zz.reshape(n,n, 4)
# torch.save(zz.detach(), 'data_plots/zz_success.txt')

# %%
# #plot = [1, 5, 10, 20]

# for jj in range(4):
#     fig, ax = plt.subplots(figsize = (16,14))
#     #
#     cs = ax.contour(xv_plot, yv_plot,  zz[:,:,jj].detach(), np.linspace( zz[:,:,jj].detach().numpy().min(), zz[:,:,jj].detach().numpy().max(), 1000), cmap = 'jet')
#     cbar = fig.colorbar(cs, ax = ax,format=OOMFormatter(0, mathText=False));
#     ax.plot(vf.tgt_loc[0],vf.tgt_loc[1], 'o', color = 'magenta', markersize=12)
#     kk = plot[jj]
#     if kk < plot[3]:
#         ax.plot(vec_x[kk,0], vec_x[kk,1],'o', color = 'black',markersize=12)
#     if kk == plot[3]:
#         ax.plot(vec_x[- 1,0], vec_x[- 1,1],'o', color = 'black',markersize=12)
#     ax.set_title('TAD Acquisition Function (Iteration '+str(kk)+')', fontsize = 40)
#     ax.set_xlabel('$d_1$')
#     ax.set_ylabel('$d_2$')
    
#     plt.savefig('figures_Carlo/tad_obj'+str(kk)+'.pdf', dpi=300, bbox_inches='tight')

# %%
p21_vec_plot
